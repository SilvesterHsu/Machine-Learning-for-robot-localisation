# %% [markdown]
# # Library

# %%
import numpy as np
import torch
import gpytorch
import argparse
import time
import pickle
import scipy.io as sio

from torch.distributions import Normal
import matplotlib.pyplot as plt
import random

import roslib
import rospy
import tf as tf_ros
from nav_msgs.msg import Odometry, Path
from sensor_msgs.msg import Image
from cv_bridge import CvBridge
from geometry_msgs.msg import PoseStamped, PoseArray, Pose
import math
import cv2
import copy

import sys
sys.path.append('..')
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'

# %% [markdown]
# ## Check GPU

# %%
import torch
import numpy as np
import sys
sys.path.append('..')

from torchlib.utils import list_device,set_device

# S1: check GPU
#list_device()

# S2: default parameters
set_device(1)
np.set_printoptions(precision = 2)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, default=420, help='size of mini batch')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data normalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')

parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/gp_net_torch', help='rnn, gru, or lstm')

parser.add_argument('--test_dataset', type=str, default=[# '/notebooks/michigan_nn_data/2012_01_08',
                                                         # '/notebooks/michigan_nn_data/2012_01_15',
                                                         # '/notebooks/michigan_nn_data/2012_01_22',
                                                         # '/notebooks/michigan_nn_data/2012_02_02',
                                                         # '/notebooks/michigan_nn_data/2012_02_04',
                                                         # '/notebooks/michigan_nn_data/2012_02_05',
                                                         '/notebooks/michigan_nn_data/2012_02_12',
                                                         # '/notebooks/michigan_nn_data/2012_03_31',
                                                         '/notebooks/michigan_nn_data/2012_04_29',
                                                         '/notebooks/michigan_nn_data/2012_05_11',
                                                         '/notebooks/michigan_nn_data/2012_06_15',
                                                         '/notebooks/michigan_nn_data/2012_08_04',
                                                         # '/notebooks/michigan_nn_data/2012_09_28'])
                                                         '/notebooks/michigan_nn_data/2012_10_28',
                                                         '/notebooks/michigan_nn_data/2012_11_16',
                                                         '/notebooks/michigan_nn_data/2012_12_01'
                                                        ] )

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/test'])
parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

#parser.add_argument('--map_dataset', type=str, default='/home/kevin/data/michigan_gt/training')
parser.add_argument('--enable_ros', type=bool, default=False, help='put data into ros')
parser.add_argument('--cuda_device', type=int, default=1, help='cuda device')

sys.argv = ['']
args = parser.parse_args()

if args.enable_ros:
    rospy.init_node('global_localization_tf_broadcaster_cnn')

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
#from PIL import Image
import numpy as np
import random

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet, cnn_auxiliary
from torchlib.cnn_auxiliary import normalize, denormalize, denormalize_navie, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

transform = transforms.Compose([transforms.ToTensor()])
dataset = LocalizationDataset(dataset_dirs = args.test_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform,
                              get_pair = False, mode='evaluate', sampling_rate=2)

[args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
print('Load norm and std:',*args.norm_tensor)

dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=False, num_workers=0, \
                        drop_last=False, pin_memory=True)
# Out:
# 100%|██████████| 14301/14301 [00:18<00:00, 786.97it/s]
# 100%|██████████| 7008/7008 [00:08<00:00, 781.31it/s]
# 100%|██████████| 12852/12852 [00:16<00:00, 791.64it/s]
# 100%|██████████| 9567/9567 [00:12<00:00, 784.99it/s]
# 100%|██████████| 13580/13580 [00:17<00:00, 797.38it/s]
# 100%|██████████| 14835/14835 [00:18<00:00, 791.33it/s]
# 100%|██████████| 7114/7114 [00:09<00:00, 784.83it/s]
# 100%|██████████| 12683/12683 [00:15<00:00, 802.57it/s]
# Load norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # Define Model

# %%
from torch.cuda.amp import autocast, GradScaler
from torchlib.GPs import Backbone, NN, BaseModule

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        #variational_strategy = gpytorch.variational.LMCVariationalStrategy(
        variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        #self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([1]))
        self.mean_module = gpytorch.means.ZeroMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([output_dim])),
            batch_shape=torch.Size([output_dim]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        inducing_points = torch.zeros(3, 1000, 128)
        self.backbone = Backbone()
        self.nn = NN()
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=3)
        
    def forward(self, input_data):
        dense_feat = self.backbone(input_data)
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention 
        trans_pred = self.gp(feature_t)
        return trans_pred, rot_pred

class PosePredictor(BaseModule):
    def __init__(self, norm_mean, norm_std, args,
                 is_training=True, mixed_precision=True,
                 regressor_context_rate = [0.0,0.0], train_rot = False):
        super().__init__(norm_mean, norm_std, args)
        self.model = Model().to(self.device)
        self.train_rot = train_rot
        self.mixed_precision = mixed_precision
        if self.mixed_precision:
            self.scaler = GradScaler()

        self.disable_requires_grad(self.model.backbone)
        
        if is_training:
            self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
            self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                             lr_lambda=lambda epoch: args.decay_rate**epoch)
            num_data = min(len(dataloader)*args.batch_size,len(dataset))
            self.mll = gpytorch.mlls.PredictiveLogLikelihood(self.model.likelihood, \
                                                         self.model.gp, num_data = num_data)
        else:
            self.disable_requires_grad(self.model)
            
    def _optimize(self,regressor_context_rate):
        # GP
        optimizer = [
                {'params': self.model.gp.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay},
                {'params': self.model.likelihood.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay}]
            
        # NN
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            self.disable_requires_grad(self.model.nn.global_regressor)
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
            self.train_rot = True
        else:
            self.disable_requires_grad(self.model.nn.global_context)
            
        
        if not self.train_rot and regressor_context_rate[1]==0.0:
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc1_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc2_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc3_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.logits_r)
                
        return optimizer
    
    def train(self,x, y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
            
        # Step 2: training
        assert trainer.model.training == True
        if self.mixed_precision:
            with autocast():
                single_loss = self._loss(x, y)
            self.scaler.scale(single_loss).backward()
            self.scaler.step(self.optimizer)
            self.scaler.update()
        else:
            single_loss = self._loss(x, y)
            single_loss.backward()
            self.optimizer.step()
            
        batch_time = time.time() - start
        
        return float(single_loss), batch_time
    
    def _loss(self,x, y):
        # target
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        # predict
        trans_pred, rot_pred = self.model(x)
        
        # trans loss
        trans_loss = -1.*self.mll(trans_pred, trans_target)
        # rot loss
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        
        total_loss = trans_loss + args.lamda_weights * rot_loss      
        
        return total_loss
    
    def eval_forward(self,x,y,num_sample = 100,output_denormalize = True):
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        
        # Step 2: forward
        assert trainer.model.training == False
        if self.mixed_precision:
            with autocast():
                trans_prediction, rot_prediction = self.model(x)
            self.scaler.scale(trans_prediction)
            self.scaler.scale(rot_prediction)
        else:
            trans_prediction, rot_prediction = self.model(x)
            
        trans_prediction, trans_mean, trans_var = self._eval_gp(trans_prediction)
        
        if args.is_normalization and output_denormalize:
            trans_prediction = denormalize_navie(trans_prediction, self.norm_mean, self.norm_std)
            trans_mean = denormalize_navie(trans_mean, self.norm_mean, self.norm_std)
            trans_var = trans_var.mul(self.norm_std)
        
        samples = self._sample(trans_mean, trans_var, num_sample)
            
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_prediction, rot_prediction, trans_target, rot_target, samples
    
    def _sample(self, mean, var, num_sample = 100):
        dist = torch.distributions.Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples
    
    def _eval_gp(self, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = self.model.likelihood(trans_pred).mean, self.model.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var

# %%
trainer = PosePredictor(args.norm_mean,args.norm_std,args,mixed_precision=False,is_training = False)
trainer.load_model('model-fast-zero-mean.pth')
# Out:
# Successfully loaded model to TITAN Xp.

# %% [markdown]
# # Initialize

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

# %%
trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward(x,y)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 420/91980, translation error = 8.355, rotation error = 3.685, time/batch = 4.927
# 840/91980, translation error = 5.943, rotation error = 3.215, time/batch = 1.103
# 1260/91980, translation error = 6.578, rotation error = 3.467, time/batch = 1.155
# 1680/91980, translation error = 5.558, rotation error = 3.604, time/batch = 1.087
# 2100/91980, translation error = 5.085, rotation error = 3.683, time/batch = 1.089
# 2520/91980, translation error = 4.585, rotation error = 3.687, time/batch = 1.086
# 2940/91980, translation error = 4.275, rotation error = 3.670, time/batch = 1.095
# 3360/91980, translation error = 4.100, rotation error = 3.707, time/batch = 1.089
# 3780/91980, translation error = 3.852, rotation error = 3.604, time/batch = 1.089
# 4200/91980, translation error = 3.557, rotation error = 3.520, time/batch = 1.089
# 4620/91980, translation error = 3.336, rotation error = 3.505, time/batch = 1.088
# 5040/91980, translation error = 3.144, rotation error = 3.496, time/batch = 1.087
# 5460/91980, translation error = 3.079, rotation error = 3.455, time/batch = 1.094
# 5880/91980, translation error = 3.040, rotation error = 3.410, time/batch = 1.088
# 6300/91980, translation error = 2.961, rotation error = 3.331, time/batch = 1.088
# 6720/91980, translation error = 5.117, rotation error = 3.715, time/batch = 1.087
# 7140/91980, translation error = 5.247, rotation error = 4.013, time/batch = 1.083
# 7560/91980, translation error = 5.078, rotation error = 4.064, time/batch = 1.086
# 7980/91980, translation error = 5.137, rotation error = 4.116, time/batch = 1.090
# 8400/91980, translation error = 5.712, rotation error = 4.208, time/batch = 1.098
# 8820/91980, translation error = 5.540, rotation error = 4.172, time/batch = 1.091
# 9240/91980, translation error = 5.396, rotation error = 4.151, time/batch = 1.101
# 9660/91980, translation error = 5.266, rotation error = 4.082, time/batch = 1.090
# 10080/91980, translation error = 5.169, rotation error = 4.071, time/batch = 1.092
# 10500/91980, translation error = 5.021, rotation error = 4.148, time/batch = 1.092
# 10920/91980, translation error = 4.901, rotation error = 4.152, time/batch = 1.087
# 11340/91980, translation error = 4.788, rotation error = 4.084, time/batch = 1.092
# 11760/91980, translation error = 4.658, rotation error = 4.015, time/batch = 1.091
# 12180/91980, translation error = 4.541, rotation error = 3.963, time/batch = 1.093
# 12600/91980, translation error = 4.436, rotation error = 3.928, time/batch = 1.096
# 13020/91980, translation error = 4.339, rotation error = 3.926, time/batch = 1.098
# 13440/91980, translation error = 4.373, rotation error = 3.937, time/batch = 1.095
# 13860/91980, translation error = 4.302, rotation error = 3.907, time/batch = 1.093
# 14280/91980, translation error = 4.230, rotation error = 3.917, time/batch = 1.089
# 14700/91980, translation error = 4.170, rotation error = 3.893, time/batch = 1.095
# 15120/91980, translation error = 4.143, rotation error = 3.889, time/batch = 1.101
# 15540/91980, translation error = 4.096, rotation error = 3.848, time/batch = 1.100
# 15960/91980, translation error = 5.057, rotation error = 4.063, time/batch = 1.094
# 16380/91980, translation error = 4.998, rotation error = 4.057, time/batch = 1.097
# 16800/91980, translation error = 4.931, rotation error = 4.097, time/batch = 1.096
# 17220/91980, translation error = 4.862, rotation error = 4.090, time/batch = 1.105
# 17640/91980, translation error = 4.781, rotation error = 4.056, time/batch = 1.088
# 18060/91980, translation error = 4.734, rotation error = 4.080, time/batch = 1.089
# 18480/91980, translation error = 4.674, rotation error = 4.089, time/batch = 1.103
# 18900/91980, translation error = 4.606, rotation error = 4.102, time/batch = 1.097
# 19320/91980, translation error = 4.552, rotation error = 4.075, time/batch = 1.094
# 19740/91980, translation error = 4.519, rotation error = 4.081, time/batch = 1.102
# 20160/91980, translation error = 4.464, rotation error = 4.069, time/batch = 1.098
# 20580/91980, translation error = 4.399, rotation error = 4.048, time/batch = 1.094
# 21000/91980, translation error = 4.345, rotation error = 4.034, time/batch = 1.095
# 21420/91980, translation error = 4.291, rotation error = 4.029, time/batch = 1.097
# 21840/91980, translation error = 5.846, rotation error = 4.202, time/batch = 1.096
# 22260/91980, translation error = 9.913, rotation error = 5.248, time/batch = 1.100
# 22680/91980, translation error = 9.854, rotation error = 5.212, time/batch = 1.104
# 23100/91980, translation error = 9.736, rotation error = 5.202, time/batch = 1.100
# 23520/91980, translation error = 9.601, rotation error = 5.172, time/batch = 1.095
# 23940/91980, translation error = 9.470, rotation error = 5.151, time/batch = 1.096
# 24360/91980, translation error = 9.386, rotation error = 5.153, time/batch = 1.097
# 24780/91980, translation error = 9.296, rotation error = 5.162, time/batch = 1.098
# 25200/91980, translation error = 9.170, rotation error = 5.139, time/batch = 1.103
# 25620/91980, translation error = 9.045, rotation error = 5.115, time/batch = 1.100
# 26040/91980, translation error = 8.930, rotation error = 5.108, time/batch = 1.104
# 26460/91980, translation error = 8.811, rotation error = 5.080, time/batch = 1.105
# 26880/91980, translation error = 8.777, rotation error = 5.064, time/batch = 1.089
# 27300/91980, translation error = 8.678, rotation error = 5.021, time/batch = 1.102
# 27720/91980, translation error = 8.584, rotation error = 4.981, time/batch = 1.101
# 28140/91980, translation error = 8.490, rotation error = 4.953, time/batch = 1.102
# 28560/91980, translation error = 8.412, rotation error = 4.936, time/batch = 1.101
# 28980/91980, translation error = 8.362, rotation error = 4.997, time/batch = 1.101
# 29400/91980, translation error = 8.480, rotation error = 5.037, time/batch = 1.100
# 29820/91980, translation error = 8.388, rotation error = 5.001, time/batch = 1.101
# 30240/91980, translation error = 8.337, rotation error = 4.985, time/batch = 1.096
# 30660/91980, translation error = 8.256, rotation error = 4.966, time/batch = 1.104
# 31080/91980, translation error = 8.168, rotation error = 4.971, time/batch = 1.096
# 31500/91980, translation error = 8.089, rotation error = 4.952, time/batch = 1.103
# 31920/91980, translation error = 8.008, rotation error = 4.922, time/batch = 1.097
# 32340/91980, translation error = 7.934, rotation error = 4.909, time/batch = 1.104
# 32760/91980, translation error = 7.857, rotation error = 4.899, time/batch = 1.093
# 33180/91980, translation error = 7.779, rotation error = 4.875, time/batch = 1.101
# 33600/91980, translation error = 7.712, rotation error = 4.857, time/batch = 1.109
# 34020/91980, translation error = 7.653, rotation error = 4.845, time/batch = 1.096
# 34440/91980, translation error = 8.962, rotation error = 5.119, time/batch = 1.101
# 34860/91980, translation error = 8.893, rotation error = 5.088, time/batch = 1.103
# 35280/91980, translation error = 8.825, rotation error = 5.068, time/batch = 1.094
# 35700/91980, translation error = 10.051, rotation error = 5.274, time/batch = 1.106
# 36120/91980, translation error = 9.967, rotation error = 5.254, time/batch = 1.099
# 36540/91980, translation error = 9.902, rotation error = 5.250, time/batch = 1.108
# 36960/91980, translation error = 9.814, rotation error = 5.243, time/batch = 1.098
# 37380/91980, translation error = 9.728, rotation error = 5.219, time/batch = 1.096
# 37800/91980, translation error = 9.639, rotation error = 5.200, time/batch = 1.098
# 38220/91980, translation error = 9.559, rotation error = 5.203, time/batch = 1.099
# 38640/91980, translation error = 9.471, rotation error = 5.184, time/batch = 1.099
# 39060/91980, translation error = 9.398, rotation error = 5.176, time/batch = 1.108
# 39480/91980, translation error = 9.325, rotation error = 5.170, time/batch = 1.099
# 39900/91980, translation error = 9.257, rotation error = 5.156, time/batch = 1.102
# 40320/91980, translation error = 9.178, rotation error = 5.140, time/batch = 1.098
# 40740/91980, translation error = 9.098, rotation error = 5.127, time/batch = 1.100
# 41160/91980, translation error = 9.024, rotation error = 5.128, time/batch = 1.106
# 41580/91980, translation error = 8.955, rotation error = 5.118, time/batch = 1.103
# 42000/91980, translation error = 8.882, rotation error = 5.112, time/batch = 1.094
# 42420/91980, translation error = 8.902, rotation error = 5.102, time/batch = 1.101
# 42840/91980, translation error = 8.845, rotation error = 5.074, time/batch = 1.097
# 43260/91980, translation error = 8.776, rotation error = 5.054, time/batch = 1.105
# 43680/91980, translation error = 8.775, rotation error = 5.070, time/batch = 1.102
# 44100/91980, translation error = 8.734, rotation error = 5.062, time/batch = 1.102
# 44520/91980, translation error = 8.706, rotation error = 5.072, time/batch = 1.100
# 44940/91980, translation error = 8.655, rotation error = 5.069, time/batch = 1.103
# 45360/91980, translation error = 8.597, rotation error = 5.061, time/batch = 1.099
# 45780/91980, translation error = 8.549, rotation error = 5.053, time/batch = 1.099
# 46200/91980, translation error = 8.496, rotation error = 5.056, time/batch = 1.107
# 46620/91980, translation error = 8.449, rotation error = 5.046, time/batch = 1.101
# 47040/91980, translation error = 8.404, rotation error = 5.037, time/batch = 1.104
# 47460/91980, translation error = 8.375, rotation error = 5.022, time/batch = 1.103
# 47880/91980, translation error = 8.314, rotation error = 5.009, time/batch = 1.102
# 48300/91980, translation error = 8.259, rotation error = 5.002, time/batch = 1.100
# 48720/91980, translation error = 8.214, rotation error = 4.983, time/batch = 1.101
# 49140/91980, translation error = 8.166, rotation error = 4.962, time/batch = 1.099
# 49560/91980, translation error = 8.113, rotation error = 4.953, time/batch = 1.100
# 49980/91980, translation error = 8.075, rotation error = 4.939, time/batch = 1.099
# 50400/91980, translation error = 8.031, rotation error = 4.924, time/batch = 1.103
# 50820/91980, translation error = 9.131, rotation error = 5.062, time/batch = 1.098
# 51240/91980, translation error = 9.089, rotation error = 5.080, time/batch = 1.103
# 51660/91980, translation error = 9.032, rotation error = 5.066, time/batch = 1.102
# 52080/91980, translation error = 8.974, rotation error = 5.072, time/batch = 1.100
# 52500/91980, translation error = 8.935, rotation error = 5.076, time/batch = 1.099
# 52920/91980, translation error = 8.882, rotation error = 5.055, time/batch = 1.101
# 53340/91980, translation error = 8.836, rotation error = 5.071, time/batch = 1.103
# 53760/91980, translation error = 8.784, rotation error = 5.068, time/batch = 1.104
# 54180/91980, translation error = 8.803, rotation error = 5.070, time/batch = 1.098
# 54600/91980, translation error = 8.787, rotation error = 5.071, time/batch = 1.101
# 55020/91980, translation error = 8.737, rotation error = 5.067, time/batch = 1.096
# 55440/91980, translation error = 8.691, rotation error = 5.066, time/batch = 1.099
# 55860/91980, translation error = 8.910, rotation error = 5.107, time/batch = 1.103
# 56280/91980, translation error = 9.039, rotation error = 5.196, time/batch = 1.099
# 56700/91980, translation error = 8.999, rotation error = 5.198, time/batch = 1.103
# 57120/91980, translation error = 8.960, rotation error = 5.199, time/batch = 1.099
# 57540/91980, translation error = 9.745, rotation error = 5.233, time/batch = 1.097
# 57960/91980, translation error = 9.697, rotation error = 5.234, time/batch = 1.098
# 58380/91980, translation error = 9.664, rotation error = 5.234, time/batch = 1.101
# 58800/91980, translation error = 9.629, rotation error = 5.232, time/batch = 1.107
# 59220/91980, translation error = 9.573, rotation error = 5.229, time/batch = 1.099
# 59640/91980, translation error = 9.523, rotation error = 5.218, time/batch = 1.101
# 60060/91980, translation error = 9.472, rotation error = 5.209, time/batch = 1.102
# 60480/91980, translation error = 9.425, rotation error = 5.201, time/batch = 1.106
# 60900/91980, translation error = 9.376, rotation error = 5.188, time/batch = 1.104
# 61320/91980, translation error = 9.337, rotation error = 5.183, time/batch = 1.104
# 61740/91980, translation error = 9.700, rotation error = 5.346, time/batch = 1.105
# 62160/91980, translation error = 9.655, rotation error = 5.346, time/batch = 1.101
# 62580/91980, translation error = 9.603, rotation error = 5.330, time/batch = 1.102
# 63000/91980, translation error = 9.553, rotation error = 5.327, time/batch = 1.100
# 63420/91980, translation error = 9.539, rotation error = 5.344, time/batch = 1.101
# 63840/91980, translation error = 9.489, rotation error = 5.328, time/batch = 1.102
# 64260/91980, translation error = 10.141, rotation error = 5.514, time/batch = 1.099
# 64680/91980, translation error = 10.133, rotation error = 5.572, time/batch = 1.100
# 65100/91980, translation error = 10.096, rotation error = 5.570, time/batch = 1.101
# 65520/91980, translation error = 10.046, rotation error = 5.553, time/batch = 1.102
# 65940/91980, translation error = 10.008, rotation error = 5.562, time/batch = 1.106
# 66360/91980, translation error = 9.963, rotation error = 5.551, time/batch = 1.102
# 66780/91980, translation error = 9.959, rotation error = 5.567, time/batch = 1.106
# 67200/91980, translation error = 9.923, rotation error = 5.568, time/batch = 1.100
# 67620/91980, translation error = 9.884, rotation error = 5.594, time/batch = 1.100
# 68040/91980, translation error = 9.833, rotation error = 5.573, time/batch = 1.104
# 68460/91980, translation error = 9.789, rotation error = 5.578, time/batch = 1.103
# 68880/91980, translation error = 9.744, rotation error = 5.563, time/batch = 1.104
# 69300/91980, translation error = 9.732, rotation error = 5.575, time/batch = 1.103
# 69720/91980, translation error = 9.711, rotation error = 5.565, time/batch = 1.108
# 70140/91980, translation error = 9.705, rotation error = 5.556, time/batch = 1.101
# 70560/91980, translation error = 9.656, rotation error = 5.542, time/batch = 1.102
# 70980/91980, translation error = 9.613, rotation error = 5.533, time/batch = 1.102
# 71400/91980, translation error = 9.565, rotation error = 5.520, time/batch = 1.105
# 71820/91980, translation error = 9.521, rotation error = 5.504, time/batch = 1.105
# 72240/91980, translation error = 9.482, rotation error = 5.492, time/batch = 1.104
# 72660/91980, translation error = 9.438, rotation error = 5.479, time/batch = 1.103
# 73080/91980, translation error = 9.398, rotation error = 5.482, time/batch = 1.104
# 73500/91980, translation error = 9.358, rotation error = 5.473, time/batch = 1.104
# 73920/91980, translation error = 9.351, rotation error = 5.477, time/batch = 1.103
# 74340/91980, translation error = 9.309, rotation error = 5.468, time/batch = 1.106
# 74760/91980, translation error = 9.589, rotation error = 5.651, time/batch = 1.100
# 75180/91980, translation error = 9.609, rotation error = 5.676, time/batch = 1.105
# 75600/91980, translation error = 9.749, rotation error = 5.706, time/batch = 1.104
# 76020/91980, translation error = 9.713, rotation error = 5.691, time/batch = 1.105
# 76440/91980, translation error = 9.675, rotation error = 5.680, time/batch = 1.103
# 76860/91980, translation error = 9.658, rotation error = 5.673, time/batch = 1.101
# 77280/91980, translation error = 9.681, rotation error = 5.673, time/batch = 1.103
# 77700/91980, translation error = 10.142, rotation error = 5.782, time/batch = 1.103
# 78120/91980, translation error = 10.270, rotation error = 5.865, time/batch = 1.100
# 78540/91980, translation error = 10.330, rotation error = 5.888, time/batch = 1.108
# 78960/91980, translation error = 10.394, rotation error = 5.919, time/batch = 1.102
# 79380/91980, translation error = 10.558, rotation error = 6.121, time/batch = 1.104
# 79800/91980, translation error = 11.029, rotation error = 6.140, time/batch = 1.105
# 80220/91980, translation error = 10.988, rotation error = 6.151, time/batch = 1.102
# 80640/91980, translation error = 11.065, rotation error = 6.207, time/batch = 1.105
# 81060/91980, translation error = 11.034, rotation error = 6.218, time/batch = 1.104
# 81480/91980, translation error = 11.088, rotation error = 6.281, time/batch = 1.097
# 81900/91980, translation error = 11.059, rotation error = 6.289, time/batch = 1.105
# 82320/91980, translation error = 11.030, rotation error = 6.278, time/batch = 1.105
# 82740/91980, translation error = 11.016, rotation error = 6.284, time/batch = 1.100
# 83160/91980, translation error = 10.987, rotation error = 6.306, time/batch = 1.106
# 83580/91980, translation error = 10.973, rotation error = 6.294, time/batch = 1.099
# 84000/91980, translation error = 10.973, rotation error = 6.294, time/batch = 1.103
# 84420/91980, translation error = 10.957, rotation error = 6.329, time/batch = 1.100
# 84840/91980, translation error = 10.917, rotation error = 6.318, time/batch = 1.105
# 85260/91980, translation error = 10.879, rotation error = 6.309, time/batch = 1.103
# 85680/91980, translation error = 10.837, rotation error = 6.293, time/batch = 1.107
# 86100/91980, translation error = 10.953, rotation error = 6.367, time/batch = 1.103
# 86520/91980, translation error = 10.916, rotation error = 6.353, time/batch = 1.102
# 86940/91980, translation error = 10.878, rotation error = 6.337, time/batch = 1.101
# 87360/91980, translation error = 10.911, rotation error = 6.350, time/batch = 1.101
# 87780/91980, translation error = 10.875, rotation error = 6.357, time/batch = 1.103
# 88200/91980, translation error = 10.983, rotation error = 6.463, time/batch = 1.101
# 88620/91980, translation error = 10.940, rotation error = 6.456, time/batch = 1.106
# 89040/91980, translation error = 11.130, rotation error = 6.472, time/batch = 1.100
# 89460/91980, translation error = 11.092, rotation error = 6.477, time/batch = 1.102
# 89880/91980, translation error = 11.102, rotation error = 6.482, time/batch = 1.106
# 90300/91980, translation error = 11.100, rotation error = 6.466, time/batch = 1.104
# 90720/91980, translation error = 11.068, rotation error = 6.460, time/batch = 1.106
# 91140/91980, translation error = 11.030, rotation error = 6.453, time/batch = 1.101
# 91560/91980, translation error = 11.007, rotation error = 6.561, time/batch = 1.106
# 91980/91980, translation error = 10.972, rotation error = 6.554, time/batch = 4.576

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.088
# median rotation error = 3.120
# mean translation error = 10.972
# mean rotation error = 6.554

# %%
def evaluate(trans_errors,rot_errors):
    t = dataset.last_indexes
    trans_errors_month = list()
    trans_errors_month.append(trans_errors[:t[0]])
    trans_errors_month.append(trans_errors[t[0]:t[1]])
    trans_errors_month.append(trans_errors[t[1]:t[2]])
    trans_errors_month.append(trans_errors[t[2]:t[3]])
    trans_errors_month.append(trans_errors[t[3]:t[4]])
    trans_errors_month.append(trans_errors[t[4]:t[5]])
    trans_errors_month.append(trans_errors[t[5]:t[6]])
    trans_errors_month.append(trans_errors[t[6]:])

    rot_errors_month = list()
    rot_errors_month.append(rot_errors[:t[0]])
    rot_errors_month.append(rot_errors[t[0]:t[1]])
    rot_errors_month.append(rot_errors[t[1]:t[2]])
    rot_errors_month.append(rot_errors[t[2]:t[3]])
    rot_errors_month.append(rot_errors[t[3]:t[4]])
    rot_errors_month.append(rot_errors[t[4]:t[5]])
    rot_errors_month.append(rot_errors[t[5]:t[6]])
    rot_errors_month.append(rot_errors[t[6]:])
    
    print('================== median translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("median translation error = {:.3f}".format(np.median(trans_errors_i)))
        
    print('================== median rotation error ==================')
    for rot_errors_i in rot_errors_month:
        print("median rotation error = {:.3f}".format(np.median(rot_errors_i)))
    
    print('================== mean translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("mean translation error = {:.3f}".format(np.mean(trans_errors_i)))
        
    print('================== mean rotation error ==================')  
    for rot_errors_i in rot_errors_month:
        print("mean rotation error = {:.3f}".format(np.mean(rot_errors_i)))
        
evaluate(trans_errors,rot_errors)
# Out:
# ================== median translation error ==================
# median translation error = 1.648
# median translation error = 1.740
# median translation error = 2.013
# median translation error = 2.008
# median translation error = 2.107
# median translation error = 2.190
# median translation error = 3.579
# median translation error = 2.932
# ================== median rotation error ==================
# median rotation error = 2.584
# median rotation error = 2.794
# median rotation error = 2.950
# median rotation error = 2.925
# median rotation error = 3.105
# median rotation error = 3.262
# median rotation error = 4.395
# median rotation error = 4.155
# ================== mean translation error ==================
# mean translation error = 4.265
# mean translation error = 4.468
# mean translation error = 13.187
# mean translation error = 12.985
# mean translation error = 9.629
# mean translation error = 11.376
# mean translation error = 21.605
# mean translation error = 13.976
# ================== mean rotation error ==================
# mean rotation error = 3.956
# mean rotation error = 4.262
# mean rotation error = 6.160
# mean rotation error = 5.901
# mean rotation error = 5.634
# mean rotation error = 6.627
# mean rotation error = 12.331
# mean rotation error = 9.281
