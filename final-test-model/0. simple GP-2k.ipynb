# %% [markdown]
# # Library

# %%
import numpy as np
import torch
import gpytorch
import argparse
import time
import pickle
import scipy.io as sio

from torch.distributions import Normal
import matplotlib.pyplot as plt
import random

import roslib
import rospy
import tf as tf_ros
from nav_msgs.msg import Odometry, Path
from sensor_msgs.msg import Image
from cv_bridge import CvBridge
from geometry_msgs.msg import PoseStamped, PoseArray, Pose
import math
import cv2
import copy

import sys
sys.path.append('..')
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'

# %% [markdown]
# ## Check GPU

# %%
import torch
import numpy as np
import sys
sys.path.append('..')

from torchlib.utils import list_device,set_device

# S1: check GPU
#list_device()

# S2: default parameters
set_device(1)
np.set_printoptions(precision = 2)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, default=420, help='size of mini batch')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data normalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')

parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/gp_net_torch', help='rnn, gru, or lstm')

parser.add_argument('--test_dataset', type=str, default=[# '/notebooks/michigan_nn_data/2012_01_08',
                                                         # '/notebooks/michigan_nn_data/2012_01_15',
                                                         # '/notebooks/michigan_nn_data/2012_01_22',
                                                         # '/notebooks/michigan_nn_data/2012_02_02',
                                                         # '/notebooks/michigan_nn_data/2012_02_04',
                                                         # '/notebooks/michigan_nn_data/2012_02_05',
                                                         '/notebooks/michigan_nn_data/2012_02_12',
                                                         # '/notebooks/michigan_nn_data/2012_03_31',
                                                         '/notebooks/michigan_nn_data/2012_04_29',
                                                         '/notebooks/michigan_nn_data/2012_05_11',
                                                         '/notebooks/michigan_nn_data/2012_06_15',
                                                         '/notebooks/michigan_nn_data/2012_08_04',
                                                         # '/notebooks/michigan_nn_data/2012_09_28'])
                                                         '/notebooks/michigan_nn_data/2012_10_28',
                                                         '/notebooks/michigan_nn_data/2012_11_16',
                                                         '/notebooks/michigan_nn_data/2012_12_01'
                                                        ] )

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/test'])
parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

#parser.add_argument('--map_dataset', type=str, default='/home/kevin/data/michigan_gt/training')
parser.add_argument('--enable_ros', type=bool, default=False, help='put data into ros')
parser.add_argument('--cuda_device', type=int, default=1, help='cuda device')

sys.argv = ['']
args = parser.parse_args()

if args.enable_ros:
    rospy.init_node('global_localization_tf_broadcaster_cnn')

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
#from PIL import Image
import numpy as np
import random

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet, cnn_auxiliary
from torchlib.cnn_auxiliary import normalize, denormalize, denormalize_navie, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

transform = transforms.Compose([transforms.ToTensor()])
dataset = LocalizationDataset(dataset_dirs = args.test_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform,
                              get_pair = False, mode='evaluate', sampling_rate=2)

[args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
print('Load norm and std:',*args.norm_tensor)

dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=False, num_workers=0, \
                        drop_last=False, pin_memory=True)
# Out:
# 100%|██████████| 14301/14301 [00:18<00:00, 787.80it/s]
# 100%|██████████| 7008/7008 [00:09<00:00, 774.59it/s]
# 100%|██████████| 12852/12852 [00:16<00:00, 788.39it/s]
# 100%|██████████| 9567/9567 [00:12<00:00, 785.24it/s]
# 100%|██████████| 13580/13580 [00:17<00:00, 794.32it/s]
# 100%|██████████| 14835/14835 [00:18<00:00, 792.29it/s]
# 100%|██████████| 7114/7114 [00:09<00:00, 780.39it/s]
# 100%|██████████| 12683/12683 [00:15<00:00, 793.37it/s]
# Load norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # Define Model

# %%
from torch.cuda.amp import autocast, GradScaler
from torchlib.GPs import Backbone, NN, BaseModule

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        #variational_strategy = gpytorch.variational.LMCVariationalStrategy(
        variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        #self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([1]))
        self.mean_module = gpytorch.means.ZeroMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([output_dim])),
            batch_shape=torch.Size([output_dim]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        inducing_points = torch.zeros(3, 2000, 128)
        self.backbone = Backbone()
        self.nn = NN()
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=3)
        
    def forward(self, input_data):
        dense_feat = self.backbone(input_data)
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention 
        trans_pred = self.gp(feature_t)
        return trans_pred, rot_pred

class PosePredictor(BaseModule):
    def __init__(self, norm_mean, norm_std, args,
                 is_training=True, mixed_precision=True,
                 regressor_context_rate = [0.0,0.0], train_rot = False):
        super().__init__(norm_mean, norm_std, args)
        self.model = Model().to(self.device)
        self.train_rot = train_rot
        self.mixed_precision = mixed_precision
        if self.mixed_precision:
            self.scaler = GradScaler()

        self.disable_requires_grad(self.model.backbone)
        
        if is_training:
            self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
            self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                             lr_lambda=lambda epoch: args.decay_rate**epoch)
            num_data = min(len(dataloader)*args.batch_size,len(dataset))
            self.mll = gpytorch.mlls.PredictiveLogLikelihood(self.model.likelihood, \
                                                         self.model.gp, num_data = num_data)
        else:
            self.disable_requires_grad(self.model)
            
    def _optimize(self,regressor_context_rate):
        # GP
        optimizer = [
                {'params': self.model.gp.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay},
                {'params': self.model.likelihood.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay}]
            
        # NN
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            self.disable_requires_grad(self.model.nn.global_regressor)
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
            self.train_rot = True
        else:
            self.disable_requires_grad(self.model.nn.global_context)
            
        
        if not self.train_rot and regressor_context_rate[1]==0.0:
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc1_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc2_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc3_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.logits_r)
                
        return optimizer
    
    def train(self,x, y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
            
        # Step 2: training
        assert trainer.model.training == True
        if self.mixed_precision:
            with autocast():
                single_loss = self._loss(x, y)
            self.scaler.scale(single_loss).backward()
            self.scaler.step(self.optimizer)
            self.scaler.update()
        else:
            single_loss = self._loss(x, y)
            single_loss.backward()
            self.optimizer.step()
            
        batch_time = time.time() - start
        
        return float(single_loss), batch_time
    
    def _loss(self,x, y):
        # target
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        # predict
        trans_pred, rot_pred = self.model(x)
        
        # trans loss
        trans_loss = -1.*self.mll(trans_pred, trans_target)
        # rot loss
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        
        total_loss = trans_loss + args.lamda_weights * rot_loss      
        
        return total_loss
    
    def eval_forward(self,x,y,num_sample = 100,output_denormalize = True):
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        
        # Step 2: forward
        assert trainer.model.training == False
        if self.mixed_precision:
            with autocast():
                trans_prediction, rot_prediction = self.model(x)
            self.scaler.scale(trans_prediction)
            self.scaler.scale(rot_prediction)
        else:
            trans_prediction, rot_prediction = self.model(x)
            
        trans_prediction, trans_mean, trans_var = self._eval_gp(trans_prediction)
        
        if args.is_normalization and output_denormalize:
            trans_prediction = denormalize_navie(trans_prediction, self.norm_mean, self.norm_std)
            trans_mean = denormalize_navie(trans_mean, self.norm_mean, self.norm_std)
            trans_var = trans_var.mul(self.norm_std)
        
        samples = self._sample(trans_mean, trans_var, num_sample)
            
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_prediction, rot_prediction, trans_target, rot_target, samples
    
    def _sample(self, mean, var, num_sample = 100):
        dist = torch.distributions.Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples
    
    def _eval_gp(self, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = self.model.likelihood(trans_pred).mean, self.model.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var

# %%
trainer = PosePredictor(args.norm_mean,args.norm_std,args,mixed_precision=False,is_training = False)
trainer.load_model('model-fast-zero-mean-2k.pth')
# Out:
# Successfully loaded model to TITAN Xp.

# %% [markdown]
# # Initialize

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

# %%
trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward(x,y)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 420/91980, translation error = 7.685, rotation error = 3.685, time/batch = 5.031
# 840/91980, translation error = 5.766, rotation error = 3.215, time/batch = 1.124
# 1260/91980, translation error = 6.536, rotation error = 3.467, time/batch = 1.186
# 1680/91980, translation error = 5.515, rotation error = 3.604, time/batch = 1.123
# 2100/91980, translation error = 5.026, rotation error = 3.683, time/batch = 1.122
# 2520/91980, translation error = 4.539, rotation error = 3.687, time/batch = 1.119
# 2940/91980, translation error = 4.229, rotation error = 3.670, time/batch = 1.120
# 3360/91980, translation error = 4.057, rotation error = 3.707, time/batch = 1.124
# 3780/91980, translation error = 3.818, rotation error = 3.604, time/batch = 1.135
# 4200/91980, translation error = 3.536, rotation error = 3.520, time/batch = 1.119
# 4620/91980, translation error = 3.317, rotation error = 3.505, time/batch = 1.128
# 5040/91980, translation error = 3.131, rotation error = 3.496, time/batch = 1.134
# 5460/91980, translation error = 3.071, rotation error = 3.455, time/batch = 1.123
# 5880/91980, translation error = 3.031, rotation error = 3.410, time/batch = 1.120
# 6300/91980, translation error = 2.959, rotation error = 3.331, time/batch = 1.130
# 6720/91980, translation error = 5.060, rotation error = 3.715, time/batch = 1.123
# 7140/91980, translation error = 5.192, rotation error = 4.013, time/batch = 1.120
# 7560/91980, translation error = 5.022, rotation error = 4.064, time/batch = 1.125
# 7980/91980, translation error = 5.077, rotation error = 4.116, time/batch = 1.121
# 8400/91980, translation error = 5.652, rotation error = 4.208, time/batch = 1.120
# 8820/91980, translation error = 5.488, rotation error = 4.172, time/batch = 1.122
# 9240/91980, translation error = 5.353, rotation error = 4.151, time/batch = 1.124
# 9660/91980, translation error = 5.207, rotation error = 4.082, time/batch = 1.125
# 10080/91980, translation error = 5.116, rotation error = 4.071, time/batch = 1.126
# 10500/91980, translation error = 4.971, rotation error = 4.148, time/batch = 1.127
# 10920/91980, translation error = 4.859, rotation error = 4.152, time/batch = 1.120
# 11340/91980, translation error = 4.745, rotation error = 4.084, time/batch = 1.123
# 11760/91980, translation error = 4.618, rotation error = 4.015, time/batch = 1.142
# 12180/91980, translation error = 4.505, rotation error = 3.963, time/batch = 1.120
# 12600/91980, translation error = 4.402, rotation error = 3.928, time/batch = 1.125
# 13020/91980, translation error = 4.314, rotation error = 3.926, time/batch = 1.121
# 13440/91980, translation error = 4.356, rotation error = 3.937, time/batch = 1.136
# 13860/91980, translation error = 4.290, rotation error = 3.907, time/batch = 1.126
# 14280/91980, translation error = 4.225, rotation error = 3.917, time/batch = 1.138
# 14700/91980, translation error = 4.164, rotation error = 3.893, time/batch = 1.130
# 15120/91980, translation error = 4.135, rotation error = 3.889, time/batch = 1.130
# 15540/91980, translation error = 4.091, rotation error = 3.848, time/batch = 1.126
# 15960/91980, translation error = 5.073, rotation error = 4.063, time/batch = 1.127
# 16380/91980, translation error = 5.011, rotation error = 4.057, time/batch = 1.127
# 16800/91980, translation error = 4.944, rotation error = 4.097, time/batch = 1.129
# 17220/91980, translation error = 4.871, rotation error = 4.090, time/batch = 1.133
# 17640/91980, translation error = 4.790, rotation error = 4.056, time/batch = 1.126
# 18060/91980, translation error = 4.743, rotation error = 4.080, time/batch = 1.135
# 18480/91980, translation error = 4.685, rotation error = 4.089, time/batch = 1.134
# 18900/91980, translation error = 4.622, rotation error = 4.102, time/batch = 1.136
# 19320/91980, translation error = 4.569, rotation error = 4.075, time/batch = 1.132
# 19740/91980, translation error = 4.535, rotation error = 4.081, time/batch = 1.132
# 20160/91980, translation error = 4.479, rotation error = 4.069, time/batch = 1.130
# 20580/91980, translation error = 4.414, rotation error = 4.048, time/batch = 1.129
# 21000/91980, translation error = 4.362, rotation error = 4.034, time/batch = 1.133
# 21420/91980, translation error = 4.309, rotation error = 4.029, time/batch = 1.146
# 21840/91980, translation error = 5.822, rotation error = 4.202, time/batch = 1.130
# 22260/91980, translation error = 9.904, rotation error = 5.248, time/batch = 1.129
# 22680/91980, translation error = 9.847, rotation error = 5.212, time/batch = 1.132
# 23100/91980, translation error = 9.724, rotation error = 5.202, time/batch = 1.132
# 23520/91980, translation error = 9.592, rotation error = 5.172, time/batch = 1.138
# 23940/91980, translation error = 9.461, rotation error = 5.151, time/batch = 1.130
# 24360/91980, translation error = 9.383, rotation error = 5.153, time/batch = 1.134
# 24780/91980, translation error = 9.290, rotation error = 5.162, time/batch = 1.129
# 25200/91980, translation error = 9.165, rotation error = 5.139, time/batch = 1.135
# 25620/91980, translation error = 9.039, rotation error = 5.115, time/batch = 1.137
# 26040/91980, translation error = 8.924, rotation error = 5.108, time/batch = 1.135
# 26460/91980, translation error = 8.803, rotation error = 5.080, time/batch = 1.135
# 26880/91980, translation error = 8.771, rotation error = 5.064, time/batch = 1.128
# 27300/91980, translation error = 8.672, rotation error = 5.021, time/batch = 1.143
# 27720/91980, translation error = 8.579, rotation error = 4.981, time/batch = 1.130
# 28140/91980, translation error = 8.486, rotation error = 4.953, time/batch = 1.139
# 28560/91980, translation error = 8.410, rotation error = 4.936, time/batch = 1.131
# 28980/91980, translation error = 8.359, rotation error = 4.997, time/batch = 1.132
# 29400/91980, translation error = 8.497, rotation error = 5.037, time/batch = 1.143
# 29820/91980, translation error = 8.405, rotation error = 5.001, time/batch = 1.131
# 30240/91980, translation error = 8.350, rotation error = 4.985, time/batch = 1.131
# 30660/91980, translation error = 8.268, rotation error = 4.966, time/batch = 1.137
# 31080/91980, translation error = 8.182, rotation error = 4.971, time/batch = 1.132
# 31500/91980, translation error = 8.102, rotation error = 4.952, time/batch = 1.134
# 31920/91980, translation error = 8.021, rotation error = 4.922, time/batch = 1.137
# 32340/91980, translation error = 7.949, rotation error = 4.909, time/batch = 1.133
# 32760/91980, translation error = 7.870, rotation error = 4.899, time/batch = 1.141
# 33180/91980, translation error = 7.794, rotation error = 4.875, time/batch = 1.135
# 33600/91980, translation error = 7.726, rotation error = 4.857, time/batch = 1.132
# 34020/91980, translation error = 7.667, rotation error = 4.845, time/batch = 1.142
# 34440/91980, translation error = 8.951, rotation error = 5.119, time/batch = 1.136
# 34860/91980, translation error = 8.881, rotation error = 5.088, time/batch = 1.136
# 35280/91980, translation error = 8.815, rotation error = 5.068, time/batch = 1.137
# 35700/91980, translation error = 10.040, rotation error = 5.274, time/batch = 1.131
# 36120/91980, translation error = 9.956, rotation error = 5.254, time/batch = 1.132
# 36540/91980, translation error = 9.887, rotation error = 5.250, time/batch = 1.130
# 36960/91980, translation error = 9.798, rotation error = 5.243, time/batch = 1.135
# 37380/91980, translation error = 9.714, rotation error = 5.219, time/batch = 1.138
# 37800/91980, translation error = 9.624, rotation error = 5.200, time/batch = 1.133
# 38220/91980, translation error = 9.546, rotation error = 5.203, time/batch = 1.131
# 38640/91980, translation error = 9.459, rotation error = 5.184, time/batch = 1.133
# 39060/91980, translation error = 9.386, rotation error = 5.176, time/batch = 1.145
# 39480/91980, translation error = 9.312, rotation error = 5.170, time/batch = 1.133
# 39900/91980, translation error = 9.246, rotation error = 5.156, time/batch = 1.138
# 40320/91980, translation error = 9.167, rotation error = 5.140, time/batch = 1.133
# 40740/91980, translation error = 9.088, rotation error = 5.127, time/batch = 1.133
# 41160/91980, translation error = 9.016, rotation error = 5.128, time/batch = 1.131
# 41580/91980, translation error = 8.945, rotation error = 5.118, time/batch = 1.136
# 42000/91980, translation error = 8.873, rotation error = 5.112, time/batch = 1.129
# 42420/91980, translation error = 8.893, rotation error = 5.102, time/batch = 1.134
# 42840/91980, translation error = 8.834, rotation error = 5.074, time/batch = 1.140
# 43260/91980, translation error = 8.766, rotation error = 5.054, time/batch = 1.132
# 43680/91980, translation error = 8.761, rotation error = 5.070, time/batch = 1.130
# 44100/91980, translation error = 8.718, rotation error = 5.062, time/batch = 1.135
# 44520/91980, translation error = 8.689, rotation error = 5.072, time/batch = 1.141
# 44940/91980, translation error = 8.639, rotation error = 5.069, time/batch = 1.140
# 45360/91980, translation error = 8.581, rotation error = 5.061, time/batch = 1.135
# 45780/91980, translation error = 8.534, rotation error = 5.053, time/batch = 1.140
# 46200/91980, translation error = 8.481, rotation error = 5.056, time/batch = 1.136
# 46620/91980, translation error = 8.433, rotation error = 5.046, time/batch = 1.134
# 47040/91980, translation error = 8.388, rotation error = 5.037, time/batch = 1.140
# 47460/91980, translation error = 8.359, rotation error = 5.022, time/batch = 1.137
# 47880/91980, translation error = 8.300, rotation error = 5.009, time/batch = 1.137
# 48300/91980, translation error = 8.245, rotation error = 5.002, time/batch = 1.141
# 48720/91980, translation error = 8.201, rotation error = 4.983, time/batch = 1.141
# 49140/91980, translation error = 8.154, rotation error = 4.962, time/batch = 1.138
# 49560/91980, translation error = 8.101, rotation error = 4.953, time/batch = 1.135
# 49980/91980, translation error = 8.061, rotation error = 4.939, time/batch = 1.135
# 50400/91980, translation error = 8.016, rotation error = 4.924, time/batch = 1.134
# 50820/91980, translation error = 9.102, rotation error = 5.062, time/batch = 1.135
# 51240/91980, translation error = 9.061, rotation error = 5.080, time/batch = 1.138
# 51660/91980, translation error = 9.004, rotation error = 5.066, time/batch = 1.137
# 52080/91980, translation error = 8.946, rotation error = 5.072, time/batch = 1.131
# 52500/91980, translation error = 8.909, rotation error = 5.076, time/batch = 1.131
# 52920/91980, translation error = 8.857, rotation error = 5.055, time/batch = 1.138
# 53340/91980, translation error = 8.811, rotation error = 5.071, time/batch = 1.142
# 53760/91980, translation error = 8.760, rotation error = 5.068, time/batch = 1.138
# 54180/91980, translation error = 8.782, rotation error = 5.070, time/batch = 1.135
# 54600/91980, translation error = 8.769, rotation error = 5.071, time/batch = 1.139
# 55020/91980, translation error = 8.718, rotation error = 5.067, time/batch = 1.136
# 55440/91980, translation error = 8.672, rotation error = 5.066, time/batch = 1.141
# 55860/91980, translation error = 8.867, rotation error = 5.107, time/batch = 1.137
# 56280/91980, translation error = 8.979, rotation error = 5.196, time/batch = 1.136
# 56700/91980, translation error = 8.941, rotation error = 5.198, time/batch = 1.137
# 57120/91980, translation error = 8.902, rotation error = 5.199, time/batch = 1.133
# 57540/91980, translation error = 9.659, rotation error = 5.233, time/batch = 1.134
# 57960/91980, translation error = 9.617, rotation error = 5.234, time/batch = 1.137
# 58380/91980, translation error = 9.585, rotation error = 5.234, time/batch = 1.137
# 58800/91980, translation error = 9.555, rotation error = 5.232, time/batch = 1.137
# 59220/91980, translation error = 9.499, rotation error = 5.229, time/batch = 1.133
# 59640/91980, translation error = 9.450, rotation error = 5.218, time/batch = 1.136
# 60060/91980, translation error = 9.399, rotation error = 5.209, time/batch = 1.141
# 60480/91980, translation error = 9.351, rotation error = 5.201, time/batch = 1.141
# 60900/91980, translation error = 9.305, rotation error = 5.188, time/batch = 1.140
# 61320/91980, translation error = 9.266, rotation error = 5.183, time/batch = 1.138
# 61740/91980, translation error = 9.644, rotation error = 5.346, time/batch = 1.134
# 62160/91980, translation error = 9.602, rotation error = 5.346, time/batch = 1.137
# 62580/91980, translation error = 9.551, rotation error = 5.330, time/batch = 1.136
# 63000/91980, translation error = 9.501, rotation error = 5.327, time/batch = 1.139
# 63420/91980, translation error = 9.487, rotation error = 5.344, time/batch = 1.135
# 63840/91980, translation error = 9.438, rotation error = 5.328, time/batch = 1.144
# 64260/91980, translation error = 10.078, rotation error = 5.514, time/batch = 1.136
# 64680/91980, translation error = 10.069, rotation error = 5.572, time/batch = 1.137
# 65100/91980, translation error = 10.029, rotation error = 5.570, time/batch = 1.136
# 65520/91980, translation error = 9.978, rotation error = 5.553, time/batch = 1.137
# 65940/91980, translation error = 9.942, rotation error = 5.562, time/batch = 1.140
# 66360/91980, translation error = 9.898, rotation error = 5.551, time/batch = 1.143
# 66780/91980, translation error = 9.892, rotation error = 5.567, time/batch = 1.138
# 67200/91980, translation error = 9.854, rotation error = 5.568, time/batch = 1.133
# 67620/91980, translation error = 9.817, rotation error = 5.594, time/batch = 1.133
# 68040/91980, translation error = 9.767, rotation error = 5.573, time/batch = 1.143
# 68460/91980, translation error = 9.722, rotation error = 5.578, time/batch = 1.138
# 68880/91980, translation error = 9.679, rotation error = 5.563, time/batch = 1.138
# 69300/91980, translation error = 9.667, rotation error = 5.575, time/batch = 1.141
# 69720/91980, translation error = 9.646, rotation error = 5.565, time/batch = 1.140
# 70140/91980, translation error = 9.637, rotation error = 5.556, time/batch = 1.140
# 70560/91980, translation error = 9.588, rotation error = 5.542, time/batch = 1.135
# 70980/91980, translation error = 9.545, rotation error = 5.533, time/batch = 1.138
# 71400/91980, translation error = 9.498, rotation error = 5.520, time/batch = 1.138
# 71820/91980, translation error = 9.455, rotation error = 5.504, time/batch = 1.142
# 72240/91980, translation error = 9.416, rotation error = 5.492, time/batch = 1.135
# 72660/91980, translation error = 9.373, rotation error = 5.479, time/batch = 1.138
# 73080/91980, translation error = 9.333, rotation error = 5.482, time/batch = 1.137
# 73500/91980, translation error = 9.294, rotation error = 5.473, time/batch = 1.145
# 73920/91980, translation error = 9.286, rotation error = 5.477, time/batch = 1.141
# 74340/91980, translation error = 9.245, rotation error = 5.468, time/batch = 1.140
# 74760/91980, translation error = 9.531, rotation error = 5.651, time/batch = 1.137
# 75180/91980, translation error = 9.550, rotation error = 5.676, time/batch = 1.142
# 75600/91980, translation error = 9.684, rotation error = 5.706, time/batch = 1.137
# 76020/91980, translation error = 9.647, rotation error = 5.691, time/batch = 1.142
# 76440/91980, translation error = 9.610, rotation error = 5.680, time/batch = 1.135
# 76860/91980, translation error = 9.596, rotation error = 5.673, time/batch = 1.136
# 77280/91980, translation error = 9.621, rotation error = 5.673, time/batch = 1.139
# 77700/91980, translation error = 10.063, rotation error = 5.782, time/batch = 1.141
# 78120/91980, translation error = 10.179, rotation error = 5.865, time/batch = 1.139
# 78540/91980, translation error = 10.226, rotation error = 5.888, time/batch = 1.135
# 78960/91980, translation error = 10.283, rotation error = 5.919, time/batch = 1.140
# 79380/91980, translation error = 10.445, rotation error = 6.121, time/batch = 1.140
# 79800/91980, translation error = 10.927, rotation error = 6.140, time/batch = 1.140
# 80220/91980, translation error = 10.888, rotation error = 6.151, time/batch = 1.139
# 80640/91980, translation error = 10.956, rotation error = 6.207, time/batch = 1.141
# 81060/91980, translation error = 10.925, rotation error = 6.218, time/batch = 1.147
# 81480/91980, translation error = 10.967, rotation error = 6.281, time/batch = 1.137
# 81900/91980, translation error = 10.939, rotation error = 6.289, time/batch = 1.139
# 82320/91980, translation error = 10.914, rotation error = 6.278, time/batch = 1.138
# 82740/91980, translation error = 10.898, rotation error = 6.284, time/batch = 1.145
# 83160/91980, translation error = 10.868, rotation error = 6.306, time/batch = 1.137
# 83580/91980, translation error = 10.853, rotation error = 6.294, time/batch = 1.144
# 84000/91980, translation error = 10.845, rotation error = 6.294, time/batch = 1.138
# 84420/91980, translation error = 10.832, rotation error = 6.329, time/batch = 1.136
# 84840/91980, translation error = 10.792, rotation error = 6.318, time/batch = 1.137
# 85260/91980, translation error = 10.754, rotation error = 6.309, time/batch = 1.143
# 85680/91980, translation error = 10.712, rotation error = 6.293, time/batch = 1.141
# 86100/91980, translation error = 10.833, rotation error = 6.367, time/batch = 1.136
# 86520/91980, translation error = 10.797, rotation error = 6.353, time/batch = 1.143
# 86940/91980, translation error = 10.759, rotation error = 6.337, time/batch = 1.137
# 87360/91980, translation error = 10.789, rotation error = 6.350, time/batch = 1.139
# 87780/91980, translation error = 10.753, rotation error = 6.357, time/batch = 1.137
# 88200/91980, translation error = 10.864, rotation error = 6.463, time/batch = 1.140
# 88620/91980, translation error = 10.821, rotation error = 6.456, time/batch = 1.138
# 89040/91980, translation error = 11.007, rotation error = 6.472, time/batch = 1.134
# 89460/91980, translation error = 10.970, rotation error = 6.477, time/batch = 1.140
# 89880/91980, translation error = 10.979, rotation error = 6.482, time/batch = 1.138
# 90300/91980, translation error = 10.979, rotation error = 6.466, time/batch = 1.143
# 90720/91980, translation error = 10.948, rotation error = 6.460, time/batch = 1.141
# 91140/91980, translation error = 10.910, rotation error = 6.453, time/batch = 1.140
# 91560/91980, translation error = 10.884, rotation error = 6.561, time/batch = 1.141
# 91980/91980, translation error = 10.850, rotation error = 6.554, time/batch = 4.602

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.103
# median rotation error = 3.120
# mean translation error = 10.850
# mean rotation error = 6.554

# %%
def evaluate(trans_errors,rot_errors):
    t = dataset.last_indexes
    trans_errors_month = list()
    trans_errors_month.append(trans_errors[:t[0]])
    trans_errors_month.append(trans_errors[t[0]:t[1]])
    trans_errors_month.append(trans_errors[t[1]:t[2]])
    trans_errors_month.append(trans_errors[t[2]:t[3]])
    trans_errors_month.append(trans_errors[t[3]:t[4]])
    trans_errors_month.append(trans_errors[t[4]:t[5]])
    trans_errors_month.append(trans_errors[t[5]:t[6]])
    trans_errors_month.append(trans_errors[t[6]:])

    rot_errors_month = list()
    rot_errors_month.append(rot_errors[:t[0]])
    rot_errors_month.append(rot_errors[t[0]:t[1]])
    rot_errors_month.append(rot_errors[t[1]:t[2]])
    rot_errors_month.append(rot_errors[t[2]:t[3]])
    rot_errors_month.append(rot_errors[t[3]:t[4]])
    rot_errors_month.append(rot_errors[t[4]:t[5]])
    rot_errors_month.append(rot_errors[t[5]:t[6]])
    rot_errors_month.append(rot_errors[t[6]:])
    
    print('================== median translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("median translation error = {:.3f}".format(np.median(trans_errors_i)))
        
    print('================== median rotation error ==================')
    for rot_errors_i in rot_errors_month:
        print("median rotation error = {:.3f}".format(np.median(rot_errors_i)))
    
    print('================== mean translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("mean translation error = {:.3f}".format(np.mean(trans_errors_i)))
        
    print('================== mean rotation error ==================')  
    for rot_errors_i in rot_errors_month:
        print("mean rotation error = {:.3f}".format(np.mean(rot_errors_i)))
        
evaluate(trans_errors,rot_errors)
# Out:
# ================== median translation error ==================
# median translation error = 1.648
# median translation error = 1.740
# median translation error = 2.013
# median translation error = 2.008
# median translation error = 2.107
# median translation error = 2.190
# median translation error = 3.579
# median translation error = 2.932
# ================== median rotation error ==================
# median rotation error = 2.584
# median rotation error = 2.794
# median rotation error = 2.950
# median rotation error = 2.925
# median rotation error = 3.105
# median rotation error = 3.262
# median rotation error = 4.395
# median rotation error = 4.155
# ================== mean translation error ==================
# mean translation error = 4.265
# mean translation error = 4.468
# mean translation error = 13.187
# mean translation error = 12.985
# mean translation error = 9.629
# mean translation error = 11.376
# mean translation error = 21.605
# mean translation error = 13.976
# ================== mean rotation error ==================
# mean rotation error = 3.956
# mean rotation error = 4.262
# mean rotation error = 6.160
# mean rotation error = 5.901
# mean rotation error = 5.634
# mean rotation error = 6.627
# mean rotation error = 12.331
# mean rotation error = 9.281
