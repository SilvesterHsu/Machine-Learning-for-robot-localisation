# %% [markdown]
# # Library

# %%
import numpy as np
import torch
import gpytorch
import argparse
import time
import pickle
import scipy.io as sio

from torch.distributions import Normal
import matplotlib.pyplot as plt
import random

import roslib
import rospy
import tf as tf_ros
from nav_msgs.msg import Odometry, Path
from sensor_msgs.msg import Image
from cv_bridge import CvBridge
from geometry_msgs.msg import PoseStamped, PoseArray, Pose
import math
import cv2
import copy

import sys
sys.path.append('..')
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'

# %% [markdown]
# ## Check GPU

# %%
import torch
import numpy as np
import sys
sys.path.append('..')

from torchlib.utils import list_device,set_device

# S1: check GPU
#list_device()

# S2: default parameters
set_device(1)
np.set_printoptions(precision = 2)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, default=420, help='size of mini batch')
#parser.add_argument('--batch_size', type=int, default=200, help='size of mini batch')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data normalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')

parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/gp_net_torch', help='rnn, gru, or lstm')

parser.add_argument('--test_dataset', type=str, default=[# '/notebooks/michigan_nn_data/2012_01_08',
                                                         # '/notebooks/michigan_nn_data/2012_01_15',
                                                         # '/notebooks/michigan_nn_data/2012_01_22',
                                                         # '/notebooks/michigan_nn_data/2012_02_02',
                                                         # '/notebooks/michigan_nn_data/2012_02_04',
                                                         # '/notebooks/michigan_nn_data/2012_02_05',
                                                         '/notebooks/michigan_nn_data/2012_02_12',
                                                         # '/notebooks/michigan_nn_data/2012_03_31',
                                                         '/notebooks/michigan_nn_data/2012_04_29',
                                                         '/notebooks/michigan_nn_data/2012_05_11',
                                                         '/notebooks/michigan_nn_data/2012_06_15',
                                                         '/notebooks/michigan_nn_data/2012_08_04',
                                                         # '/notebooks/michigan_nn_data/2012_09_28'])
                                                         '/notebooks/michigan_nn_data/2012_10_28',
                                                         '/notebooks/michigan_nn_data/2012_11_16',
                                                         '/notebooks/michigan_nn_data/2012_12_01'
                                                        ] )

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/test'])
parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

#parser.add_argument('--map_dataset', type=str, default='/home/kevin/data/michigan_gt/training')
parser.add_argument('--enable_ros', type=bool, default=False, help='put data into ros')
parser.add_argument('--cuda_device', type=int, default=1, help='cuda device')

sys.argv = ['']
args = parser.parse_args()

if args.enable_ros:
    rospy.init_node('global_localization_tf_broadcaster_cnn')

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
#from PIL import Image
import numpy as np
import random

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet, cnn_auxiliary
from torchlib.cnn_auxiliary import normalize, denormalize, denormalize_navie, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

transform = transforms.Compose([transforms.ToTensor()])
dataset = LocalizationDataset(dataset_dirs = args.test_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform,
                              get_pair = False, mode='evaluate', sampling_rate=2)

[args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
print('Load norm and std:',*args.norm_tensor)

dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=False, num_workers=0, \
                        drop_last=False, pin_memory=True)
# Out:
# 100%|██████████| 14301/14301 [00:18<00:00, 779.28it/s]
# 100%|██████████| 7008/7008 [00:09<00:00, 769.17it/s]
# 100%|██████████| 12852/12852 [00:16<00:00, 781.60it/s]
# 100%|██████████| 9567/9567 [00:12<00:00, 774.59it/s]
# 100%|██████████| 13580/13580 [00:17<00:00, 786.01it/s]
# 100%|██████████| 14835/14835 [00:18<00:00, 786.70it/s]
# 100%|██████████| 7114/7114 [00:09<00:00, 769.82it/s]
# 100%|██████████| 12683/12683 [00:16<00:00, 780.76it/s]
# Load norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # Define Model

# %%
from torch.cuda.amp import autocast, GradScaler
from torchlib.GPs import Backbone, NN, BaseModule

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([1]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([1])),
            batch_shape=torch.Size([1]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        inducing_points = torch.zeros(3, 300, 128)
        self.backbone = Backbone()
        self.nn = NN()
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=3)
        
    def forward(self, input_data):
        dense_feat = self.backbone(input_data)
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention 
        trans_pred = self.gp(feature_t)
        return trans_pred, rot_pred

class PosePredictor(BaseModule):
    def __init__(self, norm_mean, norm_std, args,
                 is_training=True, mixed_precision=True,
                 regressor_context_rate = [0.0,0.0], train_rot = False):
        super().__init__(norm_mean, norm_std, args)
        self.model = Model().to(self.device)
        self.train_rot = train_rot
        self.mixed_precision = mixed_precision
        if self.mixed_precision:
            self.scaler = GradScaler()

        self.disable_requires_grad(self.model.backbone)
        
        if is_training:
            self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
            self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                             lr_lambda=lambda epoch: args.decay_rate**epoch)
            num_data = min(len(dataloader)*args.batch_size,len(dataset))
            self.mll = gpytorch.mlls.PredictiveLogLikelihood(self.model.likelihood, \
                                                         self.model.gp, num_data = num_data)
        else:
            self.disable_requires_grad(self.model)
            
    def _optimize(self,regressor_context_rate):
        # GP
        optimizer = [
                {'params': self.model.gp.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay},
                {'params': self.model.likelihood.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay}]
            
        # NN
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            self.disable_requires_grad(self.model.nn.global_regressor)
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
            self.train_rot = True
        else:
            self.disable_requires_grad(self.model.nn.global_context)
            
        
        if not self.train_rot and regressor_context_rate[1]==0.0:
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc1_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc2_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc3_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.logits_r)
                
        return optimizer
    
    def train(self,x, y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
            
        # Step 2: training
        assert trainer.model.training == True
        if self.mixed_precision:
            with autocast():
                single_loss = self._loss(x, y)
            self.scaler.scale(single_loss).backward()
            self.scaler.step(self.optimizer)
            self.scaler.update()
        else:
            single_loss = self._loss(x, y)
            single_loss.backward()
            self.optimizer.step()
            
        batch_time = time.time() - start
        
        return float(single_loss), batch_time
    
    def _loss(self,x, y):
        # target
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        # predict
        trans_pred, rot_pred = self.model(x)
        
        # trans loss
        trans_loss = -1.*self.mll(trans_pred, trans_target)
        # rot loss
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        
        total_loss = trans_loss + args.lamda_weights * rot_loss      
        
        return total_loss
    
    def eval_forward(self,x,y,num_sample = 100,output_denormalize = True):
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        
        # Step 2: forward
        assert trainer.model.training == False
        if self.mixed_precision:
            with autocast():
                trans_prediction, rot_prediction = self.model(x)
            self.scaler.scale(trans_prediction)
            self.scaler.scale(rot_prediction)
        else:
            trans_prediction, rot_prediction = self.model(x)
            
        trans_prediction, trans_mean, trans_var = self._eval_gp(trans_prediction)
        
        if args.is_normalization and output_denormalize:
            trans_prediction = denormalize_navie(trans_prediction, self.norm_mean, self.norm_std)
            trans_mean = denormalize_navie(trans_mean, self.norm_mean, self.norm_std)
            trans_var = trans_var.mul(self.norm_std)
        
        samples = self._sample(trans_mean, trans_var, num_sample)
            
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_prediction, rot_prediction, trans_target, rot_target, samples
    
    def _sample(self, mean, var, num_sample = 100):
        dist = torch.distributions.Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples
    
    def _eval_gp(self, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = self.model.likelihood(trans_pred).mean, self.model.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var

# %%
trainer = PosePredictor(args.norm_mean,args.norm_std,args,mixed_precision=False,is_training = False)
trainer.load_model('pretrained.pth')
# Out:
# Transform from old model.
# Successfully loaded model to TITAN Xp.

# %% [markdown]
# # Initialize

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

# %%
trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward(x,y)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 420/91980, translation error = 8.986, rotation error = 3.685, time/batch = 4.806
# 840/91980, translation error = 6.466, rotation error = 3.215, time/batch = 1.033
# 1260/91980, translation error = 6.890, rotation error = 3.467, time/batch = 1.136
# 1680/91980, translation error = 5.819, rotation error = 3.604, time/batch = 1.031
# 2100/91980, translation error = 5.323, rotation error = 3.683, time/batch = 1.047
# 2520/91980, translation error = 4.826, rotation error = 3.687, time/batch = 1.035
# 2940/91980, translation error = 4.497, rotation error = 3.670, time/batch = 1.045
# 3360/91980, translation error = 4.307, rotation error = 3.707, time/batch = 1.037
# 3780/91980, translation error = 4.034, rotation error = 3.604, time/batch = 1.043
# 4200/91980, translation error = 3.727, rotation error = 3.520, time/batch = 1.033
# 4620/91980, translation error = 3.495, rotation error = 3.505, time/batch = 1.035
# 5040/91980, translation error = 3.293, rotation error = 3.496, time/batch = 1.047
# 5460/91980, translation error = 3.218, rotation error = 3.455, time/batch = 1.036
# 5880/91980, translation error = 3.165, rotation error = 3.410, time/batch = 1.036
# 6300/91980, translation error = 3.079, rotation error = 3.331, time/batch = 1.038
# 6720/91980, translation error = 5.141, rotation error = 3.715, time/batch = 1.035
# 7140/91980, translation error = 5.199, rotation error = 4.013, time/batch = 1.044
# 7560/91980, translation error = 5.037, rotation error = 4.064, time/batch = 1.036
# 7980/91980, translation error = 5.099, rotation error = 4.116, time/batch = 1.042
# 8400/91980, translation error = 5.674, rotation error = 4.208, time/batch = 1.042
# 8820/91980, translation error = 5.507, rotation error = 4.172, time/batch = 1.043
# 9240/91980, translation error = 5.371, rotation error = 4.151, time/batch = 1.040
# 9660/91980, translation error = 5.253, rotation error = 4.082, time/batch = 1.038
# 10080/91980, translation error = 5.160, rotation error = 4.071, time/batch = 1.049
# 10500/91980, translation error = 5.015, rotation error = 4.148, time/batch = 1.043
# 10920/91980, translation error = 4.905, rotation error = 4.152, time/batch = 1.038
# 11340/91980, translation error = 4.796, rotation error = 4.084, time/batch = 1.043
# 11760/91980, translation error = 4.670, rotation error = 4.015, time/batch = 1.044
# 12180/91980, translation error = 4.553, rotation error = 3.963, time/batch = 1.044
# 12600/91980, translation error = 4.448, rotation error = 3.928, time/batch = 1.045
# 13020/91980, translation error = 4.357, rotation error = 3.926, time/batch = 1.041
# 13440/91980, translation error = 4.402, rotation error = 3.937, time/batch = 1.043
# 13860/91980, translation error = 4.333, rotation error = 3.907, time/batch = 1.049
# 14280/91980, translation error = 4.268, rotation error = 3.917, time/batch = 1.041
# 14700/91980, translation error = 4.216, rotation error = 3.893, time/batch = 1.048
# 15120/91980, translation error = 4.186, rotation error = 3.889, time/batch = 1.043
# 15540/91980, translation error = 4.141, rotation error = 3.848, time/batch = 1.042
# 15960/91980, translation error = 5.092, rotation error = 4.063, time/batch = 1.046
# 16380/91980, translation error = 5.029, rotation error = 4.057, time/batch = 1.043
# 16800/91980, translation error = 4.963, rotation error = 4.097, time/batch = 1.051
# 17220/91980, translation error = 4.894, rotation error = 4.090, time/batch = 1.043
# 17640/91980, translation error = 4.812, rotation error = 4.056, time/batch = 1.044
# 18060/91980, translation error = 4.766, rotation error = 4.080, time/batch = 1.049
# 18480/91980, translation error = 4.707, rotation error = 4.089, time/batch = 1.052
# 18900/91980, translation error = 4.640, rotation error = 4.102, time/batch = 1.047
# 19320/91980, translation error = 4.590, rotation error = 4.075, time/batch = 1.047
# 19740/91980, translation error = 4.556, rotation error = 4.081, time/batch = 1.047
# 20160/91980, translation error = 4.502, rotation error = 4.069, time/batch = 1.047
# 20580/91980, translation error = 4.438, rotation error = 4.048, time/batch = 1.046
# 21000/91980, translation error = 4.383, rotation error = 4.034, time/batch = 1.044
# 21420/91980, translation error = 4.328, rotation error = 4.029, time/batch = 1.047
# 21840/91980, translation error = 5.949, rotation error = 4.202, time/batch = 1.051
# 22260/91980, translation error = 9.925, rotation error = 5.248, time/batch = 1.047
# 22680/91980, translation error = 9.874, rotation error = 5.212, time/batch = 1.045
# 23100/91980, translation error = 9.757, rotation error = 5.202, time/batch = 1.048
# 23520/91980, translation error = 9.622, rotation error = 5.172, time/batch = 1.047
# 23940/91980, translation error = 9.490, rotation error = 5.151, time/batch = 1.048
# 24360/91980, translation error = 9.420, rotation error = 5.153, time/batch = 1.051
# 24780/91980, translation error = 9.333, rotation error = 5.162, time/batch = 1.056
# 25200/91980, translation error = 9.207, rotation error = 5.139, time/batch = 1.048
# 25620/91980, translation error = 9.082, rotation error = 5.115, time/batch = 1.049
# 26040/91980, translation error = 8.968, rotation error = 5.108, time/batch = 1.059
# 26460/91980, translation error = 8.849, rotation error = 5.080, time/batch = 1.047
# 26880/91980, translation error = 8.809, rotation error = 5.064, time/batch = 1.061
# 27300/91980, translation error = 8.710, rotation error = 5.021, time/batch = 1.047
# 27720/91980, translation error = 8.616, rotation error = 4.981, time/batch = 1.048
# 28140/91980, translation error = 8.521, rotation error = 4.953, time/batch = 1.053
# 28560/91980, translation error = 8.441, rotation error = 4.936, time/batch = 1.046
# 28980/91980, translation error = 8.385, rotation error = 4.997, time/batch = 1.053
# 29400/91980, translation error = 8.498, rotation error = 5.037, time/batch = 1.054
# 29820/91980, translation error = 8.409, rotation error = 5.001, time/batch = 1.049
# 30240/91980, translation error = 8.360, rotation error = 4.985, time/batch = 1.047
# 30660/91980, translation error = 8.280, rotation error = 4.966, time/batch = 1.056
# 31080/91980, translation error = 8.192, rotation error = 4.971, time/batch = 1.049
# 31500/91980, translation error = 8.114, rotation error = 4.952, time/batch = 1.048
# 31920/91980, translation error = 8.034, rotation error = 4.922, time/batch = 1.051
# 32340/91980, translation error = 7.961, rotation error = 4.909, time/batch = 1.055
# 32760/91980, translation error = 7.885, rotation error = 4.899, time/batch = 1.047
# 33180/91980, translation error = 7.807, rotation error = 4.875, time/batch = 1.051
# 33600/91980, translation error = 7.742, rotation error = 4.857, time/batch = 1.052
# 34020/91980, translation error = 7.683, rotation error = 4.845, time/batch = 1.054
# 34440/91980, translation error = 9.010, rotation error = 5.119, time/batch = 1.054
# 34860/91980, translation error = 8.942, rotation error = 5.088, time/batch = 1.055
# 35280/91980, translation error = 8.874, rotation error = 5.068, time/batch = 1.050
# 35700/91980, translation error = 10.097, rotation error = 5.274, time/batch = 1.061
# 36120/91980, translation error = 10.014, rotation error = 5.254, time/batch = 1.049
# 36540/91980, translation error = 9.949, rotation error = 5.250, time/batch = 1.054
# 36960/91980, translation error = 9.862, rotation error = 5.243, time/batch = 1.056
# 37380/91980, translation error = 9.775, rotation error = 5.219, time/batch = 1.046
# 37800/91980, translation error = 9.685, rotation error = 5.200, time/batch = 1.054
# 38220/91980, translation error = 9.606, rotation error = 5.203, time/batch = 1.051
# 38640/91980, translation error = 9.518, rotation error = 5.184, time/batch = 1.049
# 39060/91980, translation error = 9.447, rotation error = 5.176, time/batch = 1.052
# 39480/91980, translation error = 9.374, rotation error = 5.170, time/batch = 1.058
# 39900/91980, translation error = 9.305, rotation error = 5.156, time/batch = 1.049
# 40320/91980, translation error = 9.226, rotation error = 5.140, time/batch = 1.053
# 40740/91980, translation error = 9.147, rotation error = 5.127, time/batch = 1.063
# 41160/91980, translation error = 9.074, rotation error = 5.128, time/batch = 1.052
# 41580/91980, translation error = 9.005, rotation error = 5.118, time/batch = 1.053
# 42000/91980, translation error = 8.932, rotation error = 5.112, time/batch = 1.042
# 42420/91980, translation error = 8.948, rotation error = 5.102, time/batch = 1.054
# 42840/91980, translation error = 8.889, rotation error = 5.074, time/batch = 1.060
# 43260/91980, translation error = 8.823, rotation error = 5.054, time/batch = 1.053
# 43680/91980, translation error = 8.821, rotation error = 5.070, time/batch = 1.050
# 44100/91980, translation error = 8.778, rotation error = 5.062, time/batch = 1.057
# 44520/91980, translation error = 8.752, rotation error = 5.072, time/batch = 1.063
# 44940/91980, translation error = 8.701, rotation error = 5.069, time/batch = 1.052
# 45360/91980, translation error = 8.641, rotation error = 5.061, time/batch = 1.061
# 45780/91980, translation error = 8.593, rotation error = 5.053, time/batch = 1.047
# 46200/91980, translation error = 8.540, rotation error = 5.056, time/batch = 1.049
# 46620/91980, translation error = 8.492, rotation error = 5.046, time/batch = 1.052
# 47040/91980, translation error = 8.448, rotation error = 5.037, time/batch = 1.065
# 47460/91980, translation error = 8.418, rotation error = 5.022, time/batch = 1.052
# 47880/91980, translation error = 8.358, rotation error = 5.009, time/batch = 1.051
# 48300/91980, translation error = 8.303, rotation error = 5.002, time/batch = 1.054
# 48720/91980, translation error = 8.258, rotation error = 4.983, time/batch = 1.053
# 49140/91980, translation error = 8.208, rotation error = 4.962, time/batch = 1.052
# 49560/91980, translation error = 8.155, rotation error = 4.953, time/batch = 1.053
# 49980/91980, translation error = 8.116, rotation error = 4.939, time/batch = 1.052
# 50400/91980, translation error = 8.072, rotation error = 4.924, time/batch = 1.057
# 50820/91980, translation error = 9.150, rotation error = 5.062, time/batch = 1.052
# 51240/91980, translation error = 9.109, rotation error = 5.080, time/batch = 1.052
# 51660/91980, translation error = 9.054, rotation error = 5.066, time/batch = 1.054
# 52080/91980, translation error = 8.996, rotation error = 5.072, time/batch = 1.048
# 52500/91980, translation error = 8.960, rotation error = 5.076, time/batch = 1.045
# 52920/91980, translation error = 8.907, rotation error = 5.055, time/batch = 1.053
# 53340/91980, translation error = 8.861, rotation error = 5.071, time/batch = 1.054
# 53760/91980, translation error = 8.810, rotation error = 5.068, time/batch = 1.050
# 54180/91980, translation error = 8.826, rotation error = 5.070, time/batch = 1.042
# 54600/91980, translation error = 8.809, rotation error = 5.071, time/batch = 1.049
# 55020/91980, translation error = 8.759, rotation error = 5.067, time/batch = 1.051
# 55440/91980, translation error = 8.712, rotation error = 5.066, time/batch = 1.049
# 55860/91980, translation error = 8.951, rotation error = 5.107, time/batch = 1.050
# 56280/91980, translation error = 9.097, rotation error = 5.196, time/batch = 1.049
# 56700/91980, translation error = 9.059, rotation error = 5.198, time/batch = 1.054
# 57120/91980, translation error = 9.019, rotation error = 5.199, time/batch = 1.054
# 57540/91980, translation error = 9.827, rotation error = 5.233, time/batch = 1.049
# 57960/91980, translation error = 9.779, rotation error = 5.234, time/batch = 1.052
# 58380/91980, translation error = 9.745, rotation error = 5.234, time/batch = 1.054
# 58800/91980, translation error = 9.714, rotation error = 5.232, time/batch = 1.055
# 59220/91980, translation error = 9.657, rotation error = 5.229, time/batch = 1.053
# 59640/91980, translation error = 9.607, rotation error = 5.218, time/batch = 1.055
# 60060/91980, translation error = 9.555, rotation error = 5.209, time/batch = 1.053
# 60480/91980, translation error = 9.508, rotation error = 5.201, time/batch = 1.054
# 60900/91980, translation error = 9.459, rotation error = 5.188, time/batch = 1.055
# 61320/91980, translation error = 9.419, rotation error = 5.183, time/batch = 1.055
# 61740/91980, translation error = 9.752, rotation error = 5.346, time/batch = 1.054
# 62160/91980, translation error = 9.708, rotation error = 5.346, time/batch = 1.054
# 62580/91980, translation error = 9.657, rotation error = 5.330, time/batch = 1.052
# 63000/91980, translation error = 9.607, rotation error = 5.327, time/batch = 1.052
# 63420/91980, translation error = 9.593, rotation error = 5.344, time/batch = 1.049
# 63840/91980, translation error = 9.544, rotation error = 5.328, time/batch = 1.054
# 64260/91980, translation error = 10.121, rotation error = 5.514, time/batch = 1.056
# 64680/91980, translation error = 10.118, rotation error = 5.572, time/batch = 1.051
# 65100/91980, translation error = 10.080, rotation error = 5.570, time/batch = 1.052
# 65520/91980, translation error = 10.030, rotation error = 5.553, time/batch = 1.055
# 65940/91980, translation error = 9.994, rotation error = 5.562, time/batch = 1.056
# 66360/91980, translation error = 9.949, rotation error = 5.551, time/batch = 1.055
# 66780/91980, translation error = 9.946, rotation error = 5.567, time/batch = 1.054
# 67200/91980, translation error = 9.911, rotation error = 5.568, time/batch = 1.058
# 67620/91980, translation error = 9.875, rotation error = 5.594, time/batch = 1.050
# 68040/91980, translation error = 9.825, rotation error = 5.573, time/batch = 1.056
# 68460/91980, translation error = 9.782, rotation error = 5.578, time/batch = 1.054
# 68880/91980, translation error = 9.737, rotation error = 5.563, time/batch = 1.057
# 69300/91980, translation error = 9.725, rotation error = 5.575, time/batch = 1.059
# 69720/91980, translation error = 9.704, rotation error = 5.565, time/batch = 1.055
# 70140/91980, translation error = 9.700, rotation error = 5.556, time/batch = 1.056
# 70560/91980, translation error = 9.651, rotation error = 5.542, time/batch = 1.050
# 70980/91980, translation error = 9.608, rotation error = 5.533, time/batch = 1.053
# 71400/91980, translation error = 9.560, rotation error = 5.520, time/batch = 1.053
# 71820/91980, translation error = 9.517, rotation error = 5.504, time/batch = 1.057
# 72240/91980, translation error = 9.479, rotation error = 5.492, time/batch = 1.051
# 72660/91980, translation error = 9.436, rotation error = 5.479, time/batch = 1.053
# 73080/91980, translation error = 9.396, rotation error = 5.482, time/batch = 1.054
# 73500/91980, translation error = 9.357, rotation error = 5.473, time/batch = 1.052
# 73920/91980, translation error = 9.349, rotation error = 5.477, time/batch = 1.058
# 74340/91980, translation error = 9.308, rotation error = 5.468, time/batch = 1.053
# 74760/91980, translation error = 9.571, rotation error = 5.651, time/batch = 1.053
# 75180/91980, translation error = 9.589, rotation error = 5.676, time/batch = 1.055
# 75600/91980, translation error = 9.722, rotation error = 5.706, time/batch = 1.053
# 76020/91980, translation error = 9.686, rotation error = 5.691, time/batch = 1.053
# 76440/91980, translation error = 9.648, rotation error = 5.680, time/batch = 1.055
# 76860/91980, translation error = 9.632, rotation error = 5.673, time/batch = 1.058
# 77280/91980, translation error = 9.653, rotation error = 5.673, time/batch = 1.059
# 77700/91980, translation error = 10.125, rotation error = 5.782, time/batch = 1.056
# 78120/91980, translation error = 10.255, rotation error = 5.865, time/batch = 1.053
# 78540/91980, translation error = 10.327, rotation error = 5.888, time/batch = 1.057
# 78960/91980, translation error = 10.395, rotation error = 5.919, time/batch = 1.053
# 79380/91980, translation error = 10.573, rotation error = 6.121, time/batch = 1.052
# 79800/91980, translation error = 11.061, rotation error = 6.140, time/batch = 1.055
# 80220/91980, translation error = 11.021, rotation error = 6.151, time/batch = 1.054
# 80640/91980, translation error = 11.098, rotation error = 6.207, time/batch = 1.053
# 81060/91980, translation error = 11.071, rotation error = 6.218, time/batch = 1.055
# 81480/91980, translation error = 11.137, rotation error = 6.281, time/batch = 1.050
# 81900/91980, translation error = 11.107, rotation error = 6.289, time/batch = 1.056
# 82320/91980, translation error = 11.077, rotation error = 6.278, time/batch = 1.054
# 82740/91980, translation error = 11.064, rotation error = 6.284, time/batch = 1.054
# 83160/91980, translation error = 11.035, rotation error = 6.306, time/batch = 1.058
# 83580/91980, translation error = 11.023, rotation error = 6.294, time/batch = 1.056
# 84000/91980, translation error = 11.027, rotation error = 6.294, time/batch = 1.056
# 84420/91980, translation error = 11.015, rotation error = 6.329, time/batch = 1.052
# 84840/91980, translation error = 10.975, rotation error = 6.318, time/batch = 1.055
# 85260/91980, translation error = 10.938, rotation error = 6.309, time/batch = 1.060
# 85680/91980, translation error = 10.896, rotation error = 6.293, time/batch = 1.056
# 86100/91980, translation error = 11.017, rotation error = 6.367, time/batch = 1.055
# 86520/91980, translation error = 10.982, rotation error = 6.353, time/batch = 1.052
# 86940/91980, translation error = 10.943, rotation error = 6.337, time/batch = 1.053
# 87360/91980, translation error = 10.977, rotation error = 6.350, time/batch = 1.055
# 87780/91980, translation error = 10.941, rotation error = 6.357, time/batch = 1.052
# 88200/91980, translation error = 11.048, rotation error = 6.463, time/batch = 1.053
# 88620/91980, translation error = 11.006, rotation error = 6.456, time/batch = 1.055
# 89040/91980, translation error = 11.196, rotation error = 6.472, time/batch = 1.052
# 89460/91980, translation error = 11.158, rotation error = 6.477, time/batch = 1.056
# 89880/91980, translation error = 11.170, rotation error = 6.482, time/batch = 1.061
# 90300/91980, translation error = 11.171, rotation error = 6.466, time/batch = 1.056
# 90720/91980, translation error = 11.140, rotation error = 6.460, time/batch = 1.058
# 91140/91980, translation error = 11.102, rotation error = 6.453, time/batch = 1.057
# 91560/91980, translation error = 11.081, rotation error = 6.561, time/batch = 1.056
# 91980/91980, translation error = 11.046, rotation error = 6.554, time/batch = 4.895

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.137
# median rotation error = 3.120
# mean translation error = 11.046
# mean rotation error = 6.554

# %%
def evaluate(trans_errors,rot_errors):
    t = dataset.last_indexes
    trans_errors_month = list()
    trans_errors_month.append(trans_errors[:t[0]])
    trans_errors_month.append(trans_errors[t[0]:t[1]])
    trans_errors_month.append(trans_errors[t[1]:t[2]])
    trans_errors_month.append(trans_errors[t[2]:t[3]])
    trans_errors_month.append(trans_errors[t[3]:t[4]])
    trans_errors_month.append(trans_errors[t[4]:t[5]])
    trans_errors_month.append(trans_errors[t[5]:t[6]])
    trans_errors_month.append(trans_errors[t[6]:])

    rot_errors_month = list()
    rot_errors_month.append(rot_errors[:t[0]])
    rot_errors_month.append(rot_errors[t[0]:t[1]])
    rot_errors_month.append(rot_errors[t[1]:t[2]])
    rot_errors_month.append(rot_errors[t[2]:t[3]])
    rot_errors_month.append(rot_errors[t[3]:t[4]])
    rot_errors_month.append(rot_errors[t[4]:t[5]])
    rot_errors_month.append(rot_errors[t[5]:t[6]])
    rot_errors_month.append(rot_errors[t[6]:])
    
    print('================== median translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("median translation error = {:.3f}".format(np.median(trans_errors_i)))
        
    print('================== median rotation error ==================')
    for rot_errors_i in rot_errors_month:
        print("median rotation error = {:.3f}".format(np.median(rot_errors_i)))
    
    print('================== mean translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("mean translation error = {:.3f}".format(np.mean(trans_errors_i)))
        
    print('================== mean rotation error ==================')  
    for rot_errors_i in rot_errors_month:
        print("mean rotation error = {:.3f}".format(np.mean(rot_errors_i)))
        
evaluate(trans_errors,rot_errors)
# Out:
# ================== median translation error ==================
# median translation error = 1.651
# median translation error = 1.739
# median translation error = 2.024
# median translation error = 2.008
# median translation error = 2.097
# median translation error = 2.199
# median translation error = 3.581
# median translation error = 2.938
# ================== median rotation error ==================
# median rotation error = 2.588
# median rotation error = 2.798
# median rotation error = 2.953
# median rotation error = 2.918
# median rotation error = 3.113
# median rotation error = 3.276
# median rotation error = 4.390
# median rotation error = 4.148
# ================== mean translation error ==================
# mean translation error = 4.273
# mean translation error = 4.472
# mean translation error = 13.177
# mean translation error = 12.990
# mean translation error = 9.557
# mean translation error = 11.366
# mean translation error = 21.610
# mean translation error = 13.980
# ================== mean rotation error ==================
# mean rotation error = 3.933
# mean rotation error = 4.253
# mean rotation error = 6.159
# mean rotation error = 5.911
# mean rotation error = 5.623
# mean rotation error = 6.625
# mean rotation error = 12.374
# mean rotation error = 9.312
