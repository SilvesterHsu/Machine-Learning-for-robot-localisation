# %% [markdown]
# # Library

# %%
import numpy as np
import torch
import gpytorch
import argparse
import time
import pickle
import scipy.io as sio

from torch.distributions import Normal
import matplotlib.pyplot as plt
import random

import roslib
import rospy
import tf as tf_ros
from nav_msgs.msg import Odometry, Path
from sensor_msgs.msg import Image
from cv_bridge import CvBridge
from geometry_msgs.msg import PoseStamped, PoseArray, Pose
import math
import cv2
import copy

import sys
sys.path.append('..')
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'

# %% [markdown]
# ## Check GPU

# %%
import torch
import sys
sys.path.append('..')
from torchlib.utils import list_device,set_device

list_device()
# Out:
# ------------ List Devices ------------
# Device 0 :
# GeForce RTX 2060
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
#
# Device 1 :
# TITAN Xp
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
# /home/seel/.local/lib/python3.6/site-packages/torch/cuda/memory.py:346: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   FutureWarning)

# %% [markdown]
# ## Set torch default parameters

# %%
set_device(1)
import numpy as np
np.set_printoptions(precision = 2)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=2)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, default=300, help='size of mini batch')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data normalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')
parser.add_argument('--output_dim', default=3, type=int, help='output dimention.')
parser.add_argument('--feat_dim', default=128, type=int, help='feature dimention.')
parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/gps_grid_torch', help='rnn, gru, or lstm')

parser.add_argument('--test_dataset', type=str, default=[# '/notebooks/michigan_nn_data/2012_01_08',
                                                         # '/notebooks/michigan_nn_data/2012_01_15',
                                                         # '/notebooks/michigan_nn_data/2012_01_22',
                                                         # '/notebooks/michigan_nn_data/2012_02_02',
                                                         # '/notebooks/michigan_nn_data/2012_02_04',
                                                         # '/notebooks/michigan_nn_data/2012_02_05',
                                                         '/notebooks/michigan_nn_data/2012_02_12',
                                                         # '/notebooks/michigan_nn_data/2012_03_31',
                                                         '/notebooks/michigan_nn_data/2012_04_29',
                                                         '/notebooks/michigan_nn_data/2012_05_11',
                                                         '/notebooks/michigan_nn_data/2012_06_15',
                                                         '/notebooks/michigan_nn_data/2012_08_04',
                                                         # '/notebooks/michigan_nn_data/2012_09_28'])
                                                         '/notebooks/michigan_nn_data/2012_10_28',
                                                         '/notebooks/michigan_nn_data/2012_11_16',
                                                         '/notebooks/michigan_nn_data/2012_12_01'
                                                        ] )

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/test'])
parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

#parser.add_argument('--map_dataset', type=str, default='/home/kevin/data/michigan_gt/training')
parser.add_argument('--seed', default=1337, type=int)
parser.add_argument('--enable_ros', type=bool, default=False, help='put data into ros')

sys.argv = ['']
args = parser.parse_args()

if args.enable_ros:
    rospy.init_node('global_localization_tf_broadcaster_cnn')

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
#from PIL import Image
import numpy as np
import random

#
import gpytorch

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet, cnn_auxiliary
from torchlib.cnn_auxiliary import normalize, denormalize, denormalize_navie, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

transform = transforms.Compose([transforms.ToTensor()])
dataset = LocalizationDataset(dataset_dirs = args.test_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform, get_pair = False, mode='evaluate', sampling_rate=2)

[args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
print('Load norm and std:',*args.norm_tensor)

    
dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=False, num_workers=0, \
                        drop_last=False, pin_memory=True)
# Out:
# 100%|██████████| 14301/14301 [00:18<00:00, 781.94it/s]
# 100%|██████████| 7008/7008 [00:09<00:00, 772.84it/s]
# 100%|██████████| 12852/12852 [00:16<00:00, 778.58it/s]
# 100%|██████████| 9567/9567 [00:12<00:00, 771.82it/s]
# 100%|██████████| 13580/13580 [00:17<00:00, 787.80it/s]
# 100%|██████████| 14835/14835 [00:18<00:00, 783.19it/s]
# 100%|██████████| 7114/7114 [00:09<00:00, 773.93it/s]
# 100%|██████████| 12683/12683 [00:16<00:00, 778.68it/s]
# Load norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # Grid

# %%
import math
import pickle

class Grid:
    def __init__(self,grid_size=100.,overlap=50.,**kwargs):
        self.grid_size = grid_size
        self.overlap = overlap
        if 'data' in kwargs:
            data = kwargs['data']
            assert data.shape[1] == 2
            self.boundary_x = [np.min(data[:,0]), np.max(data[:,0])]
            self.boundary_y = [np.min(data[:,1]), np.max(data[:,1])]
            self.num_grid_x,self.num_grid_y = self._cal_grid_num()
            self.num_grid = self.num_grid_x * self.num_grid_y
            self.grid_range_x,self.grid_range_y = self._cal_grid_range()
            self.save(os.path.join(args.model_dir,'grid.pkl'))
            print('Save Grids to',os.path.join(args.model_dir,'grid.pkl'))
        
    def _lenght(self):
        x_len = self.boundary_x[1] - self.boundary_x[0]
        y_len = self.boundary_y[1] - self.boundary_y[0]
        return x_len,y_len
    
    def _cal_grid_num(self):
        x_len,y_len = self._lenght()
        num_x_grid = math.ceil(x_len/self.grid_size)
        num_y_grid = math.ceil(y_len/self.grid_size)
        return num_x_grid,num_y_grid
    
    def _cal_grid_range(self):
        grid_range_x = list()
        grid_range_y = list()
        for x_inde in range(self.num_grid_x):
            x = x_inde*self.grid_size + self.boundary_x[0]
            grid_range_x.append([x-self.overlap,x+self.overlap+self.grid_size])

        for y_inde in range(self.num_grid_y):
            y = y_inde*self.grid_size + self.boundary_y[0]
            grid_range_y.append([y-self.overlap,y+self.overlap+self.grid_size])
        return np.array(grid_range_x),np.array(grid_range_y)
    
    def _grid_index(self,x,y):
        x_s = np.searchsorted(self.grid_range_x[:,1],x)
        x_s = min(max(x_s,0),self.num_grid_x-1)
        x_index = [x_s,x_s+1] if x_s+1 < self.num_grid_x and self.grid_range_x[x_s+1,0] < x else [x_s,x_s]
        
        y_s = np.searchsorted(self.grid_range_y[:,1],y)
        y_s = min(max(y_s,0),self.num_grid_y-1)
        y_index = [y_s,y_s+1] if y_s+1 < self.num_grid_y and self.grid_range_y[y_s+1,0] < y else [y_s,y_s]
        
        return x_index,y_index
    
    def in_grids(self,x,y):
        x_index,y_index = self._grid_index(x,y)
        #print(x_index,y_index)
        box = []
        for x_i in x_index:
            for y_i in y_index:
                box += [x_i+y_i*self.num_grid_x]
        return box
    
    def save(self,filename = 'grid.pkl'):
        with open(filename,'wb') as f:
            f.write(pickle.dumps(self))

    def load(self,filename = 'grid.pkl'):
        with open(filename,'rb') as f:
            dataPickle = f.read()
            self = pickle.loads(dataPickle)
        
grid = Grid()

filename = os.path.join(args.model_dir,'grid.pkl')
with open(filename,'rb') as f:
    dataPickle = f.read()
    grid = pickle.loads(dataPickle)

# %%
grid.overlap = 0
grid.num_grid_x,grid.num_grid_y = grid._cal_grid_num()
grid.grid_range_x,grid.grid_range_y = grid._cal_grid_range()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

X = np.array(dataset.Targets)[:,:2]
X = np.vstack([X,X+np.random.rand(91940, 2)*10])
label_mask = np.zeros([X.shape[0],4])
for i in range(X.shape[0]):
    label_mask[i] = np.array(grid.in_grids(*X[i]))

# %%
r = lambda: np.random.randint(0,255)
colors = ['#%02X%02X%02X' % (r(),r(),r()) for _ in range(grid.num_grid)]
fig = plt.figure(figsize=(6, 8))
ax = fig.add_subplot(1, 1, 1)
for k, col in zip(range(grid.num_grid), colors):
    my_members = np.sum(label_mask == k,axis=1) >= 1
    ax.plot(X[my_members, 0], X[my_members, 1], 'w',
            markerfacecolor=col, marker='.')
ax.set_title('Grid')
plt.show()

# %% [markdown]
# # Global GP

# %%
class Backbone(nn.Module):
    def __init__(self):
        super().__init__()
        self.resnet = resnet.resnet50(pretrained=True)
    def forward(self,input_data):
        dense_feat = self.resnet(input_data)
        return dense_feat
    
class NN(nn.Module):
    def __init__(self):
        super().__init__()
        self.global_context = vggnet.vggnet(input_channel=2048,opt="context")
        self.global_regressor = vggnet.vggnet(opt="regressor")
        
    def forward(self,input_data):
        context_feat = self.global_context(input_data)
        output,feature_t, feature_r = self.global_regressor(context_feat)
        return output, feature_t, feature_r

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([1]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([1])),
            batch_shape=torch.Size([1]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        inducing_points = torch.zeros(3, args.batch_size, 128)
        self.backbone = Backbone()
        self.nn = NN()
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=3)
        
    def forward(self, input_data):
        dense_feat = self.backbone(input_data)
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention 
        trans_pred = self.gp(feature_t)
        return trans_pred, rot_pred
    
class Trainer:
    def __init__(self,regressor_context_rate = [0.0,0.0]):
        # data
        self.model = Model().cuda()
        self.norm_mean = args.norm_mean.cuda()
        self.norm_std = args.norm_std.cuda()
        
        # disable learning backbone
        for param in self.model.backbone.parameters():
            param.requires_grad = False
        
        '''
        # training tool
        self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
        self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                         lr_lambda=lambda epoch: args.decay_rate**epoch)
        '''
        # or use `gpytorch.mlls.VariationalELBO`
        num_data = min(len(dataloader)*args.batch_size,len(dataset))
        self.mll = gpytorch.mlls.PredictiveLogLikelihood(self.model.likelihood, \
                                                         self.model.gp, num_data = num_data)
        
    def load_model(self, file_name = 'pretrained.pth'):
        # load file info
        state_dict = torch.load(os.path.join(args.model_dir, file_name))
        if 'net.resnet.conv1.weight' in state_dict:
            print('Transform from old model.')
            state_dict = self._from_old_model(state_dict)
        print('Parameters layer:',len(state_dict.keys()))
        # load file to model
        self.model.load_state_dict(state_dict,strict = True)
        # Display model structure
        for name, param in self.model.named_parameters():
            print(name, param.shape)
        print('Parameters layer:',len(self.model.state_dict().keys()))
        # check load
        assert len(state_dict.keys()) == len(self.model.state_dict().keys())
    
    def _from_old_model(self, state_dict):
        for key in list(state_dict):
            if 'net.resnet.' in key:
                state_dict[key.replace('net.resnet.','backbone.resnet.')] = state_dict.pop(key)
            elif 'net.global_regressor.' in key:
                state_dict[key.replace('net.global_regressor.','nn.global_regressor.')] = state_dict.pop(key)
            elif 'net.global_context.' in key:
                state_dict[key.replace('net.global_context.','nn.global_context.')] = state_dict.pop(key)
        return state_dict
         
    def save_model(self, file_name = 'model-{}-{}.pth'):
        checkpoint_path = os.path.join(args.model_dir, file_name)
        torch.save(self.model.state_dict(),checkpoint_path)
        print('Saving model to ' +  file_name)
  
    def _optimize(self,regressor_context_rate = [0.0,0.0]):
        optimizer = [
                {'params': self.model.gp.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay},
                {'params': self.model.likelihood.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay}]
            
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            for param in self.model.nn.global_regressor.parameters():
                param.requires_grad = False
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
        else:
            for param in self.model.nn.global_context.parameters():
                param.requires_grad = False
                
        return optimizer
    
    def train(self,x, y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        x,y = x.cuda(),y.cuda()
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
            
        # Step 2: training
        assert trainer.model.training == True
        single_loss = self._loss(x, y)
        batch_time = time.time() - start
        
        #Step 3: update
        single_loss.backward()
        self.optimizer.step()
        
        return float(single_loss), batch_time
            
    def _loss(self,x, y):
        # target
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        # predict
        trans_pred, rot_pred = self.model(x)
        
        # trans loss
        trans_loss = -1.*self.mll(trans_pred, trans_target)
        # rot loss
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        
        total_loss = trans_loss + args.lamda_weights * rot_loss      
        
        return total_loss
    
    def eval_forward(self,x,y,num_sample = 100,output_denormalize = True):
        # Step 1: get data
        x,y = x.cuda(),y.cuda()
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
        
        # Step 2: forward
        assert trainer.model.training == False
        trans_prediction, rot_prediction = self.model(x)
        trans_prediction, trans_mean, trans_var = self._eval_gp(trans_prediction)
        
        if args.is_normalization and output_denormalize:
            trans_prediction = denormalize_navie(trans_prediction, self.norm_mean, self.norm_std)
            trans_mean = denormalize_navie(trans_mean, self.norm_mean, self.norm_std)
            trans_var = trans_var.mul(self.norm_std)
            y = denormalize(y, self.norm_mean, self.norm_std)
        
        samples = self._sample(trans_mean, trans_var, num_sample)
            
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_prediction, rot_prediction, trans_target, rot_target, samples
    
    def _sample(self, mean, var, num_sample = 100):
        dist = Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples
    
    def _eval_gp(self, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = self.model.likelihood(trans_pred).mean, self.model.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var
    
global_trainer = Trainer()
global_trainer.load_model('/notebooks/global_localization/gp_net_torch/pretrained.pth')
global_trainer.model.eval()
# Out:
# Transform from old model.
# Parameters layer: 356
# backbone.resnet.conv1.weight torch.Size([64, 1, 7, 7])
# backbone.resnet.bn1.weight torch.Size([64])
# backbone.resnet.bn1.bias torch.Size([64])
# backbone.resnet.layer1.0.conv1.weight torch.Size([64, 64, 1, 1])
# backbone.resnet.layer1.0.bn1.weight torch.Size([64])
# backbone.resnet.layer1.0.bn1.bias torch.Size([64])
# backbone.resnet.layer1.0.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.0.bn2.weight torch.Size([64])
# backbone.resnet.layer1.0.bn2.bias torch.Size([64])
# backbone.resnet.layer1.0.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.0.bn3.weight torch.Size([256])
# backbone.resnet.layer1.0.bn3.bias torch.Size([256])
# backbone.resnet.layer1.0.downsample.0.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.0.downsample.1.weight torch.Size([256])
# backbone.resnet.layer1.0.downsample.1.bias torch.Size([256])
# backbone.resnet.layer1.1.conv1.weight torch.Size([64, 256, 1, 1])
# backbone.resnet.layer1.1.bn1.weight torch.Size([64])
# backbone.resnet.layer1.1.bn1.bias torch.Size([64])
# backbone.resnet.layer1.1.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.1.bn2.weight torch.Size([64])
# backbone.resnet.layer1.1.bn2.bias torch.Size([64])
# backbone.resnet.layer1.1.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.1.bn3.weight torch.Size([256])
# backbone.resnet.layer1.1.bn3.bias torch.Size([256])
# backbone.resnet.layer1.2.conv1.weight torch.Size([64, 256, 1, 1])
# backbone.resnet.layer1.2.bn1.weight torch.Size([64])
# backbone.resnet.layer1.2.bn1.bias torch.Size([64])
# backbone.resnet.layer1.2.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.2.bn2.weight torch.Size([64])
# backbone.resnet.layer1.2.bn2.bias torch.Size([64])
# backbone.resnet.layer1.2.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.2.bn3.weight torch.Size([256])
# backbone.resnet.layer1.2.bn3.bias torch.Size([256])
# backbone.resnet.layer2.0.conv1.weight torch.Size([128, 256, 1, 1])
# backbone.resnet.layer2.0.bn1.weight torch.Size([128])
# backbone.resnet.layer2.0.bn1.bias torch.Size([128])
# backbone.resnet.layer2.0.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.0.bn2.weight torch.Size([128])
# backbone.resnet.layer2.0.bn2.bias torch.Size([128])
# backbone.resnet.layer2.0.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.0.bn3.weight torch.Size([512])
# backbone.resnet.layer2.0.bn3.bias torch.Size([512])
# backbone.resnet.layer2.0.downsample.0.weight torch.Size([512, 256, 1, 1])
# backbone.resnet.layer2.0.downsample.1.weight torch.Size([512])
# backbone.resnet.layer2.0.downsample.1.bias torch.Size([512])
# backbone.resnet.layer2.1.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.1.bn1.weight torch.Size([128])
# backbone.resnet.layer2.1.bn1.bias torch.Size([128])
# backbone.resnet.layer2.1.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.1.bn2.weight torch.Size([128])
# backbone.resnet.layer2.1.bn2.bias torch.Size([128])
# backbone.resnet.layer2.1.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.1.bn3.weight torch.Size([512])
# backbone.resnet.layer2.1.bn3.bias torch.Size([512])
# backbone.resnet.layer2.2.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.2.bn1.weight torch.Size([128])
# backbone.resnet.layer2.2.bn1.bias torch.Size([128])
# backbone.resnet.layer2.2.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.2.bn2.weight torch.Size([128])
# backbone.resnet.layer2.2.bn2.bias torch.Size([128])
# backbone.resnet.layer2.2.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.2.bn3.weight torch.Size([512])
# backbone.resnet.layer2.2.bn3.bias torch.Size([512])
# backbone.resnet.layer2.3.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.3.bn1.weight torch.Size([128])
# backbone.resnet.layer2.3.bn1.bias torch.Size([128])
# backbone.resnet.layer2.3.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.3.bn2.weight torch.Size([128])
# backbone.resnet.layer2.3.bn2.bias torch.Size([128])
# backbone.resnet.layer2.3.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.3.bn3.weight torch.Size([512])
# backbone.resnet.layer2.3.bn3.bias torch.Size([512])
# backbone.resnet.layer3.0.conv1.weight torch.Size([256, 512, 1, 1])
# backbone.resnet.layer3.0.bn1.weight torch.Size([256])
# backbone.resnet.layer3.0.bn1.bias torch.Size([256])
# backbone.resnet.layer3.0.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.0.bn2.weight torch.Size([256])
# backbone.resnet.layer3.0.bn2.bias torch.Size([256])
# backbone.resnet.layer3.0.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.0.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.0.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.0.downsample.0.weight torch.Size([1024, 512, 1, 1])
# backbone.resnet.layer3.0.downsample.1.weight torch.Size([1024])
# backbone.resnet.layer3.0.downsample.1.bias torch.Size([1024])
# backbone.resnet.layer3.1.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.1.bn1.weight torch.Size([256])
# backbone.resnet.layer3.1.bn1.bias torch.Size([256])
# backbone.resnet.layer3.1.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.1.bn2.weight torch.Size([256])
# backbone.resnet.layer3.1.bn2.bias torch.Size([256])
# backbone.resnet.layer3.1.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.1.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.1.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.2.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.2.bn1.weight torch.Size([256])
# backbone.resnet.layer3.2.bn1.bias torch.Size([256])
# backbone.resnet.layer3.2.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.2.bn2.weight torch.Size([256])
# backbone.resnet.layer3.2.bn2.bias torch.Size([256])
# backbone.resnet.layer3.2.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.2.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.2.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.3.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.3.bn1.weight torch.Size([256])
# backbone.resnet.layer3.3.bn1.bias torch.Size([256])
# backbone.resnet.layer3.3.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.3.bn2.weight torch.Size([256])
# backbone.resnet.layer3.3.bn2.bias torch.Size([256])
# backbone.resnet.layer3.3.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.3.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.3.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.4.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.4.bn1.weight torch.Size([256])
# backbone.resnet.layer3.4.bn1.bias torch.Size([256])
# backbone.resnet.layer3.4.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.4.bn2.weight torch.Size([256])
# backbone.resnet.layer3.4.bn2.bias torch.Size([256])
# backbone.resnet.layer3.4.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.4.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.4.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.5.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.5.bn1.weight torch.Size([256])
# backbone.resnet.layer3.5.bn1.bias torch.Size([256])
# backbone.resnet.layer3.5.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.5.bn2.weight torch.Size([256])
# backbone.resnet.layer3.5.bn2.bias torch.Size([256])
# backbone.resnet.layer3.5.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.5.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.5.bn3.bias torch.Size([1024])
# backbone.resnet.layer4.0.conv1.weight torch.Size([512, 1024, 1, 1])
# backbone.resnet.layer4.0.bn1.weight torch.Size([512])
# backbone.resnet.layer4.0.bn1.bias torch.Size([512])
# backbone.resnet.layer4.0.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.0.bn2.weight torch.Size([512])
# backbone.resnet.layer4.0.bn2.bias torch.Size([512])
# backbone.resnet.layer4.0.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.0.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.0.bn3.bias torch.Size([2048])
# backbone.resnet.layer4.0.downsample.0.weight torch.Size([2048, 1024, 1, 1])
# backbone.resnet.layer4.0.downsample.1.weight torch.Size([2048])
# backbone.resnet.layer4.0.downsample.1.bias torch.Size([2048])
# backbone.resnet.layer4.1.conv1.weight torch.Size([512, 2048, 1, 1])
# backbone.resnet.layer4.1.bn1.weight torch.Size([512])
# backbone.resnet.layer4.1.bn1.bias torch.Size([512])
# backbone.resnet.layer4.1.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.1.bn2.weight torch.Size([512])
# backbone.resnet.layer4.1.bn2.bias torch.Size([512])
# backbone.resnet.layer4.1.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.1.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.1.bn3.bias torch.Size([2048])
# backbone.resnet.layer4.2.conv1.weight torch.Size([512, 2048, 1, 1])
# backbone.resnet.layer4.2.bn1.weight torch.Size([512])
# backbone.resnet.layer4.2.bn1.bias torch.Size([512])
# backbone.resnet.layer4.2.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.2.bn2.weight torch.Size([512])
# backbone.resnet.layer4.2.bn2.bias torch.Size([512])
# backbone.resnet.layer4.2.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.2.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.2.bn3.bias torch.Size([2048])
# nn.global_context.context.squeeze.0.weight torch.Size([128, 2048, 1, 1])
# nn.global_context.context.squeeze.0.bias torch.Size([128])
# nn.global_context.context.context5_1.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_1.0.bias torch.Size([128])
# nn.global_context.context.context5_2.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_2.0.bias torch.Size([128])
# nn.global_context.context.context5_3.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_3.0.bias torch.Size([128])
# nn.global_context.context.context5_4.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_4.0.bias torch.Size([128])
# nn.global_context.context.squeeze2.0.weight torch.Size([64, 128, 1, 1])
# nn.global_context.context.squeeze2.0.bias torch.Size([64])
# nn.global_regressor.regressor.fc1_trans.0.weight torch.Size([4096, 6400])
# nn.global_regressor.regressor.fc1_trans.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc2_trans.0.weight torch.Size([4096, 4096])
# nn.global_regressor.regressor.fc2_trans.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc3_trans.0.weight torch.Size([128, 4096])
# nn.global_regressor.regressor.fc3_trans.0.bias torch.Size([128])
# nn.global_regressor.regressor.logits_t.weight torch.Size([3, 128])
# nn.global_regressor.regressor.logits_t.bias torch.Size([3])
# nn.global_regressor.regressor.fc1_rot.0.weight torch.Size([4096, 6400])
# nn.global_regressor.regressor.fc1_rot.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc2_rot.0.weight torch.Size([4096, 4096])
# nn.global_regressor.regressor.fc2_rot.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc3_rot.0.weight torch.Size([128, 4096])
# nn.global_regressor.regressor.fc3_rot.0.bias torch.Size([128])
# nn.global_regressor.regressor.logits_r.weight torch.Size([4, 128])
# nn.global_regressor.regressor.logits_r.bias torch.Size([4])
# gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gp.mean_module.constant torch.Size([1, 1])
# gp.covar_module.raw_outputscale torch.Size([1])
# gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# likelihood.raw_noise torch.Size([1])
# likelihood.noise_covar.raw_noise torch.Size([3])
# Parameters layer: 356
# Model(
#   (backbone): Backbone(
#     (resnet): ResNet(
#       (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(4, 4), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (nn): NN(
#     (global_context): vggnet(
#       (context): Context(
#         (squeeze): Sequential(
#           (0): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU()
#         )
#         (context5_1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU()
#         )
#         (context5_2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU()
#         )
#         (context5_3): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU()
#         )
#         (context5_4): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU()
#         )
#         (squeeze2): Sequential(
#           (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU()
#         )
#       )
#     )
#     (global_regressor): vggnet(
#       (regressor): Regressor(
#         (flatten): Flatten()
#         (fc1_trans): Sequential(
#           (0): Linear(in_features=6400, out_features=4096, bias=True)
#           (1): ReLU()
#         )
#         (fc2_trans): Sequential(
#           (0): Linear(in_features=4096, out_features=4096, bias=True)
#           (1): ReLU()
#         )
#         (fc3_trans): Sequential(
#           (0): Linear(in_features=4096, out_features=128, bias=True)
#           (1): ReLU()
#         )
#         (logits_t): Linear(in_features=128, out_features=3, bias=True)
#         (fc1_rot): Sequential(
#           (0): Linear(in_features=6400, out_features=4096, bias=True)
#           (1): ReLU()
#         )
#         (fc2_rot): Sequential(
#           (0): Linear(in_features=4096, out_features=4096, bias=True)
#           (1): ReLU()
#         )
#         (fc3_rot): Sequential(
#           (0): Linear(in_features=4096, out_features=128, bias=True)
#           (1): ReLU()
#         )
#         (logits_r): Linear(in_features=128, out_features=4, bias=True)
#       )
#     )
#   )
#   (gp): GP(
#     (variational_strategy): IndependentMultitaskVariationalStrategy(
#       (base_variational_strategy): VariationalStrategy(
#         (_variational_distribution): CholeskyVariationalDistribution()
#       )
#     )
#     (mean_module): ConstantMean()
#     (covar_module): ScaleKernel(
#       (base_kernel): RBFKernel(
#         (raw_lengthscale_constraint): Positive()
#       )
#       (raw_outputscale_constraint): Positive()
#     )
#   )
#   (likelihood): MultitaskGaussianLikelihood(
#     (noise_covar): MultitaskHomoskedasticNoise(
#       (raw_noise_constraint): GreaterThan(1.000E-04)
#     )
#     (raw_noise_constraint): GreaterThan(1.000E-04)
#   )
# )

# %%
for param in global_trainer.model.parameters():
    param.requires_grad = False

# %% [markdown]
# # Define Model

# %%
class Backbone(nn.Module):
    def __init__(self):
        super().__init__()
        self.resnet = resnet.resnet50(pretrained=True)
    def forward(self,input_data):
        dense_feat = self.resnet(input_data)
        return dense_feat
    
class NN(nn.Module):
    def __init__(self):
        super().__init__()
        self.global_context = vggnet.vggnet(input_channel=2048,opt="context")
        self.global_regressor = vggnet.vggnet(opt="regressor")
        
    def forward(self,input_data):
        context_feat = self.global_context(input_data)
        output,feature_t, feature_r = self.global_regressor(context_feat)
        return output, feature_t, feature_r

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([output_dim]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([output_dim])),
            batch_shape=torch.Size([output_dim]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class GPNode(nn.Module):
    def __init__(self,inducing_points):
        super().__init__()
        output_dim = inducing_points.shape[0]
        feat_dim = inducing_points.shape[-1]
        assert output_dim == args.output_dim
        assert feat_dim == args.feat_dim
        
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=output_dim) 
        
    def forward(self,input_data):
        output = self.gp(input_data)
        return output
    
class Model(nn.Module):
    def __init__(self,num_grid):
        super().__init__()
        self.backbone = Backbone()
        self.nn = NN()
        self.gps = nn.ModuleList()
        
        self.num_gp = num_grid
        
        for i in range(self.num_gp):
            inducing_points = torch.zeros(args.output_dim, args.batch_size, args.feat_dim)
            gp = GPNode(inducing_points)
            self.gps.append(gp)
        
    def forward_nn(self, input_data):
        dense_feat = self.backbone(input_data)
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention            
        return feature_t, rot_pred
    
    def forward_gp(self,gp,trans_feat):
        trans_pred = gp(trans_feat)
        return trans_pred

# %%
class Trainer:
    def __init__(self,grid,is_training=True,regressor_context_rate = [0.0,0.0]):
        self.model = Model(grid.num_grid).cuda()
        self.norm_mean = args.norm_mean.cuda()
        self.norm_std = args.norm_std.cuda()
        
        # disable learning backbone
        for param in self.model.backbone.parameters():
            param.requires_grad = False
        
        if is_training:
            # training tool
            self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
            self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                             lr_lambda=lambda epoch: args.decay_rate**epoch)
        else:
            # disable all learning
            for param in self.model.parameters():
                param.requires_grad = False
        
    def load_model(self, file_name = 'pretrained.pth'):
        # load file info
        state_dict = torch.load(os.path.join(args.model_dir, file_name))
        if 'net.resnet.conv1.weight' in state_dict:
            print('Transform from old model.')
            # Part 1: backbone
            backbone_state_dict = self._from_old_model(state_dict,'backbone')
            print('Backbone parameters layer:',len(backbone_state_dict.keys()))
            self.model.backbone.load_state_dict(backbone_state_dict,strict = True)
            # Part 2: nn
            nn_state_dict = self._from_old_model(torch.load(os.path.join(args.model_dir, file_name)),'nn')
            print('NN parameters layer:',len(nn_state_dict.keys()))
            self.model.nn.load_state_dict(nn_state_dict,strict = True)
        else:
            print('Parameters layer:',len(state_dict.keys()))
            # load file to model
            self.model.load_state_dict(state_dict,strict = True)
        print('Model Structure:')
        # Display model structure
        for name, param in self.model.named_parameters():
            print(name, param.shape)
        print('Parameters layer:',len(self.model.state_dict().keys()))
    
    def _from_old_model(self, state_dict, select = 'backbone'):
        if select == 'backbone':
            for key in list(state_dict):
                if 'net.resnet.' in key:
                    state_dict[key.replace('net.resnet.','resnet.')] = state_dict.pop(key)
                else:
                    state_dict.pop(key)
        elif select == 'nn':
            for key in list(state_dict):
                if 'net.global_regressor.' in key:
                    state_dict[key.replace('net.global_regressor.','global_regressor.')] = state_dict.pop(key)
                elif 'net.global_context.' in key:
                    state_dict[key.replace('net.global_context.','global_context.')] = state_dict.pop(key)
                else:
                    state_dict.pop(key)
        return state_dict
    
    def save_model(self, file_name = 'model-{}-{}.pth'):
        checkpoint_path = os.path.join(args.model_dir, file_name)
        torch.save(self.model.state_dict(),checkpoint_path)
        print('Saving model to ' +  file_name)
        
    def _optimize(self,regressor_context_rate = [0.0,0.0]):
        optimizer = [
                {'params': self.model.gps.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay}]
            
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            for param in self.model.nn.global_regressor.parameters():
                param.requires_grad = False
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
        else:
            for param in self.model.nn.global_context.parameters():
                param.requires_grad = False
                
        return optimizer
            
    def train(self,x,y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        #labels = torch.from_numpy(pairwise_distances_argmin(y[:,:2].numpy(), mbk_means_cluster_centers)).cuda()
        label = np.zeros([y.shape[0],4])
        for i in range(y.shape[0]):
            label[i] = np.array(grid.in_grids(*y[i,:2]))
        
        x,y = x.cuda(),y.cuda()
        
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std) # input should be 7 dim       
            
        # Step 2: training
        assert self.model.training == True
        
        trans_loss = torch.tensor(0.).cuda()
        
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        trans_feat, rot_pred = self.model.forward_nn(x)
        rot_loss = self._nn_loss(rot_pred,rot_target)
        
        gps_loss = np.zeros(self.model.num_gp)
        for i,gp in enumerate(self.model.gps):
            num_data = dis[i]
            if num_data > 0:
                label_mask = np.sum(label == i,axis=1) >= 1
                sub_x = trans_feat[label_mask]
                sub_y = trans_target[label_mask] # unnormalized data 
                if sub_y.shape[0]>0:
                    gp_loss = self._gp_loss(gp,num_data,sub_x,sub_y)
                    gps_loss[i] = float(gp_loss)
                    trans_loss += gp_loss #* int(sub_y.shape[0])/args.batch_size
        trans_loss = trans_loss/self.model.num_gp
        total_loss = trans_loss + args.lamda_weights * rot_loss
        
        #Step 3: update
        total_loss.backward()
        self.optimizer.step()
        
        batch_time = time.time() - start
        return float(total_loss), batch_time, gps_loss
    
    def _nn_loss(self,rot_pred,rot_target):
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        return rot_loss
        
    def _gp_loss(self,gp,num_data,trans_feat,trans_target):
        # predict
        trans_pred = self.model.forward_gp(gp,trans_feat)
        mll = gpytorch.mlls.PredictiveLogLikelihood(gp.likelihood, gp.gp, num_data = num_data)
        
        # trans loss
        trans_loss = -1.*mll(trans_pred, trans_target)
        
        return trans_loss
    
    def _eval_gp(self, gp, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = gp.likelihood(trans_pred).mean, gp.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var
    
    def _sample(self, mean, var, num_sample = 100):
        dist = Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples

    def eval_forward(self,x,y,num_sample = 100,output_denormalize = True,label_from_gp = True):
        # Step 1: get data
        x,y = x.cuda(),y.cuda()
        
        if not label_from_gp:
            #labels = pairwise_distances_argmin(y[:,:2].cpu().numpy(), mbk_means_cluster_centers)
            
            labels = np.zeros([y.shape[0],4])
            for i in range(y.shape[0]):
                labels[i] = np.array(grid.in_grids(*y[i,:2].cpu().numpy()))
        else:
            global_trans_pred,_ = global_trainer.model(x)
            global_trans_pred, _, _ = global_trainer._eval_gp(global_trans_pred)
            global_trans_pred = denormalize_navie(global_trans_pred, global_trainer.norm_mean, global_trainer.norm_std)
            
            #labels = pairwise_distances_argmin(global_trans_pred[:,:2].cpu().numpy(), mbk_means_cluster_centers)
            labels = np.zeros([y.shape[0],4])
            for i in range(y.shape[0]):
                labels[i] = np.array(grid.in_grids(*global_trans_pred[i,:2].cpu().numpy()))
        
        labels = labels[:,0] 
        
        #if args.is_normalization:
        #    y = normalize(y,self.norm_mean, self.norm_std)
        
        # Step 2: forward
        assert self.model.training == False
        trans_feat, rot_pred = self.model.forward_nn(x)
        
        trans_pred = torch.zeros(y.shape[0],args.output_dim).cuda()
        trans_mean = torch.zeros(y.shape[0],args.output_dim).cuda()
        trans_var = torch.zeros(y.shape[0],args.output_dim).cuda()

        for i,gp in enumerate(trainer.model.gps):
            label_mask = labels == i
            #label_mask = np.sum(labels == i,axis=1) >= 1
            sub_x = trans_feat[label_mask]
            if sub_x.shape[0]>0:
                sub_trans_pred = self.model.forward_gp(gp,sub_x)
                sub_trans_pred, sub_trans_mean, sub_trans_var = self._eval_gp(gp, sub_trans_pred)
                if args.is_normalization and output_denormalize:
                    trans_pred[label_mask] = denormalize_navie(sub_trans_pred,self.norm_mean,self.norm_std)
                    trans_mean[label_mask] = denormalize_navie(sub_trans_mean,self.norm_mean,self.norm_std)
                    trans_var[label_mask] = sub_trans_var.mul(self.norm_std)
                else:
                    trans_pred[label_mask] = sub_trans_pred
                    trans_mean[label_mask] = sub_trans_mean
                    trans_var[label_mask] = sub_trans_var
        
        #if args.is_normalization and output_denormalize:
        #    y = denormalize(y, self.norm_mean, self.norm_std)
        
        samples = self._sample(trans_mean, trans_var, num_sample)
        
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_pred, rot_pred, trans_target, rot_target, samples

trainer = Trainer(grid,is_training=False)
#trainer = Trainer(grid,regressor_context_rate = [0.1,0.])

trainer.load_model('pretrained.pth')
#trainer.load_model('model-3-1500.pth')
#trainer.load_model('model-2-1000.pth')
# Out:
# Parameters layer: 666
# Model Structure:
# backbone.resnet.conv1.weight torch.Size([64, 1, 7, 7])
# backbone.resnet.bn1.weight torch.Size([64])
# backbone.resnet.bn1.bias torch.Size([64])
# backbone.resnet.layer1.0.conv1.weight torch.Size([64, 64, 1, 1])
# backbone.resnet.layer1.0.bn1.weight torch.Size([64])
# backbone.resnet.layer1.0.bn1.bias torch.Size([64])
# backbone.resnet.layer1.0.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.0.bn2.weight torch.Size([64])
# backbone.resnet.layer1.0.bn2.bias torch.Size([64])
# backbone.resnet.layer1.0.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.0.bn3.weight torch.Size([256])
# backbone.resnet.layer1.0.bn3.bias torch.Size([256])
# backbone.resnet.layer1.0.downsample.0.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.0.downsample.1.weight torch.Size([256])
# backbone.resnet.layer1.0.downsample.1.bias torch.Size([256])
# backbone.resnet.layer1.1.conv1.weight torch.Size([64, 256, 1, 1])
# backbone.resnet.layer1.1.bn1.weight torch.Size([64])
# backbone.resnet.layer1.1.bn1.bias torch.Size([64])
# backbone.resnet.layer1.1.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.1.bn2.weight torch.Size([64])
# backbone.resnet.layer1.1.bn2.bias torch.Size([64])
# backbone.resnet.layer1.1.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.1.bn3.weight torch.Size([256])
# backbone.resnet.layer1.1.bn3.bias torch.Size([256])
# backbone.resnet.layer1.2.conv1.weight torch.Size([64, 256, 1, 1])
# backbone.resnet.layer1.2.bn1.weight torch.Size([64])
# backbone.resnet.layer1.2.bn1.bias torch.Size([64])
# backbone.resnet.layer1.2.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.2.bn2.weight torch.Size([64])
# backbone.resnet.layer1.2.bn2.bias torch.Size([64])
# backbone.resnet.layer1.2.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.2.bn3.weight torch.Size([256])
# backbone.resnet.layer1.2.bn3.bias torch.Size([256])
# backbone.resnet.layer2.0.conv1.weight torch.Size([128, 256, 1, 1])
# backbone.resnet.layer2.0.bn1.weight torch.Size([128])
# backbone.resnet.layer2.0.bn1.bias torch.Size([128])
# backbone.resnet.layer2.0.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.0.bn2.weight torch.Size([128])
# backbone.resnet.layer2.0.bn2.bias torch.Size([128])
# backbone.resnet.layer2.0.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.0.bn3.weight torch.Size([512])
# backbone.resnet.layer2.0.bn3.bias torch.Size([512])
# backbone.resnet.layer2.0.downsample.0.weight torch.Size([512, 256, 1, 1])
# backbone.resnet.layer2.0.downsample.1.weight torch.Size([512])
# backbone.resnet.layer2.0.downsample.1.bias torch.Size([512])
# backbone.resnet.layer2.1.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.1.bn1.weight torch.Size([128])
# backbone.resnet.layer2.1.bn1.bias torch.Size([128])
# backbone.resnet.layer2.1.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.1.bn2.weight torch.Size([128])
# backbone.resnet.layer2.1.bn2.bias torch.Size([128])
# backbone.resnet.layer2.1.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.1.bn3.weight torch.Size([512])
# backbone.resnet.layer2.1.bn3.bias torch.Size([512])
# backbone.resnet.layer2.2.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.2.bn1.weight torch.Size([128])
# backbone.resnet.layer2.2.bn1.bias torch.Size([128])
# backbone.resnet.layer2.2.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.2.bn2.weight torch.Size([128])
# backbone.resnet.layer2.2.bn2.bias torch.Size([128])
# backbone.resnet.layer2.2.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.2.bn3.weight torch.Size([512])
# backbone.resnet.layer2.2.bn3.bias torch.Size([512])
# backbone.resnet.layer2.3.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.3.bn1.weight torch.Size([128])
# backbone.resnet.layer2.3.bn1.bias torch.Size([128])
# backbone.resnet.layer2.3.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.3.bn2.weight torch.Size([128])
# backbone.resnet.layer2.3.bn2.bias torch.Size([128])
# backbone.resnet.layer2.3.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.3.bn3.weight torch.Size([512])
# backbone.resnet.layer2.3.bn3.bias torch.Size([512])
# backbone.resnet.layer3.0.conv1.weight torch.Size([256, 512, 1, 1])
# backbone.resnet.layer3.0.bn1.weight torch.Size([256])
# backbone.resnet.layer3.0.bn1.bias torch.Size([256])
# backbone.resnet.layer3.0.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.0.bn2.weight torch.Size([256])
# backbone.resnet.layer3.0.bn2.bias torch.Size([256])
# backbone.resnet.layer3.0.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.0.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.0.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.0.downsample.0.weight torch.Size([1024, 512, 1, 1])
# backbone.resnet.layer3.0.downsample.1.weight torch.Size([1024])
# backbone.resnet.layer3.0.downsample.1.bias torch.Size([1024])
# backbone.resnet.layer3.1.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.1.bn1.weight torch.Size([256])
# backbone.resnet.layer3.1.bn1.bias torch.Size([256])
# backbone.resnet.layer3.1.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.1.bn2.weight torch.Size([256])
# backbone.resnet.layer3.1.bn2.bias torch.Size([256])
# backbone.resnet.layer3.1.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.1.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.1.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.2.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.2.bn1.weight torch.Size([256])
# backbone.resnet.layer3.2.bn1.bias torch.Size([256])
# backbone.resnet.layer3.2.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.2.bn2.weight torch.Size([256])
# backbone.resnet.layer3.2.bn2.bias torch.Size([256])
# backbone.resnet.layer3.2.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.2.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.2.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.3.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.3.bn1.weight torch.Size([256])
# backbone.resnet.layer3.3.bn1.bias torch.Size([256])
# backbone.resnet.layer3.3.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.3.bn2.weight torch.Size([256])
# backbone.resnet.layer3.3.bn2.bias torch.Size([256])
# backbone.resnet.layer3.3.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.3.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.3.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.4.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.4.bn1.weight torch.Size([256])
# backbone.resnet.layer3.4.bn1.bias torch.Size([256])
# backbone.resnet.layer3.4.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.4.bn2.weight torch.Size([256])
# backbone.resnet.layer3.4.bn2.bias torch.Size([256])
# backbone.resnet.layer3.4.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.4.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.4.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.5.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.5.bn1.weight torch.Size([256])
# backbone.resnet.layer3.5.bn1.bias torch.Size([256])
# backbone.resnet.layer3.5.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.5.bn2.weight torch.Size([256])
# backbone.resnet.layer3.5.bn2.bias torch.Size([256])
# backbone.resnet.layer3.5.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.5.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.5.bn3.bias torch.Size([1024])
# backbone.resnet.layer4.0.conv1.weight torch.Size([512, 1024, 1, 1])
# backbone.resnet.layer4.0.bn1.weight torch.Size([512])
# backbone.resnet.layer4.0.bn1.bias torch.Size([512])
# backbone.resnet.layer4.0.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.0.bn2.weight torch.Size([512])
# backbone.resnet.layer4.0.bn2.bias torch.Size([512])
# backbone.resnet.layer4.0.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.0.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.0.bn3.bias torch.Size([2048])
# backbone.resnet.layer4.0.downsample.0.weight torch.Size([2048, 1024, 1, 1])
# backbone.resnet.layer4.0.downsample.1.weight torch.Size([2048])
# backbone.resnet.layer4.0.downsample.1.bias torch.Size([2048])
# backbone.resnet.layer4.1.conv1.weight torch.Size([512, 2048, 1, 1])
# backbone.resnet.layer4.1.bn1.weight torch.Size([512])
# backbone.resnet.layer4.1.bn1.bias torch.Size([512])
# backbone.resnet.layer4.1.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.1.bn2.weight torch.Size([512])
# backbone.resnet.layer4.1.bn2.bias torch.Size([512])
# backbone.resnet.layer4.1.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.1.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.1.bn3.bias torch.Size([2048])
# backbone.resnet.layer4.2.conv1.weight torch.Size([512, 2048, 1, 1])
# backbone.resnet.layer4.2.bn1.weight torch.Size([512])
# backbone.resnet.layer4.2.bn1.bias torch.Size([512])
# backbone.resnet.layer4.2.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.2.bn2.weight torch.Size([512])
# backbone.resnet.layer4.2.bn2.bias torch.Size([512])
# backbone.resnet.layer4.2.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.2.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.2.bn3.bias torch.Size([2048])
# nn.global_context.context.squeeze.0.weight torch.Size([128, 2048, 1, 1])
# nn.global_context.context.squeeze.0.bias torch.Size([128])
# nn.global_context.context.context5_1.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_1.0.bias torch.Size([128])
# nn.global_context.context.context5_2.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_2.0.bias torch.Size([128])
# nn.global_context.context.context5_3.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_3.0.bias torch.Size([128])
# nn.global_context.context.context5_4.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_4.0.bias torch.Size([128])
# nn.global_context.context.squeeze2.0.weight torch.Size([64, 128, 1, 1])
# nn.global_context.context.squeeze2.0.bias torch.Size([64])
# nn.global_regressor.regressor.fc1_trans.0.weight torch.Size([4096, 6400])
# nn.global_regressor.regressor.fc1_trans.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc2_trans.0.weight torch.Size([4096, 4096])
# nn.global_regressor.regressor.fc2_trans.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc3_trans.0.weight torch.Size([128, 4096])
# nn.global_regressor.regressor.fc3_trans.0.bias torch.Size([128])
# nn.global_regressor.regressor.logits_t.weight torch.Size([3, 128])
# nn.global_regressor.regressor.logits_t.bias torch.Size([3])
# nn.global_regressor.regressor.fc1_rot.0.weight torch.Size([4096, 6400])
# nn.global_regressor.regressor.fc1_rot.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc2_rot.0.weight torch.Size([4096, 4096])
# nn.global_regressor.regressor.fc2_rot.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc3_rot.0.weight torch.Size([128, 4096])
# nn.global_regressor.regressor.fc3_rot.0.bias torch.Size([128])
# nn.global_regressor.regressor.logits_r.weight torch.Size([4, 128])
# nn.global_regressor.regressor.logits_r.bias torch.Size([4])
# gps.0.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.0.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.0.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.0.gp.mean_module.constant torch.Size([3, 1])
# gps.0.gp.covar_module.raw_outputscale torch.Size([3])
# gps.0.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.0.likelihood.raw_noise torch.Size([1])
# gps.0.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.1.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.1.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.1.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.1.gp.mean_module.constant torch.Size([3, 1])
# gps.1.gp.covar_module.raw_outputscale torch.Size([3])
# gps.1.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.1.likelihood.raw_noise torch.Size([1])
# gps.1.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.2.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.2.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.2.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.2.gp.mean_module.constant torch.Size([3, 1])
# gps.2.gp.covar_module.raw_outputscale torch.Size([3])
# gps.2.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.2.likelihood.raw_noise torch.Size([1])
# gps.2.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.3.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.3.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.3.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.3.gp.mean_module.constant torch.Size([3, 1])
# gps.3.gp.covar_module.raw_outputscale torch.Size([3])
# gps.3.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.3.likelihood.raw_noise torch.Size([1])
# gps.3.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.4.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.4.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.4.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.4.gp.mean_module.constant torch.Size([3, 1])
# gps.4.gp.covar_module.raw_outputscale torch.Size([3])
# gps.4.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.4.likelihood.raw_noise torch.Size([1])
# gps.4.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.5.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.5.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.5.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.5.gp.mean_module.constant torch.Size([3, 1])
# gps.5.gp.covar_module.raw_outputscale torch.Size([3])
# gps.5.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.5.likelihood.raw_noise torch.Size([1])
# gps.5.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.6.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.6.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.6.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.6.gp.mean_module.constant torch.Size([3, 1])
# gps.6.gp.covar_module.raw_outputscale torch.Size([3])
# gps.6.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.6.likelihood.raw_noise torch.Size([1])
# gps.6.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.7.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.7.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.7.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.7.gp.mean_module.constant torch.Size([3, 1])
# gps.7.gp.covar_module.raw_outputscale torch.Size([3])
# gps.7.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.7.likelihood.raw_noise torch.Size([1])
# gps.7.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.8.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.8.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.8.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.8.gp.mean_module.constant torch.Size([3, 1])
# gps.8.gp.covar_module.raw_outputscale torch.Size([3])
# gps.8.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.8.likelihood.raw_noise torch.Size([1])
# gps.8.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.9.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.9.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.9.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.9.gp.mean_module.constant torch.Size([3, 1])
# gps.9.gp.covar_module.raw_outputscale torch.Size([3])
# gps.9.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.9.likelihood.raw_noise torch.Size([1])
# gps.9.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.10.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.10.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.10.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.10.gp.mean_module.constant torch.Size([3, 1])
# gps.10.gp.covar_module.raw_outputscale torch.Size([3])
# gps.10.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.10.likelihood.raw_noise torch.Size([1])
# gps.10.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.11.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.11.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.11.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.11.gp.mean_module.constant torch.Size([3, 1])
# gps.11.gp.covar_module.raw_outputscale torch.Size([3])
# gps.11.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.11.likelihood.raw_noise torch.Size([1])
# gps.11.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.12.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.12.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.12.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.12.gp.mean_module.constant torch.Size([3, 1])
# gps.12.gp.covar_module.raw_outputscale torch.Size([3])
# gps.12.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.12.likelihood.raw_noise torch.Size([1])
# gps.12.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.13.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.13.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.13.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.13.gp.mean_module.constant torch.Size([3, 1])
# gps.13.gp.covar_module.raw_outputscale torch.Size([3])
# gps.13.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.13.likelihood.raw_noise torch.Size([1])
# gps.13.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.14.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.14.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.14.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.14.gp.mean_module.constant torch.Size([3, 1])
# gps.14.gp.covar_module.raw_outputscale torch.Size([3])
# gps.14.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.14.likelihood.raw_noise torch.Size([1])
# gps.14.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.15.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.15.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.15.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.15.gp.mean_module.constant torch.Size([3, 1])
# gps.15.gp.covar_module.raw_outputscale torch.Size([3])
# gps.15.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.15.likelihood.raw_noise torch.Size([1])
# gps.15.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.16.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.16.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.16.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.16.gp.mean_module.constant torch.Size([3, 1])
# gps.16.gp.covar_module.raw_outputscale torch.Size([3])
# gps.16.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.16.likelihood.raw_noise torch.Size([1])
# gps.16.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.17.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.17.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.17.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.17.gp.mean_module.constant torch.Size([3, 1])
# gps.17.gp.covar_module.raw_outputscale torch.Size([3])
# gps.17.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.17.likelihood.raw_noise torch.Size([1])
# gps.17.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.18.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.18.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.18.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.18.gp.mean_module.constant torch.Size([3, 1])
# gps.18.gp.covar_module.raw_outputscale torch.Size([3])
# gps.18.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.18.likelihood.raw_noise torch.Size([1])
# gps.18.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.19.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.19.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.19.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.19.gp.mean_module.constant torch.Size([3, 1])
# gps.19.gp.covar_module.raw_outputscale torch.Size([3])
# gps.19.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.19.likelihood.raw_noise torch.Size([1])
# gps.19.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.20.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.20.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.20.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.20.gp.mean_module.constant torch.Size([3, 1])
# gps.20.gp.covar_module.raw_outputscale torch.Size([3])
# gps.20.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.20.likelihood.raw_noise torch.Size([1])
# gps.20.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.21.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.21.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.21.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.21.gp.mean_module.constant torch.Size([3, 1])
# gps.21.gp.covar_module.raw_outputscale torch.Size([3])
# gps.21.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.21.likelihood.raw_noise torch.Size([1])
# gps.21.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.22.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.22.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.22.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.22.gp.mean_module.constant torch.Size([3, 1])
# gps.22.gp.covar_module.raw_outputscale torch.Size([3])
# gps.22.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.22.likelihood.raw_noise torch.Size([1])
# gps.22.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.23.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.23.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.23.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.23.gp.mean_module.constant torch.Size([3, 1])
# gps.23.gp.covar_module.raw_outputscale torch.Size([3])
# gps.23.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.23.likelihood.raw_noise torch.Size([1])
# gps.23.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.24.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.24.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.24.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.24.gp.mean_module.constant torch.Size([3, 1])
# gps.24.gp.covar_module.raw_outputscale torch.Size([3])
# gps.24.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.24.likelihood.raw_noise torch.Size([1])
# gps.24.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.25.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.25.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.25.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.25.gp.mean_module.constant torch.Size([3, 1])
# gps.25.gp.covar_module.raw_outputscale torch.Size([3])
# gps.25.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.25.likelihood.raw_noise torch.Size([1])
# gps.25.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.26.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.26.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.26.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.26.gp.mean_module.constant torch.Size([3, 1])
# gps.26.gp.covar_module.raw_outputscale torch.Size([3])
# gps.26.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.26.likelihood.raw_noise torch.Size([1])
# gps.26.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.27.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.27.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.27.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.27.gp.mean_module.constant torch.Size([3, 1])
# gps.27.gp.covar_module.raw_outputscale torch.Size([3])
# gps.27.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.27.likelihood.raw_noise torch.Size([1])
# gps.27.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.28.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.28.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.28.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.28.gp.mean_module.constant torch.Size([3, 1])
# gps.28.gp.covar_module.raw_outputscale torch.Size([3])
# gps.28.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.28.likelihood.raw_noise torch.Size([1])
# gps.28.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.29.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.29.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.29.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.29.gp.mean_module.constant torch.Size([3, 1])
# gps.29.gp.covar_module.raw_outputscale torch.Size([3])
# gps.29.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.29.likelihood.raw_noise torch.Size([1])
# gps.29.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.30.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.30.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.30.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.30.gp.mean_module.constant torch.Size([3, 1])
# gps.30.gp.covar_module.raw_outputscale torch.Size([3])
# gps.30.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.30.likelihood.raw_noise torch.Size([1])
# gps.30.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.31.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gps.31.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.31.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.31.gp.mean_module.constant torch.Size([3, 1])
# gps.31.gp.covar_module.raw_outputscale torch.Size([3])
# gps.31.gp.covar_module.base_kernel.raw_lengthscale torch.Size([3, 1, 1])
# gps.31.likelihood.raw_noise torch.Size([1])
# gps.31.likelihood.noise_covar.raw_noise torch.Size([3])
# Parameters layer: 666

# %%
for param in trainer.model.parameters():
    param.requires_grad = False

# %% [markdown]
# # Initialize

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

# %%
trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward(x,y,label_from_gp = True)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 300/92100, translation error = 9.004, rotation error = 6.642, time/batch = 1.509
# 600/92100, translation error = 9.017, rotation error = 6.634, time/batch = 1.484
# 900/92100, translation error = 9.015, rotation error = 6.623, time/batch = 1.466
# 1200/92100, translation error = 8.997, rotation error = 6.613, time/batch = 1.458
# 1500/92100, translation error = 8.978, rotation error = 6.605, time/batch = 1.454
# 1800/92100, translation error = 8.956, rotation error = 6.595, time/batch = 1.456
# 2100/92100, translation error = 8.939, rotation error = 6.588, time/batch = 1.464
# 2400/92100, translation error = 8.916, rotation error = 6.576, time/batch = 1.460
# 2700/92100, translation error = 8.898, rotation error = 6.570, time/batch = 1.465
# 3000/92100, translation error = 8.879, rotation error = 6.562, time/batch = 1.458
# 3300/92100, translation error = 8.856, rotation error = 6.549, time/batch = 1.468
# 3600/92100, translation error = 8.839, rotation error = 6.540, time/batch = 1.465
# 3900/92100, translation error = 8.816, rotation error = 6.530, time/batch = 1.466
# 4200/92100, translation error = 8.791, rotation error = 6.517, time/batch = 1.468
# 4500/92100, translation error = 8.768, rotation error = 6.506, time/batch = 1.470
# 4800/92100, translation error = 8.744, rotation error = 6.496, time/batch = 1.468
# 5100/92100, translation error = 8.723, rotation error = 6.488, time/batch = 1.466
# 5400/92100, translation error = 8.703, rotation error = 6.477, time/batch = 1.470
# 5700/92100, translation error = 8.681, rotation error = 6.464, time/batch = 1.472
# 6000/92100, translation error = 8.663, rotation error = 6.455, time/batch = 1.469
# 6300/92100, translation error = 8.642, rotation error = 6.441, time/batch = 1.470
# 6600/92100, translation error = 8.626, rotation error = 6.433, time/batch = 1.463
# 6900/92100, translation error = 8.767, rotation error = 6.464, time/batch = 1.493
# 7200/92100, translation error = 8.752, rotation error = 6.464, time/batch = 1.477
# 7500/92100, translation error = 8.729, rotation error = 6.460, time/batch = 1.469
# 7800/92100, translation error = 8.725, rotation error = 6.458, time/batch = 1.481
# 8100/92100, translation error = 8.718, rotation error = 6.449, time/batch = 1.482
# 8400/92100, translation error = 8.751, rotation error = 6.451, time/batch = 1.474
# 8700/92100, translation error = 8.732, rotation error = 6.443, time/batch = 1.477
# 9000/92100, translation error = 8.712, rotation error = 6.434, time/batch = 1.480
# 9300/92100, translation error = 8.695, rotation error = 6.426, time/batch = 1.472
# 9600/92100, translation error = 8.679, rotation error = 6.413, time/batch = 1.478
# 9900/92100, translation error = 8.660, rotation error = 6.405, time/batch = 1.481
# 10200/92100, translation error = 8.643, rotation error = 6.398, time/batch = 1.481
# 10500/92100, translation error = 8.623, rotation error = 6.400, time/batch = 1.478
# 10800/92100, translation error = 8.603, rotation error = 6.393, time/batch = 1.481
# 11100/92100, translation error = 8.586, rotation error = 6.384, time/batch = 1.479
# 11400/92100, translation error = 8.566, rotation error = 6.372, time/batch = 1.483
# 11700/92100, translation error = 8.545, rotation error = 6.360, time/batch = 1.487
# 12000/92100, translation error = 8.524, rotation error = 6.350, time/batch = 1.474
# 12300/92100, translation error = 8.502, rotation error = 6.338, time/batch = 1.471
# 12600/92100, translation error = 8.483, rotation error = 6.329, time/batch = 1.496
# 12900/92100, translation error = 8.466, rotation error = 6.326, time/batch = 1.474
# 13200/92100, translation error = 8.447, rotation error = 6.316, time/batch = 1.479
# 13500/92100, translation error = 8.441, rotation error = 6.311, time/batch = 1.490
# 13800/92100, translation error = 8.423, rotation error = 6.301, time/batch = 1.477
# 14100/92100, translation error = 8.406, rotation error = 6.293, time/batch = 1.487
# 14400/92100, translation error = 8.392, rotation error = 6.290, time/batch = 1.475
# 14700/92100, translation error = 8.374, rotation error = 6.279, time/batch = 1.491
# 15000/92100, translation error = 8.359, rotation error = 6.272, time/batch = 1.488
# 15300/92100, translation error = 8.344, rotation error = 6.262, time/batch = 1.487
# 15600/92100, translation error = 8.333, rotation error = 6.264, time/batch = 1.489
# 15900/92100, translation error = 8.467, rotation error = 6.277, time/batch = 1.505
# 16200/92100, translation error = 8.452, rotation error = 6.273, time/batch = 1.486
# 16500/92100, translation error = 8.435, rotation error = 6.264, time/batch = 1.491
# 16800/92100, translation error = 8.418, rotation error = 6.264, time/batch = 1.482
# 17100/92100, translation error = 8.401, rotation error = 6.258, time/batch = 1.476
# 17400/92100, translation error = 8.383, rotation error = 6.249, time/batch = 1.480
# 17700/92100, translation error = 8.364, rotation error = 6.241, time/batch = 1.480
# 18000/92100, translation error = 8.350, rotation error = 6.240, time/batch = 1.484
# 18300/92100, translation error = 8.333, rotation error = 6.237, time/batch = 1.490
# 18600/92100, translation error = 8.317, rotation error = 6.230, time/batch = 1.487
# 18900/92100, translation error = 8.299, rotation error = 6.225, time/batch = 1.488
# 19200/92100, translation error = 8.282, rotation error = 6.215, time/batch = 1.483
# 19500/92100, translation error = 8.269, rotation error = 6.208, time/batch = 1.486
# 19800/92100, translation error = 8.253, rotation error = 6.203, time/batch = 1.490
# 20100/92100, translation error = 8.237, rotation error = 6.197, time/batch = 1.491
# 20400/92100, translation error = 8.218, rotation error = 6.187, time/batch = 1.481
# 20700/92100, translation error = 8.201, rotation error = 6.180, time/batch = 1.483
# 21000/92100, translation error = 8.184, rotation error = 6.174, time/batch = 1.493
# 21300/92100, translation error = 8.165, rotation error = 6.169, time/batch = 1.477
# 21600/92100, translation error = 8.167, rotation error = 6.163, time/batch = 1.502
# 21900/92100, translation error = 8.547, rotation error = 6.224, time/batch = 1.532
# 22200/92100, translation error = 9.206, rotation error = 6.393, time/batch = 1.554
# 22500/92100, translation error = 9.234, rotation error = 6.384, time/batch = 1.493
# 22800/92100, translation error = 9.219, rotation error = 6.376, time/batch = 1.484
# 23100/92100, translation error = 9.206, rotation error = 6.374, time/batch = 1.489
# 23400/92100, translation error = 9.189, rotation error = 6.366, time/batch = 1.493
# 23700/92100, translation error = 9.170, rotation error = 6.360, time/batch = 1.486
# 24000/92100, translation error = 9.152, rotation error = 6.356, time/batch = 1.491
# 24300/92100, translation error = 9.145, rotation error = 6.355, time/batch = 1.491
# 24600/92100, translation error = 9.129, rotation error = 6.354, time/batch = 1.491
# 24900/92100, translation error = 9.117, rotation error = 6.351, time/batch = 1.490
# 25200/92100, translation error = 9.099, rotation error = 6.344, time/batch = 1.494
# 25500/92100, translation error = 9.080, rotation error = 6.338, time/batch = 1.495
# 25800/92100, translation error = 9.061, rotation error = 6.333, time/batch = 1.478
# 26100/92100, translation error = 9.043, rotation error = 6.328, time/batch = 1.482
# 26400/92100, translation error = 9.024, rotation error = 6.321, time/batch = 1.496
# 26700/92100, translation error = 9.006, rotation error = 6.313, time/batch = 1.482
# 27000/92100, translation error = 9.004, rotation error = 6.309, time/batch = 1.507
# 27300/92100, translation error = 8.988, rotation error = 6.299, time/batch = 1.483
# 27600/92100, translation error = 8.973, rotation error = 6.289, time/batch = 1.490
# 27900/92100, translation error = 8.956, rotation error = 6.280, time/batch = 1.479
# 28200/92100, translation error = 8.939, rotation error = 6.271, time/batch = 1.481
# 28500/92100, translation error = 8.925, rotation error = 6.266, time/batch = 1.494
# 28800/92100, translation error = 8.913, rotation error = 6.258, time/batch = 1.496
# 29100/92100, translation error = 8.910, rotation error = 6.277, time/batch = 1.498
# 29400/92100, translation error = 8.931, rotation error = 6.280, time/batch = 1.495
# 29700/92100, translation error = 8.914, rotation error = 6.269, time/batch = 1.485
# 30000/92100, translation error = 8.904, rotation error = 6.263, time/batch = 1.487
# 30300/92100, translation error = 8.891, rotation error = 6.257, time/batch = 1.492
# 30600/92100, translation error = 8.876, rotation error = 6.251, time/batch = 1.498
# 30900/92100, translation error = 8.859, rotation error = 6.246, time/batch = 1.490
# 31200/92100, translation error = 8.843, rotation error = 6.245, time/batch = 1.485
# 31500/92100, translation error = 8.827, rotation error = 6.238, time/batch = 1.488
# 31800/92100, translation error = 8.811, rotation error = 6.229, time/batch = 1.491
# 32100/92100, translation error = 8.796, rotation error = 6.222, time/batch = 1.485
# 32400/92100, translation error = 8.780, rotation error = 6.218, time/batch = 1.499
# 32700/92100, translation error = 8.763, rotation error = 6.212, time/batch = 1.492
# 33000/92100, translation error = 8.745, rotation error = 6.205, time/batch = 1.477
# 33300/92100, translation error = 8.731, rotation error = 6.198, time/batch = 1.501
# 33600/92100, translation error = 8.717, rotation error = 6.192, time/batch = 1.488
# 33900/92100, translation error = 8.705, rotation error = 6.186, time/batch = 1.494
# 34200/92100, translation error = 8.776, rotation error = 6.200, time/batch = 1.517
# 34500/92100, translation error = 9.080, rotation error = 6.251, time/batch = 1.538
# 34800/92100, translation error = 9.067, rotation error = 6.241, time/batch = 1.494
# 35100/92100, translation error = 9.052, rotation error = 6.237, time/batch = 1.489
# 35400/92100, translation error = 9.334, rotation error = 6.285, time/batch = 1.534
# 35700/92100, translation error = 9.402, rotation error = 6.285, time/batch = 1.501
# 36000/92100, translation error = 9.389, rotation error = 6.278, time/batch = 1.490
# 36300/92100, translation error = 9.379, rotation error = 6.278, time/batch = 1.493
# 36600/92100, translation error = 9.365, rotation error = 6.273, time/batch = 1.491
# 36900/92100, translation error = 9.348, rotation error = 6.268, time/batch = 1.488
# 37200/92100, translation error = 9.332, rotation error = 6.262, time/batch = 1.489
# 37500/92100, translation error = 9.314, rotation error = 6.255, time/batch = 1.479
# 37800/92100, translation error = 9.297, rotation error = 6.249, time/batch = 1.481
# 38100/92100, translation error = 9.281, rotation error = 6.248, time/batch = 1.498
# 38400/92100, translation error = 9.264, rotation error = 6.243, time/batch = 1.493
# 38700/92100, translation error = 9.246, rotation error = 6.238, time/batch = 1.488
# 39000/92100, translation error = 9.231, rotation error = 6.233, time/batch = 1.484
# 39300/92100, translation error = 9.216, rotation error = 6.227, time/batch = 1.492
# 39600/92100, translation error = 9.201, rotation error = 6.226, time/batch = 1.496
# 39900/92100, translation error = 9.188, rotation error = 6.222, time/batch = 1.492
# 40200/92100, translation error = 9.170, rotation error = 6.216, time/batch = 1.489
# 40500/92100, translation error = 9.155, rotation error = 6.210, time/batch = 1.490
# 40800/92100, translation error = 9.137, rotation error = 6.205, time/batch = 1.498
# 41100/92100, translation error = 9.121, rotation error = 6.203, time/batch = 1.493
# 41400/92100, translation error = 9.106, rotation error = 6.199, time/batch = 1.494
# 41700/92100, translation error = 9.089, rotation error = 6.195, time/batch = 1.484
# 42000/92100, translation error = 9.074, rotation error = 6.192, time/batch = 1.481
# 42300/92100, translation error = 9.083, rotation error = 6.190, time/batch = 1.504
# 42600/92100, translation error = 9.072, rotation error = 6.181, time/batch = 1.494
# 42900/92100, translation error = 9.058, rotation error = 6.172, time/batch = 1.487
# 43200/92100, translation error = 9.042, rotation error = 6.165, time/batch = 1.489
# 43500/92100, translation error = 9.032, rotation error = 6.158, time/batch = 1.479
# 43800/92100, translation error = 9.037, rotation error = 6.164, time/batch = 1.513
# 44100/92100, translation error = 9.024, rotation error = 6.159, time/batch = 1.493
# 44400/92100, translation error = 9.023, rotation error = 6.163, time/batch = 1.514
# 44700/92100, translation error = 9.010, rotation error = 6.159, time/batch = 1.496
# 45000/92100, translation error = 8.996, rotation error = 6.154, time/batch = 1.483
# 45300/92100, translation error = 8.982, rotation error = 6.152, time/batch = 1.487
# 45600/92100, translation error = 8.971, rotation error = 6.150, time/batch = 1.494
# 45900/92100, translation error = 8.955, rotation error = 6.144, time/batch = 1.493
# 46200/92100, translation error = 8.942, rotation error = 6.143, time/batch = 1.490
# 46500/92100, translation error = 8.931, rotation error = 6.138, time/batch = 1.489
# 46800/92100, translation error = 8.918, rotation error = 6.132, time/batch = 1.488
# 47100/92100, translation error = 8.906, rotation error = 6.128, time/batch = 1.491
# 47400/92100, translation error = 8.900, rotation error = 6.121, time/batch = 1.502
# 47700/92100, translation error = 8.885, rotation error = 6.115, time/batch = 1.505
# 48000/92100, translation error = 8.869, rotation error = 6.112, time/batch = 1.490
# 48300/92100, translation error = 8.855, rotation error = 6.107, time/batch = 1.496
# 48600/92100, translation error = 8.842, rotation error = 6.101, time/batch = 1.498
# 48900/92100, translation error = 8.829, rotation error = 6.093, time/batch = 1.495
# 49200/92100, translation error = 8.816, rotation error = 6.086, time/batch = 1.496
# 49500/92100, translation error = 8.802, rotation error = 6.082, time/batch = 1.508
# 49800/92100, translation error = 8.788, rotation error = 6.075, time/batch = 1.490
# 50100/92100, translation error = 8.780, rotation error = 6.071, time/batch = 1.495
# 50400/92100, translation error = 8.767, rotation error = 6.064, time/batch = 1.495
# 50700/92100, translation error = 8.967, rotation error = 6.108, time/batch = 1.526
# 51000/92100, translation error = 9.111, rotation error = 6.121, time/batch = 1.529
# 51300/92100, translation error = 9.097, rotation error = 6.116, time/batch = 1.492
# 51600/92100, translation error = 9.083, rotation error = 6.110, time/batch = 1.490
# 51900/92100, translation error = 9.068, rotation error = 6.110, time/batch = 1.495
# 52200/92100, translation error = 9.059, rotation error = 6.109, time/batch = 1.489
# 52500/92100, translation error = 9.045, rotation error = 6.105, time/batch = 1.496
# 52800/92100, translation error = 9.031, rotation error = 6.097, time/batch = 1.496
# 53100/92100, translation error = 9.017, rotation error = 6.090, time/batch = 1.495
# 53400/92100, translation error = 9.005, rotation error = 6.097, time/batch = 1.506
# 53700/92100, translation error = 8.992, rotation error = 6.094, time/batch = 1.491
# 54000/92100, translation error = 8.977, rotation error = 6.091, time/batch = 1.529
# 54300/92100, translation error = 8.999, rotation error = 6.095, time/batch = 1.582
# 54600/92100, translation error = 8.988, rotation error = 6.091, time/batch = 1.490
# 54900/92100, translation error = 8.975, rotation error = 6.090, time/batch = 1.490
# 55200/92100, translation error = 8.960, rotation error = 6.084, time/batch = 1.487
# 55500/92100, translation error = 8.948, rotation error = 6.083, time/batch = 1.488
# 55800/92100, translation error = 9.029, rotation error = 6.085, time/batch = 1.525
# 56100/92100, translation error = 9.084, rotation error = 6.117, time/batch = 1.505
# 56400/92100, translation error = 9.108, rotation error = 6.124, time/batch = 1.495
# 56700/92100, translation error = 9.099, rotation error = 6.127, time/batch = 1.499
# 57000/92100, translation error = 9.089, rotation error = 6.123, time/batch = 1.504
# 57300/92100, translation error = 9.077, rotation error = 6.124, time/batch = 1.488
# 57600/92100, translation error = 9.394, rotation error = 6.135, time/batch = 1.548
# 57900/92100, translation error = 9.382, rotation error = 6.133, time/batch = 1.485
# 58200/92100, translation error = 9.370, rotation error = 6.132, time/batch = 1.493
# 58500/92100, translation error = 9.370, rotation error = 6.133, time/batch = 1.505
# 58800/92100, translation error = 9.356, rotation error = 6.126, time/batch = 1.501
# 59100/92100, translation error = 9.340, rotation error = 6.122, time/batch = 1.493
# 59400/92100, translation error = 9.326, rotation error = 6.120, time/batch = 1.594
# 59700/92100, translation error = 9.313, rotation error = 6.114, time/batch = 1.543
# 60000/92100, translation error = 9.298, rotation error = 6.110, time/batch = 1.498
# 60300/92100, translation error = 9.284, rotation error = 6.105, time/batch = 1.501
# 60600/92100, translation error = 9.272, rotation error = 6.102, time/batch = 1.494
# 60900/92100, translation error = 9.259, rotation error = 6.097, time/batch = 1.499
# 61200/92100, translation error = 9.250, rotation error = 6.094, time/batch = 1.501
# 61500/92100, translation error = 9.270, rotation error = 6.101, time/batch = 1.536
# 61800/92100, translation error = 9.374, rotation error = 6.153, time/batch = 1.544
# 62100/92100, translation error = 9.361, rotation error = 6.151, time/batch = 1.490
# 62400/92100, translation error = 9.349, rotation error = 6.147, time/batch = 1.489
# 62700/92100, translation error = 9.335, rotation error = 6.143, time/batch = 1.506
# 63000/92100, translation error = 9.322, rotation error = 6.140, time/batch = 1.489
# 63300/92100, translation error = 9.322, rotation error = 6.145, time/batch = 1.515
# 63600/92100, translation error = 9.308, rotation error = 6.141, time/batch = 1.496
# 63900/92100, translation error = 9.295, rotation error = 6.135, time/batch = 1.495
# 64200/92100, translation error = 9.480, rotation error = 6.189, time/batch = 1.533
# 64500/92100, translation error = 9.551, rotation error = 6.234, time/batch = 1.527
# 64800/92100, translation error = 9.538, rotation error = 6.231, time/batch = 1.481
# 65100/92100, translation error = 9.531, rotation error = 6.232, time/batch = 1.508
# 65400/92100, translation error = 9.517, rotation error = 6.225, time/batch = 1.542
# 65700/92100, translation error = 9.504, rotation error = 6.219, time/batch = 1.590
# 66000/92100, translation error = 9.496, rotation error = 6.224, time/batch = 1.516
# 66300/92100, translation error = 9.483, rotation error = 6.220, time/batch = 1.500
# 66600/92100, translation error = 9.470, rotation error = 6.215, time/batch = 1.487
# 66900/92100, translation error = 9.475, rotation error = 6.224, time/batch = 1.507
# 67200/92100, translation error = 9.466, rotation error = 6.222, time/batch = 1.500
# 67500/92100, translation error = 9.457, rotation error = 6.231, time/batch = 1.500
# 67800/92100, translation error = 9.443, rotation error = 6.225, time/batch = 1.497
# 68100/92100, translation error = 9.430, rotation error = 6.218, time/batch = 1.497
# 68400/92100, translation error = 9.417, rotation error = 6.219, time/batch = 1.501
# 68700/92100, translation error = 9.404, rotation error = 6.215, time/batch = 1.506
# 69000/92100, translation error = 9.393, rotation error = 6.213, time/batch = 1.503
# 69300/92100, translation error = 9.392, rotation error = 6.214, time/batch = 1.500
# 69600/92100, translation error = 9.390, rotation error = 6.213, time/batch = 1.500
# 69900/92100, translation error = 9.395, rotation error = 6.209, time/batch = 1.505
# 70200/92100, translation error = 9.383, rotation error = 6.204, time/batch = 1.496
# 70500/92100, translation error = 9.369, rotation error = 6.199, time/batch = 1.489
# 70800/92100, translation error = 9.355, rotation error = 6.194, time/batch = 1.544
# 71100/92100, translation error = 9.342, rotation error = 6.190, time/batch = 1.583
# 71400/92100, translation error = 9.328, rotation error = 6.185, time/batch = 1.519
# 71700/92100, translation error = 9.314, rotation error = 6.179, time/batch = 1.499
# 72000/92100, translation error = 9.302, rotation error = 6.174, time/batch = 1.503
# 72300/92100, translation error = 9.291, rotation error = 6.170, time/batch = 1.507
# 72600/92100, translation error = 9.277, rotation error = 6.164, time/batch = 1.489
# 72900/92100, translation error = 9.265, rotation error = 6.161, time/batch = 1.496
# 73200/92100, translation error = 9.253, rotation error = 6.159, time/batch = 1.494
# 73500/92100, translation error = 9.240, rotation error = 6.156, time/batch = 1.499
# 73800/92100, translation error = 9.240, rotation error = 6.155, time/batch = 1.517
# 74100/92100, translation error = 9.231, rotation error = 6.153, time/batch = 1.594
# 74400/92100, translation error = 9.248, rotation error = 6.163, time/batch = 1.567
# 74700/92100, translation error = 9.340, rotation error = 6.231, time/batch = 1.532
# 75000/92100, translation error = 9.329, rotation error = 6.228, time/batch = 1.497
# 75300/92100, translation error = 9.405, rotation error = 6.248, time/batch = 1.529
# 75600/92100, translation error = 9.412, rotation error = 6.253, time/batch = 1.513
# 75900/92100, translation error = 9.401, rotation error = 6.247, time/batch = 1.491
# 76200/92100, translation error = 9.390, rotation error = 6.244, time/batch = 1.516
# 76500/92100, translation error = 9.378, rotation error = 6.238, time/batch = 1.492
# 76800/92100, translation error = 9.377, rotation error = 6.236, time/batch = 1.528
# 77100/92100, translation error = 9.387, rotation error = 6.235, time/batch = 1.521
# 77400/92100, translation error = 9.446, rotation error = 6.253, time/batch = 1.546
# 77700/92100, translation error = 9.625, rotation error = 6.290, time/batch = 1.565
# 78000/92100, translation error = 9.693, rotation error = 6.329, time/batch = 1.521
# 78300/92100, translation error = 9.715, rotation error = 6.330, time/batch = 1.521
# 78600/92100, translation error = 9.727, rotation error = 6.339, time/batch = 1.496
# 78900/92100, translation error = 9.730, rotation error = 6.343, time/batch = 1.510
# 79200/92100, translation error = 9.831, rotation error = 6.430, time/batch = 1.612
# 79500/92100, translation error = 10.097, rotation error = 6.459, time/batch = 1.567
# 79800/92100, translation error = 10.084, rotation error = 6.463, time/batch = 1.491
# 80100/92100, translation error = 10.074, rotation error = 6.469, time/batch = 1.484
# 80400/92100, translation error = 10.061, rotation error = 6.465, time/batch = 1.495
# 80700/92100, translation error = 10.103, rotation error = 6.496, time/batch = 1.502
# 81000/92100, translation error = 10.092, rotation error = 6.493, time/batch = 1.496
# 81300/92100, translation error = 10.105, rotation error = 6.519, time/batch = 1.508
# 81600/92100, translation error = 10.127, rotation error = 6.529, time/batch = 1.510
# 81900/92100, translation error = 10.120, rotation error = 6.529, time/batch = 1.505
# 82200/92100, translation error = 10.111, rotation error = 6.527, time/batch = 1.493
# 82500/92100, translation error = 10.104, rotation error = 6.526, time/batch = 1.502
# 82800/92100, translation error = 10.105, rotation error = 6.533, time/batch = 1.504
# 83100/92100, translation error = 10.095, rotation error = 6.536, time/batch = 1.504
# 83400/92100, translation error = 10.094, rotation error = 6.536, time/batch = 1.543
# 83700/92100, translation error = 10.088, rotation error = 6.532, time/batch = 1.566
# 84000/92100, translation error = 10.098, rotation error = 6.535, time/batch = 1.515
# 84300/92100, translation error = 10.100, rotation error = 6.552, time/batch = 1.502
# 84600/92100, translation error = 10.088, rotation error = 6.548, time/batch = 1.490
# 84900/92100, translation error = 10.077, rotation error = 6.545, time/batch = 1.498
# 85200/92100, translation error = 10.065, rotation error = 6.540, time/batch = 1.525
# 85500/92100, translation error = 10.052, rotation error = 6.534, time/batch = 1.512
# 85800/92100, translation error = 10.040, rotation error = 6.529, time/batch = 1.503
# 86100/92100, translation error = 10.104, rotation error = 6.565, time/batch = 1.521
# 86400/92100, translation error = 10.093, rotation error = 6.561, time/batch = 1.494
# 86700/92100, translation error = 10.082, rotation error = 6.554, time/batch = 1.497
# 87000/92100, translation error = 10.070, rotation error = 6.548, time/batch = 1.499
# 87300/92100, translation error = 10.062, rotation error = 6.545, time/batch = 1.502
# 87600/92100, translation error = 10.081, rotation error = 6.556, time/batch = 1.619
# 87900/92100, translation error = 10.081, rotation error = 6.575, time/batch = 1.548
# 88200/92100, translation error = 10.128, rotation error = 6.610, time/batch = 1.504
# 88500/92100, translation error = 10.114, rotation error = 6.607, time/batch = 1.499
# 88800/92100, translation error = 10.159, rotation error = 6.608, time/batch = 1.527
# 89100/92100, translation error = 10.210, rotation error = 6.616, time/batch = 1.504
# 89400/92100, translation error = 10.198, rotation error = 6.617, time/batch = 1.503
# 89700/92100, translation error = 10.186, rotation error = 6.613, time/batch = 1.494
# 90000/92100, translation error = 10.217, rotation error = 6.616, time/batch = 1.521
# 90300/92100, translation error = 10.204, rotation error = 6.610, time/batch = 1.495
# 90600/92100, translation error = 10.195, rotation error = 6.608, time/batch = 1.501
# 90900/92100, translation error = 10.184, rotation error = 6.605, time/batch = 1.491
# 91200/92100, translation error = 10.177, rotation error = 6.620, time/batch = 1.590
# 91500/92100, translation error = 10.167, rotation error = 6.659, time/batch = 1.544
# 91800/92100, translation error = 10.154, rotation error = 6.654, time/batch = 1.499
# 92100/92100, translation error = 10.149, rotation error = 6.655, time/batch = 0.722

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.180
# median rotation error = 3.162
# mean translation error = 10.149
# mean rotation error = 6.655

# %%
def evaluate(trans_errors,rot_errors):
    t = [14301,7008,12852,9567,13580,14835,7114,12683]
    for i in range(len(t)):
        if i >0:
            t[i] += t[i-1]
    trans_errors_month = list()
    trans_errors_month.append(trans_errors[:t[0]])
    trans_errors_month.append(trans_errors[t[0]:t[1]])
    trans_errors_month.append(trans_errors[t[1]:t[2]])
    trans_errors_month.append(trans_errors[t[2]:t[3]])
    trans_errors_month.append(trans_errors[t[3]:t[4]])
    trans_errors_month.append(trans_errors[t[4]:t[5]])
    trans_errors_month.append(trans_errors[t[5]:t[6]])
    trans_errors_month.append(trans_errors[t[6]:])

    rot_errors_month = list()
    rot_errors_month.append(rot_errors[:t[0]])
    rot_errors_month.append(rot_errors[t[0]:t[1]])
    rot_errors_month.append(rot_errors[t[1]:t[2]])
    rot_errors_month.append(rot_errors[t[2]:t[3]])
    rot_errors_month.append(rot_errors[t[3]:t[4]])
    rot_errors_month.append(rot_errors[t[4]:t[5]])
    rot_errors_month.append(rot_errors[t[5]:t[6]])
    rot_errors_month.append(rot_errors[t[6]:])
    
    print('================== var translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("var translation error = {:.3f}".format(np.var(trans_errors_i)))
    
    print('================== median translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("median translation error = {:.3f}".format(np.median(trans_errors_i)))
        
    print('================== median rotation error ==================')
    for rot_errors_i in rot_errors_month:
        print("median rotation error = {:.3f}".format(np.median(rot_errors_i)))
    
    print('================== mean translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("mean translation error = {:.3f}".format(np.mean(trans_errors_i)))
        
    print('================== mean rotation error ==================')  
    for rot_errors_i in rot_errors_month:
        print("mean rotation error = {:.3f}".format(np.mean(rot_errors_i)))
        
evaluate(trans_errors,rot_errors)
# Out:
# ================== var translation error ==================
# var translation error = 257.094
# var translation error = 401.739
# var translation error = 996.768
# var translation error = 834.107
# var translation error = 940.275
# var translation error = 1156.460
# var translation error = 1411.537
# var translation error = 2108.744
# ================== median translation error ==================
# median translation error = 1.710
# median translation error = 1.780
# median translation error = 2.065
# median translation error = 2.044
# median translation error = 2.160
# median translation error = 2.203
# median translation error = 3.632
# median translation error = 2.270
# ================== median rotation error ==================
# median rotation error = 2.600
# median rotation error = 2.830
# median rotation error = 2.998
# median rotation error = 2.957
# median rotation error = 3.196
# median rotation error = 3.324
# median rotation error = 4.470
# median rotation error = 3.249
# ================== mean translation error ==================
# mean translation error = 4.105
# mean translation error = 4.585
# mean translation error = 9.743
# mean translation error = 8.892
# mean translation error = 7.723
# mean translation error = 8.834
# mean translation error = 19.380
# mean translation error = 11.387
# ================== mean rotation error ==================
# mean rotation error = 3.971
# mean rotation error = 4.282
# mean rotation error = 6.275
# mean rotation error = 5.986
# mean rotation error = 5.712
# mean rotation error = 6.647
# mean rotation error = 12.905
# mean rotation error = 6.986
