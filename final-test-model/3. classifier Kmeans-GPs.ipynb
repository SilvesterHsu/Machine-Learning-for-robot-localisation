# %% [markdown]
# # Library

# %%
import numpy as np
import torch
import gpytorch
import argparse
import time
import pickle
import scipy.io as sio

from torch.distributions import Normal
import matplotlib.pyplot as plt
import random

import roslib
import rospy
import tf as tf_ros
from nav_msgs.msg import Odometry, Path
from sensor_msgs.msg import Image
from cv_bridge import CvBridge
from geometry_msgs.msg import PoseStamped, PoseArray, Pose
import math
import cv2
import copy

import sys
sys.path.append('..')
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'

# %% [markdown]
# ## Check GPU

# %%
import torch
import numpy as np
import sys
sys.path.append('..')

from torchlib.utils import list_device,set_device

# S1: check GPU
#list_device()

# S2: default parameters
set_device(1)
np.set_printoptions(precision = 2)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, default=300, help='size of mini batch')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data normalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')
parser.add_argument('--output_dim', default=3, type=int, help='output dimention.')
parser.add_argument('--feat_dim', default=128, type=int, help='feature dimention.')
parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/kmeans_gps', help='rnn, gru, or lstm')

parser.add_argument('--test_dataset', type=str, default=[# '/notebooks/michigan_nn_data/2012_01_08',
                                                         # '/notebooks/michigan_nn_data/2012_01_15',
                                                         # '/notebooks/michigan_nn_data/2012_01_22',
                                                         # '/notebooks/michigan_nn_data/2012_02_02',
                                                         # '/notebooks/michigan_nn_data/2012_02_04',
                                                         # '/notebooks/michigan_nn_data/2012_02_05',
                                                         '/notebooks/michigan_nn_data/2012_02_12',
                                                         # '/notebooks/michigan_nn_data/2012_03_31',
                                                         '/notebooks/michigan_nn_data/2012_04_29',
                                                         '/notebooks/michigan_nn_data/2012_05_11',
                                                         '/notebooks/michigan_nn_data/2012_06_15',
                                                         '/notebooks/michigan_nn_data/2012_08_04',
                                                         # '/notebooks/michigan_nn_data/2012_09_28'])
                                                         '/notebooks/michigan_nn_data/2012_10_28',
                                                         '/notebooks/michigan_nn_data/2012_11_16',
                                                         '/notebooks/michigan_nn_data/2012_12_01'
                                                        ] )

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/test'])
parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

#parser.add_argument('--map_dataset', type=str, default='/home/kevin/data/michigan_gt/training')
parser.add_argument('--seed', default=1337, type=int)
parser.add_argument('--enable_ros', type=bool, default=False, help='put data into ros')
parser.add_argument('--num_gp', type=int, default=15, help='number of local gps')

sys.argv = ['']
args = parser.parse_args()

if args.enable_ros:
    rospy.init_node('global_localization_tf_broadcaster_cnn')

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
#from PIL import Image
import numpy as np
import random

#
import gpytorch

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet, cnn_auxiliary
from torchlib.cnn_auxiliary import normalize, denormalize, denormalize_navie, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

transform = transforms.Compose([transforms.ToTensor()])
dataset = LocalizationDataset(dataset_dirs = args.test_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform, get_pair = False, mode='evaluate', sampling_rate=2)


[args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
print('Load norm and std:',*args.norm_tensor)

    
dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=False, num_workers=0, \
                        drop_last=False, pin_memory=True)
# Out:
# 100%|██████████| 14301/14301 [00:18<00:00, 787.97it/s]
# 100%|██████████| 7008/7008 [00:09<00:00, 771.56it/s]
# 100%|██████████| 12852/12852 [00:16<00:00, 779.28it/s]
# 100%|██████████| 9567/9567 [00:12<00:00, 785.04it/s]
# 100%|██████████| 13580/13580 [00:17<00:00, 795.09it/s]
# 100%|██████████| 14835/14835 [00:18<00:00, 793.13it/s]
# 100%|██████████| 7114/7114 [00:09<00:00, 781.77it/s]
# 100%|██████████| 12683/12683 [00:16<00:00, 786.55it/s]
# Load norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # K-means

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import pairwise_distances_argmin

centers = np.load(os.path.join(args.model_dir,'k-means_gp15.npy'))

def draw(X,centers,seed):
    num_gp = centers.shape[0]
    np.random.seed(seed)
    r = lambda: np.random.randint(0,255)
    colors = ['#%02X%02X%02X' % (r(),r(),r()) for _ in range(num_gp)]
    
    labels = pairwise_distances_argmin(X, centers)
    
    fig = plt.figure(figsize=(6, 8))
    ax = fig.add_subplot(1, 1, 1)
    for i in range(num_gp):
        points_mask = labels == i
        center = centers[i]
        ax.plot(X[points_mask, 0], X[points_mask, 1], 'w',
                markerfacecolor=colors[i], marker='.')
        ax.plot(center[0], center[1], 'o', 
                markerfacecolor=colors[i], markeredgecolor='k', markersize=6)
        ax.annotate("(%s)" % i, xy=center, xytext=(-8, 8), textcoords='offset points')
    ax.set_title('MiniBatchKMeans')
    plt.show()
    
X = np.array(dataset.Targets)[:,:2]
draw(X,centers, args.seed)

# %% [markdown]
# # Define Model

# %%
from torchlib.model import Backbone, NN, GP#, GPNode_local
from gpytorch.models import ApproximateGP
from gpytorch.variational import CholeskyVariationalDistribution, VariationalStrategy
from gpytorch.likelihoods import BernoulliLikelihood

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([output_dim]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([output_dim])),
            batch_shape=torch.Size([output_dim]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class BasicTrainer:
    def __init__(self,norm_mean,norm_std):
        self.model = None
        self.norm_mean = args.norm_mean.cuda()
        self.norm_std = args.norm_std.cuda()
        
    def disable_requires_grad(self,model):
        for param in model.parameters():
            param.requires_grad = False
            
    def load_model(self, file_name = 'pretrained.pth', strict = True):
        # load file info
        state_dict = torch.load(os.path.join(args.model_dir, file_name))
        if 'net.resnet.conv1.weight' in state_dict:
            print('Transform from old model.')
            # Part 1: backbone
            backbone_state_dict = self._from_old_model(state_dict,'backbone')
            print('Backbone parameters layer:',len(backbone_state_dict.keys()))
            self.model.backbone.load_state_dict(backbone_state_dict,strict = True)
            # Part 2: nn
            nn_state_dict = self._from_old_model(torch.load(os.path.join(args.model_dir, file_name)),'nn')
            print('NN parameters layer:',len(nn_state_dict.keys()))
            self.model.nn.load_state_dict(nn_state_dict,strict = strict)
        else:
            print('Parameters layer:',len(state_dict.keys()))
            # load file to model
            self.model.load_state_dict(state_dict,strict = strict)
        # Display model structure
        #print('Model Structure:')
        #for name, param in self.model.named_parameters():
        #    print(name, param.shape)
        print('Successfully loaded model...')
        print('Parameters layer:',len(self.model.state_dict().keys()))
    
    def _from_old_model(self, state_dict, select = 'backbone'):
        if select == 'backbone':
            for key in list(state_dict):
                if 'net.resnet.' in key:
                    state_dict[key.replace('net.resnet.','resnet.')] = state_dict.pop(key)
                else:
                    state_dict.pop(key)
        elif select == 'nn':
            for key in list(state_dict):
                if 'net.global_regressor.' in key:
                    state_dict[key.replace('net.global_regressor.','global_regressor.')] = state_dict.pop(key)
                elif 'net.global_context.' in key:
                    state_dict[key.replace('net.global_context.','global_context.')] = state_dict.pop(key)
                else:
                    state_dict.pop(key)
        return state_dict
    
    def save_model(self, file_name = 'model-{}-{}.pth'):
        checkpoint_path = os.path.join(args.model_dir, file_name)
        torch.save(self.model.state_dict(),checkpoint_path)
        print('Saving model to ' +  file_name)
        
    def show_require_grad(self):
        for name, param in self.model.named_parameters():
            if param.requires_grad:
                print (name, param.shape)

class GPNode_local(nn.Module):
    def __init__(self,inducing_points):
        super(GPNode_local,self).__init__()
        output_dim = inducing_points.shape[0] # 3-dim
        feat_dim = inducing_points.shape[-1]
        
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=output_dim) 
        
    def forward(self,input_data):
        output = self.gp(input_data)
        return output

class GPNode_global(nn.Module):
    def __init__(self,inducing_points,num_gp,p):
        super(GPNode_global,self).__init__()
        
        self.layer = nn.Sequential(
                    nn.Linear(128,128),
                    nn.ReLU(True),
                    nn.Dropout(p = p),
                    nn.Linear(128,128),
        )
        self.gp = GP(inducing_points,num_gp)
        self.likelihood = gpytorch.likelihoods.SoftmaxLikelihood(num_features=num_gp, num_classes=num_gp)

    def forward(self,input_data):
        input_data = self.layer(input_data)
        output = self.gp(input_data)
        return output

class Model(nn.Module):
    def __init__(self,num_gp,p=0.4):
        super().__init__()
        self.num_gp = num_gp

        # Part 1: basic NN
        self.backbone = Backbone()
        self.nn = NN()
        # Part 2: global GP
        inducing_points = torch.zeros(self.num_gp, 300, args.feat_dim) # num_grid x 300 x 128
        self.global_gp = GPNode_global(inducing_points,self.num_gp,p)
        
        # Part 3: local GPs
        self.local_gps = nn.ModuleList()
        for i in range(self.num_gp):
            inducing_points = torch.zeros(args.output_dim, 300, args.feat_dim)
            gp = GPNode_local(inducing_points)
            self.local_gps.append(gp)
        
    def forward_nn(self, input_data):
        dense_feat = self.backbone(input_data)
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention  
        return feature_t, rot_pred
    '''
    def forward_gp(self, gp, trans_feat):
        trans_pred = gp(trans_feat)
        return trans_pred
    '''

# %%
class Trainer(BasicTrainer):
    def __init__(self, centers,norm_mean, norm_std,
                 regressor_context_rate = [0.0,0.0],
                 is_training=True, disable_rot_learning = True, 
                 train_global_gp = True, train_local_gps = True):
        
        super().__init__(norm_mean, norm_std)
        self.centers = centers
        self.model = Model(centers.shape[0]).cuda()
        self.disable_rot_learning = disable_rot_learning
        self.train_global_gp = train_global_gp
        self.train_local_gps = train_local_gps
        
        self.disable_requires_grad(self.model.backbone)
        
        if is_training:
            # training tool
            self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
            self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                             lr_lambda=lambda epoch: args.decay_rate**epoch)
            #self.scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer=self.optimizer, T_max = 80)
        else:
            self.disable_requires_grad(self.model)
            
    def _optimize(self,regressor_context_rate):
        optimizer = list()
        # Local GPs
        if self.train_local_gps:
            optimizer += [
                    {'params': self.model.local_gps.parameters(), \
                     'lr': args.learning_rate,'weight_decay':args.weight_decay}]            
        else:
            self.disable_requires_grad(self.model.local_gps)
            
        # Global GP
        if self.train_global_gp:
            optimizer += [{'params': self.model.global_gp.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay}]
        else:
            self.disable_requires_grad(self.model.global_gp)
            
        # NN
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            self.disable_requires_grad(self.model.nn.global_regressor)
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
        else:
            self.disable_requires_grad(self.model.nn.global_context)
            
        if self.disable_rot_learning and regressor_context_rate[1]!=0.0:
            print("Warning: Set 'disable_rot_learning' to False")
            self.disable_rot_learning = False
        
        if self.disable_rot_learning and regressor_context_rate[1]==0.0:
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc1_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc2_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc3_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.logits_r)
                
        return optimizer
    
    def train(self,x,y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        start = time.time()
        
        label = pairwise_distances_argmin(y[:,:2],self.centers)
        label = torch.from_numpy(label).cuda()
            
        x,y = x.cuda(),y.cuda()
        
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std) # input should be 7 dim
            
        # Step 2: training
        assert self.model.training == True
        
        trans_loss = torch.tensor(0.).cuda()
        global_gp_loss = torch.tensor(0.).cuda()
        local_gps_loss = np.zeros(self.model.num_gp)
        
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        trans_feat, rot_pred = self.model.forward_nn(x)
        
        # Step 2-0: rotation
        if not self.disable_rot_learning:
            rot_loss = self._nn_loss(rot_pred,rot_target)
        
        # Step 2-1: global GP classification
        if self.train_global_gp:
            gp = self.model.global_gp # gp + likelihood
            num_data = min(len(dataloader)*args.batch_size,len(dataset)) # !!! not safe
            global_gp_loss = self._gp_loss(gp,num_data,trans_feat,label)
        
        # Step 2-2: local GPs regression
        if self.train_local_gps:
            num_batch_data = 0
            for i,gp in enumerate(self.model.local_gps):
                num_data = dis[i]
                label_mask = label == i
                sub_x = trans_feat[label_mask]
                sub_y = trans_target[label_mask]
                gp_loss = self._gp_loss(gp,num_data,sub_x,sub_y)
                local_gps_loss[i] = float(gp_loss)
                trans_loss += gp_loss * int(sub_y.shape[0])
                num_batch_data += int(sub_y.shape[0])
            trans_loss = trans_loss/num_batch_data
        
        # Step 2-3: rotation 
        if not self.disable_rot_learning:
            if self.train_global_gp:
                total_loss = trans_loss + global_gp_loss + args.lamda_weights * rot_loss
            else:
                total_loss = trans_loss + args.lamda_weights * rot_loss
        else:
            if self.train_global_gp:
                total_loss = trans_loss + global_gp_loss
            else:
                total_loss = trans_loss
            
        #Step 3: update
        if self.train_global_gp or self.train_local_gps:
            total_loss.backward()
            self.optimizer.step()
        
        batch_time = time.time() - start
        return float(total_loss), float(global_gp_loss), local_gps_loss, batch_time
        
    def _nn_loss(self,rot_pred,rot_target):
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        return rot_loss
        
    def _gp_loss(self,gp,num_data,trans_feat,trans_target):
        trans_pred = gp(trans_feat)
        #mll = gpytorch.mlls.VariationalELBO(gp.likelihood, gp.gp, 
        #                                    num_data=num_data).cuda()
        mll = gpytorch.mlls.PredictiveLogLikelihood(gp.likelihood, gp.gp, 
                                            num_data=num_data).cuda()
        
        trans_loss = -1.*mll(trans_pred, trans_target)
        return trans_loss
    
    def _eval_gp(self, gp, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = gp.likelihood(trans_pred).mean, gp.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var
    
    def _sample(self, mean, var, num_sample = 100):
        dist = Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples
    
    def eval_classifier(self,x,y):
        label = pairwise_distances_argmin(y[:,:2],self.centers) # n x ,
        label = torch.from_numpy(label).cuda() # n x ,
        x = x.cuda()
        
        assert self.model.training == False
    
        trans_feat, rot_pred = self.model.forward_nn(x)
        with torch.no_grad(), gpytorch.settings.num_likelihood_samples(100):
            gp = self.model.global_gp # gp + likelihood
            output = gp(trans_feat)
            output = gp.likelihood(output)
            pred = output.probs.mean(0).argmax(-1)
        return pred, label
    
    def eval_classifier_top2(self,x,y):
        label = pairwise_distances_argmin(y[:,:2],self.centers) # n x ,
        label = torch.from_numpy(label).cuda() # n x ,
        x = x.cuda()
        
        assert self.model.training == False
    
        trans_feat, rot_pred = self.model.forward_nn(x)
        with torch.no_grad(), gpytorch.settings.num_likelihood_samples(100):
            gp = self.model.global_gp # gp + likelihood
            output = gp(trans_feat)
            output = gp.likelihood(output)
            pred_i = output.probs.mean(0)#.argmax(-1)
            pred_1 = pred_i.argsort(-1)[:,-3:][:,[2,1,0]][:,0]
            pred_2 = pred_i.argsort(-1)[:,-3:][:,[2,1,0]][:,1]
            prob_1 = pred_i[range(pred_i.shape[0]),pred_1]
            prob_2 = pred_i[range(pred_i.shape[0]),pred_2]
            
        return pred_1, prob_1, pred_2, prob_2
    
    def eval_forward(self,x,y,num_sample = 100, output_denormalize = True, label_from_gp = True):
        # Step 1: get data
        if not label_from_gp:
            label = pairwise_distances_argmin(y[:,:2],self.centers) # n x ,
        else:
            label,_ = self.eval_classifier(x.cpu(),y.cpu())
            
        x,y = x.cuda(),y.cuda()
        
        # Step 2: forward
        assert self.model.training == False
        trans_feat, rot_pred = self.model.forward_nn(x)
        
        trans_pred = torch.zeros(y.shape[0],args.output_dim).cuda()
        trans_mean = torch.zeros(y.shape[0],args.output_dim).cuda()
        trans_var = torch.zeros(y.shape[0],args.output_dim).cuda()
        
        for i,gp in enumerate(self.model.local_gps):
            label_mask = label == i
            sub_x = trans_feat[label_mask]
            sub_trans_pred = gp(sub_x)
            sub_trans_pred, sub_trans_mean, sub_trans_var = self._eval_gp(gp, sub_trans_pred)
            if args.is_normalization and output_denormalize:
                trans_pred[label_mask] = denormalize_navie(sub_trans_pred,self.norm_mean,self.norm_std)
                trans_mean[label_mask] = denormalize_navie(sub_trans_mean,self.norm_mean,self.norm_std)
                trans_var[label_mask] = sub_trans_var.mul(self.norm_std)
            else:
                trans_pred[label_mask] = sub_trans_pred
                trans_mean[label_mask] = sub_trans_mean
                trans_var[label_mask] = sub_trans_var
                    
        samples = self._sample(trans_mean, trans_var, num_sample)
        
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_pred, rot_pred, trans_target, rot_target, samples
    
    def eval_forward_top2(self,x,y,num_sample = 100, output_denormalize = True):
        # Step 1: get data
        label_1, prob_1, label_2, prob_2 = self.eval_classifier_top2(x.cpu(),y.cpu())
        threshold = 0.8
        prob_1[prob_1>threshold] = 1
        prob_1[prob_1<=1-threshold] = 0
        prob_2[prob_2>threshold] = 1
        prob_2[prob_2<=1-threshold] = 0    
        
        x,y = x.cuda(),y.cuda()
        
        # Step 2: forward
        assert self.model.training == False
        trans_feat, rot_pred = self.model.forward_nn(x)
        
        trans_pred = torch.zeros(y.shape[0],args.output_dim).cuda()
        trans_mean = torch.zeros(y.shape[0],args.output_dim).cuda()
        trans_var = torch.zeros(y.shape[0],args.output_dim).cuda()
        
        for i,gp in enumerate(self.model.local_gps):
            label_mask = label_1 == i
            sub_x = trans_feat[label_mask]
            prob_weight = prob_1[label_mask].reshape(-1,1)
            sub_trans_pred = gp(sub_x)
            sub_trans_pred, sub_trans_mean, sub_trans_var = self._eval_gp(gp, sub_trans_pred)
            if args.is_normalization:
                trans_pred[label_mask] += denormalize_navie(sub_trans_pred,self.norm_mean,self.norm_std) * prob_weight
                trans_mean[label_mask] += denormalize_navie(sub_trans_mean,self.norm_mean,self.norm_std) * prob_weight
                trans_var[label_mask] += sub_trans_var.mul(self.norm_std) * prob_weight
            else:
                trans_pred[label_mask] += sub_trans_pred * prob_weight
                trans_mean[label_mask] += sub_trans_mean * prob_weight
                trans_var[label_mask] += sub_trans_var * prob_weight
        
        for i,gp in enumerate(self.model.local_gps):
            label_mask = label_2 == i
            sub_x = trans_feat[label_mask]
            prob_weight = prob_2[label_mask].reshape(-1,1)
            sub_trans_pred = gp(sub_x)
            sub_trans_pred, sub_trans_mean, sub_trans_var = self._eval_gp(gp, sub_trans_pred)
            if args.is_normalization and output_denormalize:
                trans_pred[label_mask] += denormalize_navie(sub_trans_pred,self.norm_mean,self.norm_std) * prob_weight
                trans_mean[label_mask] += denormalize_navie(sub_trans_mean,self.norm_mean,self.norm_std) * prob_weight
                trans_var[label_mask] += sub_trans_var.mul(self.norm_std) * prob_weight
            else:
                trans_pred[label_mask] += sub_trans_pred * prob_weight
                trans_mean[label_mask] += sub_trans_mean * prob_weight
                trans_var[label_mask] += sub_trans_var * prob_weight
        
        total_weight = (prob_1 + prob_2).reshape(-1,1)
        trans_pred /= total_weight
        trans_mean /= total_weight
        trans_var /= total_weight
                    
        samples = self._sample(trans_mean, trans_var, num_sample)
        
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_pred, rot_pred, trans_target, rot_target, samples

trainer = Trainer(centers,args.norm_mean,args.norm_std,
                  is_training=False)

trainer.load_model('pretrained.pth')
trainer.show_require_grad()
# Out:
# Parameters layer: 509
# Successfully loaded model...
# Parameters layer: 509

# %% [markdown]
# # Classification

# %%
from torch.distributions import Normal
trainer.model.eval()

error_num = 0
total_num = 0
for b, data in enumerate(dataloader, 0):
    x,y = data.values()
    pred, target = trainer.eval_classifier(x,y)
    acc = float(torch.sum(pred - target == 0))/float(target.shape[0])
    error_num += float(torch.sum(pred - target != 0))
    total_num += float(target.shape[0])
    if error_num >0:
        break
        pass
    
    if b % 10 == 0:
        print("%.2f" % acc,'-',float(torch.sum(pred - target != 0)),'/',float(target.shape[0]))
        
print("ACC: %.2f" % (1-(error_num/total_num)))
print('Total error number:', error_num)
# Out:
# 1.00 - 0.0 / 300.0
# ACC: 0.99
# Total error number: 5.0

# %% [markdown]
# # `y` + local GP

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward(x,y,label_from_gp = False)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 300/92100, translation error = 2.723, rotation error = 2.763, time/batch = 5.110
# 600/92100, translation error = 6.593, rotation error = 3.388, time/batch = 1.616
# 900/92100, translation error = 7.297, rotation error = 3.357, time/batch = 1.609
# 1200/92100, translation error = 6.380, rotation error = 3.423, time/batch = 1.613
# 1500/92100, translation error = 5.749, rotation error = 3.531, time/batch = 1.607
# 1800/92100, translation error = 5.092, rotation error = 3.514, time/batch = 1.607
# 2100/92100, translation error = 4.883, rotation error = 3.635, time/batch = 1.613
# 2400/92100, translation error = 4.510, rotation error = 3.546, time/batch = 1.606
# 2700/92100, translation error = 4.317, rotation error = 3.670, time/batch = 1.611
# 3000/92100, translation error = 4.190, rotation error = 3.689, time/batch = 1.614
# 3300/92100, translation error = 3.954, rotation error = 3.575, time/batch = 1.613
# 3600/92100, translation error = 3.896, rotation error = 3.603, time/batch = 1.618
# 3900/92100, translation error = 3.699, rotation error = 3.565, time/batch = 1.616
# 4200/92100, translation error = 3.501, rotation error = 3.495, time/batch = 1.613
# 4500/92100, translation error = 3.343, rotation error = 3.460, time/batch = 1.615
# 4800/92100, translation error = 3.195, rotation error = 3.441, time/batch = 1.616
# 5100/92100, translation error = 3.141, rotation error = 3.486, time/batch = 1.611
# 5400/92100, translation error = 3.072, rotation error = 3.451, time/batch = 1.622
# 5700/92100, translation error = 3.000, rotation error = 3.391, time/batch = 1.615
# 6000/92100, translation error = 2.985, rotation error = 3.384, time/batch = 1.616
# 6300/92100, translation error = 2.938, rotation error = 3.320, time/batch = 1.622
# 6600/92100, translation error = 2.952, rotation error = 3.342, time/batch = 1.623
# 6900/92100, translation error = 5.212, rotation error = 3.911, time/batch = 1.626
# 7200/92100, translation error = 5.151, rotation error = 4.012, time/batch = 1.633
# 7500/92100, translation error = 4.999, rotation error = 4.068, time/batch = 1.622
# 7800/92100, translation error = 5.078, rotation error = 4.143, time/batch = 1.629
# 8100/92100, translation error = 5.127, rotation error = 4.114, time/batch = 1.620
# 8400/92100, translation error = 5.633, rotation error = 4.224, time/batch = 1.629
# 8700/92100, translation error = 5.516, rotation error = 4.208, time/batch = 1.626
# 9000/92100, translation error = 5.395, rotation error = 4.178, time/batch = 1.620
# 9300/92100, translation error = 5.319, rotation error = 4.162, time/batch = 1.635
# 9600/92100, translation error = 5.233, rotation error = 4.101, time/batch = 1.624
# 9900/92100, translation error = 5.145, rotation error = 4.080, time/batch = 1.630
# 10200/92100, translation error = 5.072, rotation error = 4.076, time/batch = 1.628
# 10500/92100, translation error = 4.978, rotation error = 4.167, time/batch = 1.621
# 10800/92100, translation error = 4.894, rotation error = 4.159, time/batch = 1.622
# 11100/92100, translation error = 4.827, rotation error = 4.144, time/batch = 1.621
# 11400/92100, translation error = 4.745, rotation error = 4.094, time/batch = 1.627
# 11700/92100, translation error = 4.654, rotation error = 4.047, time/batch = 1.626
# 12000/92100, translation error = 4.571, rotation error = 4.015, time/batch = 1.627
# 12300/92100, translation error = 4.485, rotation error = 3.975, time/batch = 1.635
# 12600/92100, translation error = 4.420, rotation error = 3.952, time/batch = 1.631
# 12900/92100, translation error = 4.365, rotation error = 3.979, time/batch = 1.628
# 13200/92100, translation error = 4.303, rotation error = 3.954, time/batch = 1.625
# 13500/92100, translation error = 4.328, rotation error = 3.964, time/batch = 1.650
# 13800/92100, translation error = 4.278, rotation error = 3.942, time/batch = 1.626
# 14100/92100, translation error = 4.234, rotation error = 3.934, time/batch = 1.629
# /home/seel/.local/lib/python3.6/site-packages/gpytorch/utils/cholesky.py:46: NumericalWarning: A not p.d., added jitter of 1.0e-04 to the diagonal
#   warnings.warn(f"A not p.d., added jitter of {jitter_new:.1e} to the diagonal", NumericalWarning)
# 14400/92100, translation error = 4.206, rotation error = 3.957, time/batch = 1.782
# 14700/92100, translation error = 4.160, rotation error = 3.926, time/batch = 1.626
# 15000/92100, translation error = 4.139, rotation error = 3.924, time/batch = 1.624
# 15300/92100, translation error = 4.113, rotation error = 3.901, time/batch = 1.626
# 15600/92100, translation error = 4.117, rotation error = 3.962, time/batch = 1.633
# 15900/92100, translation error = 5.116, rotation error = 4.097, time/batch = 1.632
# 16200/92100, translation error = 5.076, rotation error = 4.111, time/batch = 1.630
# 16500/92100, translation error = 5.025, rotation error = 4.088, time/batch = 1.629
# 16800/92100, translation error = 4.978, rotation error = 4.133, time/batch = 1.635
# 17100/92100, translation error = 4.928, rotation error = 4.131, time/batch = 1.631
# 17400/92100, translation error = 4.870, rotation error = 4.111, time/batch = 1.635
# 17700/92100, translation error = 4.814, rotation error = 4.096, time/batch = 1.622
# 18000/92100, translation error = 4.785, rotation error = 4.122, time/batch = 1.630
# 18300/92100, translation error = 4.747, rotation error = 4.136, time/batch = 1.627
# 18600/92100, translation error = 4.703, rotation error = 4.128, time/batch = 1.635
# 18900/92100, translation error = 4.653, rotation error = 4.134, time/batch = 1.626
# 19200/92100, translation error = 4.610, rotation error = 4.110, time/batch = 1.631
# 19500/92100, translation error = 4.590, rotation error = 4.102, time/batch = 1.639
# 19800/92100, translation error = 4.557, rotation error = 4.109, time/batch = 1.629
# 20100/92100, translation error = 4.520, rotation error = 4.103, time/batch = 1.633
# 20400/92100, translation error = 4.474, rotation error = 4.082, time/batch = 1.630
# 20700/92100, translation error = 4.432, rotation error = 4.074, time/batch = 1.629
# 21000/92100, translation error = 4.392, rotation error = 4.072, time/batch = 1.639
# 21300/92100, translation error = 4.349, rotation error = 4.076, time/batch = 1.628
# 21600/92100, translation error = 4.424, rotation error = 4.077, time/batch = 1.638
# 21900/92100, translation error = 6.513, rotation error = 4.419, time/batch = 1.640
# 22200/92100, translation error = 10.113, rotation error = 5.306, time/batch = 1.645
# 22500/92100, translation error = 10.245, rotation error = 5.278, time/batch = 1.628
# 22800/92100, translation error = 10.152, rotation error = 5.252, time/batch = 1.631
# 23100/92100, translation error = 10.075, rotation error = 5.254, time/batch = 1.632
# 23400/92100, translation error = 9.975, rotation error = 5.232, time/batch = 1.632
# 23700/92100, translation error = 9.872, rotation error = 5.216, time/batch = 1.631
# 24000/92100, translation error = 9.776, rotation error = 5.208, time/batch = 1.631
# 24300/92100, translation error = 9.734, rotation error = 5.220, time/batch = 1.638
# 24600/92100, translation error = 9.649, rotation error = 5.228, time/batch = 1.631
# 24900/92100, translation error = 9.586, rotation error = 5.224, time/batch = 1.638
# 25200/92100, translation error = 9.494, rotation error = 5.206, time/batch = 1.631
# 25500/92100, translation error = 9.404, rotation error = 5.188, time/batch = 1.637
# 25800/92100, translation error = 9.310, rotation error = 5.180, time/batch = 1.631
# 26100/92100, translation error = 9.230, rotation error = 5.172, time/batch = 1.631
# 26400/92100, translation error = 9.142, rotation error = 5.150, time/batch = 1.634
# 26700/92100, translation error = 9.059, rotation error = 5.129, time/batch = 1.635
# 27000/92100, translation error = 9.052, rotation error = 5.125, time/batch = 1.631
# 27300/92100, translation error = 8.978, rotation error = 5.093, time/batch = 1.643
# 27600/92100, translation error = 8.911, rotation error = 5.062, time/batch = 1.636
# 27900/92100, translation error = 8.838, rotation error = 5.036, time/batch = 1.628
# 28200/92100, translation error = 8.769, rotation error = 5.012, time/batch = 1.624
# 28500/92100, translation error = 8.712, rotation error = 5.004, time/batch = 1.631
# 28800/92100, translation error = 8.660, rotation error = 4.985, time/batch = 1.638
# 29100/92100, translation error = 8.654, rotation error = 5.078, time/batch = 1.633
# 29400/92100, translation error = 8.751, rotation error = 5.100, time/batch = 1.653
# 29700/92100, translation error = 8.684, rotation error = 5.068, time/batch = 1.632
# 30000/92100, translation error = 8.643, rotation error = 5.058, time/batch = 1.631
# 30300/92100, translation error = 8.594, rotation error = 5.047, time/batch = 1.637
# 30600/92100, translation error = 8.535, rotation error = 5.034, time/batch = 1.633
# 30900/92100, translation error = 8.467, rotation error = 5.026, time/batch = 1.636
# 31200/92100, translation error = 8.411, rotation error = 5.035, time/batch = 1.624
# 31500/92100, translation error = 8.351, rotation error = 5.016, time/batch = 1.630
# 31800/92100, translation error = 8.292, rotation error = 4.996, time/batch = 1.647
# 32100/92100, translation error = 8.240, rotation error = 4.981, time/batch = 1.630
# 32400/92100, translation error = 8.184, rotation error = 4.974, time/batch = 1.634
# 32700/92100, translation error = 8.125, rotation error = 4.966, time/batch = 1.636
# 33000/92100, translation error = 8.063, rotation error = 4.950, time/batch = 1.627
# 33300/92100, translation error = 8.017, rotation error = 4.933, time/batch = 1.638
# 33600/92100, translation error = 7.966, rotation error = 4.922, time/batch = 1.635
# 33900/92100, translation error = 7.926, rotation error = 4.914, time/batch = 1.628
# 34200/92100, translation error = 8.170, rotation error = 4.975, time/batch = 1.642
# 34500/92100, translation error = 9.267, rotation error = 5.177, time/batch = 1.649
# 34800/92100, translation error = 9.217, rotation error = 5.151, time/batch = 1.632
# 35100/92100, translation error = 9.160, rotation error = 5.143, time/batch = 1.633
# 35400/92100, translation error = 10.174, rotation error = 5.326, time/batch = 1.647
# 35700/92100, translation error = 10.411, rotation error = 5.336, time/batch = 1.636
# 36000/92100, translation error = 10.354, rotation error = 5.318, time/batch = 1.632
# 36300/92100, translation error = 10.307, rotation error = 5.326, time/batch = 1.641
# 36600/92100, translation error = 10.248, rotation error = 5.315, time/batch = 1.639
# 36900/92100, translation error = 10.183, rotation error = 5.307, time/batch = 1.636
# 37200/92100, translation error = 10.119, rotation error = 5.295, time/batch = 1.640
# 37500/92100, translation error = 10.050, rotation error = 5.278, time/batch = 1.628
# 37800/92100, translation error = 9.984, rotation error = 5.264, time/batch = 1.639
# 38100/92100, translation error = 9.925, rotation error = 5.267, time/batch = 1.630
# 38400/92100, translation error = 9.863, rotation error = 5.257, time/batch = 1.638
# 38700/92100, translation error = 9.798, rotation error = 5.250, time/batch = 1.634
# 39000/92100, translation error = 9.743, rotation error = 5.241, time/batch = 1.643
# 39300/92100, translation error = 9.686, rotation error = 5.227, time/batch = 1.637
# 39600/92100, translation error = 9.632, rotation error = 5.230, time/batch = 1.635
# 39900/92100, translation error = 9.584, rotation error = 5.224, time/batch = 1.632
# 40200/92100, translation error = 9.522, rotation error = 5.212, time/batch = 1.635
# 40500/92100, translation error = 9.468, rotation error = 5.200, time/batch = 1.638
# 40800/92100, translation error = 9.409, rotation error = 5.194, time/batch = 1.641
# 41100/92100, translation error = 9.355, rotation error = 5.195, time/batch = 1.637
# 41400/92100, translation error = 9.302, rotation error = 5.188, time/batch = 1.642
# 41700/92100, translation error = 9.247, rotation error = 5.183, time/batch = 1.634
# 42000/92100, translation error = 9.196, rotation error = 5.180, time/batch = 1.632
# 42300/92100, translation error = 9.224, rotation error = 5.182, time/batch = 1.631
# 42600/92100, translation error = 9.184, rotation error = 5.161, time/batch = 1.642
# 42900/92100, translation error = 9.139, rotation error = 5.138, time/batch = 1.641
# 43200/92100, translation error = 9.087, rotation error = 5.123, time/batch = 1.636
# 43500/92100, translation error = 9.052, rotation error = 5.108, time/batch = 1.635
# 43800/92100, translation error = 9.071, rotation error = 5.134, time/batch = 1.643
# 44100/92100, translation error = 9.030, rotation error = 5.127, time/batch = 1.637
# 44400/92100, translation error = 9.022, rotation error = 5.144, time/batch = 1.644
# 44700/92100, translation error = 8.984, rotation error = 5.137, time/batch = 1.642
# 45000/92100, translation error = 8.939, rotation error = 5.131, time/batch = 1.634
# 45300/92100, translation error = 8.895, rotation error = 5.132, time/batch = 1.643
# 45600/92100, translation error = 8.863, rotation error = 5.132, time/batch = 1.635
# 45900/92100, translation error = 8.816, rotation error = 5.121, time/batch = 1.638
# 46200/92100, translation error = 8.779, rotation error = 5.123, time/batch = 1.638
# 46500/92100, translation error = 8.745, rotation error = 5.116, time/batch = 1.648
# 46800/92100, translation error = 8.708, rotation error = 5.103, time/batch = 1.634
# 47100/92100, translation error = 8.676, rotation error = 5.098, time/batch = 1.632
# 47400/92100, translation error = 8.659, rotation error = 5.086, time/batch = 1.647
# 47700/92100, translation error = 8.614, rotation error = 5.077, time/batch = 1.640
# 48000/92100, translation error = 8.569, rotation error = 5.074, time/batch = 1.637
# 48300/92100, translation error = 8.529, rotation error = 5.066, time/batch = 1.646
# 48600/92100, translation error = 8.493, rotation error = 5.054, time/batch = 1.644
# 48900/92100, translation error = 8.457, rotation error = 5.037, time/batch = 1.633
# 49200/92100, translation error = 8.421, rotation error = 5.023, time/batch = 1.643
# 49500/92100, translation error = 8.382, rotation error = 5.018, time/batch = 1.630
# 49800/92100, translation error = 8.347, rotation error = 5.005, time/batch = 1.634
# 50100/92100, translation error = 8.324, rotation error = 5.001, time/batch = 1.634
# 50400/92100, translation error = 8.290, rotation error = 4.989, time/batch = 1.638
# 50700/92100, translation error = 8.851, rotation error = 5.117, time/batch = 1.645
# 51000/92100, translation error = 9.265, rotation error = 5.155, time/batch = 1.647
# 51300/92100, translation error = 9.225, rotation error = 5.147, time/batch = 1.639
# 51600/92100, translation error = 9.183, rotation error = 5.135, time/batch = 1.640
# 51900/92100, translation error = 9.140, rotation error = 5.142, time/batch = 1.632
# 52200/92100, translation error = 9.117, rotation error = 5.146, time/batch = 1.634
# 52500/92100, translation error = 9.077, rotation error = 5.140, time/batch = 1.631
# 52800/92100, translation error = 9.038, rotation error = 5.124, time/batch = 1.642
# 53100/92100, translation error = 9.000, rotation error = 5.110, time/batch = 1.640
# 53400/92100, translation error = 8.969, rotation error = 5.134, time/batch = 1.637
# 53700/92100, translation error = 8.933, rotation error = 5.134, time/batch = 1.642
# 54000/92100, translation error = 8.890, rotation error = 5.128, time/batch = 1.637
# 54300/92100, translation error = 8.953, rotation error = 5.147, time/batch = 1.632
# 54600/92100, translation error = 8.923, rotation error = 5.144, time/batch = 1.639
# 54900/92100, translation error = 8.888, rotation error = 5.145, time/batch = 1.634
# 55200/92100, translation error = 8.847, rotation error = 5.134, time/batch = 1.637
# 55500/92100, translation error = 8.817, rotation error = 5.136, time/batch = 1.637
# 55800/92100, translation error = 8.987, rotation error = 5.145, time/batch = 1.641
# 56100/92100, translation error = 9.113, rotation error = 5.237, time/batch = 1.637
# 56400/92100, translation error = 9.167, rotation error = 5.260, time/batch = 1.643
# 56700/92100, translation error = 9.139, rotation error = 5.271, time/batch = 1.642
# 57000/92100, translation error = 9.113, rotation error = 5.264, time/batch = 1.637
# 57300/92100, translation error = 9.080, rotation error = 5.272, time/batch = 1.631
# 57600/92100, translation error = 9.890, rotation error = 5.306, time/batch = 1.648
# 57900/92100, translation error = 9.854, rotation error = 5.304, time/batch = 1.635
# 58200/92100, translation error = 9.819, rotation error = 5.307, time/batch = 1.634
# 58500/92100, translation error = 9.816, rotation error = 5.314, time/batch = 1.640
# 58800/92100, translation error = 9.776, rotation error = 5.301, time/batch = 1.646
# 59100/92100, translation error = 9.735, rotation error = 5.295, time/batch = 1.633
# 59400/92100, translation error = 9.696, rotation error = 5.294, time/batch = 1.636
# 59700/92100, translation error = 9.661, rotation error = 5.283, time/batch = 1.637
# 60000/92100, translation error = 9.624, rotation error = 5.276, time/batch = 1.643
# 60300/92100, translation error = 9.586, rotation error = 5.268, time/batch = 1.640
# 60600/92100, translation error = 9.554, rotation error = 5.264, time/batch = 1.641
# 60900/92100, translation error = 9.519, rotation error = 5.257, time/batch = 1.641
# 61200/92100, translation error = 9.495, rotation error = 5.253, time/batch = 1.644
# 61500/92100, translation error = 9.543, rotation error = 5.276, time/batch = 1.648
# 61800/92100, translation error = 9.816, rotation error = 5.413, time/batch = 1.644
# 62100/92100, translation error = 9.780, rotation error = 5.409, time/batch = 1.643
# 62400/92100, translation error = 9.753, rotation error = 5.405, time/batch = 1.642
# 62700/92100, translation error = 9.716, rotation error = 5.397, time/batch = 1.638
# 63000/92100, translation error = 9.680, rotation error = 5.393, time/batch = 1.634
# 63300/92100, translation error = 9.681, rotation error = 5.410, time/batch = 1.638
# 63600/92100, translation error = 9.645, rotation error = 5.403, time/batch = 1.642
# 63900/92100, translation error = 9.611, rotation error = 5.392, time/batch = 1.641
# 64200/92100, translation error = 10.079, rotation error = 5.526, time/batch = 1.651
# 64500/92100, translation error = 10.250, rotation error = 5.639, time/batch = 1.645
# 64800/92100, translation error = 10.215, rotation error = 5.636, time/batch = 1.634
# 65100/92100, translation error = 10.196, rotation error = 5.639, time/batch = 1.635
# 65400/92100, translation error = 10.160, rotation error = 5.626, time/batch = 1.643
# 65700/92100, translation error = 10.127, rotation error = 5.615, time/batch = 1.638
# 66000/92100, translation error = 10.104, rotation error = 5.632, time/batch = 1.640
# 66300/92100, translation error = 10.070, rotation error = 5.624, time/batch = 1.639
# 66600/92100, translation error = 10.036, rotation error = 5.615, time/batch = 1.639
# 66900/92100, translation error = 10.048, rotation error = 5.637, time/batch = 1.639
# 67200/92100, translation error = 10.026, rotation error = 5.636, time/batch = 1.639
# 67500/92100, translation error = 10.001, rotation error = 5.660, time/batch = 1.635
# 67800/92100, translation error = 9.966, rotation error = 5.650, time/batch = 1.636
# 68100/92100, translation error = 9.931, rotation error = 5.636, time/batch = 1.639
# 68400/92100, translation error = 9.898, rotation error = 5.641, time/batch = 1.641
# 68700/92100, translation error = 9.868, rotation error = 5.634, time/batch = 1.638
# 69000/92100, translation error = 9.840, rotation error = 5.630, time/batch = 1.643
# 69300/92100, translation error = 9.837, rotation error = 5.636, time/batch = 1.640
# 69600/92100, translation error = 9.827, rotation error = 5.636, time/batch = 1.639
# 69900/92100, translation error = 9.836, rotation error = 5.629, time/batch = 1.649
# 70200/92100, translation error = 9.805, rotation error = 5.619, time/batch = 1.637
# 70500/92100, translation error = 9.770, rotation error = 5.612, time/batch = 1.632
# 70800/92100, translation error = 9.736, rotation error = 5.601, time/batch = 1.638
# 71100/92100, translation error = 9.705, rotation error = 5.595, time/batch = 1.639
# 71400/92100, translation error = 9.671, rotation error = 5.585, time/batch = 1.640
# 71700/92100, translation error = 9.639, rotation error = 5.575, time/batch = 1.643
# 72000/92100, translation error = 9.610, rotation error = 5.565, time/batch = 1.640
# 72300/92100, translation error = 9.582, rotation error = 5.557, time/batch = 1.635
# 72600/92100, translation error = 9.549, rotation error = 5.548, time/batch = 1.640
# 72900/92100, translation error = 9.521, rotation error = 5.542, time/batch = 1.642
# 73200/92100, translation error = 9.494, rotation error = 5.542, time/batch = 1.636
# 73500/92100, translation error = 9.464, rotation error = 5.537, time/batch = 1.641
# 73800/92100, translation error = 9.463, rotation error = 5.538, time/batch = 1.644
# 74100/92100, translation error = 9.440, rotation error = 5.535, time/batch = 1.636
# 74400/92100, translation error = 9.480, rotation error = 5.560, time/batch = 1.646
# 74700/92100, translation error = 9.686, rotation error = 5.715, time/batch = 1.651
# 75000/92100, translation error = 9.659, rotation error = 5.711, time/batch = 1.643
# 75300/92100, translation error = 9.825, rotation error = 5.756, time/batch = 1.649
# 75600/92100, translation error = 9.841, rotation error = 5.767, time/batch = 1.646
# 75900/92100, translation error = 9.814, rotation error = 5.758, time/batch = 1.645
# 76200/92100, translation error = 9.790, rotation error = 5.752, time/batch = 1.637
# 76500/92100, translation error = 9.762, rotation error = 5.741, time/batch = 1.639
# 76800/92100, translation error = 9.754, rotation error = 5.739, time/batch = 1.643
# 77100/92100, translation error = 9.769, rotation error = 5.739, time/batch = 1.651
# 77400/92100, translation error = 9.896, rotation error = 5.779, time/batch = 1.652
# 77700/92100, translation error = 10.276, rotation error = 5.862, time/batch = 1.654
# 78000/92100, translation error = 10.426, rotation error = 5.948, time/batch = 1.648
# 78300/92100, translation error = 10.468, rotation error = 5.952, time/batch = 1.640
# 78600/92100, translation error = 10.490, rotation error = 5.973, time/batch = 1.640
# 78900/92100, translation error = 10.494, rotation error = 5.982, time/batch = 1.639
# 79200/92100, translation error = 10.713, rotation error = 6.175, time/batch = 1.648
# 79500/92100, translation error = 11.285, rotation error = 6.240, time/batch = 1.648
# 79800/92100, translation error = 11.250, rotation error = 6.249, time/batch = 1.635
# 80100/92100, translation error = 11.219, rotation error = 6.263, time/batch = 1.635
# 80400/92100, translation error = 11.187, rotation error = 6.255, time/batch = 1.634
# 80700/92100, translation error = 11.275, rotation error = 6.322, time/batch = 1.638
# 81000/92100, translation error = 11.247, rotation error = 6.318, time/batch = 1.669
# 81300/92100, translation error = 11.259, rotation error = 6.373, time/batch = 1.658
# 81600/92100, translation error = 11.294, rotation error = 6.395, time/batch = 1.644
# 81900/92100, translation error = 11.271, rotation error = 6.397, time/batch = 1.639
# 82200/92100, translation error = 11.245, rotation error = 6.391, time/batch = 1.644
# 82500/92100, translation error = 11.225, rotation error = 6.389, time/batch = 1.642
# 82800/92100, translation error = 11.222, rotation error = 6.405, time/batch = 1.638
# 83100/92100, translation error = 11.196, rotation error = 6.413, time/batch = 1.640
# 83400/92100, translation error = 11.188, rotation error = 6.412, time/batch = 1.639
# 83700/92100, translation error = 11.170, rotation error = 6.405, time/batch = 1.640
# 84000/92100, translation error = 11.176, rotation error = 6.411, time/batch = 1.642
# 84300/92100, translation error = 11.175, rotation error = 6.445, time/batch = 1.637
# 84600/92100, translation error = 11.145, rotation error = 6.437, time/batch = 1.640
# 84900/92100, translation error = 11.117, rotation error = 6.430, time/batch = 1.641
# 85200/92100, translation error = 11.090, rotation error = 6.422, time/batch = 1.639
# 85500/92100, translation error = 11.059, rotation error = 6.408, time/batch = 1.642
# 85800/92100, translation error = 11.029, rotation error = 6.398, time/batch = 1.643
# 86100/92100, translation error = 11.162, rotation error = 6.474, time/batch = 1.648
# 86400/92100, translation error = 11.136, rotation error = 6.466, time/batch = 1.636
# 86700/92100, translation error = 11.109, rotation error = 6.453, time/batch = 1.638
# 87000/92100, translation error = 11.081, rotation error = 6.441, time/batch = 1.641
# 87300/92100, translation error = 11.061, rotation error = 6.436, time/batch = 1.643
# 87600/92100, translation error = 11.099, rotation error = 6.459, time/batch = 1.643
# 87900/92100, translation error = 11.096, rotation error = 6.497, time/batch = 1.638
# 88200/92100, translation error = 11.186, rotation error = 6.568, time/batch = 1.641
# 88500/92100, translation error = 11.154, rotation error = 6.562, time/batch = 1.639
# 88800/92100, translation error = 11.242, rotation error = 6.564, time/batch = 1.648
# 89100/92100, translation error = 11.344, rotation error = 6.581, time/batch = 1.639
# 89400/92100, translation error = 11.314, rotation error = 6.583, time/batch = 1.641
# 89700/92100, translation error = 11.286, rotation error = 6.575, time/batch = 1.642
# 90000/92100, translation error = 11.336, rotation error = 6.580, time/batch = 1.645
# 90300/92100, translation error = 11.305, rotation error = 6.568, time/batch = 1.642
# 90600/92100, translation error = 11.285, rotation error = 6.565, time/batch = 1.641
# 90900/92100, translation error = 11.257, rotation error = 6.559, time/batch = 1.645
# 91200/92100, translation error = 11.240, rotation error = 6.591, time/batch = 1.636
# 91500/92100, translation error = 11.217, rotation error = 6.668, time/batch = 1.636
# 91800/92100, translation error = 11.186, rotation error = 6.658, time/batch = 1.642
# 92100/92100, translation error = 11.175, rotation error = 6.659, time/batch = 2.682

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.126
# median rotation error = 3.168
# mean translation error = 11.175
# mean rotation error = 6.659

# %% [markdown]
# # Classification + local GP

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward(x,y,label_from_gp = True)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 300/92100, translation error = 2.713, rotation error = 2.763, time/batch = 1.593
# 600/92100, translation error = 6.584, rotation error = 3.388, time/batch = 1.570
# 900/92100, translation error = 7.289, rotation error = 3.357, time/batch = 1.563
# 1200/92100, translation error = 6.373, rotation error = 3.423, time/batch = 1.565
# 1500/92100, translation error = 5.743, rotation error = 3.531, time/batch = 1.564
# 1800/92100, translation error = 5.088, rotation error = 3.514, time/batch = 1.568
# 2100/92100, translation error = 4.880, rotation error = 3.635, time/batch = 1.563
# 2400/92100, translation error = 4.507, rotation error = 3.546, time/batch = 1.569
# 2700/92100, translation error = 4.314, rotation error = 3.670, time/batch = 1.569
# 3000/92100, translation error = 4.188, rotation error = 3.689, time/batch = 1.572
# 3300/92100, translation error = 3.951, rotation error = 3.575, time/batch = 1.580
# 3600/92100, translation error = 3.894, rotation error = 3.603, time/batch = 1.570
# 3900/92100, translation error = 3.696, rotation error = 3.565, time/batch = 1.571
# 4200/92100, translation error = 3.498, rotation error = 3.495, time/batch = 1.576
# 4500/92100, translation error = 3.341, rotation error = 3.460, time/batch = 1.574
# 4800/92100, translation error = 3.193, rotation error = 3.441, time/batch = 1.580
# 5100/92100, translation error = 3.139, rotation error = 3.486, time/batch = 1.581
# 5400/92100, translation error = 3.070, rotation error = 3.451, time/batch = 1.574
# 5700/92100, translation error = 2.998, rotation error = 3.391, time/batch = 1.577
# 6000/92100, translation error = 2.984, rotation error = 3.384, time/batch = 1.579
# 6300/92100, translation error = 2.937, rotation error = 3.320, time/batch = 1.578
# 6600/92100, translation error = 2.951, rotation error = 3.342, time/batch = 1.574
# 6900/92100, translation error = 5.211, rotation error = 3.911, time/batch = 1.583
# 7200/92100, translation error = 5.151, rotation error = 4.012, time/batch = 1.580
# 7500/92100, translation error = 4.999, rotation error = 4.068, time/batch = 1.578
# 7800/92100, translation error = 5.078, rotation error = 4.143, time/batch = 1.576
# 8100/92100, translation error = 5.127, rotation error = 4.114, time/batch = 1.585
# 8400/92100, translation error = 5.634, rotation error = 4.224, time/batch = 1.588
# 8700/92100, translation error = 5.516, rotation error = 4.208, time/batch = 1.582
# 9000/92100, translation error = 5.395, rotation error = 4.178, time/batch = 1.585
# 9300/92100, translation error = 5.319, rotation error = 4.162, time/batch = 1.587
# 9600/92100, translation error = 5.234, rotation error = 4.101, time/batch = 1.584
# 9900/92100, translation error = 5.145, rotation error = 4.080, time/batch = 1.585
# 10200/92100, translation error = 5.072, rotation error = 4.076, time/batch = 1.588
# 10500/92100, translation error = 4.978, rotation error = 4.167, time/batch = 1.572
# 10800/92100, translation error = 4.895, rotation error = 4.159, time/batch = 1.579
# 11100/92100, translation error = 4.827, rotation error = 4.144, time/batch = 1.582
# 11400/92100, translation error = 4.745, rotation error = 4.094, time/batch = 1.591
# 11700/92100, translation error = 4.654, rotation error = 4.047, time/batch = 1.589
# 12000/92100, translation error = 4.571, rotation error = 4.015, time/batch = 1.584
# 12300/92100, translation error = 4.485, rotation error = 3.975, time/batch = 1.585
# 12600/92100, translation error = 4.420, rotation error = 3.952, time/batch = 1.591
# 12900/92100, translation error = 4.365, rotation error = 3.979, time/batch = 1.576
# 13200/92100, translation error = 4.303, rotation error = 3.954, time/batch = 1.585
# 13500/92100, translation error = 4.328, rotation error = 3.964, time/batch = 1.592
# 13800/92100, translation error = 4.278, rotation error = 3.942, time/batch = 1.588
# 14100/92100, translation error = 4.234, rotation error = 3.934, time/batch = 1.587
# /home/seel/.local/lib/python3.6/site-packages/gpytorch/utils/cholesky.py:44: NumericalWarning: A not p.d., added jitter of 9.999999999999999e-05 to the diagonal
#   warnings.warn(f"A not p.d., added jitter of {jitter_new} to the diagonal", NumericalWarning)
# 14400/92100, translation error = 4.206, rotation error = 3.957, time/batch = 1.689
# 14700/92100, translation error = 4.160, rotation error = 3.926, time/batch = 1.585
# 15000/92100, translation error = 4.139, rotation error = 3.924, time/batch = 1.589
# 15300/92100, translation error = 4.112, rotation error = 3.901, time/batch = 1.592
# 15600/92100, translation error = 4.116, rotation error = 3.962, time/batch = 1.587
# 15900/92100, translation error = 5.115, rotation error = 4.097, time/batch = 1.590
# 16200/92100, translation error = 5.076, rotation error = 4.111, time/batch = 1.596
# 16500/92100, translation error = 5.024, rotation error = 4.088, time/batch = 1.590
# 16800/92100, translation error = 4.977, rotation error = 4.133, time/batch = 1.588
# 17100/92100, translation error = 4.927, rotation error = 4.131, time/batch = 1.591
# 17400/92100, translation error = 4.869, rotation error = 4.111, time/batch = 1.596
# 17700/92100, translation error = 4.813, rotation error = 4.096, time/batch = 1.593
# 18000/92100, translation error = 4.784, rotation error = 4.122, time/batch = 1.597
# 18300/92100, translation error = 4.746, rotation error = 4.136, time/batch = 1.594
# 18600/92100, translation error = 4.702, rotation error = 4.128, time/batch = 1.595
# 18900/92100, translation error = 4.652, rotation error = 4.134, time/batch = 1.597
# 19200/92100, translation error = 4.609, rotation error = 4.110, time/batch = 1.589
# 19500/92100, translation error = 4.589, rotation error = 4.102, time/batch = 1.594
# 19800/92100, translation error = 4.556, rotation error = 4.109, time/batch = 1.590
# 20100/92100, translation error = 4.519, rotation error = 4.103, time/batch = 1.595
# 20400/92100, translation error = 4.473, rotation error = 4.082, time/batch = 1.590
# 20700/92100, translation error = 4.431, rotation error = 4.074, time/batch = 1.598
# 21000/92100, translation error = 4.392, rotation error = 4.072, time/batch = 1.591
# 21300/92100, translation error = 4.348, rotation error = 4.076, time/batch = 1.645
# 21600/92100, translation error = 4.423, rotation error = 4.077, time/batch = 1.686
# 21900/92100, translation error = 6.514, rotation error = 4.419, time/batch = 1.622
# 22200/92100, translation error = 10.115, rotation error = 5.306, time/batch = 1.609
# 22500/92100, translation error = 10.247, rotation error = 5.278, time/batch = 1.591
# 22800/92100, translation error = 10.154, rotation error = 5.252, time/batch = 1.591
# 23100/92100, translation error = 10.077, rotation error = 5.254, time/batch = 1.593
# 23400/92100, translation error = 9.976, rotation error = 5.232, time/batch = 1.594
# 23700/92100, translation error = 9.873, rotation error = 5.216, time/batch = 1.594
# 24000/92100, translation error = 9.778, rotation error = 5.208, time/batch = 1.590
# 24300/92100, translation error = 9.736, rotation error = 5.220, time/batch = 1.641
# 24600/92100, translation error = 9.650, rotation error = 5.228, time/batch = 1.647
# 24900/92100, translation error = 9.587, rotation error = 5.224, time/batch = 1.598
# 25200/92100, translation error = 9.496, rotation error = 5.206, time/batch = 1.599
# 25500/92100, translation error = 9.405, rotation error = 5.188, time/batch = 1.592
# 25800/92100, translation error = 9.312, rotation error = 5.180, time/batch = 1.594
# 26100/92100, translation error = 9.231, rotation error = 5.172, time/batch = 1.590
# 26400/92100, translation error = 9.144, rotation error = 5.150, time/batch = 1.592
# 26700/92100, translation error = 9.060, rotation error = 5.129, time/batch = 1.585
# 27000/92100, translation error = 9.053, rotation error = 5.125, time/batch = 1.584
# 27300/92100, translation error = 8.979, rotation error = 5.093, time/batch = 1.591
# 27600/92100, translation error = 8.912, rotation error = 5.062, time/batch = 1.598
# 27900/92100, translation error = 8.840, rotation error = 5.036, time/batch = 1.589
# 28200/92100, translation error = 8.771, rotation error = 5.012, time/batch = 1.589
# 28500/92100, translation error = 8.714, rotation error = 5.004, time/batch = 1.589
# 28800/92100, translation error = 8.661, rotation error = 4.985, time/batch = 1.595
# 29100/92100, translation error = 8.656, rotation error = 5.078, time/batch = 1.644
# 29400/92100, translation error = 8.752, rotation error = 5.100, time/batch = 1.687
# 29700/92100, translation error = 8.685, rotation error = 5.068, time/batch = 1.622
# 30000/92100, translation error = 8.645, rotation error = 5.058, time/batch = 1.593
# 30300/92100, translation error = 8.595, rotation error = 5.047, time/batch = 1.596
# 30600/92100, translation error = 8.537, rotation error = 5.034, time/batch = 1.595
# 30900/92100, translation error = 8.468, rotation error = 5.026, time/batch = 1.592
# 31200/92100, translation error = 8.412, rotation error = 5.035, time/batch = 1.584
# 31500/92100, translation error = 8.352, rotation error = 5.016, time/batch = 1.585
# 31800/92100, translation error = 8.293, rotation error = 4.996, time/batch = 1.590
# 32100/92100, translation error = 8.242, rotation error = 4.981, time/batch = 1.646
# 32400/92100, translation error = 8.185, rotation error = 4.974, time/batch = 1.667
# 32700/92100, translation error = 8.126, rotation error = 4.966, time/batch = 1.598
# 33000/92100, translation error = 8.064, rotation error = 4.950, time/batch = 1.594
# 33300/92100, translation error = 8.018, rotation error = 4.933, time/batch = 1.592
# 33600/92100, translation error = 7.967, rotation error = 4.922, time/batch = 1.584
# 33900/92100, translation error = 7.927, rotation error = 4.914, time/batch = 1.593
# 34200/92100, translation error = 8.171, rotation error = 4.975, time/batch = 1.615
# 34500/92100, translation error = 9.269, rotation error = 5.177, time/batch = 1.612
# 34800/92100, translation error = 9.219, rotation error = 5.151, time/batch = 1.632
# 35100/92100, translation error = 9.162, rotation error = 5.143, time/batch = 1.629
# 35400/92100, translation error = 10.177, rotation error = 5.326, time/batch = 1.603
# 35700/92100, translation error = 10.414, rotation error = 5.336, time/batch = 1.602
# 36000/92100, translation error = 10.357, rotation error = 5.318, time/batch = 1.591
# 36300/92100, translation error = 10.310, rotation error = 5.326, time/batch = 1.599
# 36600/92100, translation error = 10.251, rotation error = 5.315, time/batch = 1.597
# 36900/92100, translation error = 10.186, rotation error = 5.307, time/batch = 1.593
# 37200/92100, translation error = 10.121, rotation error = 5.295, time/batch = 1.592
# 37500/92100, translation error = 10.053, rotation error = 5.278, time/batch = 1.590
# 37800/92100, translation error = 9.986, rotation error = 5.264, time/batch = 1.591
# 38100/92100, translation error = 9.928, rotation error = 5.267, time/batch = 1.595
# 38400/92100, translation error = 9.865, rotation error = 5.257, time/batch = 1.592
# 38700/92100, translation error = 9.800, rotation error = 5.250, time/batch = 1.599
# 39000/92100, translation error = 9.745, rotation error = 5.241, time/batch = 1.633
# 39300/92100, translation error = 9.688, rotation error = 5.227, time/batch = 1.611
# 39600/92100, translation error = 9.634, rotation error = 5.230, time/batch = 1.699
# 39900/92100, translation error = 9.586, rotation error = 5.224, time/batch = 1.650
# 40200/92100, translation error = 9.524, rotation error = 5.212, time/batch = 1.599
# 40500/92100, translation error = 9.470, rotation error = 5.200, time/batch = 1.640
# 40800/92100, translation error = 9.411, rotation error = 5.194, time/batch = 1.651
# 41100/92100, translation error = 9.358, rotation error = 5.195, time/batch = 1.604
# 41400/92100, translation error = 9.304, rotation error = 5.188, time/batch = 1.598
# 41700/92100, translation error = 9.249, rotation error = 5.183, time/batch = 1.596
# 42000/92100, translation error = 9.199, rotation error = 5.180, time/batch = 1.587
# 42300/92100, translation error = 9.226, rotation error = 5.182, time/batch = 1.595
# 42600/92100, translation error = 9.186, rotation error = 5.161, time/batch = 1.601
# 42900/92100, translation error = 9.141, rotation error = 5.138, time/batch = 1.593
# 43200/92100, translation error = 9.089, rotation error = 5.123, time/batch = 1.639
# 43500/92100, translation error = 9.054, rotation error = 5.108, time/batch = 1.692
# 43800/92100, translation error = 9.073, rotation error = 5.134, time/batch = 1.635
# 44100/92100, translation error = 9.032, rotation error = 5.127, time/batch = 1.592
# 44400/92100, translation error = 9.024, rotation error = 5.144, time/batch = 1.598
# 44700/92100, translation error = 8.985, rotation error = 5.137, time/batch = 1.600
# 45000/92100, translation error = 8.941, rotation error = 5.131, time/batch = 1.640
# 45300/92100, translation error = 8.897, rotation error = 5.132, time/batch = 1.667
# 45600/92100, translation error = 8.865, rotation error = 5.132, time/batch = 1.603
# 45900/92100, translation error = 8.818, rotation error = 5.121, time/batch = 1.587
# 46200/92100, translation error = 8.780, rotation error = 5.123, time/batch = 1.597
# 46500/92100, translation error = 8.746, rotation error = 5.116, time/batch = 1.595
# 46800/92100, translation error = 8.710, rotation error = 5.103, time/batch = 1.594
# 47100/92100, translation error = 8.678, rotation error = 5.098, time/batch = 1.589
# 47400/92100, translation error = 8.660, rotation error = 5.086, time/batch = 1.599
# 47700/92100, translation error = 8.616, rotation error = 5.077, time/batch = 1.602
# 48000/92100, translation error = 8.570, rotation error = 5.074, time/batch = 1.599
# 48300/92100, translation error = 8.531, rotation error = 5.066, time/batch = 1.644
# 48600/92100, translation error = 8.495, rotation error = 5.054, time/batch = 1.688
# 48900/92100, translation error = 8.459, rotation error = 5.037, time/batch = 1.609
# 49200/92100, translation error = 8.422, rotation error = 5.023, time/batch = 1.598
# 49500/92100, translation error = 8.383, rotation error = 5.018, time/batch = 1.592
# 49800/92100, translation error = 8.349, rotation error = 5.005, time/batch = 1.591
# 50100/92100, translation error = 8.325, rotation error = 5.001, time/batch = 1.592
# 50400/92100, translation error = 8.291, rotation error = 4.989, time/batch = 1.636
# 50700/92100, translation error = 8.852, rotation error = 5.117, time/batch = 1.683
# 51000/92100, translation error = 9.266, rotation error = 5.155, time/batch = 1.622
# 51300/92100, translation error = 9.226, rotation error = 5.147, time/batch = 1.594
# 51600/92100, translation error = 9.184, rotation error = 5.135, time/batch = 1.589
# 51900/92100, translation error = 9.141, rotation error = 5.142, time/batch = 1.588
# 52200/92100, translation error = 9.119, rotation error = 5.146, time/batch = 1.591
# 52500/92100, translation error = 9.079, rotation error = 5.140, time/batch = 1.589
# 52800/92100, translation error = 9.040, rotation error = 5.124, time/batch = 1.593
# 53100/92100, translation error = 9.001, rotation error = 5.110, time/batch = 1.646
# 53400/92100, translation error = 8.970, rotation error = 5.134, time/batch = 1.598
# 53700/92100, translation error = 8.934, rotation error = 5.134, time/batch = 1.695
# 54000/92100, translation error = 8.892, rotation error = 5.128, time/batch = 1.614
# 54300/92100, translation error = 8.954, rotation error = 5.147, time/batch = 1.592
# 54600/92100, translation error = 8.924, rotation error = 5.144, time/batch = 1.589
# 54900/92100, translation error = 8.889, rotation error = 5.145, time/batch = 1.583
# 55200/92100, translation error = 8.848, rotation error = 5.134, time/batch = 1.597
# 55500/92100, translation error = 8.818, rotation error = 5.136, time/batch = 1.648
# 55800/92100, translation error = 8.988, rotation error = 5.145, time/batch = 1.694
# 56100/92100, translation error = 9.114, rotation error = 5.237, time/batch = 1.601
# 56400/92100, translation error = 9.168, rotation error = 5.260, time/batch = 1.610
# 56700/92100, translation error = 9.140, rotation error = 5.271, time/batch = 1.600
# 57000/92100, translation error = 9.114, rotation error = 5.264, time/batch = 1.594
# 57300/92100, translation error = 9.081, rotation error = 5.272, time/batch = 1.584
# 57600/92100, translation error = 9.891, rotation error = 5.306, time/batch = 1.651
# 57900/92100, translation error = 9.855, rotation error = 5.304, time/batch = 1.683
# 58200/92100, translation error = 9.820, rotation error = 5.307, time/batch = 1.613
# 58500/92100, translation error = 9.817, rotation error = 5.314, time/batch = 1.596
# 58800/92100, translation error = 9.777, rotation error = 5.301, time/batch = 1.597
# 59100/92100, translation error = 9.736, rotation error = 5.295, time/batch = 1.589
# 59400/92100, translation error = 9.697, rotation error = 5.294, time/batch = 1.590
# 59700/92100, translation error = 9.662, rotation error = 5.283, time/batch = 1.602
# 60000/92100, translation error = 9.625, rotation error = 5.276, time/batch = 1.592
# 60300/92100, translation error = 9.587, rotation error = 5.268, time/batch = 1.619
# 60600/92100, translation error = 9.555, rotation error = 5.264, time/batch = 1.607
# 60900/92100, translation error = 9.520, rotation error = 5.257, time/batch = 1.691
# 61200/92100, translation error = 9.496, rotation error = 5.253, time/batch = 1.624
# 61500/92100, translation error = 9.544, rotation error = 5.276, time/batch = 1.611
# 61800/92100, translation error = 9.816, rotation error = 5.413, time/batch = 1.602
# 62100/92100, translation error = 9.780, rotation error = 5.409, time/batch = 1.610
# 62400/92100, translation error = 9.753, rotation error = 5.405, time/batch = 1.593
# 62700/92100, translation error = 9.716, rotation error = 5.397, time/batch = 1.698
# 63000/92100, translation error = 9.680, rotation error = 5.393, time/batch = 1.645
# 63300/92100, translation error = 9.681, rotation error = 5.410, time/batch = 1.588
# 63600/92100, translation error = 9.645, rotation error = 5.403, time/batch = 1.632
# 63900/92100, translation error = 9.611, rotation error = 5.392, time/batch = 1.629
# 64200/92100, translation error = 10.079, rotation error = 5.526, time/batch = 1.610
# 64500/92100, translation error = 10.250, rotation error = 5.639, time/batch = 1.598
# 64800/92100, translation error = 10.215, rotation error = 5.636, time/batch = 1.593
# 65100/92100, translation error = 10.197, rotation error = 5.639, time/batch = 1.591
# 65400/92100, translation error = 10.160, rotation error = 5.626, time/batch = 1.600
# 65700/92100, translation error = 10.127, rotation error = 5.615, time/batch = 1.593
# 66000/92100, translation error = 10.104, rotation error = 5.632, time/batch = 1.601
# 66300/92100, translation error = 10.070, rotation error = 5.624, time/batch = 1.601
# 66600/92100, translation error = 10.036, rotation error = 5.615, time/batch = 1.606
# 66900/92100, translation error = 10.048, rotation error = 5.637, time/batch = 1.648
# 67200/92100, translation error = 10.026, rotation error = 5.636, time/batch = 1.693
# 67500/92100, translation error = 10.001, rotation error = 5.660, time/batch = 1.605
# 67800/92100, translation error = 9.966, rotation error = 5.650, time/batch = 1.597
# 68100/92100, translation error = 9.931, rotation error = 5.636, time/batch = 1.605
# 68400/92100, translation error = 9.898, rotation error = 5.641, time/batch = 1.598
# 68700/92100, translation error = 9.868, rotation error = 5.634, time/batch = 1.639
# 69000/92100, translation error = 9.840, rotation error = 5.630, time/batch = 1.666
# 69300/92100, translation error = 9.837, rotation error = 5.636, time/batch = 1.604
# 69600/92100, translation error = 9.827, rotation error = 5.636, time/batch = 1.592
# 69900/92100, translation error = 9.837, rotation error = 5.629, time/batch = 1.606
# 70200/92100, translation error = 9.806, rotation error = 5.619, time/batch = 1.595
# 70500/92100, translation error = 9.770, rotation error = 5.612, time/batch = 1.587
# 70800/92100, translation error = 9.736, rotation error = 5.601, time/batch = 1.589
# 71100/92100, translation error = 9.705, rotation error = 5.595, time/batch = 1.596
# 71400/92100, translation error = 9.671, rotation error = 5.585, time/batch = 1.646
# 71700/92100, translation error = 9.639, rotation error = 5.575, time/batch = 1.603
# 72000/92100, translation error = 9.610, rotation error = 5.565, time/batch = 1.694
# 72300/92100, translation error = 9.582, rotation error = 5.557, time/batch = 1.652
# 72600/92100, translation error = 9.549, rotation error = 5.548, time/batch = 1.596
# 72900/92100, translation error = 9.521, rotation error = 5.542, time/batch = 1.640
# 73200/92100, translation error = 9.494, rotation error = 5.542, time/batch = 1.641
# 73500/92100, translation error = 9.464, rotation error = 5.537, time/batch = 1.596
# 73800/92100, translation error = 9.463, rotation error = 5.538, time/batch = 1.600
# 74100/92100, translation error = 9.440, rotation error = 5.535, time/batch = 1.591
# 74400/92100, translation error = 9.480, rotation error = 5.560, time/batch = 1.606
# 74700/92100, translation error = 9.686, rotation error = 5.715, time/batch = 1.602
# 75000/92100, translation error = 9.658, rotation error = 5.711, time/batch = 1.622
# 75300/92100, translation error = 9.825, rotation error = 5.756, time/batch = 1.651
# 75600/92100, translation error = 9.841, rotation error = 5.767, time/batch = 1.696
# 75900/92100, translation error = 9.814, rotation error = 5.758, time/batch = 1.618
# 76200/92100, translation error = 9.790, rotation error = 5.752, time/batch = 1.589
# 76500/92100, translation error = 9.762, rotation error = 5.741, time/batch = 1.624
# 76800/92100, translation error = 9.754, rotation error = 5.739, time/batch = 1.612
# 77100/92100, translation error = 9.769, rotation error = 5.739, time/batch = 1.607
# 77400/92100, translation error = 9.895, rotation error = 5.779, time/batch = 1.617
# 77700/92100, translation error = 10.276, rotation error = 5.862, time/batch = 1.610
# 78000/92100, translation error = 10.425, rotation error = 5.948, time/batch = 1.599
# 78300/92100, translation error = 10.467, rotation error = 5.952, time/batch = 1.596
# 78600/92100, translation error = 10.489, rotation error = 5.973, time/batch = 1.595
# 78900/92100, translation error = 10.493, rotation error = 5.982, time/batch = 1.589
# 79200/92100, translation error = 10.712, rotation error = 6.175, time/batch = 1.596
# 79500/92100, translation error = 11.284, rotation error = 6.240, time/batch = 1.654
# 79800/92100, translation error = 11.249, rotation error = 6.249, time/batch = 1.641
# 80100/92100, translation error = 11.218, rotation error = 6.263, time/batch = 1.593
# 80400/92100, translation error = 11.186, rotation error = 6.255, time/batch = 1.591
# 80700/92100, translation error = 11.274, rotation error = 6.322, time/batch = 1.595
# 81000/92100, translation error = 11.246, rotation error = 6.318, time/batch = 1.606
# 81300/92100, translation error = 11.258, rotation error = 6.373, time/batch = 1.597
# 81600/92100, translation error = 11.293, rotation error = 6.395, time/batch = 1.594
# 81900/92100, translation error = 11.270, rotation error = 6.397, time/batch = 1.592
# 82200/92100, translation error = 11.244, rotation error = 6.391, time/batch = 1.597
# 82500/92100, translation error = 11.225, rotation error = 6.389, time/batch = 1.611
# 82800/92100, translation error = 11.221, rotation error = 6.405, time/batch = 1.650
# 83100/92100, translation error = 11.195, rotation error = 6.413, time/batch = 1.598
# 83400/92100, translation error = 11.187, rotation error = 6.412, time/batch = 1.637
# 83700/92100, translation error = 11.169, rotation error = 6.405, time/batch = 1.586
# 84000/92100, translation error = 11.175, rotation error = 6.411, time/batch = 1.599
# 84300/92100, translation error = 11.174, rotation error = 6.445, time/batch = 1.588
# 84600/92100, translation error = 11.144, rotation error = 6.437, time/batch = 1.591
# 84900/92100, translation error = 11.116, rotation error = 6.430, time/batch = 1.595
# 85200/92100, translation error = 11.089, rotation error = 6.422, time/batch = 1.593
# 85500/92100, translation error = 11.058, rotation error = 6.408, time/batch = 1.668
# 85800/92100, translation error = 11.029, rotation error = 6.398, time/batch = 1.616
# 86100/92100, translation error = 11.161, rotation error = 6.474, time/batch = 1.602
# 86400/92100, translation error = 11.135, rotation error = 6.466, time/batch = 1.595
# 86700/92100, translation error = 11.109, rotation error = 6.453, time/batch = 1.687
# 87000/92100, translation error = 11.080, rotation error = 6.441, time/batch = 1.613
# 87300/92100, translation error = 11.060, rotation error = 6.436, time/batch = 1.599
# 87600/92100, translation error = 11.098, rotation error = 6.459, time/batch = 1.602
# 87900/92100, translation error = 11.095, rotation error = 6.497, time/batch = 1.590
# 88200/92100, translation error = 11.186, rotation error = 6.568, time/batch = 1.642
# 88500/92100, translation error = 11.153, rotation error = 6.562, time/batch = 1.600
# 88800/92100, translation error = 11.241, rotation error = 6.564, time/batch = 1.609
# 89100/92100, translation error = 11.343, rotation error = 6.581, time/batch = 1.691
# 89400/92100, translation error = 11.313, rotation error = 6.583, time/batch = 1.625
# 89700/92100, translation error = 11.285, rotation error = 6.575, time/batch = 1.648
# 90000/92100, translation error = 11.335, rotation error = 6.580, time/batch = 1.654
# 90300/92100, translation error = 11.305, rotation error = 6.568, time/batch = 1.611
# 90600/92100, translation error = 11.284, rotation error = 6.565, time/batch = 1.594
# 90900/92100, translation error = 11.256, rotation error = 6.559, time/batch = 1.590
# 91200/92100, translation error = 11.239, rotation error = 6.591, time/batch = 1.596
# 91500/92100, translation error = 11.216, rotation error = 6.668, time/batch = 1.587
# 91800/92100, translation error = 11.185, rotation error = 6.658, time/batch = 1.590
# 92100/92100, translation error = 11.174, rotation error = 6.659, time/batch = 0.785

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.125
# median rotation error = 3.168
# mean translation error = 11.174
# mean rotation error = 6.659

# %% [markdown]
# # Classification `top-2` + local GP

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward_top2(x,y)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
    if (b+1)*args.batch_size == 21900:
        break
# Out:
# 300/92100, translation error = 2.713, rotation error = 2.763, time/batch = 1.650
# 600/92100, translation error = 6.571, rotation error = 3.388, time/batch = 1.632
# 900/92100, translation error = 7.270, rotation error = 3.357, time/batch = 1.630
# 1200/92100, translation error = 6.358, rotation error = 3.423, time/batch = 1.641
# 1500/92100, translation error = 5.731, rotation error = 3.531, time/batch = 1.636
# 1800/92100, translation error = 5.078, rotation error = 3.514, time/batch = 1.631
# 2100/92100, translation error = 4.872, rotation error = 3.635, time/batch = 1.645
# 2400/92100, translation error = 4.500, rotation error = 3.546, time/batch = 1.635
# 2700/92100, translation error = 4.308, rotation error = 3.670, time/batch = 1.642
# 3000/92100, translation error = 4.183, rotation error = 3.689, time/batch = 1.642
# 3300/92100, translation error = 3.947, rotation error = 3.575, time/batch = 1.647
# 3600/92100, translation error = 3.889, rotation error = 3.603, time/batch = 1.646
# 3900/92100, translation error = 3.693, rotation error = 3.565, time/batch = 1.638
# 4200/92100, translation error = 3.495, rotation error = 3.495, time/batch = 1.641
# 4500/92100, translation error = 3.338, rotation error = 3.460, time/batch = 1.645
# 4800/92100, translation error = 3.190, rotation error = 3.441, time/batch = 1.647
# 5100/92100, translation error = 3.136, rotation error = 3.486, time/batch = 1.643
# 5400/92100, translation error = 3.068, rotation error = 3.451, time/batch = 1.644
# 5700/92100, translation error = 2.995, rotation error = 3.391, time/batch = 1.642
# 6000/92100, translation error = 2.982, rotation error = 3.384, time/batch = 1.636
# 6300/92100, translation error = 2.934, rotation error = 3.320, time/batch = 1.641
# 6600/92100, translation error = 2.949, rotation error = 3.342, time/batch = 1.636
# 6900/92100, translation error = 5.204, rotation error = 3.911, time/batch = 1.683
# 7200/92100, translation error = 5.139, rotation error = 4.012, time/batch = 1.646
# 7500/92100, translation error = 4.987, rotation error = 4.068, time/batch = 1.644
# 7800/92100, translation error = 5.070, rotation error = 4.143, time/batch = 1.654
# 8100/92100, translation error = 5.120, rotation error = 4.114, time/batch = 1.649
# 8400/92100, translation error = 5.631, rotation error = 4.224, time/batch = 1.657
# 8700/92100, translation error = 5.514, rotation error = 4.208, time/batch = 1.646
# 9000/92100, translation error = 5.393, rotation error = 4.178, time/batch = 1.646
# 9300/92100, translation error = 5.317, rotation error = 4.162, time/batch = 1.652
# 9600/92100, translation error = 5.232, rotation error = 4.101, time/batch = 1.647
# 9900/92100, translation error = 5.143, rotation error = 4.080, time/batch = 1.644
# 10200/92100, translation error = 5.070, rotation error = 4.076, time/batch = 1.654
# 10500/92100, translation error = 4.976, rotation error = 4.167, time/batch = 1.644
# 10800/92100, translation error = 4.893, rotation error = 4.159, time/batch = 1.645
# 11100/92100, translation error = 4.826, rotation error = 4.144, time/batch = 1.652
# 11400/92100, translation error = 4.743, rotation error = 4.094, time/batch = 1.656
# 11700/92100, translation error = 4.652, rotation error = 4.047, time/batch = 1.662
# 12000/92100, translation error = 4.569, rotation error = 4.015, time/batch = 1.643
# 12300/92100, translation error = 4.483, rotation error = 3.975, time/batch = 1.656
# 12600/92100, translation error = 4.418, rotation error = 3.952, time/batch = 1.657
# 12900/92100, translation error = 4.363, rotation error = 3.979, time/batch = 1.650
# 13200/92100, translation error = 4.302, rotation error = 3.954, time/batch = 1.656
# 13500/92100, translation error = 4.332, rotation error = 3.964, time/batch = 1.658
# 13800/92100, translation error = 4.282, rotation error = 3.942, time/batch = 1.658
# 14100/92100, translation error = 4.238, rotation error = 3.934, time/batch = 1.645
# /home/seel/.local/lib/python3.6/site-packages/gpytorch/utils/cholesky.py:44: NumericalWarning: A not p.d., added jitter of 9.999999999999999e-05 to the diagonal
#   warnings.warn(f"A not p.d., added jitter of {jitter_new} to the diagonal", NumericalWarning)
# 14400/92100, translation error = 4.210, rotation error = 3.957, time/batch = 1.696
# 14700/92100, translation error = 4.164, rotation error = 3.926, time/batch = 1.653
# 15000/92100, translation error = 4.143, rotation error = 3.924, time/batch = 1.653
# 15300/92100, translation error = 4.116, rotation error = 3.901, time/batch = 1.661
# 15600/92100, translation error = 4.123, rotation error = 3.962, time/batch = 1.657
# 15900/92100, translation error = 5.121, rotation error = 4.097, time/batch = 1.667
# 16200/92100, translation error = 5.082, rotation error = 4.111, time/batch = 1.655
# 16500/92100, translation error = 5.030, rotation error = 4.088, time/batch = 1.665
# 16800/92100, translation error = 4.983, rotation error = 4.133, time/batch = 1.659
# 17100/92100, translation error = 4.933, rotation error = 4.131, time/batch = 1.662
# 17400/92100, translation error = 4.875, rotation error = 4.111, time/batch = 1.661
# 17700/92100, translation error = 4.819, rotation error = 4.096, time/batch = 1.655
# 18000/92100, translation error = 4.789, rotation error = 4.122, time/batch = 1.661
# 18300/92100, translation error = 4.752, rotation error = 4.136, time/batch = 1.659
# 18600/92100, translation error = 4.708, rotation error = 4.128, time/batch = 1.662
# 18900/92100, translation error = 4.658, rotation error = 4.134, time/batch = 1.653
# 19200/92100, translation error = 4.614, rotation error = 4.110, time/batch = 1.664
# 19500/92100, translation error = 4.595, rotation error = 4.102, time/batch = 1.655
# 19800/92100, translation error = 4.561, rotation error = 4.109, time/batch = 1.662
# 20100/92100, translation error = 4.524, rotation error = 4.103, time/batch = 1.663
# 20400/92100, translation error = 4.478, rotation error = 4.082, time/batch = 1.672
# 20700/92100, translation error = 4.435, rotation error = 4.074, time/batch = 1.662
# 21000/92100, translation error = 4.396, rotation error = 4.072, time/batch = 1.667
# 21300/92100, translation error = 4.352, rotation error = 4.076, time/batch = 1.668
# 21600/92100, translation error = 4.429, rotation error = 4.077, time/batch = 1.670
# 21900/92100, translation error = 6.529, rotation error = 4.419, time/batch = 1.699

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.124
# median rotation error = 3.168
# mean translation error = 11.172
# mean rotation error = 6.659

# %%
def evaluate(trans_errors,rot_errors):
    t = [14301,7008,12852,9567,13580,14835,7114,12683]
    for i in range(len(t)):
        if i >0:
            t[i] += t[i-1]
    trans_errors_month = list()
    trans_errors_month.append(trans_errors[:t[0]])
    trans_errors_month.append(trans_errors[t[0]:t[1]])
    trans_errors_month.append(trans_errors[t[1]:t[2]])
    trans_errors_month.append(trans_errors[t[2]:t[3]])
    trans_errors_month.append(trans_errors[t[3]:t[4]])
    trans_errors_month.append(trans_errors[t[4]:t[5]])
    trans_errors_month.append(trans_errors[t[5]:t[6]])
    trans_errors_month.append(trans_errors[t[6]:])

    rot_errors_month = list()
    rot_errors_month.append(rot_errors[:t[0]])
    rot_errors_month.append(rot_errors[t[0]:t[1]])
    rot_errors_month.append(rot_errors[t[1]:t[2]])
    rot_errors_month.append(rot_errors[t[2]:t[3]])
    rot_errors_month.append(rot_errors[t[3]:t[4]])
    rot_errors_month.append(rot_errors[t[4]:t[5]])
    rot_errors_month.append(rot_errors[t[5]:t[6]])
    rot_errors_month.append(rot_errors[t[6]:])
    
    print('================== var translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("var translation error = {:.3f}".format(np.var(trans_errors_i)))
    
    print('================== median translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("median translation error = {:.3f}".format(np.median(trans_errors_i)))
        
    print('================== median rotation error ==================')
    for rot_errors_i in rot_errors_month:
        print("median rotation error = {:.3f}".format(np.median(rot_errors_i)))
    
    print('================== mean translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("mean translation error = {:.3f}".format(np.mean(trans_errors_i)))
        
    print('================== mean rotation error ==================')  
    for rot_errors_i in rot_errors_month:
        print("mean rotation error = {:.3f}".format(np.mean(rot_errors_i)))
        
evaluate(trans_errors,rot_errors)
# Out:
# ================== var translation error ==================
# var translation error = 385.414
# var translation error = 455.154
# var translation error = 2621.602
# var translation error = 2642.811
# var translation error = 2212.643
# var translation error = 3028.174
# var translation error = 2256.304
# var translation error = 2842.328
# ================== median translation error ==================
# median translation error = 1.711
# median translation error = 1.851
# median translation error = 2.002
# median translation error = 2.076
# median translation error = 2.132
# median translation error = 2.319
# median translation error = 3.547
# median translation error = 2.959
# ================== median rotation error ==================
# median rotation error = 2.934
# median rotation error = 2.836
# median rotation error = 3.045
# median rotation error = 2.972
# median rotation error = 3.298
# median rotation error = 3.246
# median rotation error = 4.498
# median rotation error = 4.396
# ================== mean translation error ==================
# mean translation error = 4.067
# mean translation error = 4.689
# mean translation error = 13.480
# mean translation error = 12.613
# mean translation error = 9.106
# mean translation error = 11.270
# mean translation error = 20.803
# mean translation error = 13.138
# ================== mean rotation error ==================
# mean rotation error = 4.407
# mean rotation error = 4.424
# mean rotation error = 6.504
# mean rotation error = 6.115
# mean rotation error = 6.091
# mean rotation error = 6.747
# mean rotation error = 11.529
# mean rotation error = 10.100
