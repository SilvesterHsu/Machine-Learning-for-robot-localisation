# %% [markdown]
# # Torch
# ## Check GPU¶

# %%
import torch
import sys
sys.path.append('..')
from torchlib.utils import list_device,set_device

list_device()
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'
# ------------ List Devices ------------
# Device 0 :
# GeForce RTX 2060
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
#
# Device 1 :
# TITAN Xp
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %% [markdown]
# ## Set torch default parameters¶

# %%
set_device(1)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()

'''Training Parameters'''
parser.add_argument('--batch_size', type=int, default=300, help='minibatch size')
parser.add_argument('--num_epochs', type=int, default=80, help='number of epochs')
parser.add_argument('--grad_clip', type=float, default=5., help='clip gradients at this value')
parser.add_argument('--learning_rate', type=float, default=0.1, help='learning rate')
parser.add_argument('--learning_rate_clip', type=float, default=0.0000001, help='learning rate clip')
parser.add_argument('--decay_rate', type=float, default=.75, help='decay rate for rmsprop')
parser.add_argument('--weight_decay', type=float, default=.0001, help='decay rate for rmsprop')
parser.add_argument('--batch_norm_decay', type=float, default=.999, help='decay rate for rmsprop')
parser.add_argument('--keep_prob', type=float, default=1.0, help='dropout keep probability')
parser.add_argument('--lamda_weights', type=float, default=.01, help='lamda weight')
parser.add_argument('--data_argumentation', type=bool, default=True, help='whether do data argument')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data nomalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')
parser.add_argument('--output_dim', default=3, type=int, help='output dimention.')
parser.add_argument('--feat_dim', default=128, type=int, help='feature dimention.')

'''Configure'''
parser.add_argument('--network', type=str, default='vggnet_localization')
parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/gps_net_torch', help='rnn, gru, or lstm')

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/2012_01_08',
                                                            '/notebooks/michigan_nn_data/2012_01_15',
                                                            '/notebooks/michigan_nn_data/2012_01_22',
                                                            '/notebooks/michigan_nn_data/2012_02_02',
                                                            '/notebooks/michigan_nn_data/2012_02_04',
                                                            '/notebooks/michigan_nn_data/2012_02_05',
                                                            '/notebooks/michigan_nn_data/2012_03_31',
                                                            '/notebooks/michigan_nn_data/2012_09_28'])
'''
#parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/test'])
parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/2012_01_08'])
'''
parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

parser.add_argument('--seed', default=1337, type=int)
parser.add_argument('--save_every', type=int, default=1000, help='save frequency')
parser.add_argument('--display', type=int, default=10, help='display frequency')
parser.add_argument('--tensorboard', type=bool, default=True, help='open tensorboard')

sys.argv = ['']
args = parser.parse_args()

if args.tensorboard:
    import os
    os.system('rm -rf runs/gps')
    from torch.utils.tensorboard import SummaryWriter
    writer = SummaryWriter('runs/gps')

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
from PIL import Image
import numpy as np
import random

#import gpflow.multioutput.kernels as mk
import gpytorch

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet
from torchlib.cnn_auxiliary import normalize, denormalize_navie, denormalize, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

transform = transforms.Compose([transforms.ToTensor()])
dataset = LocalizationDataset(dataset_dirs = args.train_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform, get_pair = False)

if len(args.train_dataset)>7:
    [args.norm_mean, args.norm_std] = [torch.tensor(x) for x in dataset.get_norm()]
    torch.save([args.norm_mean, args.norm_std], *args.norm_tensor)
    print('Save norm and std:',*args.norm_tensor)
else:
    [args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
    print('Load norm and std:',*args.norm_tensor)


dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=True, num_workers=0, \
                        drop_last=True, pin_memory=True)
# Out:
# 100%|██████████| 16446/16446 [00:22<00:00, 725.48it/s]
# 100%|██████████| 22584/22584 [00:31<00:00, 716.43it/s]
# 100%|██████████| 18655/18655 [00:25<00:00, 726.75it/s]
# 100%|██████████| 17310/17310 [00:23<00:00, 723.50it/s]
# 100%|██████████| 10766/10766 [00:14<00:00, 731.28it/s]
# 100%|██████████| 14878/14878 [00:22<00:00, 664.90it/s]
# 100%|██████████| 13452/13452 [00:20<00:00, 645.97it/s]
# 100%|██████████| 14037/14037 [00:26<00:00, 539.73it/s]
# Save norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # Define Model

# %%
class Backbone(nn.Module):
    def __init__(self):
        super().__init__()
        self.resnet = resnet.resnet50(pretrained=True)
    def forward(self,input_data):
        dense_feat = self.resnet(input_data)
        return dense_feat
    
class NN(nn.Module):
    def __init__(self):
        super().__init__()
        self.global_context = vggnet.vggnet(input_channel=2048,opt="context")
        self.global_regressor = vggnet.vggnet(opt="regressor")
        
    def forward(self,input_data):
        context_feat = self.global_context(input_data)
        output,feature_t, feature_r = self.global_regressor(context_feat)
        return output, feature_t, feature_r

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.MultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([output_dim]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([output_dim])),
            batch_shape=torch.Size([output_dim]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class GPNode(nn.Module):
    def __init__(self,inducing_points, seed):
        super().__init__()
        output_dim = inducing_points.shape[0]
        sub_feat_dim = inducing_points.shape[-1]
        torch.manual_seed(seed)
        
        #self.feat_index = torch.randint(high=args.feat_dim, size=(sub_feat_dim,))
        self.feat_index = torch.randperm(args.feat_dim)[:sub_feat_dim]
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=output_dim) 
        
    def forward(self,input_data):
        output = self.gp(input_data)
        return output
    
class Model(nn.Module):
    def __init__(self,gp_args):
        super().__init__()
        self.backbone = Backbone()
        self.nn = NN()
        self.gps = nn.ModuleList()
        
        self.num_gp = gp_args['num_gp']
        #self.sub_batch_rate = gp_args['sub_rate']
        self.sub_feat_rate = gp_args['feat_rate']
        #self.sub_batch_size = int(args.batch_size*self.sub_batch_rate)
        self.sub_feat_dim = int(args.feat_dim*self.sub_feat_rate)
        
        for i in range(self.num_gp):
            #inducing_points = torch.zeros(args.output_dim, self.sub_batch_size, self.sub_feat_dim)
            inducing_points = torch.zeros(args.output_dim, args.batch_size, self.sub_feat_dim)
            # use i as seed to fix sub features
            gp = GPNode(inducing_points,seed=i)
            self.gps.append(gp)
        
    def forward_nn(self, input_data):
        dense_feat = self.backbone(input_data)
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention            
        return feature_t, rot_pred
    
    def forward_gp(self,gp,trans_feat):
        sub_trans_feat = trans_feat[:,gp.feat_index]
        trans_pred = gp(sub_trans_feat)
        return trans_pred

# %%
class Trainer:
    def __init__(self,gp_args,regressor_context_rate = [0.0,0.0]):
        self.model = Model(gp_args).cuda()
        self.norm_mean = args.norm_mean.cuda()
        self.norm_std = args.norm_std.cuda()
        
        # disable learning backbone
        for param in self.model.backbone.parameters():
            param.requires_grad = False
            
        # training tool
        self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
        self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                         lr_lambda=lambda epoch: args.decay_rate**epoch)
        
    def load_model(self, file_name = 'pretrained.pth'):
        # load file info
        state_dict = torch.load(os.path.join(args.model_dir, file_name))
        if 'net.resnet.conv1.weight' in state_dict:
            print('Transform from old model.')
            # Part 1: backbone
            backbone_state_dict = self._from_old_model(state_dict,'backbone')
            print('Backbone parameters layer:',len(backbone_state_dict.keys()))
            self.model.backbone.load_state_dict(backbone_state_dict,strict = True)
            # Part 2: nn
            nn_state_dict = self._from_old_model(torch.load(os.path.join(args.model_dir, file_name)),'nn')
            print('NN parameters layer:',len(nn_state_dict.keys()))
            self.model.nn.load_state_dict(nn_state_dict,strict = True)
        else:
            print('Parameters layer:',len(state_dict.keys()))
            # load file to model
            self.model.load_state_dict(state_dict,strict = True)
        print('Model Structure:')
        # Display model structure
        for name, param in self.model.named_parameters():
            print(name, param.shape)
        print('Parameters layer:',len(self.model.state_dict().keys()))
    
    def _from_old_model(self, state_dict, select = 'backbone'):
        if select == 'backbone':
            for key in list(state_dict):
                if 'net.resnet.' in key:
                    state_dict[key.replace('net.resnet.','resnet.')] = state_dict.pop(key)
                else:
                    state_dict.pop(key)
        elif select == 'nn':
            for key in list(state_dict):
                if 'net.global_regressor.' in key:
                    state_dict[key.replace('net.global_regressor.','global_regressor.')] = state_dict.pop(key)
                elif 'net.global_context.' in key:
                    state_dict[key.replace('net.global_context.','global_context.')] = state_dict.pop(key)
                else:
                    state_dict.pop(key)
        return state_dict
    
    def save_model(self, file_name = 'model-{}-{}.pth'):
        checkpoint_path = os.path.join(args.model_dir, file_name)
        torch.save(self.model.state_dict(),checkpoint_path)
        print('Saving model to ' +  file_name)
        
    def _optimize(self,regressor_context_rate = [0.0,0.0]):
        optimizer = [
                {'params': self.model.gps.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay}]
            
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            for param in self.model.nn.global_regressor.parameters():
                param.requires_grad = False
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
        else:
            for param in self.model.nn.global_context.parameters():
                param.requires_grad = False
                
        return optimizer
            
    def train(self,x,y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        x,y = x.cuda(),y.cuda()
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
            
        # Step 2: training
        assert self.model.training == True
        
        trans_loss = torch.tensor(0.).cuda()
        
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        trans_feat, rot_pred = self.model.forward_nn(x)
        rot_loss = self._nn_loss(rot_pred,rot_target)
        for i,gp in enumerate(self.model.gps):
            #torch.manual_seed(i)
            #sampled_mask = torch.randint(high=args.batch_size, size=(self.model.sub_batch_size,))
            sampled_mask = torch.randint(high=args.batch_size, size=(args.batch_size,))
            sub_x = trans_feat[sampled_mask]
            sub_y = trans_target[sampled_mask]
            gp_loss = self._gp_loss(gp,sub_x,sub_y)
            trans_loss += gp_loss
        trans_loss = trans_loss/self.model.num_gp
        
        total_loss = trans_loss + args.lamda_weights * rot_loss
        
        batch_time = time.time() - start
        
        #Step 3: update
        total_loss.backward()
        self.optimizer.step()
        
        return float(total_loss), batch_time    
    
    def _nn_loss(self,rot_pred,rot_target):
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        return rot_loss
        
    def _gp_loss(self,gp,trans_feat,trans_target):
        # predict
        trans_pred = self.model.forward_gp(gp,trans_feat)
        #sub_trans_feat = trans_feat[:,gp.feat_index]
        #trans_pred = gp(sub_trans_feat)
        
        #num_data = int(min(len(dataloader)*args.batch_size,len(dataset))*self.model.sub_batch_rate)
        num_data = min(len(dataloader)*args.batch_size,len(dataset))
        mll = gpytorch.mlls.PredictiveLogLikelihood(gp.likelihood, gp.gp, num_data = num_data)
        
        # trans loss
        trans_loss = -1.*mll(trans_pred, trans_target)
        
        return trans_loss
    
    def _eval_gp(self, gp, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = gp.likelihood(trans_pred).mean, gp.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var
    
    def _sample(self, mean, var, num_sample = 100):
        dist = Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples

    def eval_forward(self,x,y,num_sample = 100,output_denormalize = True):
        # Step 1: get data
        x,y = x.cuda(),y.cuda()
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
        
        # Step 2: forward
        assert self.model.training == False
        trans_feat, rot_pred = self.model.forward_nn(x)
        
        trans_preds = 0
        trans_means = 0
        trans_vars = 0
        for gp in self.model.gps:
            trans_pred = self.model.forward_gp(gp,trans_feat)
            trans_pred, trans_mean, trans_var = self._eval_gp(gp, trans_pred)
            trans_preds += trans_pred
            trans_means += trans_mean
            trans_vars += trans_var
            
        trans_preds /= self.model.num_gp
        trans_means /= self.model.num_gp
        trans_vars /= self.model.num_gp
        
        if args.is_normalization and output_denormalize:
            trans_preds = denormalize_navie(trans_preds, self.norm_mean, self.norm_std)
            trans_means = denormalize_navie(trans_means, self.norm_mean, self.norm_std)
            trans_vars = trans_vars.mul(self.norm_std)
            y = denormalize(y, self.norm_mean, self.norm_std)
        
        samples = self._sample(trans_means, trans_vars, num_sample)
            
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_preds, rot_pred, trans_target, rot_target, samples

num_gp = 100
gp_args = {
    'feat_rate':1-1/3,
    'num_gp':num_gp
}    

#trainer = Trainer(gp_args,regressor_context_rate = [0.1,0.01])
trainer = Trainer(gp_args,regressor_context_rate = [0.,0.])
#trainer.load_model('model-2-1000.pth')
trainer.load_model('pretrained_old.pth')
# Out:
# Regressor learn rate: 0.1
# Parameters layer: 1346
# Model Structure:
# backbone.resnet.conv1.weight torch.Size([64, 1, 7, 7])
# backbone.resnet.bn1.weight torch.Size([64])
# backbone.resnet.bn1.bias torch.Size([64])
# backbone.resnet.layer1.0.conv1.weight torch.Size([64, 64, 1, 1])
# backbone.resnet.layer1.0.bn1.weight torch.Size([64])
# backbone.resnet.layer1.0.bn1.bias torch.Size([64])
# backbone.resnet.layer1.0.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.0.bn2.weight torch.Size([64])
# backbone.resnet.layer1.0.bn2.bias torch.Size([64])
# backbone.resnet.layer1.0.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.0.bn3.weight torch.Size([256])
# backbone.resnet.layer1.0.bn3.bias torch.Size([256])
# backbone.resnet.layer1.0.downsample.0.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.0.downsample.1.weight torch.Size([256])
# backbone.resnet.layer1.0.downsample.1.bias torch.Size([256])
# backbone.resnet.layer1.1.conv1.weight torch.Size([64, 256, 1, 1])
# backbone.resnet.layer1.1.bn1.weight torch.Size([64])
# backbone.resnet.layer1.1.bn1.bias torch.Size([64])
# backbone.resnet.layer1.1.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.1.bn2.weight torch.Size([64])
# backbone.resnet.layer1.1.bn2.bias torch.Size([64])
# backbone.resnet.layer1.1.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.1.bn3.weight torch.Size([256])
# backbone.resnet.layer1.1.bn3.bias torch.Size([256])
# backbone.resnet.layer1.2.conv1.weight torch.Size([64, 256, 1, 1])
# backbone.resnet.layer1.2.bn1.weight torch.Size([64])
# backbone.resnet.layer1.2.bn1.bias torch.Size([64])
# backbone.resnet.layer1.2.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.2.bn2.weight torch.Size([64])
# backbone.resnet.layer1.2.bn2.bias torch.Size([64])
# backbone.resnet.layer1.2.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.2.bn3.weight torch.Size([256])
# backbone.resnet.layer1.2.bn3.bias torch.Size([256])
# backbone.resnet.layer2.0.conv1.weight torch.Size([128, 256, 1, 1])
# backbone.resnet.layer2.0.bn1.weight torch.Size([128])
# backbone.resnet.layer2.0.bn1.bias torch.Size([128])
# backbone.resnet.layer2.0.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.0.bn2.weight torch.Size([128])
# backbone.resnet.layer2.0.bn2.bias torch.Size([128])
# backbone.resnet.layer2.0.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.0.bn3.weight torch.Size([512])
# backbone.resnet.layer2.0.bn3.bias torch.Size([512])
# backbone.resnet.layer2.0.downsample.0.weight torch.Size([512, 256, 1, 1])
# backbone.resnet.layer2.0.downsample.1.weight torch.Size([512])
# backbone.resnet.layer2.0.downsample.1.bias torch.Size([512])
# backbone.resnet.layer2.1.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.1.bn1.weight torch.Size([128])
# backbone.resnet.layer2.1.bn1.bias torch.Size([128])
# backbone.resnet.layer2.1.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.1.bn2.weight torch.Size([128])
# backbone.resnet.layer2.1.bn2.bias torch.Size([128])
# backbone.resnet.layer2.1.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.1.bn3.weight torch.Size([512])
# backbone.resnet.layer2.1.bn3.bias torch.Size([512])
# backbone.resnet.layer2.2.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.2.bn1.weight torch.Size([128])
# backbone.resnet.layer2.2.bn1.bias torch.Size([128])
# backbone.resnet.layer2.2.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.2.bn2.weight torch.Size([128])
# backbone.resnet.layer2.2.bn2.bias torch.Size([128])
# backbone.resnet.layer2.2.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.2.bn3.weight torch.Size([512])
# backbone.resnet.layer2.2.bn3.bias torch.Size([512])
# backbone.resnet.layer2.3.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.3.bn1.weight torch.Size([128])
# backbone.resnet.layer2.3.bn1.bias torch.Size([128])
# backbone.resnet.layer2.3.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.3.bn2.weight torch.Size([128])
# backbone.resnet.layer2.3.bn2.bias torch.Size([128])
# backbone.resnet.layer2.3.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.3.bn3.weight torch.Size([512])
# backbone.resnet.layer2.3.bn3.bias torch.Size([512])
# backbone.resnet.layer3.0.conv1.weight torch.Size([256, 512, 1, 1])
# backbone.resnet.layer3.0.bn1.weight torch.Size([256])
# backbone.resnet.layer3.0.bn1.bias torch.Size([256])
# backbone.resnet.layer3.0.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.0.bn2.weight torch.Size([256])
# backbone.resnet.layer3.0.bn2.bias torch.Size([256])
# backbone.resnet.layer3.0.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.0.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.0.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.0.downsample.0.weight torch.Size([1024, 512, 1, 1])
# backbone.resnet.layer3.0.downsample.1.weight torch.Size([1024])
# backbone.resnet.layer3.0.downsample.1.bias torch.Size([1024])
# backbone.resnet.layer3.1.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.1.bn1.weight torch.Size([256])
# backbone.resnet.layer3.1.bn1.bias torch.Size([256])
# backbone.resnet.layer3.1.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.1.bn2.weight torch.Size([256])
# backbone.resnet.layer3.1.bn2.bias torch.Size([256])
# backbone.resnet.layer3.1.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.1.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.1.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.2.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.2.bn1.weight torch.Size([256])
# backbone.resnet.layer3.2.bn1.bias torch.Size([256])
# backbone.resnet.layer3.2.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.2.bn2.weight torch.Size([256])
# backbone.resnet.layer3.2.bn2.bias torch.Size([256])
# backbone.resnet.layer3.2.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.2.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.2.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.3.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.3.bn1.weight torch.Size([256])
# backbone.resnet.layer3.3.bn1.bias torch.Size([256])
# backbone.resnet.layer3.3.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.3.bn2.weight torch.Size([256])
# backbone.resnet.layer3.3.bn2.bias torch.Size([256])
# backbone.resnet.layer3.3.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.3.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.3.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.4.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.4.bn1.weight torch.Size([256])
# backbone.resnet.layer3.4.bn1.bias torch.Size([256])
# backbone.resnet.layer3.4.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.4.bn2.weight torch.Size([256])
# backbone.resnet.layer3.4.bn2.bias torch.Size([256])
# backbone.resnet.layer3.4.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.4.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.4.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.5.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.5.bn1.weight torch.Size([256])
# backbone.resnet.layer3.5.bn1.bias torch.Size([256])
# backbone.resnet.layer3.5.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.5.bn2.weight torch.Size([256])
# backbone.resnet.layer3.5.bn2.bias torch.Size([256])
# backbone.resnet.layer3.5.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.5.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.5.bn3.bias torch.Size([1024])
# backbone.resnet.layer4.0.conv1.weight torch.Size([512, 1024, 1, 1])
# backbone.resnet.layer4.0.bn1.weight torch.Size([512])
# backbone.resnet.layer4.0.bn1.bias torch.Size([512])
# backbone.resnet.layer4.0.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.0.bn2.weight torch.Size([512])
# backbone.resnet.layer4.0.bn2.bias torch.Size([512])
# backbone.resnet.layer4.0.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.0.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.0.bn3.bias torch.Size([2048])
# backbone.resnet.layer4.0.downsample.0.weight torch.Size([2048, 1024, 1, 1])
# backbone.resnet.layer4.0.downsample.1.weight torch.Size([2048])
# backbone.resnet.layer4.0.downsample.1.bias torch.Size([2048])
# backbone.resnet.layer4.1.conv1.weight torch.Size([512, 2048, 1, 1])
# backbone.resnet.layer4.1.bn1.weight torch.Size([512])
# backbone.resnet.layer4.1.bn1.bias torch.Size([512])
# backbone.resnet.layer4.1.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.1.bn2.weight torch.Size([512])
# backbone.resnet.layer4.1.bn2.bias torch.Size([512])
# backbone.resnet.layer4.1.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.1.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.1.bn3.bias torch.Size([2048])
# backbone.resnet.layer4.2.conv1.weight torch.Size([512, 2048, 1, 1])
# backbone.resnet.layer4.2.bn1.weight torch.Size([512])
# backbone.resnet.layer4.2.bn1.bias torch.Size([512])
# backbone.resnet.layer4.2.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.2.bn2.weight torch.Size([512])
# backbone.resnet.layer4.2.bn2.bias torch.Size([512])
# backbone.resnet.layer4.2.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.2.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.2.bn3.bias torch.Size([2048])
# nn.global_context.context.squeeze.0.weight torch.Size([128, 2048, 1, 1])
# nn.global_context.context.squeeze.0.bias torch.Size([128])
# nn.global_context.context.context5_1.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_1.0.bias torch.Size([128])
# nn.global_context.context.context5_2.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_2.0.bias torch.Size([128])
# nn.global_context.context.context5_3.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_3.0.bias torch.Size([128])
# nn.global_context.context.context5_4.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_4.0.bias torch.Size([128])
# nn.global_context.context.squeeze2.0.weight torch.Size([64, 128, 1, 1])
# nn.global_context.context.squeeze2.0.bias torch.Size([64])
# nn.global_regressor.regressor.fc1_trans.0.weight torch.Size([4096, 6400])
# nn.global_regressor.regressor.fc1_trans.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc2_trans.0.weight torch.Size([4096, 4096])
# nn.global_regressor.regressor.fc2_trans.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc3_trans.0.weight torch.Size([128, 4096])
# nn.global_regressor.regressor.fc3_trans.0.bias torch.Size([128])
# nn.global_regressor.regressor.logits_t.weight torch.Size([3, 128])
# nn.global_regressor.regressor.logits_t.bias torch.Size([3])
# nn.global_regressor.regressor.fc1_rot.0.weight torch.Size([4096, 6400])
# nn.global_regressor.regressor.fc1_rot.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc2_rot.0.weight torch.Size([4096, 4096])
# nn.global_regressor.regressor.fc2_rot.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc3_rot.0.weight torch.Size([128, 4096])
# nn.global_regressor.regressor.fc3_rot.0.bias torch.Size([128])
# nn.global_regressor.regressor.logits_r.weight torch.Size([4, 128])
# nn.global_regressor.regressor.logits_r.bias torch.Size([4])
# gps.0.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.0.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.0.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.0.gp.mean_module.constant torch.Size([1, 1])
# gps.0.gp.covar_module.raw_outputscale torch.Size([1])
# gps.0.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.0.likelihood.raw_noise torch.Size([1])
# gps.0.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.1.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.1.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.1.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.1.gp.mean_module.constant torch.Size([1, 1])
# gps.1.gp.covar_module.raw_outputscale torch.Size([1])
# gps.1.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.1.likelihood.raw_noise torch.Size([1])
# gps.1.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.2.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.2.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.2.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.2.gp.mean_module.constant torch.Size([1, 1])
# gps.2.gp.covar_module.raw_outputscale torch.Size([1])
# gps.2.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.2.likelihood.raw_noise torch.Size([1])
# gps.2.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.3.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.3.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.3.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.3.gp.mean_module.constant torch.Size([1, 1])
# gps.3.gp.covar_module.raw_outputscale torch.Size([1])
# gps.3.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.3.likelihood.raw_noise torch.Size([1])
# gps.3.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.4.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.4.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.4.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.4.gp.mean_module.constant torch.Size([1, 1])
# gps.4.gp.covar_module.raw_outputscale torch.Size([1])
# gps.4.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.4.likelihood.raw_noise torch.Size([1])
# gps.4.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.5.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.5.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.5.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.5.gp.mean_module.constant torch.Size([1, 1])
# gps.5.gp.covar_module.raw_outputscale torch.Size([1])
# gps.5.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.5.likelihood.raw_noise torch.Size([1])
# gps.5.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.6.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.6.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.6.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.6.gp.mean_module.constant torch.Size([1, 1])
# gps.6.gp.covar_module.raw_outputscale torch.Size([1])
# gps.6.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.6.likelihood.raw_noise torch.Size([1])
# gps.6.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.7.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.7.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.7.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.7.gp.mean_module.constant torch.Size([1, 1])
# gps.7.gp.covar_module.raw_outputscale torch.Size([1])
# gps.7.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.7.likelihood.raw_noise torch.Size([1])
# gps.7.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.8.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.8.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.8.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.8.gp.mean_module.constant torch.Size([1, 1])
# gps.8.gp.covar_module.raw_outputscale torch.Size([1])
# gps.8.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.8.likelihood.raw_noise torch.Size([1])
# gps.8.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.9.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.9.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.9.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.9.gp.mean_module.constant torch.Size([1, 1])
# gps.9.gp.covar_module.raw_outputscale torch.Size([1])
# gps.9.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.9.likelihood.raw_noise torch.Size([1])
# gps.9.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.10.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.10.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.10.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.10.gp.mean_module.constant torch.Size([1, 1])
# gps.10.gp.covar_module.raw_outputscale torch.Size([1])
# gps.10.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.10.likelihood.raw_noise torch.Size([1])
# gps.10.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.11.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.11.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.11.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.11.gp.mean_module.constant torch.Size([1, 1])
# gps.11.gp.covar_module.raw_outputscale torch.Size([1])
# gps.11.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.11.likelihood.raw_noise torch.Size([1])
# gps.11.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.12.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.12.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.12.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.12.gp.mean_module.constant torch.Size([1, 1])
# gps.12.gp.covar_module.raw_outputscale torch.Size([1])
# gps.12.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.12.likelihood.raw_noise torch.Size([1])
# gps.12.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.13.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.13.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.13.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.13.gp.mean_module.constant torch.Size([1, 1])
# gps.13.gp.covar_module.raw_outputscale torch.Size([1])
# gps.13.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.13.likelihood.raw_noise torch.Size([1])
# gps.13.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.14.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.14.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.14.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.14.gp.mean_module.constant torch.Size([1, 1])
# gps.14.gp.covar_module.raw_outputscale torch.Size([1])
# gps.14.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.14.likelihood.raw_noise torch.Size([1])
# gps.14.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.15.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.15.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.15.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.15.gp.mean_module.constant torch.Size([1, 1])
# gps.15.gp.covar_module.raw_outputscale torch.Size([1])
# gps.15.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.15.likelihood.raw_noise torch.Size([1])
# gps.15.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.16.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.16.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.16.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.16.gp.mean_module.constant torch.Size([1, 1])
# gps.16.gp.covar_module.raw_outputscale torch.Size([1])
# gps.16.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.16.likelihood.raw_noise torch.Size([1])
# gps.16.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.17.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.17.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.17.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.17.gp.mean_module.constant torch.Size([1, 1])
# gps.17.gp.covar_module.raw_outputscale torch.Size([1])
# gps.17.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.17.likelihood.raw_noise torch.Size([1])
# gps.17.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.18.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.18.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.18.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.18.gp.mean_module.constant torch.Size([1, 1])
# gps.18.gp.covar_module.raw_outputscale torch.Size([1])
# gps.18.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.18.likelihood.raw_noise torch.Size([1])
# gps.18.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.19.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.19.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.19.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.19.gp.mean_module.constant torch.Size([1, 1])
# gps.19.gp.covar_module.raw_outputscale torch.Size([1])
# gps.19.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.19.likelihood.raw_noise torch.Size([1])
# gps.19.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.20.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.20.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.20.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.20.gp.mean_module.constant torch.Size([1, 1])
# gps.20.gp.covar_module.raw_outputscale torch.Size([1])
# gps.20.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.20.likelihood.raw_noise torch.Size([1])
# gps.20.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.21.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.21.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.21.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.21.gp.mean_module.constant torch.Size([1, 1])
# gps.21.gp.covar_module.raw_outputscale torch.Size([1])
# gps.21.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.21.likelihood.raw_noise torch.Size([1])
# gps.21.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.22.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.22.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.22.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.22.gp.mean_module.constant torch.Size([1, 1])
# gps.22.gp.covar_module.raw_outputscale torch.Size([1])
# gps.22.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.22.likelihood.raw_noise torch.Size([1])
# gps.22.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.23.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.23.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.23.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.23.gp.mean_module.constant torch.Size([1, 1])
# gps.23.gp.covar_module.raw_outputscale torch.Size([1])
# gps.23.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.23.likelihood.raw_noise torch.Size([1])
# gps.23.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.24.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.24.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.24.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.24.gp.mean_module.constant torch.Size([1, 1])
# gps.24.gp.covar_module.raw_outputscale torch.Size([1])
# gps.24.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.24.likelihood.raw_noise torch.Size([1])
# gps.24.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.25.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.25.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.25.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.25.gp.mean_module.constant torch.Size([1, 1])
# gps.25.gp.covar_module.raw_outputscale torch.Size([1])
# gps.25.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.25.likelihood.raw_noise torch.Size([1])
# gps.25.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.26.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.26.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.26.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.26.gp.mean_module.constant torch.Size([1, 1])
# gps.26.gp.covar_module.raw_outputscale torch.Size([1])
# gps.26.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.26.likelihood.raw_noise torch.Size([1])
# gps.26.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.27.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.27.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.27.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.27.gp.mean_module.constant torch.Size([1, 1])
# gps.27.gp.covar_module.raw_outputscale torch.Size([1])
# gps.27.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.27.likelihood.raw_noise torch.Size([1])
# gps.27.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.28.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.28.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.28.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.28.gp.mean_module.constant torch.Size([1, 1])
# gps.28.gp.covar_module.raw_outputscale torch.Size([1])
# gps.28.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.28.likelihood.raw_noise torch.Size([1])
# gps.28.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.29.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.29.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.29.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.29.gp.mean_module.constant torch.Size([1, 1])
# gps.29.gp.covar_module.raw_outputscale torch.Size([1])
# gps.29.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.29.likelihood.raw_noise torch.Size([1])
# gps.29.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.30.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.30.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.30.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.30.gp.mean_module.constant torch.Size([1, 1])
# gps.30.gp.covar_module.raw_outputscale torch.Size([1])
# gps.30.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.30.likelihood.raw_noise torch.Size([1])
# gps.30.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.31.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.31.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.31.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.31.gp.mean_module.constant torch.Size([1, 1])
# gps.31.gp.covar_module.raw_outputscale torch.Size([1])
# gps.31.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.31.likelihood.raw_noise torch.Size([1])
# gps.31.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.32.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.32.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.32.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.32.gp.mean_module.constant torch.Size([1, 1])
# gps.32.gp.covar_module.raw_outputscale torch.Size([1])
# gps.32.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.32.likelihood.raw_noise torch.Size([1])
# gps.32.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.33.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.33.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.33.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.33.gp.mean_module.constant torch.Size([1, 1])
# gps.33.gp.covar_module.raw_outputscale torch.Size([1])
# gps.33.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.33.likelihood.raw_noise torch.Size([1])
# gps.33.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.34.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.34.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.34.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.34.gp.mean_module.constant torch.Size([1, 1])
# gps.34.gp.covar_module.raw_outputscale torch.Size([1])
# gps.34.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.34.likelihood.raw_noise torch.Size([1])
# gps.34.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.35.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.35.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.35.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.35.gp.mean_module.constant torch.Size([1, 1])
# gps.35.gp.covar_module.raw_outputscale torch.Size([1])
# gps.35.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.35.likelihood.raw_noise torch.Size([1])
# gps.35.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.36.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.36.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.36.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.36.gp.mean_module.constant torch.Size([1, 1])
# gps.36.gp.covar_module.raw_outputscale torch.Size([1])
# gps.36.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.36.likelihood.raw_noise torch.Size([1])
# gps.36.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.37.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.37.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.37.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.37.gp.mean_module.constant torch.Size([1, 1])
# gps.37.gp.covar_module.raw_outputscale torch.Size([1])
# gps.37.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.37.likelihood.raw_noise torch.Size([1])
# gps.37.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.38.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.38.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.38.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.38.gp.mean_module.constant torch.Size([1, 1])
# gps.38.gp.covar_module.raw_outputscale torch.Size([1])
# gps.38.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.38.likelihood.raw_noise torch.Size([1])
# gps.38.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.39.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.39.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.39.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.39.gp.mean_module.constant torch.Size([1, 1])
# gps.39.gp.covar_module.raw_outputscale torch.Size([1])
# gps.39.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.39.likelihood.raw_noise torch.Size([1])
# gps.39.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.40.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.40.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.40.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.40.gp.mean_module.constant torch.Size([1, 1])
# gps.40.gp.covar_module.raw_outputscale torch.Size([1])
# gps.40.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.40.likelihood.raw_noise torch.Size([1])
# gps.40.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.41.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.41.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.41.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.41.gp.mean_module.constant torch.Size([1, 1])
# gps.41.gp.covar_module.raw_outputscale torch.Size([1])
# gps.41.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.41.likelihood.raw_noise torch.Size([1])
# gps.41.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.42.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.42.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.42.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.42.gp.mean_module.constant torch.Size([1, 1])
# gps.42.gp.covar_module.raw_outputscale torch.Size([1])
# gps.42.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.42.likelihood.raw_noise torch.Size([1])
# gps.42.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.43.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.43.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.43.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.43.gp.mean_module.constant torch.Size([1, 1])
# gps.43.gp.covar_module.raw_outputscale torch.Size([1])
# gps.43.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.43.likelihood.raw_noise torch.Size([1])
# gps.43.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.44.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.44.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.44.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.44.gp.mean_module.constant torch.Size([1, 1])
# gps.44.gp.covar_module.raw_outputscale torch.Size([1])
# gps.44.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.44.likelihood.raw_noise torch.Size([1])
# gps.44.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.45.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.45.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.45.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.45.gp.mean_module.constant torch.Size([1, 1])
# gps.45.gp.covar_module.raw_outputscale torch.Size([1])
# gps.45.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.45.likelihood.raw_noise torch.Size([1])
# gps.45.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.46.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.46.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.46.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.46.gp.mean_module.constant torch.Size([1, 1])
# gps.46.gp.covar_module.raw_outputscale torch.Size([1])
# gps.46.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.46.likelihood.raw_noise torch.Size([1])
# gps.46.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.47.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.47.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.47.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.47.gp.mean_module.constant torch.Size([1, 1])
# gps.47.gp.covar_module.raw_outputscale torch.Size([1])
# gps.47.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.47.likelihood.raw_noise torch.Size([1])
# gps.47.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.48.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.48.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.48.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.48.gp.mean_module.constant torch.Size([1, 1])
# gps.48.gp.covar_module.raw_outputscale torch.Size([1])
# gps.48.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.48.likelihood.raw_noise torch.Size([1])
# gps.48.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.49.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.49.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.49.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.49.gp.mean_module.constant torch.Size([1, 1])
# gps.49.gp.covar_module.raw_outputscale torch.Size([1])
# gps.49.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.49.likelihood.raw_noise torch.Size([1])
# gps.49.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.50.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.50.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.50.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.50.gp.mean_module.constant torch.Size([1, 1])
# gps.50.gp.covar_module.raw_outputscale torch.Size([1])
# gps.50.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.50.likelihood.raw_noise torch.Size([1])
# gps.50.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.51.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.51.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.51.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.51.gp.mean_module.constant torch.Size([1, 1])
# gps.51.gp.covar_module.raw_outputscale torch.Size([1])
# gps.51.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.51.likelihood.raw_noise torch.Size([1])
# gps.51.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.52.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.52.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.52.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.52.gp.mean_module.constant torch.Size([1, 1])
# gps.52.gp.covar_module.raw_outputscale torch.Size([1])
# gps.52.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.52.likelihood.raw_noise torch.Size([1])
# gps.52.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.53.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.53.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.53.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.53.gp.mean_module.constant torch.Size([1, 1])
# gps.53.gp.covar_module.raw_outputscale torch.Size([1])
# gps.53.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.53.likelihood.raw_noise torch.Size([1])
# gps.53.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.54.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.54.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.54.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.54.gp.mean_module.constant torch.Size([1, 1])
# gps.54.gp.covar_module.raw_outputscale torch.Size([1])
# gps.54.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.54.likelihood.raw_noise torch.Size([1])
# gps.54.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.55.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.55.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.55.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.55.gp.mean_module.constant torch.Size([1, 1])
# gps.55.gp.covar_module.raw_outputscale torch.Size([1])
# gps.55.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.55.likelihood.raw_noise torch.Size([1])
# gps.55.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.56.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.56.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.56.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.56.gp.mean_module.constant torch.Size([1, 1])
# gps.56.gp.covar_module.raw_outputscale torch.Size([1])
# gps.56.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.56.likelihood.raw_noise torch.Size([1])
# gps.56.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.57.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.57.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.57.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.57.gp.mean_module.constant torch.Size([1, 1])
# gps.57.gp.covar_module.raw_outputscale torch.Size([1])
# gps.57.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.57.likelihood.raw_noise torch.Size([1])
# gps.57.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.58.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.58.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.58.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# ...
# gps.74.gp.covar_module.raw_outputscale torch.Size([1])
# gps.74.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.74.likelihood.raw_noise torch.Size([1])
# gps.74.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.75.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.75.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.75.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.75.gp.mean_module.constant torch.Size([1, 1])
# gps.75.gp.covar_module.raw_outputscale torch.Size([1])
# gps.75.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.75.likelihood.raw_noise torch.Size([1])
# gps.75.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.76.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.76.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.76.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.76.gp.mean_module.constant torch.Size([1, 1])
# gps.76.gp.covar_module.raw_outputscale torch.Size([1])
# gps.76.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.76.likelihood.raw_noise torch.Size([1])
# gps.76.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.77.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.77.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.77.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.77.gp.mean_module.constant torch.Size([1, 1])
# gps.77.gp.covar_module.raw_outputscale torch.Size([1])
# gps.77.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.77.likelihood.raw_noise torch.Size([1])
# gps.77.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.78.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.78.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.78.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.78.gp.mean_module.constant torch.Size([1, 1])
# gps.78.gp.covar_module.raw_outputscale torch.Size([1])
# gps.78.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.78.likelihood.raw_noise torch.Size([1])
# gps.78.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.79.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.79.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.79.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.79.gp.mean_module.constant torch.Size([1, 1])
# gps.79.gp.covar_module.raw_outputscale torch.Size([1])
# gps.79.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.79.likelihood.raw_noise torch.Size([1])
# gps.79.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.80.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.80.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.80.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.80.gp.mean_module.constant torch.Size([1, 1])
# gps.80.gp.covar_module.raw_outputscale torch.Size([1])
# gps.80.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.80.likelihood.raw_noise torch.Size([1])
# gps.80.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.81.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.81.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.81.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.81.gp.mean_module.constant torch.Size([1, 1])
# gps.81.gp.covar_module.raw_outputscale torch.Size([1])
# gps.81.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.81.likelihood.raw_noise torch.Size([1])
# gps.81.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.82.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.82.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.82.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.82.gp.mean_module.constant torch.Size([1, 1])
# gps.82.gp.covar_module.raw_outputscale torch.Size([1])
# gps.82.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.82.likelihood.raw_noise torch.Size([1])
# gps.82.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.83.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.83.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.83.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.83.gp.mean_module.constant torch.Size([1, 1])
# gps.83.gp.covar_module.raw_outputscale torch.Size([1])
# gps.83.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.83.likelihood.raw_noise torch.Size([1])
# gps.83.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.84.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.84.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.84.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.84.gp.mean_module.constant torch.Size([1, 1])
# gps.84.gp.covar_module.raw_outputscale torch.Size([1])
# gps.84.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.84.likelihood.raw_noise torch.Size([1])
# gps.84.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.85.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.85.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.85.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.85.gp.mean_module.constant torch.Size([1, 1])
# gps.85.gp.covar_module.raw_outputscale torch.Size([1])
# gps.85.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.85.likelihood.raw_noise torch.Size([1])
# gps.85.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.86.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.86.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.86.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.86.gp.mean_module.constant torch.Size([1, 1])
# gps.86.gp.covar_module.raw_outputscale torch.Size([1])
# gps.86.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.86.likelihood.raw_noise torch.Size([1])
# gps.86.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.87.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.87.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.87.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.87.gp.mean_module.constant torch.Size([1, 1])
# gps.87.gp.covar_module.raw_outputscale torch.Size([1])
# gps.87.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.87.likelihood.raw_noise torch.Size([1])
# gps.87.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.88.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.88.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.88.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.88.gp.mean_module.constant torch.Size([1, 1])
# gps.88.gp.covar_module.raw_outputscale torch.Size([1])
# gps.88.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.88.likelihood.raw_noise torch.Size([1])
# gps.88.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.89.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.89.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.89.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.89.gp.mean_module.constant torch.Size([1, 1])
# gps.89.gp.covar_module.raw_outputscale torch.Size([1])
# gps.89.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.89.likelihood.raw_noise torch.Size([1])
# gps.89.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.90.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.90.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.90.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.90.gp.mean_module.constant torch.Size([1, 1])
# gps.90.gp.covar_module.raw_outputscale torch.Size([1])
# gps.90.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.90.likelihood.raw_noise torch.Size([1])
# gps.90.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.91.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.91.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.91.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.91.gp.mean_module.constant torch.Size([1, 1])
# gps.91.gp.covar_module.raw_outputscale torch.Size([1])
# gps.91.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.91.likelihood.raw_noise torch.Size([1])
# gps.91.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.92.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.92.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.92.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.92.gp.mean_module.constant torch.Size([1, 1])
# gps.92.gp.covar_module.raw_outputscale torch.Size([1])
# gps.92.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.92.likelihood.raw_noise torch.Size([1])
# gps.92.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.93.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.93.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.93.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.93.gp.mean_module.constant torch.Size([1, 1])
# gps.93.gp.covar_module.raw_outputscale torch.Size([1])
# gps.93.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.93.likelihood.raw_noise torch.Size([1])
# gps.93.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.94.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.94.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.94.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.94.gp.mean_module.constant torch.Size([1, 1])
# gps.94.gp.covar_module.raw_outputscale torch.Size([1])
# gps.94.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.94.likelihood.raw_noise torch.Size([1])
# gps.94.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.95.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.95.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.95.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.95.gp.mean_module.constant torch.Size([1, 1])
# gps.95.gp.covar_module.raw_outputscale torch.Size([1])
# gps.95.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.95.likelihood.raw_noise torch.Size([1])
# gps.95.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.96.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.96.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.96.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.96.gp.mean_module.constant torch.Size([1, 1])
# gps.96.gp.covar_module.raw_outputscale torch.Size([1])
# gps.96.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.96.likelihood.raw_noise torch.Size([1])
# gps.96.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.97.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.97.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.97.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.97.gp.mean_module.constant torch.Size([1, 1])
# gps.97.gp.covar_module.raw_outputscale torch.Size([1])
# gps.97.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.97.likelihood.raw_noise torch.Size([1])
# gps.97.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.98.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.98.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.98.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.98.gp.mean_module.constant torch.Size([1, 1])
# gps.98.gp.covar_module.raw_outputscale torch.Size([1])
# gps.98.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.98.likelihood.raw_noise torch.Size([1])
# gps.98.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.99.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.99.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.99.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.99.gp.mean_module.constant torch.Size([1, 1])
# gps.99.gp.covar_module.raw_outputscale torch.Size([1])
# gps.99.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.99.likelihood.raw_noise torch.Size([1])
# gps.99.likelihood.noise_covar.raw_noise torch.Size([3])
# Parameters layer: 1346

# %%
for name,param in trainer.model.named_parameters():
    if param.requires_grad:
        print(name, param.shape)
# Out:
# nn.global_regressor.regressor.fc1_trans.0.weight torch.Size([4096, 6400])
# nn.global_regressor.regressor.fc1_trans.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc2_trans.0.weight torch.Size([4096, 4096])
# nn.global_regressor.regressor.fc2_trans.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc3_trans.0.weight torch.Size([128, 4096])
# nn.global_regressor.regressor.fc3_trans.0.bias torch.Size([128])
# nn.global_regressor.regressor.logits_t.weight torch.Size([3, 128])
# nn.global_regressor.regressor.logits_t.bias torch.Size([3])
# nn.global_regressor.regressor.fc1_rot.0.weight torch.Size([4096, 6400])
# nn.global_regressor.regressor.fc1_rot.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc2_rot.0.weight torch.Size([4096, 4096])
# nn.global_regressor.regressor.fc2_rot.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc3_rot.0.weight torch.Size([128, 4096])
# nn.global_regressor.regressor.fc3_rot.0.bias torch.Size([128])
# nn.global_regressor.regressor.logits_r.weight torch.Size([4, 128])
# nn.global_regressor.regressor.logits_r.bias torch.Size([4])
# gps.0.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.0.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.0.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.0.gp.mean_module.constant torch.Size([1, 1])
# gps.0.gp.covar_module.raw_outputscale torch.Size([1])
# gps.0.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.0.likelihood.raw_noise torch.Size([1])
# gps.0.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.1.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.1.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.1.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.1.gp.mean_module.constant torch.Size([1, 1])
# gps.1.gp.covar_module.raw_outputscale torch.Size([1])
# gps.1.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.1.likelihood.raw_noise torch.Size([1])
# gps.1.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.2.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.2.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.2.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.2.gp.mean_module.constant torch.Size([1, 1])
# gps.2.gp.covar_module.raw_outputscale torch.Size([1])
# gps.2.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.2.likelihood.raw_noise torch.Size([1])
# gps.2.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.3.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.3.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.3.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.3.gp.mean_module.constant torch.Size([1, 1])
# gps.3.gp.covar_module.raw_outputscale torch.Size([1])
# gps.3.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.3.likelihood.raw_noise torch.Size([1])
# gps.3.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.4.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.4.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.4.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.4.gp.mean_module.constant torch.Size([1, 1])
# gps.4.gp.covar_module.raw_outputscale torch.Size([1])
# gps.4.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.4.likelihood.raw_noise torch.Size([1])
# gps.4.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.5.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.5.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.5.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.5.gp.mean_module.constant torch.Size([1, 1])
# gps.5.gp.covar_module.raw_outputscale torch.Size([1])
# gps.5.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.5.likelihood.raw_noise torch.Size([1])
# gps.5.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.6.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.6.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.6.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.6.gp.mean_module.constant torch.Size([1, 1])
# gps.6.gp.covar_module.raw_outputscale torch.Size([1])
# gps.6.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.6.likelihood.raw_noise torch.Size([1])
# gps.6.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.7.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.7.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.7.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.7.gp.mean_module.constant torch.Size([1, 1])
# gps.7.gp.covar_module.raw_outputscale torch.Size([1])
# gps.7.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.7.likelihood.raw_noise torch.Size([1])
# gps.7.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.8.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.8.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.8.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.8.gp.mean_module.constant torch.Size([1, 1])
# gps.8.gp.covar_module.raw_outputscale torch.Size([1])
# gps.8.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.8.likelihood.raw_noise torch.Size([1])
# gps.8.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.9.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.9.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.9.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.9.gp.mean_module.constant torch.Size([1, 1])
# gps.9.gp.covar_module.raw_outputscale torch.Size([1])
# gps.9.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.9.likelihood.raw_noise torch.Size([1])
# gps.9.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.10.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.10.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.10.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.10.gp.mean_module.constant torch.Size([1, 1])
# gps.10.gp.covar_module.raw_outputscale torch.Size([1])
# gps.10.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.10.likelihood.raw_noise torch.Size([1])
# gps.10.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.11.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.11.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.11.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.11.gp.mean_module.constant torch.Size([1, 1])
# gps.11.gp.covar_module.raw_outputscale torch.Size([1])
# gps.11.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.11.likelihood.raw_noise torch.Size([1])
# gps.11.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.12.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.12.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.12.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.12.gp.mean_module.constant torch.Size([1, 1])
# gps.12.gp.covar_module.raw_outputscale torch.Size([1])
# gps.12.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.12.likelihood.raw_noise torch.Size([1])
# gps.12.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.13.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.13.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.13.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.13.gp.mean_module.constant torch.Size([1, 1])
# gps.13.gp.covar_module.raw_outputscale torch.Size([1])
# gps.13.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.13.likelihood.raw_noise torch.Size([1])
# gps.13.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.14.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.14.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.14.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.14.gp.mean_module.constant torch.Size([1, 1])
# gps.14.gp.covar_module.raw_outputscale torch.Size([1])
# gps.14.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.14.likelihood.raw_noise torch.Size([1])
# gps.14.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.15.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.15.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.15.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.15.gp.mean_module.constant torch.Size([1, 1])
# gps.15.gp.covar_module.raw_outputscale torch.Size([1])
# gps.15.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.15.likelihood.raw_noise torch.Size([1])
# gps.15.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.16.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.16.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.16.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.16.gp.mean_module.constant torch.Size([1, 1])
# gps.16.gp.covar_module.raw_outputscale torch.Size([1])
# gps.16.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.16.likelihood.raw_noise torch.Size([1])
# gps.16.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.17.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.17.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.17.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.17.gp.mean_module.constant torch.Size([1, 1])
# gps.17.gp.covar_module.raw_outputscale torch.Size([1])
# gps.17.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.17.likelihood.raw_noise torch.Size([1])
# gps.17.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.18.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.18.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.18.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.18.gp.mean_module.constant torch.Size([1, 1])
# gps.18.gp.covar_module.raw_outputscale torch.Size([1])
# gps.18.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.18.likelihood.raw_noise torch.Size([1])
# gps.18.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.19.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.19.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.19.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.19.gp.mean_module.constant torch.Size([1, 1])
# gps.19.gp.covar_module.raw_outputscale torch.Size([1])
# gps.19.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.19.likelihood.raw_noise torch.Size([1])
# gps.19.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.20.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.20.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.20.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.20.gp.mean_module.constant torch.Size([1, 1])
# gps.20.gp.covar_module.raw_outputscale torch.Size([1])
# gps.20.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.20.likelihood.raw_noise torch.Size([1])
# gps.20.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.21.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.21.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.21.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.21.gp.mean_module.constant torch.Size([1, 1])
# gps.21.gp.covar_module.raw_outputscale torch.Size([1])
# gps.21.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.21.likelihood.raw_noise torch.Size([1])
# gps.21.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.22.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.22.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.22.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.22.gp.mean_module.constant torch.Size([1, 1])
# gps.22.gp.covar_module.raw_outputscale torch.Size([1])
# gps.22.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.22.likelihood.raw_noise torch.Size([1])
# gps.22.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.23.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.23.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.23.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.23.gp.mean_module.constant torch.Size([1, 1])
# gps.23.gp.covar_module.raw_outputscale torch.Size([1])
# gps.23.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.23.likelihood.raw_noise torch.Size([1])
# gps.23.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.24.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.24.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.24.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.24.gp.mean_module.constant torch.Size([1, 1])
# gps.24.gp.covar_module.raw_outputscale torch.Size([1])
# gps.24.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.24.likelihood.raw_noise torch.Size([1])
# gps.24.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.25.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.25.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.25.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.25.gp.mean_module.constant torch.Size([1, 1])
# gps.25.gp.covar_module.raw_outputscale torch.Size([1])
# gps.25.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.25.likelihood.raw_noise torch.Size([1])
# gps.25.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.26.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.26.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.26.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.26.gp.mean_module.constant torch.Size([1, 1])
# gps.26.gp.covar_module.raw_outputscale torch.Size([1])
# gps.26.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.26.likelihood.raw_noise torch.Size([1])
# gps.26.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.27.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.27.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.27.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.27.gp.mean_module.constant torch.Size([1, 1])
# gps.27.gp.covar_module.raw_outputscale torch.Size([1])
# gps.27.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.27.likelihood.raw_noise torch.Size([1])
# gps.27.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.28.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.28.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.28.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.28.gp.mean_module.constant torch.Size([1, 1])
# gps.28.gp.covar_module.raw_outputscale torch.Size([1])
# gps.28.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.28.likelihood.raw_noise torch.Size([1])
# gps.28.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.29.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.29.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.29.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.29.gp.mean_module.constant torch.Size([1, 1])
# gps.29.gp.covar_module.raw_outputscale torch.Size([1])
# gps.29.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.29.likelihood.raw_noise torch.Size([1])
# gps.29.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.30.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.30.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.30.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.30.gp.mean_module.constant torch.Size([1, 1])
# gps.30.gp.covar_module.raw_outputscale torch.Size([1])
# gps.30.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.30.likelihood.raw_noise torch.Size([1])
# gps.30.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.31.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.31.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.31.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.31.gp.mean_module.constant torch.Size([1, 1])
# gps.31.gp.covar_module.raw_outputscale torch.Size([1])
# gps.31.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.31.likelihood.raw_noise torch.Size([1])
# gps.31.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.32.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.32.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.32.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.32.gp.mean_module.constant torch.Size([1, 1])
# gps.32.gp.covar_module.raw_outputscale torch.Size([1])
# gps.32.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.32.likelihood.raw_noise torch.Size([1])
# gps.32.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.33.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.33.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.33.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.33.gp.mean_module.constant torch.Size([1, 1])
# gps.33.gp.covar_module.raw_outputscale torch.Size([1])
# gps.33.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.33.likelihood.raw_noise torch.Size([1])
# gps.33.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.34.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.34.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.34.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.34.gp.mean_module.constant torch.Size([1, 1])
# gps.34.gp.covar_module.raw_outputscale torch.Size([1])
# gps.34.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.34.likelihood.raw_noise torch.Size([1])
# gps.34.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.35.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.35.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.35.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.35.gp.mean_module.constant torch.Size([1, 1])
# gps.35.gp.covar_module.raw_outputscale torch.Size([1])
# gps.35.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.35.likelihood.raw_noise torch.Size([1])
# gps.35.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.36.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.36.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.36.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.36.gp.mean_module.constant torch.Size([1, 1])
# gps.36.gp.covar_module.raw_outputscale torch.Size([1])
# gps.36.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.36.likelihood.raw_noise torch.Size([1])
# gps.36.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.37.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.37.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.37.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.37.gp.mean_module.constant torch.Size([1, 1])
# gps.37.gp.covar_module.raw_outputscale torch.Size([1])
# gps.37.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.37.likelihood.raw_noise torch.Size([1])
# gps.37.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.38.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.38.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.38.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.38.gp.mean_module.constant torch.Size([1, 1])
# gps.38.gp.covar_module.raw_outputscale torch.Size([1])
# gps.38.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.38.likelihood.raw_noise torch.Size([1])
# gps.38.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.39.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.39.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.39.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.39.gp.mean_module.constant torch.Size([1, 1])
# gps.39.gp.covar_module.raw_outputscale torch.Size([1])
# gps.39.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.39.likelihood.raw_noise torch.Size([1])
# gps.39.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.40.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.40.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.40.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.40.gp.mean_module.constant torch.Size([1, 1])
# gps.40.gp.covar_module.raw_outputscale torch.Size([1])
# gps.40.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.40.likelihood.raw_noise torch.Size([1])
# gps.40.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.41.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.41.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.41.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.41.gp.mean_module.constant torch.Size([1, 1])
# gps.41.gp.covar_module.raw_outputscale torch.Size([1])
# gps.41.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.41.likelihood.raw_noise torch.Size([1])
# gps.41.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.42.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.42.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.42.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.42.gp.mean_module.constant torch.Size([1, 1])
# gps.42.gp.covar_module.raw_outputscale torch.Size([1])
# gps.42.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.42.likelihood.raw_noise torch.Size([1])
# gps.42.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.43.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.43.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.43.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.43.gp.mean_module.constant torch.Size([1, 1])
# gps.43.gp.covar_module.raw_outputscale torch.Size([1])
# gps.43.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.43.likelihood.raw_noise torch.Size([1])
# gps.43.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.44.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.44.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.44.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.44.gp.mean_module.constant torch.Size([1, 1])
# gps.44.gp.covar_module.raw_outputscale torch.Size([1])
# gps.44.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.44.likelihood.raw_noise torch.Size([1])
# gps.44.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.45.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.45.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.45.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.45.gp.mean_module.constant torch.Size([1, 1])
# gps.45.gp.covar_module.raw_outputscale torch.Size([1])
# gps.45.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.45.likelihood.raw_noise torch.Size([1])
# gps.45.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.46.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.46.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.46.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.46.gp.mean_module.constant torch.Size([1, 1])
# gps.46.gp.covar_module.raw_outputscale torch.Size([1])
# gps.46.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.46.likelihood.raw_noise torch.Size([1])
# gps.46.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.47.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.47.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.47.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.47.gp.mean_module.constant torch.Size([1, 1])
# gps.47.gp.covar_module.raw_outputscale torch.Size([1])
# gps.47.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.47.likelihood.raw_noise torch.Size([1])
# gps.47.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.48.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.48.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.48.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.48.gp.mean_module.constant torch.Size([1, 1])
# gps.48.gp.covar_module.raw_outputscale torch.Size([1])
# gps.48.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.48.likelihood.raw_noise torch.Size([1])
# gps.48.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.49.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.49.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.49.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.49.gp.mean_module.constant torch.Size([1, 1])
# gps.49.gp.covar_module.raw_outputscale torch.Size([1])
# gps.49.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.49.likelihood.raw_noise torch.Size([1])
# gps.49.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.50.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.50.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.50.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.50.gp.mean_module.constant torch.Size([1, 1])
# gps.50.gp.covar_module.raw_outputscale torch.Size([1])
# gps.50.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.50.likelihood.raw_noise torch.Size([1])
# gps.50.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.51.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.51.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.51.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.51.gp.mean_module.constant torch.Size([1, 1])
# gps.51.gp.covar_module.raw_outputscale torch.Size([1])
# gps.51.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.51.likelihood.raw_noise torch.Size([1])
# gps.51.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.52.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.52.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.52.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.52.gp.mean_module.constant torch.Size([1, 1])
# gps.52.gp.covar_module.raw_outputscale torch.Size([1])
# gps.52.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.52.likelihood.raw_noise torch.Size([1])
# gps.52.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.53.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.53.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.53.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.53.gp.mean_module.constant torch.Size([1, 1])
# gps.53.gp.covar_module.raw_outputscale torch.Size([1])
# gps.53.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.53.likelihood.raw_noise torch.Size([1])
# gps.53.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.54.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.54.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.54.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.54.gp.mean_module.constant torch.Size([1, 1])
# gps.54.gp.covar_module.raw_outputscale torch.Size([1])
# gps.54.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.54.likelihood.raw_noise torch.Size([1])
# gps.54.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.55.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.55.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.55.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.55.gp.mean_module.constant torch.Size([1, 1])
# gps.55.gp.covar_module.raw_outputscale torch.Size([1])
# gps.55.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.55.likelihood.raw_noise torch.Size([1])
# gps.55.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.56.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.56.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.56.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.56.gp.mean_module.constant torch.Size([1, 1])
# gps.56.gp.covar_module.raw_outputscale torch.Size([1])
# gps.56.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.56.likelihood.raw_noise torch.Size([1])
# gps.56.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.57.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.57.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.57.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.57.gp.mean_module.constant torch.Size([1, 1])
# gps.57.gp.covar_module.raw_outputscale torch.Size([1])
# gps.57.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.57.likelihood.raw_noise torch.Size([1])
# gps.57.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.58.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.58.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.58.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.58.gp.mean_module.constant torch.Size([1, 1])
# gps.58.gp.covar_module.raw_outputscale torch.Size([1])
# gps.58.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.58.likelihood.raw_noise torch.Size([1])
# gps.58.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.59.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.59.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.59.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.59.gp.mean_module.constant torch.Size([1, 1])
# gps.59.gp.covar_module.raw_outputscale torch.Size([1])
# gps.59.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.59.likelihood.raw_noise torch.Size([1])
# gps.59.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.60.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.60.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.60.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.60.gp.mean_module.constant torch.Size([1, 1])
# gps.60.gp.covar_module.raw_outputscale torch.Size([1])
# gps.60.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.60.likelihood.raw_noise torch.Size([1])
# gps.60.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.61.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.61.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.61.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.61.gp.mean_module.constant torch.Size([1, 1])
# gps.61.gp.covar_module.raw_outputscale torch.Size([1])
# gps.61.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.61.likelihood.raw_noise torch.Size([1])
# gps.61.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.62.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.62.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.62.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.62.gp.mean_module.constant torch.Size([1, 1])
# gps.62.gp.covar_module.raw_outputscale torch.Size([1])
# gps.62.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.62.likelihood.raw_noise torch.Size([1])
# gps.62.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.63.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.63.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.63.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.63.gp.mean_module.constant torch.Size([1, 1])
# gps.63.gp.covar_module.raw_outputscale torch.Size([1])
# gps.63.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.63.likelihood.raw_noise torch.Size([1])
# gps.63.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.64.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.64.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.64.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.64.gp.mean_module.constant torch.Size([1, 1])
# gps.64.gp.covar_module.raw_outputscale torch.Size([1])
# gps.64.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.64.likelihood.raw_noise torch.Size([1])
# gps.64.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.65.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.65.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.65.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.65.gp.mean_module.constant torch.Size([1, 1])
# gps.65.gp.covar_module.raw_outputscale torch.Size([1])
# gps.65.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.65.likelihood.raw_noise torch.Size([1])
# gps.65.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.66.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.66.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.66.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.66.gp.mean_module.constant torch.Size([1, 1])
# gps.66.gp.covar_module.raw_outputscale torch.Size([1])
# gps.66.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.66.likelihood.raw_noise torch.Size([1])
# gps.66.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.67.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.67.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.67.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.67.gp.mean_module.constant torch.Size([1, 1])
# gps.67.gp.covar_module.raw_outputscale torch.Size([1])
# gps.67.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.67.likelihood.raw_noise torch.Size([1])
# gps.67.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.68.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.68.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.68.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.68.gp.mean_module.constant torch.Size([1, 1])
# gps.68.gp.covar_module.raw_outputscale torch.Size([1])
# gps.68.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.68.likelihood.raw_noise torch.Size([1])
# gps.68.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.69.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.69.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.69.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.69.gp.mean_module.constant torch.Size([1, 1])
# gps.69.gp.covar_module.raw_outputscale torch.Size([1])
# gps.69.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.69.likelihood.raw_noise torch.Size([1])
# gps.69.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.70.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.70.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.70.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.70.gp.mean_module.constant torch.Size([1, 1])
# gps.70.gp.covar_module.raw_outputscale torch.Size([1])
# gps.70.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.70.likelihood.raw_noise torch.Size([1])
# gps.70.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.71.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.71.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.71.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.71.gp.mean_module.constant torch.Size([1, 1])
# gps.71.gp.covar_module.raw_outputscale torch.Size([1])
# gps.71.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.71.likelihood.raw_noise torch.Size([1])
# gps.71.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.72.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.72.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.72.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.72.gp.mean_module.constant torch.Size([1, 1])
# gps.72.gp.covar_module.raw_outputscale torch.Size([1])
# gps.72.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.72.likelihood.raw_noise torch.Size([1])
# gps.72.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.73.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.73.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.73.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.73.gp.mean_module.constant torch.Size([1, 1])
# gps.73.gp.covar_module.raw_outputscale torch.Size([1])
# gps.73.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.73.likelihood.raw_noise torch.Size([1])
# gps.73.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.74.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.74.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.74.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.74.gp.mean_module.constant torch.Size([1, 1])
# gps.74.gp.covar_module.raw_outputscale torch.Size([1])
# gps.74.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.74.likelihood.raw_noise torch.Size([1])
# gps.74.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.75.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.75.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.75.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.75.gp.mean_module.constant torch.Size([1, 1])
# gps.75.gp.covar_module.raw_outputscale torch.Size([1])
# gps.75.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.75.likelihood.raw_noise torch.Size([1])
# gps.75.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.76.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.76.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.76.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.76.gp.mean_module.constant torch.Size([1, 1])
# gps.76.gp.covar_module.raw_outputscale torch.Size([1])
# gps.76.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.76.likelihood.raw_noise torch.Size([1])
# gps.76.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.77.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.77.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.77.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.77.gp.mean_module.constant torch.Size([1, 1])
# gps.77.gp.covar_module.raw_outputscale torch.Size([1])
# gps.77.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.77.likelihood.raw_noise torch.Size([1])
# gps.77.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.78.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.78.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.78.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.78.gp.mean_module.constant torch.Size([1, 1])
# gps.78.gp.covar_module.raw_outputscale torch.Size([1])
# gps.78.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.78.likelihood.raw_noise torch.Size([1])
# gps.78.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.79.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.79.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.79.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.79.gp.mean_module.constant torch.Size([1, 1])
# gps.79.gp.covar_module.raw_outputscale torch.Size([1])
# gps.79.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.79.likelihood.raw_noise torch.Size([1])
# gps.79.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.80.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.80.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.80.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.80.gp.mean_module.constant torch.Size([1, 1])
# gps.80.gp.covar_module.raw_outputscale torch.Size([1])
# gps.80.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.80.likelihood.raw_noise torch.Size([1])
# gps.80.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.81.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.81.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.81.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.81.gp.mean_module.constant torch.Size([1, 1])
# gps.81.gp.covar_module.raw_outputscale torch.Size([1])
# gps.81.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.81.likelihood.raw_noise torch.Size([1])
# gps.81.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.82.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.82.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.82.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.82.gp.mean_module.constant torch.Size([1, 1])
# gps.82.gp.covar_module.raw_outputscale torch.Size([1])
# gps.82.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.82.likelihood.raw_noise torch.Size([1])
# gps.82.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.83.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.83.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.83.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.83.gp.mean_module.constant torch.Size([1, 1])
# gps.83.gp.covar_module.raw_outputscale torch.Size([1])
# gps.83.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.83.likelihood.raw_noise torch.Size([1])
# gps.83.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.84.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.84.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.84.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.84.gp.mean_module.constant torch.Size([1, 1])
# gps.84.gp.covar_module.raw_outputscale torch.Size([1])
# gps.84.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.84.likelihood.raw_noise torch.Size([1])
# gps.84.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.85.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.85.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.85.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.85.gp.mean_module.constant torch.Size([1, 1])
# gps.85.gp.covar_module.raw_outputscale torch.Size([1])
# gps.85.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.85.likelihood.raw_noise torch.Size([1])
# gps.85.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.86.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.86.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.86.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.86.gp.mean_module.constant torch.Size([1, 1])
# gps.86.gp.covar_module.raw_outputscale torch.Size([1])
# gps.86.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.86.likelihood.raw_noise torch.Size([1])
# gps.86.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.87.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.87.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.87.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.87.gp.mean_module.constant torch.Size([1, 1])
# gps.87.gp.covar_module.raw_outputscale torch.Size([1])
# gps.87.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.87.likelihood.raw_noise torch.Size([1])
# gps.87.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.88.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.88.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.88.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.88.gp.mean_module.constant torch.Size([1, 1])
# gps.88.gp.covar_module.raw_outputscale torch.Size([1])
# gps.88.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.88.likelihood.raw_noise torch.Size([1])
# gps.88.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.89.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.89.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.89.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.89.gp.mean_module.constant torch.Size([1, 1])
# gps.89.gp.covar_module.raw_outputscale torch.Size([1])
# gps.89.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.89.likelihood.raw_noise torch.Size([1])
# gps.89.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.90.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.90.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.90.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.90.gp.mean_module.constant torch.Size([1, 1])
# gps.90.gp.covar_module.raw_outputscale torch.Size([1])
# gps.90.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.90.likelihood.raw_noise torch.Size([1])
# gps.90.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.91.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.91.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.91.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.91.gp.mean_module.constant torch.Size([1, 1])
# gps.91.gp.covar_module.raw_outputscale torch.Size([1])
# gps.91.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.91.likelihood.raw_noise torch.Size([1])
# gps.91.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.92.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.92.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.92.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.92.gp.mean_module.constant torch.Size([1, 1])
# gps.92.gp.covar_module.raw_outputscale torch.Size([1])
# gps.92.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.92.likelihood.raw_noise torch.Size([1])
# gps.92.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.93.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.93.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.93.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.93.gp.mean_module.constant torch.Size([1, 1])
# gps.93.gp.covar_module.raw_outputscale torch.Size([1])
# gps.93.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.93.likelihood.raw_noise torch.Size([1])
# gps.93.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.94.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.94.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.94.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.94.gp.mean_module.constant torch.Size([1, 1])
# gps.94.gp.covar_module.raw_outputscale torch.Size([1])
# gps.94.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.94.likelihood.raw_noise torch.Size([1])
# gps.94.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.95.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.95.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.95.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.95.gp.mean_module.constant torch.Size([1, 1])
# gps.95.gp.covar_module.raw_outputscale torch.Size([1])
# gps.95.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.95.likelihood.raw_noise torch.Size([1])
# gps.95.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.96.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.96.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.96.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.96.gp.mean_module.constant torch.Size([1, 1])
# gps.96.gp.covar_module.raw_outputscale torch.Size([1])
# gps.96.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.96.likelihood.raw_noise torch.Size([1])
# gps.96.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.97.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.97.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.97.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.97.gp.mean_module.constant torch.Size([1, 1])
# gps.97.gp.covar_module.raw_outputscale torch.Size([1])
# gps.97.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.97.likelihood.raw_noise torch.Size([1])
# gps.97.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.98.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.98.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.98.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.98.gp.mean_module.constant torch.Size([1, 1])
# gps.98.gp.covar_module.raw_outputscale torch.Size([1])
# gps.98.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.98.likelihood.raw_noise torch.Size([1])
# gps.98.likelihood.noise_covar.raw_noise torch.Size([3])
# gps.99.gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 85])
# gps.99.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gps.99.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gps.99.gp.mean_module.constant torch.Size([1, 1])
# gps.99.gp.covar_module.raw_outputscale torch.Size([1])
# gps.99.gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# gps.99.likelihood.raw_noise torch.Size([1])
# gps.99.likelihood.noise_covar.raw_noise torch.Size([3])

# %% [markdown]
# # Training

# %% [markdown]
# ## Training Epoch

# %%
trainer.model.train()
for e in range(args.num_epochs):
#for e in range(1):
    torch.manual_seed(args.seed)
    train_loss = 0.
    for b, data in enumerate(dataloader, 0):
        x,y = data.values()
        
        single_loss, batch_time = trainer.train(x,y)
        
        with torch.no_grad():
            train_loss += single_loss
            args.tensorboard and data2tensorboard(writer,single_loss,train_loss/(b+1),e*len(dataloader)+(b+1))
            if ((b+1)%args.display == 0):
                 display_loss(e*len(dataloader)+(b+1),args.num_epochs*len(dataloader),e,
                              train_loss/(b+1),batch_time,trainer.scheduler.get_last_lr()[0])          
            if (e * len(dataloader) + (b+1)) % args.save_every == 0:
                trainer.save_model('model-{}-{}.pth'.format(e, e * len(dataloader) + (b+1)))
            if trainer.scheduler.get_last_lr()[0] > args.learning_rate_clip and (e * len(dataloader) + (b+1)) % 150 == 0:
                trainer.scheduler.step()
# Out:
# 10/34160 (epoch 0), train_loss = -7.42033644, time/batch = 2.315, learning rate = 0.00130000
# 20/34160 (epoch 0), train_loss = -7.58430595, time/batch = 2.318, learning rate = 0.00130000
# 30/34160 (epoch 0), train_loss = -7.66486074, time/batch = 2.330, learning rate = 0.00130000
# 40/34160 (epoch 0), train_loss = -7.70595225, time/batch = 2.322, learning rate = 0.00130000
# 50/34160 (epoch 0), train_loss = -7.73845427, time/batch = 2.319, learning rate = 0.00130000
# 60/34160 (epoch 0), train_loss = -7.76018190, time/batch = 2.326, learning rate = 0.00130000
# 70/34160 (epoch 0), train_loss = -7.77607707, time/batch = 2.330, learning rate = 0.00130000
# 80/34160 (epoch 0), train_loss = -7.78149038, time/batch = 2.336, learning rate = 0.00130000
# 90/34160 (epoch 0), train_loss = -7.79083312, time/batch = 2.329, learning rate = 0.00130000
# 100/34160 (epoch 0), train_loss = -7.79813015, time/batch = 2.331, learning rate = 0.00130000
# 110/34160 (epoch 0), train_loss = -7.80500672, time/batch = 2.318, learning rate = 0.00130000
# 120/34160 (epoch 0), train_loss = -7.81043799, time/batch = 2.320, learning rate = 0.00130000
# 130/34160 (epoch 0), train_loss = -7.81468833, time/batch = 2.327, learning rate = 0.00130000
# 140/34160 (epoch 0), train_loss = -7.81671435, time/batch = 2.341, learning rate = 0.00130000
# 150/34160 (epoch 0), train_loss = -7.82066003, time/batch = 2.336, learning rate = 0.00130000
# 160/34160 (epoch 0), train_loss = -7.82564549, time/batch = 2.320, learning rate = 0.00097500
# 170/34160 (epoch 0), train_loss = -7.82951028, time/batch = 2.327, learning rate = 0.00097500
# 180/34160 (epoch 0), train_loss = -7.83243288, time/batch = 2.336, learning rate = 0.00097500
# 190/34160 (epoch 0), train_loss = -7.83538160, time/batch = 2.336, learning rate = 0.00097500
# 200/34160 (epoch 0), train_loss = -7.83762514, time/batch = 2.332, learning rate = 0.00097500
# 210/34160 (epoch 0), train_loss = -7.84065239, time/batch = 2.362, learning rate = 0.00097500
# 220/34160 (epoch 0), train_loss = -7.84344408, time/batch = 2.336, learning rate = 0.00097500
# 230/34160 (epoch 0), train_loss = -7.84603047, time/batch = 2.323, learning rate = 0.00097500
# 240/34160 (epoch 0), train_loss = -7.84837865, time/batch = 2.329, learning rate = 0.00097500
# 250/34160 (epoch 0), train_loss = -7.85084675, time/batch = 2.325, learning rate = 0.00097500
# 260/34160 (epoch 0), train_loss = -7.85233838, time/batch = 2.328, learning rate = 0.00097500
# 270/34160 (epoch 0), train_loss = -7.85484661, time/batch = 2.328, learning rate = 0.00097500
# 280/34160 (epoch 0), train_loss = -7.85744254, time/batch = 2.322, learning rate = 0.00097500
# 290/34160 (epoch 0), train_loss = -7.85898769, time/batch = 2.322, learning rate = 0.00097500
# 300/34160 (epoch 0), train_loss = -7.86075516, time/batch = 2.331, learning rate = 0.00097500
# 310/34160 (epoch 0), train_loss = -7.86298632, time/batch = 2.415, learning rate = 0.00073125
# 320/34160 (epoch 0), train_loss = -7.86506334, time/batch = 2.337, learning rate = 0.00073125
# 330/34160 (epoch 0), train_loss = -7.86743888, time/batch = 2.326, learning rate = 0.00073125
# 340/34160 (epoch 0), train_loss = -7.86932860, time/batch = 2.333, learning rate = 0.00073125
# 350/34160 (epoch 0), train_loss = -7.87090652, time/batch = 2.329, learning rate = 0.00073125
# 360/34160 (epoch 0), train_loss = -7.87240506, time/batch = 2.334, learning rate = 0.00073125
# 370/34160 (epoch 0), train_loss = -7.87431108, time/batch = 2.330, learning rate = 0.00073125
# 380/34160 (epoch 0), train_loss = -7.87570397, time/batch = 2.326, learning rate = 0.00073125
# 390/34160 (epoch 0), train_loss = -7.87737466, time/batch = 2.326, learning rate = 0.00073125
# 400/34160 (epoch 0), train_loss = -7.87896020, time/batch = 2.325, learning rate = 0.00073125
# 410/34160 (epoch 0), train_loss = -7.88095611, time/batch = 2.376, learning rate = 0.00073125
# 420/34160 (epoch 0), train_loss = -7.88227352, time/batch = 2.329, learning rate = 0.00073125
# 437/34160 (epoch 1), train_loss = -7.98080034, time/batch = 2.341, learning rate = 0.00073125
# 447/34160 (epoch 1), train_loss = -7.98818042, time/batch = 2.341, learning rate = 0.00073125
# 457/34160 (epoch 1), train_loss = -7.99132876, time/batch = 2.330, learning rate = 0.00054844
# 467/34160 (epoch 1), train_loss = -7.99219050, time/batch = 2.368, learning rate = 0.00054844
# 477/34160 (epoch 1), train_loss = -7.99244780, time/batch = 2.332, learning rate = 0.00054844
# 487/34160 (epoch 1), train_loss = -7.99461776, time/batch = 2.333, learning rate = 0.00054844
# 497/34160 (epoch 1), train_loss = -7.99401889, time/batch = 2.339, learning rate = 0.00054844
# 507/34160 (epoch 1), train_loss = -7.99541861, time/batch = 2.341, learning rate = 0.00054844
# 517/34160 (epoch 1), train_loss = -7.99768985, time/batch = 2.324, learning rate = 0.00054844
# 527/34160 (epoch 1), train_loss = -7.99835906, time/batch = 2.347, learning rate = 0.00054844
# 537/34160 (epoch 1), train_loss = -7.99994882, time/batch = 2.328, learning rate = 0.00054844
# 547/34160 (epoch 1), train_loss = -8.00121889, time/batch = 2.329, learning rate = 0.00054844
# 557/34160 (epoch 1), train_loss = -8.00136108, time/batch = 2.325, learning rate = 0.00054844
# 567/34160 (epoch 1), train_loss = -8.00196752, time/batch = 2.340, learning rate = 0.00054844
# 577/34160 (epoch 1), train_loss = -8.00210846, time/batch = 2.330, learning rate = 0.00054844
# 587/34160 (epoch 1), train_loss = -8.00275747, time/batch = 2.327, learning rate = 0.00054844
# 597/34160 (epoch 1), train_loss = -8.00286775, time/batch = 2.328, learning rate = 0.00054844
# 607/34160 (epoch 1), train_loss = -8.00338401, time/batch = 2.332, learning rate = 0.00041133
# 617/34160 (epoch 1), train_loss = -8.00415563, time/batch = 2.334, learning rate = 0.00041133
# 627/34160 (epoch 1), train_loss = -8.00534066, time/batch = 2.336, learning rate = 0.00041133
# 637/34160 (epoch 1), train_loss = -8.00648694, time/batch = 2.336, learning rate = 0.00041133
# 647/34160 (epoch 1), train_loss = -8.00711720, time/batch = 2.329, learning rate = 0.00041133
# 657/34160 (epoch 1), train_loss = -8.00780769, time/batch = 2.338, learning rate = 0.00041133
# 667/34160 (epoch 1), train_loss = -8.00860534, time/batch = 2.328, learning rate = 0.00041133
# 677/34160 (epoch 1), train_loss = -8.00879148, time/batch = 2.326, learning rate = 0.00041133
# 687/34160 (epoch 1), train_loss = -8.00917882, time/batch = 2.375, learning rate = 0.00041133
# 697/34160 (epoch 1), train_loss = -8.00987804, time/batch = 2.332, learning rate = 0.00041133
# 707/34160 (epoch 1), train_loss = -8.01073569, time/batch = 2.323, learning rate = 0.00041133
# 717/34160 (epoch 1), train_loss = -8.01098069, time/batch = 2.324, learning rate = 0.00041133
# 727/34160 (epoch 1), train_loss = -8.01154822, time/batch = 2.329, learning rate = 0.00041133
# 737/34160 (epoch 1), train_loss = -8.01159334, time/batch = 2.328, learning rate = 0.00041133
# 747/34160 (epoch 1), train_loss = -8.01155013, time/batch = 2.329, learning rate = 0.00041133
# 757/34160 (epoch 1), train_loss = -8.01201462, time/batch = 2.336, learning rate = 0.00030850
# 767/34160 (epoch 1), train_loss = -8.01273449, time/batch = 2.335, learning rate = 0.00030850
# 777/34160 (epoch 1), train_loss = -8.01369387, time/batch = 2.322, learning rate = 0.00030850
# 787/34160 (epoch 1), train_loss = -8.01408197, time/batch = 2.330, learning rate = 0.00030850
# 797/34160 (epoch 1), train_loss = -8.01510128, time/batch = 2.335, learning rate = 0.00030850
# 807/34160 (epoch 1), train_loss = -8.01555030, time/batch = 2.320, learning rate = 0.00030850
# 817/34160 (epoch 1), train_loss = -8.01610103, time/batch = 2.326, learning rate = 0.00030850
# 827/34160 (epoch 1), train_loss = -8.01661726, time/batch = 2.338, learning rate = 0.00030850
# 837/34160 (epoch 1), train_loss = -8.01722826, time/batch = 2.372, learning rate = 0.00030850
# 847/34160 (epoch 1), train_loss = -8.01804676, time/batch = 2.337, learning rate = 0.00030850
# 864/34160 (epoch 2), train_loss = -8.06340227, time/batch = 2.329, learning rate = 0.00030850
# 874/34160 (epoch 2), train_loss = -8.06489649, time/batch = 2.319, learning rate = 0.00030850
# 884/34160 (epoch 2), train_loss = -8.06197653, time/batch = 2.332, learning rate = 0.00030850
# 894/34160 (epoch 2), train_loss = -8.06125762, time/batch = 2.363, learning rate = 0.00030850
# 904/34160 (epoch 2), train_loss = -8.06164865, time/batch = 2.326, learning rate = 0.00023137
# 914/34160 (epoch 2), train_loss = -8.06277947, time/batch = 2.325, learning rate = 0.00023137
# 924/34160 (epoch 2), train_loss = -8.06249894, time/batch = 2.329, learning rate = 0.00023137
# 934/34160 (epoch 2), train_loss = -8.06334822, time/batch = 2.338, learning rate = 0.00023137
# 944/34160 (epoch 2), train_loss = -8.06351674, time/batch = 2.328, learning rate = 0.00023137
# 954/34160 (epoch 2), train_loss = -8.06284156, time/batch = 2.320, learning rate = 0.00023137
# 964/34160 (epoch 2), train_loss = -8.06260314, time/batch = 2.331, learning rate = 0.00023137
# 974/34160 (epoch 2), train_loss = -8.06315239, time/batch = 2.317, learning rate = 0.00023137
# 984/34160 (epoch 2), train_loss = -8.06265717, time/batch = 2.320, learning rate = 0.00023137
# 994/34160 (epoch 2), train_loss = -8.06331020, time/batch = 2.368, learning rate = 0.00023137
# Saving model to model-2-1000.pth
# 1004/34160 (epoch 2), train_loss = -8.06353029, time/batch = 2.329, learning rate = 0.00023137
# 1014/34160 (epoch 2), train_loss = -8.06342127, time/batch = 2.322, learning rate = 0.00023137
# 1024/34160 (epoch 2), train_loss = -8.06464697, time/batch = 2.336, learning rate = 0.00023137
# 1034/34160 (epoch 2), train_loss = -8.06512381, time/batch = 2.323, learning rate = 0.00023137
# 1044/34160 (epoch 2), train_loss = -8.06515009, time/batch = 2.334, learning rate = 0.00023137
# 1054/34160 (epoch 2), train_loss = -8.06586375, time/batch = 2.323, learning rate = 0.00017353
# 1064/34160 (epoch 2), train_loss = -8.06592502, time/batch = 2.372, learning rate = 0.00017353
# 1074/34160 (epoch 2), train_loss = -8.06554126, time/batch = 2.334, learning rate = 0.00017353
# 1084/34160 (epoch 2), train_loss = -8.06609672, time/batch = 2.331, learning rate = 0.00017353
# 1094/34160 (epoch 2), train_loss = -8.06624868, time/batch = 2.332, learning rate = 0.00017353
# 1104/34160 (epoch 2), train_loss = -8.06620731, time/batch = 2.324, learning rate = 0.00017353
# 1114/34160 (epoch 2), train_loss = -8.06624268, time/batch = 2.331, learning rate = 0.00017353
# 1124/34160 (epoch 2), train_loss = -8.06699816, time/batch = 2.334, learning rate = 0.00017353
# 1134/34160 (epoch 2), train_loss = -8.06731880, time/batch = 2.330, learning rate = 0.00017353
# 1144/34160 (epoch 2), train_loss = -8.06741060, time/batch = 2.338, learning rate = 0.00017353
# 1154/34160 (epoch 2), train_loss = -8.06779900, time/batch = 2.326, learning rate = 0.00017353
# 1164/34160 (epoch 2), train_loss = -8.06784858, time/batch = 2.329, learning rate = 0.00017353
# 1174/34160 (epoch 2), train_loss = -8.06761304, time/batch = 2.324, learning rate = 0.00017353
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4a97b48a8bc6> in <module>
#       7         x,y = data.values()
#       8
# ----> 9         single_loss, batch_time = trainer.train(x,y)
#      10
#      11         with torch.no_grad():
#
# <ipython-input-6-1ead0e7ce6bc> in train(self, x, y)
#     104             #sampled_mask = torch.randint(high=args.batch_size, size=(self.model.sub_batch_size,))
#     105             sampled_mask = torch.randint(high=args.batch_size, size=(args.batch_size,))
# --> 106             sub_x = trans_feat[sampled_mask]
#     107             sub_y = trans_target[sampled_mask]
#     108             gp_loss = self._gp_loss(gp,sub_x,sub_y)
#
# KeyboardInterrupt:
