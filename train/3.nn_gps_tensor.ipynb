# %% [markdown]
# # Torch
# ## Check GPU¶

# %%
import torch
import numpy as np
import sys
sys.path.append('..')

from torchlib.utils import list_device,set_device

# S1: check GPU
#list_device()

# S2: default parameters
set_device(1)
np.set_printoptions(precision = 2)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()

'''Training Parameters'''
parser.add_argument('--batch_size', type=int, default=5000, help='minibatch size')
parser.add_argument('--num_epochs', type=int, default=80, help='number of epochs')
parser.add_argument('--grad_clip', type=float, default=5., help='clip gradients at this value')
parser.add_argument('--learning_rate', type=float, default=0.01, help='learning rate')
parser.add_argument('--learning_rate_clip', type=float, default=0.0000001, help='learning rate clip')
parser.add_argument('--decay_rate', type=float, default=.9, help='decay rate for rmsprop')
parser.add_argument('--weight_decay', type=float, default=.0001, help='decay rate for rmsprop')
parser.add_argument('--batch_norm_decay', type=float, default=.999, help='decay rate for rmsprop')
parser.add_argument('--keep_prob', type=float, default=1.0, help='dropout keep probability')
parser.add_argument('--lamda_weights', type=float, default=.01, help='lamda weight')
parser.add_argument('--data_argumentation', type=bool, default=True, help='whether do data argument')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data nomalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')
parser.add_argument('--output_dim', default=3, type=int, help='output dimention.')
parser.add_argument('--feat_dim', default=128, type=int, help='feature dimention.')

'''Configure'''
parser.add_argument('--network', type=str, default='vggnet_localization')
parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/gps_net_torch', help='rnn, gru, or lstm')

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/train_dense_old'])

parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

parser.add_argument('--seed', default=1337, type=int)
parser.add_argument('--save_every', type=int, default=1000, help='save frequency')
parser.add_argument('--display', type=int, default=10, help='display frequency')
parser.add_argument('--tensorboard', type=bool, default=True, help='open tensorboard')
parser.add_argument('--cuda_device', type=int, default=1, help='cuda device')

sys.argv = ['']
args = parser.parse_args()

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
from PIL import Image
import numpy as np
import random

import gpytorch

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet
from torchlib.cnn_auxiliary import normalize, denormalize_navie, denormalize, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

path = args.train_dataset[0]
x_dense = torch.load(os.path.join(path,'x.pt'))#[::10,:]
y_dense = torch.load(os.path.join(path,'y.pt'))#[::10,:]
dataset = TensorDataset(x_dense, y_dense)

[args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
print('Load norm and std:',*args.norm_tensor)

dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=True, num_workers=0, \
                        drop_last=True, pin_memory=True)
# Out:
# Load norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # Define Model

# %%
from torch.cuda.amp import autocast, GradScaler
from torchlib.GPs import Backbone, NN, GPNode, BaseModule

class NN(nn.Module):
    def __init__(self):
        super().__init__()
        self.global_context = vggnet.vggnet(input_channel=2048,opt="context")
        self.global_regressor = vggnet.vggnet(opt="regressor")
        
    def forward(self,input_data):
        #context_feat = self.global_context(input_data)
        context_feat = input_data
        output,feature_t, feature_r = self.global_regressor(context_feat)
        return output, feature_t, feature_r

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.MultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ZeroMean()
        #self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([output_dim]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([output_dim])),
            batch_shape=torch.Size([output_dim]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class GPNode(nn.Module):
    def __init__(self, inducing_points):
        super().__init__()
        output_dim = inducing_points.shape[0]
        
        self.fc = nn.Linear(128,128)

        self.gp = GP(inducing_points,output_dim)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=output_dim) 
        
    def forward(self,input_data):
        input_data = self.fc(input_data)
        output = self.gp(input_data)
        return output

class Model(nn.Module):
    def __init__(self, num_gp = 20):
        super().__init__()
        self.backbone = Backbone()
        self.nn = NN()
        self.gps = nn.ModuleList()
        
        self.num_gp = num_gp
        
        for i in range(self.num_gp):
            inducing_points = torch.zeros(3, 1000, 128)
            gp = GPNode(inducing_points)
            self.gps.append(gp)
        
    def forward_nn(self, input_data):
        #dense_feat = self.backbone(input_data)
        dense_feat = input_data
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention            
        return feature_t, rot_pred
    
    def forward_gp(self,gp,trans_feat):
        trans_pred = gp(trans_feat)
        return trans_pred
    
class PosePredictor(BaseModule):
    def __init__(self, norm_mean, norm_std, args, num_gp = 20,
                 regressor_context_rate = [0.0,0.0],
                 is_training=True, train_rot = True):
        
        super().__init__(norm_mean, norm_std, args)
        self.num_gp = num_gp
        self.model = Model(num_gp).to(self.device)
        self.train_rot = train_rot
        self.num_sub_data = self.args.batch_size//num_gp
        
        # disable learning backbone
        self.disable_requires_grad(self.model.backbone)
        
        if is_training:
            # training tool
            self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
            self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                             lr_lambda=lambda epoch: args.decay_rate**epoch)
        else:
            self.disable_requires_grad(self.model)
            
    def _optimize(self, regressor_context_rate = [0.0,0.0]):
        optimizer = [
                {'params': self.model.gps.parameters(), \
                 'lr': self.args.learning_rate,'weight_decay':self.args.weight_decay}]
            
        # NN
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            self.disable_requires_grad(self.model.nn.global_regressor)
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
            self.train_rot = True
        else:
            self.disable_requires_grad(self.model.nn.global_context)
            
        
        if not self.train_rot and regressor_context_rate[1]==0.0:
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc1_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc2_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc3_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.logits_r)
                
        return optimizer
    
    def train(self, x, y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        if self.args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
            
        # Step 2: training
        assert self.model.training == True
        
        trans_loss = torch.tensor(0.).to(self.device)
        
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        trans_feat, rot_pred = self.model.forward_nn(x)
        rot_loss = self._nn_loss(rot_pred,rot_target)
        
        mask = torch.randperm(self.args.batch_size)
        for i,gp in enumerate(self.model.gps):
            sampled_mask = mask[self.num_sub_data*i:self.num_sub_data*(i+1)]
            sub_x = trans_feat[sampled_mask]
            sub_y = trans_target[sampled_mask]
            gp_loss = self._gp_loss(gp,sub_x,sub_y)
            trans_loss += gp_loss
        trans_loss = trans_loss/self.model.num_gp
        
        total_loss = trans_loss + self.args.lamda_weights * rot_loss
        
        batch_time = time.time() - start
        
        #Step 3: update
        total_loss.backward()
        self.optimizer.step()
        
        return float(total_loss), batch_time    
    
    def _nn_loss(self, rot_pred, rot_target):
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        return rot_loss
        
    def _gp_loss(self, gp, trans_feat, trans_target):
        # predict
        trans_pred = self.model.forward_gp(gp,trans_feat)
        
        #num_data = int(min(len(dataloader)*args.batch_size,len(dataset))*self.model.sub_batch_rate)
        num_data = min(len(dataloader)*self.args.batch_size,len(dataset))//self.num_gp
        mll = gpytorch.mlls.PredictiveLogLikelihood(gp.likelihood, gp.gp, num_data = num_data)
        
        # trans loss
        trans_loss = -1.*mll(trans_pred, trans_target)
        
        return trans_loss
    
    def _eval_gp(self, gp, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = gp.likelihood(trans_pred).mean, gp.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var
    
    def _sample(self, mean, var, num_sample = 100):
        dist = torch.distributions.Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples

    def eval_forward(self, x, y, num_sample = 100, output_denormalize = True):
        # Step 1: get data
        x = x.to(self.device)
        
        # Step 2: forward
        assert self.model.training == False
        trans_feat, rot_pred = self.model.forward_nn(x)
        
        trans_preds = 0
        trans_means = 0
        trans_vars = 0
        for gp in self.model.gps:
            trans_pred = self.model.forward_gp(gp,trans_feat)
            trans_pred, trans_mean, trans_var = self._eval_gp(gp, trans_pred)
            trans_preds += trans_pred * 1/trans_var
            trans_means += trans_mean * 1/trans_var
            trans_vars += 1/trans_var
         
        trans_vars = 1/trans_vars
        trans_preds *= trans_vars
        trans_means *= trans_vars
        
        if self.args.is_normalization and output_denormalize:
            trans_preds = denormalize_navie(trans_preds, self.norm_mean, self.norm_std)
            trans_means = denormalize_navie(trans_means, self.norm_mean, self.norm_std)
            trans_vars = trans_vars.mul(self.norm_std)
        
        samples = self._sample(trans_means, trans_vars, num_sample)
        
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_preds, rot_pred, trans_target, rot_target, samples

# %%
trainer = PosePredictor(args.norm_mean,args.norm_std,args,
                        regressor_context_rate = [0.,0.], train_rot = False)
#trainer.load_model('pretrained_gp20_fix.pth')
trainer.load_model('model-fast-zero-mean-fc.pth',strict = False)
#trainer.show_require_grad()
# Out:
# Successfully loaded model to TITAN Xp.

# %%
'''
state_dict = torch.load(os.path.join(args.model_dir, 'pretrained.pth'))
state_dict = trainer._from_old_model(state_dict)
for key in list(state_dict):
    if 'gp' in key or 'likelihood' in key:
        state_dict.pop(key)
trainer.model.load_state_dict(state_dict, strict=False)
'''
# Out:
# "\nstate_dict = torch.load(os.path.join(args.model_dir, 'pretrained.pth'))\nstate_dict = trainer._from_old_model(state_dict)\nfor key in list(state_dict):\n    if 'gp' in key or 'likelihood' in key:\n        state_dict.pop(key)\ntrainer.model.load_state_dict(state_dict, strict=False)\n"

# %%
list(trainer.model.gps.named_parameters())
# Out:
# [('0.fc.weight',
#   Parameter containing:
#   tensor([[     0.4046,      0.4207,     -0.0154,  ...,      0.0019,
#                 0.4005,      0.1801],
#           [     0.5204,      0.5434,     -0.4008,  ...,      0.0002,
#                 0.4568,      0.2893],
#           [    -0.4439,     -0.5083,      0.5050,  ...,      0.0839,
#                -0.5123,      0.0222],
#           ...,
#           [    -0.4321,     -0.5253,     -0.5349,  ...,      0.0047,
#                -0.5353,      0.0185],
#           [    -0.4439,     -0.5115,     -0.4452,  ...,     -0.1687,
#                -0.5088,      0.0005],
#           [     0.4401,      0.4433,      0.4658,  ...,      0.0014,
#                 0.3794,     -0.0211]], device='cuda:1', requires_grad=True)),
#  ('0.fc.bias',
#   Parameter containing:
#   tensor([ 0.5023,  0.5398,  0.5448,  0.3759, -0.5002, -0.5285,  0.4919,  0.4678,
#           -0.4694,  0.5164,  0.0569,  0.4849, -0.5386,  0.5403,  0.2692,  0.4419,
#           -0.4841, -0.4884,  0.4128,  0.5510, -0.4631, -0.5580,  0.4582, -0.5189,
#            0.4591, -0.4955, -0.5350,  0.5213,  0.5579,  0.5459, -0.5086, -0.4436,
#            0.4814, -0.4708, -0.5449,  0.4742,  0.4019,  0.5399,  0.1746,  0.5401,
#           -0.5367,  0.4424,  0.5361,  0.3927,  0.4606,  0.4667, -0.5052, -0.5340,
#           -0.5512,  0.5279, -0.5067, -0.5256, -0.4681, -0.5018,  0.5482, -0.4630,
#            0.5379, -0.5663, -0.4730, -0.4653, -0.5265, -0.5098, -0.4179, -0.4930,
#            0.4386, -0.5137,  0.5327,  0.4600, -0.4285,  0.5218,  0.4774, -0.4291,
#            0.4039, -0.5314, -0.4898, -0.5200,  0.4855,  0.5245, -0.4643, -0.5523,
#            0.5253,  0.5639, -0.4795, -0.4892,  0.5243,  0.4807, -0.5255,  0.5088,
#           -0.4374,  0.4928,  0.5392, -0.5670,  0.5353, -0.5538,  0.5298, -0.5007,
#           -0.4160, -0.5368, -0.4792, -0.5441,  0.5662,  0.5225, -0.5477,  0.4646,
#            0.2959, -0.5194,  0.4801, -0.5334, -0.4773,  0.4720,  0.5515, -0.5033,
#            0.4804,  0.5266, -0.4668, -0.4404,  0.4384, -0.5328, -0.4533,  0.5446,
#           -0.4480, -0.4878, -0.4018, -0.5243, -0.4294, -0.4373, -0.5232,  0.4342],
#          device='cuda:1', requires_grad=True)),
#  ('0.gp.variational_strategy.base_variational_strategy.inducing_points',
#   Parameter containing:
#   tensor([[[    -0.4097,     -0.3617,      0.6025,  ...,      0.4614,
#                 -0.4543,      0.4327],
#            [    -0.4386,     -0.3032,     -0.5379,  ...,      0.4009,
#                 -0.4011,      0.3204],
#            [     0.3356,      0.4183,      0.0224,  ...,     -0.3935,
#                 -0.3957,     -0.3185],
#            ...,
#            [    -0.0048,      0.0019,      0.0033,  ...,     -0.0065,
#                 -0.0053,      0.0035],
#            [     0.0014,     -0.0017,     -0.0019,  ...,     -0.0001,
#                 -0.0015,      0.0019],
#            [     0.0053,     -0.0197,     -0.0043,  ...,     -0.0017,
#                 -0.0438,      0.0032]],
#
#           [[     0.4585,      0.6274,     -0.4000,  ...,     -0.3847,
#                 -0.1783,     -0.3104],
#            [    -0.4605,      0.2676,     -0.1690,  ...,     -0.0019,
#                  0.3572,      0.1522],
#            [    -0.2444,     -0.4039,      0.4943,  ...,     -0.2507,
#                 -0.4790,      0.0224],
#            ...,
#            [    -0.0019,      0.0014,     -0.0035,  ...,      0.0020,
#                  0.0002,     -0.0015],
#            [     0.0042,      0.0028,     -0.0019,  ...,     -0.0034,
#                 -0.0013,      0.0015],
#            [     0.0016,      0.0018,     -0.0035,  ...,     -0.0014,
#                 -0.0015,     -0.0005]],
#
#           [[    -0.3064,      0.6868,      0.3549,  ...,      0.4230,
#                 -0.2905,      0.3488],
#            [    -0.3009,     -0.2830,     -0.4039,  ...,     -0.0845,
#                 -0.3589,     -0.4382],
#            [     0.4273,      0.7214,      0.5976,  ...,     -0.3506,
#                 -0.2796,      0.4560],
#            ...,
#            [     0.0012,      0.0019,      0.0016,  ...,      0.0068,
#                  0.0027,      0.0015],
#            [    -0.0173,     -0.0062,     -0.0197,  ...,     -0.0169,
#                  0.2071,     -0.0048],
#            [    -0.0002,     -0.0035,     -0.0043,  ...,      0.0022,
#                 -0.0119,     -0.0003]]], device='cuda:1', requires_grad=True)),
#  ('0.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean',
#   Parameter containing:
#   tensor([[    -0.1896,     -1.5376,      0.0058,  ...,     -0.0069,
#                 0.0030,     -0.0018],
#           [    -0.2274,     -1.2063,     -0.2427,  ...,      0.0019,
#                -0.0016,     -0.0017],
#           [    -0.0055,      0.3575,      0.0213,  ...,     -0.1592,
#                 0.0006,     -0.0031]], device='cuda:1', requires_grad=True)),
#  ('0.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar',
#   Parameter containing:
#   tensor([[[    -0.5083,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.6498,      0.5444,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.3735,      0.4515,     -0.2423,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [     0.0038,      0.1262,      0.0016,  ...,      0.1956,
#                  0.0000,      0.0000],
#            [     0.0026,      0.0001,      0.0019,  ...,     -0.0014,
#                  0.1931,      0.0000],
#            [    -0.0033,      0.0148,     -0.0014,  ...,      0.0015,
#                 -0.0014,      0.1932]],
#
#           [[    -0.4922,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.5593,      0.5854,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.4246,     -0.5343,      0.5328,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [     0.0014,     -0.0014,      0.0005,  ...,      0.1914,
#                  0.0000,      0.0000],
#            [     0.0018,      0.0017,     -0.0035,  ...,     -0.0014,
#                  0.1934,      0.0000],
#            [     0.0019,      0.0019,      0.0014,  ...,     -0.0031,
#                 -0.0014,      0.1934]],
#
#           [[    -0.3974,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.4517,      0.5266,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.4629,     -0.5894,     -0.4311,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [    -0.0031,     -0.1158,     -0.0765,  ...,      0.1955,
#                  0.0000,      0.0000],
#            [     0.0026,      0.0015,      0.0016,  ...,      0.0031,
#                  0.1932,      0.0000],
#            [    -0.0016,     -0.0005,     -0.0065,  ...,      0.0019,
#                 -0.0014,      0.1957]]], device='cuda:1', requires_grad=True)),
#  ('0.gp.covar_module.raw_outputscale',
#   Parameter containing:
#   tensor([0.4828, 0.4988, 0.4965], device='cuda:1', requires_grad=True)),
#  ('0.gp.covar_module.base_kernel.raw_lengthscale',
#   Parameter containing:
#   tensor([[[1.4459]],
#
#           [[1.6512]],
#
#           [[1.5503]]], device='cuda:1', requires_grad=True)),
#  ('0.likelihood.raw_noise',
#   Parameter containing:
#   tensor([-5.6537], device='cuda:1', requires_grad=True)),
#  ('0.likelihood.noise_covar.raw_noise',
#   Parameter containing:
#   tensor([-5.0735, -4.8365, -4.1679], device='cuda:1', requires_grad=True)),
#  ('1.fc.weight',
#   Parameter containing:
#   tensor([[ 0.4052,  0.5296, -0.4543,  ..., -0.0542,  0.3646, -0.0024],
#           [ 0.4372,  0.5431,  0.4726,  ...,  0.0015,  0.4575,  0.2003],
#           [-0.4104, -0.4695,  0.4300,  ...,  0.1386, -0.5173, -0.1194],
#           ...,
#           [ 0.2572,  0.3868,  0.4764,  ...,  0.0022,  0.1203, -0.0021],
#           [ 0.4433,  0.4865, -0.4836,  ..., -0.1420,  0.4336, -0.0053],
#           [ 0.4795,  0.4870,  0.4337,  ...,  0.0053,  0.4214, -0.0022]],
#          device='cuda:1', requires_grad=True)),
#  ('1.fc.bias',
#   Parameter containing:
#   tensor([-0.5068,  0.4888,  0.5388,  0.4515, -0.5014, -0.4696,  0.4979,  0.4481,
#           -0.5557, -0.5440, -0.4156, -0.5307,  0.4076,  0.5578,  0.5373, -0.5606,
#            0.4770, -0.5658, -0.5240, -0.3436, -0.5514,  0.4790,  0.5106,  0.5276,
#           -0.5618, -0.4855,  0.4620, -0.5686, -0.5405,  0.4001, -0.4751, -0.5039,
#           -0.3785,  0.4048,  0.5626, -0.5034, -0.5100, -0.5643, -0.4646,  0.5461,
#           -0.3808,  0.5316,  0.3769,  0.4172, -0.4253, -0.4933,  0.5232,  0.4440,
#            0.5258, -0.5267,  0.4763, -0.5261,  0.4439, -0.5619,  0.5328, -0.5677,
#           -0.4774,  0.4209, -0.5468,  0.5612, -0.5488, -0.5240, -0.4180,  0.4921,
#           -0.5525, -0.5332, -0.5373,  0.5164,  0.4235, -0.5577,  0.5682,  0.5076,
#            0.4886,  0.5094,  0.5395, -0.4928, -0.5555, -0.5602, -0.5470,  0.5488,
#           -0.5668,  0.4627,  0.5160,  0.4151, -0.4721,  0.4723, -0.5665,  0.4833,
#           -0.5376, -0.4506, -0.5394, -0.4381,  0.5264, -0.5175, -0.4688, -0.5588,
#            0.4813,  0.4827,  0.5551,  0.5458, -0.5418,  0.5672,  0.5587, -0.4427,
#            0.4135, -0.4373, -0.5432, -0.4884, -0.5389, -0.5469,  0.5329,  0.5558,
#            0.4726, -0.5290,  0.4705,  0.5586,  0.4973, -0.5661, -0.5330,  0.4801,
#            0.3407, -0.5663,  0.5281, -0.5480, -0.5576,  0.4077, -0.5360,  0.5505],
#          device='cuda:1', requires_grad=True)),
#  ('1.gp.variational_strategy.base_variational_strategy.inducing_points',
#   Parameter containing:
#   tensor([[[    -0.0217,     -0.1007,     -0.2665,  ...,      0.2977,
#                  0.5511,     -0.4669],
#            [     0.3692,      0.5036,     -0.4383,  ...,     -0.3300,
#                  0.4482,      0.1783],
#            [    -0.4518,      0.3852,      0.3578,  ...,     -0.2752,
#                 -0.1085,      0.4050],
#            ...,
#            [    -0.0021,     -0.0019,      0.0030,  ...,     -0.0035,
#                  0.0019,     -0.0050],
#            [     0.0026,     -0.0160,      0.0032,  ...,     -0.0019,
#                 -0.0014,     -0.1449],
#            [    -0.0035,     -0.0066,      0.0014,  ...,      0.0013,
#                  0.0035,      0.0110]],
#
#           [[    -0.1607,     -0.2037,      0.4403,  ...,     -0.4053,
#                  0.5236,      0.4851],
#            [    -0.4511,     -0.4195,     -0.1373,  ...,      0.3974,
#                  0.4570,     -0.4538],
#            [     0.3015,      0.6418,      0.1728,  ...,     -0.2591,
#                  0.4107,      0.3761],
#            ...,
#            [    -0.0015,      0.0014,     -0.0028,  ...,     -0.0019,
#                 -0.0017,      0.0042],
#            [     0.0019,     -0.0014,      0.0018,  ...,     -0.0001,
#                  0.0019,      0.0068],
#            [    -0.0004,     -0.0019,      0.0017,  ...,      0.0017,
#                  0.0016,      0.0034]],
#
#           [[     0.4906,     -0.4079,      0.4693,  ...,      0.4259,
#                  0.5451,     -0.4940],
#            [     0.3372,      0.2416,     -0.4745,  ...,      0.3726,
#                  0.4276,      0.4536],
#            [    -0.2364,      0.3924,     -0.4053,  ...,     -0.4306,
#                 -0.0189,      0.2917],
#            ...,
#            [    -0.0064,      0.2528,      0.0232,  ...,     -0.2155,
#                 -0.0069,      0.2906],
#            [     0.0032,      0.0033,     -0.0019,  ...,      0.0031,
#                 -0.0017,      0.0015],
#            [    -0.0027,     -0.0016,     -0.0014,  ...,      0.0065,
#                 -0.0018,     -0.0015]]], device='cuda:1', requires_grad=True)),
#  ('1.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean',
#   Parameter containing:
#   tensor([[     0.2690,     -0.0018,     -0.6937,  ...,     -0.0016,
#                -0.0011,      0.0019],
#           [     0.0225,     -1.0028,      0.4319,  ...,     -0.0031,
#                -0.0008,     -0.0019],
#           [     0.4793,      0.2516,      0.9721,  ...,      0.0017,
#                 0.0024,     -0.0031]], device='cuda:1', requires_grad=True)),
#  ('1.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar',
#   Parameter containing:
#   tensor([[[-0.5088,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [-0.5153, -0.2016,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [-0.4260, -0.4007, -0.3190,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.0021, -0.0019,  0.0015,  ...,  0.1949,  0.0000,  0.0000],
#            [ 0.0059, -0.0013, -0.0034,  ...,  0.0014,  0.1944,  0.0000],
#            [-0.0068, -0.0014,  0.0019,  ...,  0.0014, -0.0015,  0.1934]],
#
#           [[ 0.5273,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.4909, -0.5415,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [-0.2762,  0.2061,  0.1955,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [-0.0016, -0.0014,  0.0016,  ...,  0.1934,  0.0000,  0.0000],
#            [ 0.0016,  0.0035, -0.0019,  ...,  0.0014,  0.1948,  0.0000],
#            [-0.0020, -0.0019,  0.0015,  ...,  0.0014,  0.0014,  0.1934]],
#
#           [[-0.4033,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [-0.5589,  0.4299,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [-0.6653,  0.5919,  0.2107,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.0012, -0.0025,  0.0030,  ...,  0.1949,  0.0000,  0.0000],
#            [-0.0064,  0.0034, -0.0017,  ..., -0.0014,  0.1929,  0.0000],
#            [ 0.0014, -0.0015, -0.0014,  ..., -0.0014, -0.0014,  0.1927]]],
#          device='cuda:1', requires_grad=True)),
#  ('1.gp.covar_module.raw_outputscale',
#   Parameter containing:
#   tensor([0.4077, 0.4870, 0.4263], device='cuda:1', requires_grad=True)),
#  ('1.gp.covar_module.base_kernel.raw_lengthscale',
#   Parameter containing:
#   tensor([[[1.2636]],
#
#           [[1.5378]],
#
#           [[1.6994]]], device='cuda:1', requires_grad=True)),
#  ('1.likelihood.raw_noise',
#   Parameter containing:
#   tensor([-5.0992], device='cuda:1', requires_grad=True)),
#  ('1.likelihood.noise_covar.raw_noise',
#   Parameter containing:
#   tensor([-4.1313, -4.1875, -4.3647], device='cuda:1', requires_grad=True)),
#  ('2.fc.weight',
#   Parameter containing:
#   tensor([[     0.4235,      0.4061,     -0.5238,  ...,     -0.0009,
#                 0.3661,     -0.0004],
#           [     0.5101,      0.4519,     -0.4780,  ...,      0.0016,
#                 0.3972,      0.1942],
#           [    -0.3506,     -0.4614,      0.4412,  ...,      0.1539,
#                -0.3631,      0.0225],
#           ...,
#           [    -0.4767,     -0.5226,     -0.4538,  ...,     -0.0790,
#                -0.3721,     -0.0132],
#           [     0.4466,      0.5378,     -0.5221,  ...,     -0.1289,
#                 0.4713,      0.1035],
#           [    -0.4351,     -0.4255,     -0.5150,  ...,     -0.0244,
#                -0.4156,     -0.1072]], device='cuda:1', requires_grad=True)),
#  ('2.fc.bias',
#   Parameter containing:
#   tensor([-0.5189,  0.5062,  0.5077,  0.5546, -0.4519,  0.5478,  0.5409,  0.4846,
#           -0.5100, -0.4924, -0.4159, -0.1880,  0.5453, -0.5159, -0.4931, -0.4315,
#           -0.4313, -0.4170, -0.4076,  0.4877, -0.4781,  0.5315,  0.5022,  0.4113,
#           -0.4145, -0.5626, -0.4771, -0.5483, -0.5512,  0.4956, -0.5477, -0.5673,
#            0.5551, -0.5317,  0.5020,  0.5227,  0.5421, -0.4818, -0.4450, -0.5138,
#           -0.4411, -0.5316, -0.5554, -0.4782,  0.4987,  0.4504, -0.4600, -0.5114,
#           -0.5223, -0.4568, -0.3966,  0.4746,  0.5528,  0.4845,  0.4879,  0.5329,
#            0.5653, -0.5342, -0.4234, -0.4920, -0.5550, -0.5673, -0.4748, -0.5520,
#           -0.5575,  0.4693,  0.4992, -0.1901,  0.4326, -0.5619, -0.5528, -0.4824,
#            0.4680, -0.4891, -0.5040, -0.5458,  0.4909, -0.4380, -0.4484, -0.4287,
#            0.4283, -0.5075,  0.4814, -0.5617, -0.5552,  0.5684, -0.5339, -0.5652,
#           -0.4695, -0.5000,  0.4718, -0.5381, -0.4847, -0.4797,  0.4895, -0.4878,
#            0.4872,  0.3925, -0.5574,  0.4057, -0.4395, -0.4709,  0.5493, -0.5175,
#           -0.3890,  0.5694,  0.5348, -0.4413,  0.3819, -0.5412,  0.3685,  0.4814,
#           -0.5043, -0.5067, -0.4959, -0.5414, -0.5513, -0.5546,  0.4956,  0.4117,
#            0.5306,  0.4620, -0.4834, -0.4183,  0.4632, -0.5628, -0.4796, -0.5644],
#          device='cuda:1', requires_grad=True)),
#  ('2.gp.variational_strategy.base_variational_strategy.inducing_points',
#   Parameter containing:
#   tensor([[[     0.4695,     -0.3979,     -0.4592,  ...,      0.4279,
#                 -0.3816,      0.4278],
#            [    -0.3392,     -0.3140,      0.4777,  ...,      0.0757,
#                 -0.3429,      0.5304],
#            [     0.3488,      0.0628,     -0.2654,  ...,      0.3700,
#                  0.1709,      0.4619],
#            ...,
#            [    -0.0011,      0.0016,      0.0014,  ...,     -0.0017,
#                 -0.0026,      0.0009],
#            [     0.0009,      0.0018,     -0.0019,  ...,     -0.0060,
#                 -0.0015,      0.0031],
#            [    -0.0005,     -0.0016,     -0.0017,  ...,     -0.0066,
#                  0.0015,      0.0026]],
#
#           [[    -0.0220,      0.3109,     -0.1854,  ...,      0.3985,
#                 -0.4068,     -0.3366],
#            [    -0.2434,     -0.5458,     -0.0396,  ...,      0.3906,
#                  0.1961,      0.4174],
#            [     0.4875,     -0.3041,     -0.4063,  ...,      0.3377,
#                 -0.0785,      0.4017],
#            ...,
#            [     0.0017,     -0.1737,      0.0034,  ...,      0.0939,
#                 -0.0033,      0.1929],
#            [    -0.0015,     -0.0069,      0.0480,  ...,     -0.1921,
#                  0.0035,      0.0034],
#            [     0.0018,     -0.0019,     -0.0031,  ...,      0.0015,
#                  0.0014,     -0.0013]],
#
#           [[     0.5064,     -0.3781,     -0.3862,  ...,      0.4567,
#                  0.5161,      0.4607],
#            [     0.1172,      0.4441,     -0.4485,  ...,      0.2445,
#                  0.3511,     -0.3724],
#            [     0.2685,     -0.4298,     -0.4498,  ...,      0.2939,
#                  0.3414,      0.4083],
#            ...,
#            [     0.0173,      0.2809,      0.0019,  ...,     -0.0269,
#                  0.0045,     -0.2532],
#            [    -0.0015,     -0.0214,      0.0023,  ...,     -0.0031,
#                 -0.0016,      0.0002],
#            [    -0.0031,      0.1869,     -0.0016,  ...,      0.0222,
#                 -0.0014,     -0.1532]]], device='cuda:1', requires_grad=True)),
#  ('2.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean',
#   Parameter containing:
#   tensor([[     0.2628,      0.0430,      0.3618,  ...,     -0.0012,
#                 0.0027,      0.0025],
#           [    -0.7625,     -0.9930,      0.0409,  ...,     -0.0017,
#                -0.0297,     -0.0035],
#           [     0.9077,      0.0322,      0.4249,  ...,      0.0015,
#                 0.0202,     -0.0006]], device='cuda:1', requires_grad=True)),
#  ('2.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar',
#   Parameter containing:
#   tensor([[[    -0.4029,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.4430,      0.4638,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.5050,      0.5184,      0.5576,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [     0.0019,      0.0019,      0.0007,  ...,      0.1934,
#                  0.0000,      0.0000],
#            [    -0.0010,     -0.0012,      0.0027,  ...,      0.0014,
#                  0.1934,      0.0000],
#            [    -0.0016,     -0.0017,     -0.0014,  ...,      0.0014,
#                  0.0014,      0.1934]],
#
#           [[     0.4687,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.4662,      0.4431,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.3658,      0.4184,     -0.3889,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [    -0.0062,      0.0064,      0.0226,  ...,      0.1928,
#                  0.0000,      0.0000],
#            [    -0.0067,      0.0006,      0.0016,  ...,     -0.0014,
#                  0.1930,      0.0000],
#            [     0.0029,     -0.0016,     -0.0013,  ...,     -0.0015,
#                  0.0020,      0.1933]],
#
#           [[    -0.4810,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.4770,      0.5240,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.4842,      0.4296,      0.6400,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [     0.0029,      0.0067,     -0.0004,  ...,      0.1956,
#                  0.0000,      0.0000],
#            [    -0.0028,      0.0005,     -0.0031,  ...,      0.0023,
#                  0.1920,      0.0000],
#            [    -0.0019,     -0.0016,      0.0064,  ...,     -0.0019,
#                 -0.0016,      0.1953]]], device='cuda:1', requires_grad=True)),
#  ('2.gp.covar_module.raw_outputscale',
#   Parameter containing:
#   tensor([0.4593, 0.4684, 0.4399], device='cuda:1', requires_grad=True)),
#  ('2.gp.covar_module.base_kernel.raw_lengthscale',
#   Parameter containing:
#   tensor([[[1.4624]],
#
#           [[1.4860]],
#
#           [[1.3145]]], device='cuda:1', requires_grad=True)),
#  ('2.likelihood.raw_noise',
#   Parameter containing:
#   tensor([-5.0732], device='cuda:1', requires_grad=True)),
#  ('2.likelihood.noise_covar.raw_noise',
#   Parameter containing:
#   tensor([-4.0846, -4.2514, -4.2401], device='cuda:1', requires_grad=True)),
#  ('3.fc.weight',
#   Parameter containing:
#   tensor([[     0.4411,      0.4543,     -0.4492,  ...,     -0.0641,
#                 0.5117,     -0.0020],
#           [     0.5304,      0.4129,     -0.3759,  ...,      0.0015,
#                 0.4843,      0.0143],
#           [    -0.5335,     -0.4572,      0.4587,  ...,      0.0614,
#                -0.5354,     -0.1393],
#           ...,
#           [     0.3790,      0.4393,      0.4609,  ...,     -0.0066,
#                 0.3102,     -0.0000],
#           [     0.5128,      0.4899,     -0.4360,  ...,     -0.0072,
#                 0.4285,     -0.0112],
#           [     0.5018,      0.4817,      0.4105,  ...,      0.0014,
#                 0.4686,     -0.0189]], device='cuda:1', requires_grad=True)),
#  ('3.fc.bias',
#   Parameter containing:
#   tensor([-0.5226,  0.5070,  0.4469,  0.3746, -0.5026,  0.4493,  0.4954, -0.5094,
#            0.5228, -0.4150, -0.5207,  0.4891,  0.5009, -0.4785, -0.4999, -0.5598,
#            0.5034,  0.5045, -0.5443, -0.4603, -0.5687,  0.4831,  0.5430, -0.5508,
#           -0.4166,  0.4820, -0.5040,  0.5457, -0.5400,  0.5161,  0.4511,  0.4679,
#           -0.5604, -0.5604, -0.4902,  0.4410, -0.4990, -0.4940, -0.4390,  0.5380,
#           -0.5240, -0.2275,  0.4090,  0.4892, -0.4344,  0.4819, -0.5264,  0.5702,
#            0.5143, -0.4857,  0.5202,  0.5141, -0.5163,  0.4795, -0.5504, -0.5233,
#           -0.4560,  0.5382, -0.5385,  0.5658, -0.5034, -0.4359,  0.4547, -0.5176,
#           -0.4894, -0.5364, -0.4374, -0.5410, -0.4105,  0.5264, -0.4927,  0.5314,
#           -0.5190,  0.4603,  0.5375,  0.5181,  0.5204, -0.4792,  0.5613,  0.3808,
#            0.4931,  0.5541, -0.4523,  0.5307, -0.5673,  0.4404, -0.5645, -0.4275,
#           -0.5351,  0.5175,  0.4586,  0.4397,  0.5652,  0.5381,  0.4859, -0.5286,
#            0.5003,  0.5234, -0.4770,  0.5280,  0.4666,  0.5564, -0.4272, -0.5231,
#           -0.5337,  0.5356, -0.5293,  0.5260, -0.4331,  0.5686,  0.5523, -0.5433,
#            0.4674, -0.4298, -0.5617, -0.4270, -0.4668, -0.5493,  0.4982,  0.5596,
#            0.5435,  0.5319, -0.2847, -0.4770, -0.5047,  0.5163, -0.4126,  0.4869],
#          device='cuda:1', requires_grad=True)),
#  ('3.gp.variational_strategy.base_variational_strategy.inducing_points',
#   Parameter containing:
#   tensor([[[     0.5770,      0.3681,     -0.4047,  ...,     -0.2682,
#                  0.5627,     -0.1788],
#            [    -0.3238,     -0.2083,      0.7201,  ...,      0.4019,
#                  0.1256,      0.0021],
#            [     0.4292,      0.6293,     -0.3703,  ...,     -0.3345,
#                  0.5260,     -0.0017],
#            ...,
#            [     0.0019,     -0.0017,      0.0016,  ...,     -0.0016,
#                 -0.0022,      0.0030],
#            [     0.0010,     -0.0035,      0.0014,  ...,     -0.0015,
#                 -0.0016,     -0.0035],
#            [    -0.0019,      0.0017,      0.0032,  ...,     -0.0011,
#                 -0.0063,     -0.0062]],
#
#           [[     0.5358,     -0.2684,      0.5072,  ...,      0.0033,
#                 -0.3527,     -0.3898],
#            [    -0.3312,      0.2800,      0.2590,  ...,     -0.4988,
#                  0.5555,     -0.4735],
#            [     0.3732,      0.0029,      0.0159,  ...,     -0.2633,
#                  0.0142,      0.3296],
#            ...,
#            [    -0.0053,      0.0033,      0.0011,  ...,     -0.0017,
#                 -0.0027,      0.0035],
#            [     0.0010,     -0.0023,     -0.0016,  ...,     -0.0025,
#                 -0.0015,      0.0027],
#            [    -0.0009,     -0.0019,     -0.0012,  ...,     -0.0019,
#                  0.0022,      0.0017]],
#
#           [[     0.5518,      0.6319,     -0.3342,  ...,      0.4179,
#                  0.5635,      0.2575],
#            [     0.3285,     -0.4653,      0.6363,  ...,      0.3995,
#                 -0.4816,     -0.4408],
#            [     0.4203,      0.7458,      0.3569,  ...,      0.0009,
#                 -0.0072,     -0.0173],
#            ...,
#            [     0.3084,     -0.2748,      0.0035,  ...,     -0.0013,
#                 -0.0870,      0.0942],
#            [     0.0069,     -0.0005,      0.0035,  ...,     -0.0019,
#                 -0.0015,      0.0004],
#            [     0.3010,     -0.2514,     -0.0018,  ...,      0.0035,
#                 -0.0784,      0.0846]]], device='cuda:1', requires_grad=True)),
#  ('3.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean',
#   Parameter containing:
#   tensor([[     0.4924,      1.2450,      0.5674,  ...,     -0.0019,
#                 0.0015,     -0.0019],
#           [     0.2110,      0.9627,      0.0197,  ...,     -0.0007,
#                 0.0013,      0.0012],
#           [     0.2512,      1.4933,     -0.0045,  ...,     -0.0197,
#                 0.0015,     -0.0223]], device='cuda:1', requires_grad=True)),
#  ('3.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar',
#   Parameter containing:
#   tensor([[[ 0.4650,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [-0.0030, -0.2689,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [-0.0222, -0.2533,  0.5813,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.0019,  0.0017, -0.0016,  ...,  0.1934,  0.0000,  0.0000],
#            [ 0.0030, -0.0010, -0.0007,  ...,  0.0014,  0.1934,  0.0000],
#            [-0.0018,  0.0026, -0.0030,  ..., -0.0014, -0.0014,  0.1933]],
#
#           [[ 0.5002,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.3815, -0.3601,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.4500, -0.4065,  0.4436,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [-0.0018,  0.0015, -0.0014,  ...,  0.1932,  0.0000,  0.0000],
#            [-0.0016,  0.0018,  0.0033,  ..., -0.0014,  0.1949,  0.0000],
#            [ 0.0027, -0.0019, -0.0012,  ..., -0.0028, -0.0014,  0.1933]],
#
#           [[ 0.4968,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.4090, -0.4014,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.3935, -0.4290, -0.3750,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [-0.0075,  0.0171,  0.0041,  ...,  0.1961,  0.0000,  0.0000],
#            [-0.0012,  0.0015,  0.0019,  ..., -0.0017,  0.1962,  0.0000],
#            [-0.0138,  0.0191,  0.0056,  ...,  0.0019,  0.0015,  0.1962]]],
#          device='cuda:1', requires_grad=True)),
#  ('3.gp.covar_module.raw_outputscale',
#   Parameter containing:
#   tensor([0.5127, 0.4914, 0.4677], device='cuda:1', requires_grad=True)),
#  ('3.gp.covar_module.base_kernel.raw_lengthscale',
#   Parameter containing:
#   tensor([[[1.3975]],
#
#           [[1.3674]],
#
#           [[1.5886]]], device='cuda:1', requires_grad=True)),
#  ('3.likelihood.raw_noise',
#   Parameter containing:
#   tensor([-4.9029], device='cuda:1', requires_grad=True)),
#  ('3.likelihood.noise_covar.raw_noise',
#   Parameter containing:
#   tensor([-4.0178, -3.8686, -4.3138], device='cuda:1', requires_grad=True)),
#  ('4.fc.weight',
#   Parameter containing:
#   tensor([[     0.3557,      0.3711,     -0.4099,  ...,     -0.0013,
#                 0.4516,      0.0022],
#           [     0.3850,      0.5017,     -0.5562,  ...,     -0.0264,
#                 0.5061,      0.1508],
#           [    -0.4828,     -0.4929,      0.4611,  ...,     -0.0184,
#                -0.4555,     -0.0752],
#           ...,
#           [     0.3995,      0.4890,      0.5098,  ...,      0.0903,
#                 0.4221,     -0.0138],
#           [     0.4639,      0.4046,     -0.3922,  ...,      0.0012,
#                 0.3934,      0.0143],
#           [    -0.4149,     -0.4948,     -0.4684,  ...,      0.0068,
#                -0.5114,      0.0001]], device='cuda:1', requires_grad=True)),
#  ('4.fc.bias',
#   Parameter containing:
#   tensor([-0.2739, -0.2220,  0.4275,  0.4281, -0.5205, -0.5218,  0.5357,  0.5413,
#            0.4477,  0.5622, -0.5043, -0.4435,  0.5174, -0.5536,  0.3924, -0.5174,
#            0.5513,  0.5164, -0.5249, -0.4719,  0.4884, -0.4385, -0.5658, -0.5085,
#           -0.5586,  0.5368, -0.3633, -0.5689,  0.5264,  0.4541,  0.5496,  0.1268,
#            0.5676,  0.5361,  0.5464, -0.5406, -0.5472, -0.5582,  0.5422,  0.3769,
#            0.5018, -0.5262,  0.4373,  0.5315, -0.4720,  0.5524, -0.5521, -0.5066,
#            0.5323,  0.3951, -0.5198,  0.4395, -0.4635,  0.5252,  0.5571,  0.4946,
#            0.5494,  0.5405, -0.4935,  0.5349,  0.5510,  0.5635, -0.4428,  0.4374,
#            0.5473,  0.5253, -0.5547,  0.4935,  0.4230,  0.5183,  0.5521,  0.5374,
#            0.5642,  0.5229, -0.5435,  0.5250, -0.5234,  0.5105,  0.4741, -0.3381,
#           -0.5098, -0.5524,  0.4455, -0.4790, -0.5480,  0.5255,  0.4635, -0.5624,
#           -0.4593,  0.5660,  0.4741, -0.5269, -0.4803,  0.4789, -0.4191,  0.5154,
#            0.4958, -0.5425,  0.4918, -0.5245,  0.5581,  0.5353,  0.5302,  0.4247,
#           -0.4907,  0.4823, -0.4858,  0.5591, -0.4255, -0.5111, -0.5676,  0.4679,
#            0.4918, -0.4101, -0.5165, -0.5061,  0.1977, -0.4713,  0.4454,  0.4815,
#            0.4945,  0.1093, -0.4466, -0.4030, -0.4450,  0.5285,  0.5124, -0.5583],
#          device='cuda:1', requires_grad=True)),
#  ('4.gp.variational_strategy.base_variational_strategy.inducing_points',
#   Parameter containing:
#   tensor([[[     0.4512,     -0.3499,      0.3564,  ...,     -0.3713,
#                 -0.0019,      0.4421],
#            [    -0.0002,     -0.2257,      0.1387,  ...,      0.2638,
#                 -0.2421,      0.4118],
#            [     0.0257,      0.3425,      0.4919,  ...,     -0.2917,
#                  0.1537,     -0.0070],
#            ...,
#            [     0.0030,      0.0021,      0.1669,  ...,     -0.0008,
#                 -0.0394,      0.2578],
#            [     0.0016,     -0.0019,     -0.0854,  ...,     -0.0019,
#                  0.1553,     -0.2748],
#            [     0.0035,      0.0006,     -0.0006,  ...,      0.0019,
#                  0.0019,     -0.0073]],
#
#           [[     0.2632,      0.3288,      0.6843,  ...,     -0.1560,
#                 -0.2775,     -0.3047],
#            [     0.5638,      0.5532,      0.4600,  ...,     -0.5085,
#                 -0.2070,      0.4588],
#            [     0.0222,     -0.4484,      0.0017,  ...,      0.3088,
#                  0.1270,      0.3189],
#            ...,
#            [     0.0019,     -0.0019,      0.0018,  ...,     -0.1383,
#                 -0.0052,      0.0074],
#            [    -0.0023,     -0.0472,     -0.0014,  ...,      0.2995,
#                  0.2486,     -0.2400],
#            [     0.0008,     -0.0033,     -0.0066,  ...,     -0.0205,
#                  0.0033,      0.0034]],
#
#           [[     0.2740,     -0.3467,      0.4671,  ...,     -0.4476,
#                  0.5664,      0.4844],
#            [    -0.0016,     -0.1161,      0.5919,  ...,     -0.3578,
#                 -0.2482,      0.4392],
#            [    -0.2614,      0.0795,      0.4514,  ...,     -0.3831,
#                 -0.2135,      0.3597],
#            ...,
#            [     0.0043,     -0.0072,     -0.0004,  ...,     -0.0032,
#                  0.0223,     -0.0069],
#            [    -0.1324,      0.3785,     -0.0035,  ...,     -0.2923,
#                 -0.1750,      0.2022],
#            [     0.0310,     -0.0061,      0.0016,  ...,     -0.0087,
#                  0.1872,      0.0070]]], device='cuda:1', requires_grad=True)),
#  ('4.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean',
#   Parameter containing:
#   tensor([[     0.1084,     -0.0072,      0.4648,  ...,      0.0016,
#                -0.0014,     -0.0027],
#           [    -0.7377,      0.0759,     -0.9206,  ...,      0.0033,
#                 0.0014,      0.0172],
#           [     0.6390,     -0.0145,      0.6085,  ...,      0.0019,
#                 0.0000,     -0.0034]], device='cuda:1', requires_grad=True)),
#  ('4.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar',
#   Parameter containing:
#   tensor([[[    -0.4357,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.4784,      0.4428,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.4109,      0.3938,      0.4135,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [    -0.2014,      0.1407,     -0.0019,  ...,      0.1930,
#                  0.0000,      0.0000],
#            [     0.2235,     -0.1744,     -0.0030,  ...,      0.0010,
#                  0.1961,      0.0000],
#            [    -0.3437,      0.2440,      0.0006,  ...,      0.0030,
#                  0.0009,      0.1960]],
#
#           [[    -0.4909,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.4974,      0.5269,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.5560,      0.5179,      0.5242,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [    -0.1118,      0.0881,     -0.0225,  ...,      0.1949,
#                  0.0000,      0.0000],
#            [     0.0016,      0.0019,     -0.0010,  ...,     -0.0016,
#                  0.1924,      0.0000],
#            [     0.0681,      0.0035,     -0.0024,  ...,     -0.0018,
#                 -0.0013,      0.1930]],
#
#           [[    -0.4458,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.6077,     -0.4747,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.5858,     -0.4532,     -0.3870,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [    -0.0220,      0.0023,      0.0072,  ...,      0.1948,
#                  0.0000,      0.0000],
#            [     0.0036,      0.0035,      0.0051,  ...,      0.0016,
#                  0.1964,      0.0000],
#            [     0.0018,     -0.0007,     -0.0027,  ...,     -0.0021,
#                  0.0014,      0.1934]]], device='cuda:1', requires_grad=True)),
#  ('4.gp.covar_module.raw_outputscale',
#   Parameter containing:
#   tensor([0.4566, 0.5196, 0.4964], device='cuda:1', requires_grad=True)),
#  ('4.gp.covar_module.base_kernel.raw_lengthscale',
#   Parameter containing:
#   tensor([[[1.3182]],
#
#           [[1.3544]],
#
#           [[1.6817]]], device='cuda:1', requires_grad=True)),
#  ('4.likelihood.raw_noise',
#   Parameter containing:
#   tensor([-4.8576], device='cuda:1', requires_grad=True)),
#  ('4.likelihood.noise_covar.raw_noise',
#   Parameter containing:
#   tensor([-4.0550, -4.0774, -3.9600], device='cuda:1', requires_grad=True)),
#  ('5.fc.weight',
#   Parameter containing:
#   tensor([[ 0.4927,  0.4748, -0.3744,  ..., -0.0024,  0.4119, -0.0107],
#           [ 0.4663,  0.4057, -0.4883,  ..., -0.0228,  0.5089, -0.0072],
#           [-0.5479, -0.4458,  0.4040,  ..., -0.0070, -0.4322, -0.2009],
#           ...,
#           [-0.3876, -0.5309, -0.3396,  ..., -0.0018, -0.4499, -0.1408],
#           [ 0.5056,  0.4083, -0.4040,  ..., -0.0106,  0.4792,  0.1783],
#           [ 0.5387,  0.5510,  0.1834,  ..., -0.0019,  0.4892,  0.1309]],
#          device='cuda:1', requires_grad=True)),
#  ('5.fc.bias',
#   Parameter containing:
#   tensor([ 0.5283, -0.5582, -0.5119, -0.5229,  0.5423, -0.5378,  0.5348,  0.4755,
#            0.4869,  0.5525, -0.4854, -0.5227, -0.5178, -0.5352, -0.5311,  0.5553,
#           -0.5527, -0.4825, -0.5204,  0.4416, -0.5296, -0.0039, -0.5674, -0.5134,
#            0.4809,  0.5549, -0.4924, -0.5355,  0.3595,  0.5597, -0.4181,  0.3164,
#            0.2811, -0.5427,  0.5282,  0.4601, -0.5112, -0.4332,  0.5110, -0.5119,
#            0.5062, -0.4871,  0.4689,  0.5587,  0.5525, -0.5582, -0.4979,  0.3734,
#           -0.4833,  0.5680,  0.5643,  0.5107,  0.5486, -0.5245, -0.4546,  0.4892,
#            0.5549,  0.5341,  0.5407, -0.5423, -0.5422, -0.4876,  0.5137,  0.5101,
#            0.5682,  0.5323,  0.5123,  0.5642, -0.3700,  0.5405,  0.5282, -0.5207,
#            0.5483, -0.5610,  0.5124,  0.4637,  0.4824, -0.4049,  0.4919,  0.4417,
#           -0.4431,  0.5121,  0.5618, -0.4855,  0.4339,  0.4517, -0.5176,  0.5587,
#           -0.5053, -0.5114,  0.5072,  0.5204, -0.4990, -0.5430,  0.4405, -0.4959,
#           -0.3350, -0.4723,  0.4874, -0.4371,  0.4960,  0.5491,  0.5181,  0.5596,
#           -0.5044, -0.5613,  0.5634,  0.4924,  0.5083,  0.5646, -0.5522, -0.5580,
#            0.4523,  0.4714,  0.5544, -0.5368,  0.5054, -0.5590, -0.5142,  0.5199,
#           -0.5376, -0.5064, -0.5455,  0.5318,  0.5139, -0.5157,  0.4929,  0.4984],
#          device='cuda:1', requires_grad=True)),
#  ('5.gp.variational_strategy.base_variational_strategy.inducing_points',
#   Parameter containing:
#   tensor([[[     0.5161,     -0.2784,     -0.0574,  ...,     -0.4111,
#                  0.0009,      0.2659],
#            [    -0.0019,     -0.3253,     -0.4258,  ...,     -0.3153,
#                 -0.0000,      0.0019],
#            [     0.4115,      0.0028,     -0.4449,  ...,     -0.3551,
#                 -0.1391,     -0.0710],
#            ...,
#            [    -0.0021,     -0.0064,     -0.0006,  ...,     -0.0034,
#                  0.0035,      0.0025],
#            [     0.0228,      0.1555,     -0.0014,  ...,     -0.0010,
#                  0.0145,      0.0071],
#            [    -0.0014,     -0.0016,     -0.0064,  ...,     -0.0018,
#                 -0.0010,      0.0014]],
#
#           [[    -0.0160,      0.0018,      0.1159,  ...,     -0.4501,
#                 -0.3772,      0.4127],
#            [    -0.4949,     -0.5534,      0.5139,  ...,     -0.3606,
#                 -0.6239,     -0.1520],
#            [    -0.2229,     -0.1798,      0.5277,  ...,     -0.3295,
#                  0.5185,     -0.4079],
#            ...,
#            [    -0.0006,      0.0017,      0.0035,  ...,      0.0185,
#                  0.0022,     -0.0041],
#            [     0.0225,      0.0014,     -0.0051,  ...,      0.0049,
#                 -0.0070,     -0.0055],
#            [     0.0011,     -0.0031,     -0.0020,  ...,      0.0988,
#                  0.0008,     -0.0108]],
#
#           [[    -0.1953,     -0.1640,      0.5277,  ...,     -0.0025,
#                 -0.2291,     -0.3374],
#            [     0.0294,      0.4284,     -0.0035,  ...,     -0.3477,
#                  0.4883,     -0.1503],
#            [     0.0619,      0.4698,      0.0032,  ...,      0.2784,
#                  0.0007,     -0.1746],
#            ...,
#            [    -0.1294,      0.0004,     -0.1933,  ...,     -0.1737,
#                 -0.1076,      0.0029],
#            [    -0.0014,     -0.0018,      0.0071,  ...,      0.0014,
#                  0.0018,      0.0015],
#            [    -0.0097,     -0.0021,      0.0223,  ...,     -0.0060,
#                  0.0206,      0.0019]]], device='cuda:1', requires_grad=True)),
#  ('5.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean',
#   Parameter containing:
#   tensor([[    -0.1595,     -0.8322,     -0.7227,  ...,     -0.0003,
#                 0.0004,      0.0027],
#           [    -0.0047,     -0.0347,      1.2927,  ...,      0.0016,
#                -0.0004,     -0.0016],
#           [    -0.0163,     -0.0027,      0.8466,  ...,      0.0066,
#                 0.0015,     -0.0020]], device='cuda:1', requires_grad=True)),
#  ('5.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar',
#   Parameter containing:
#   tensor([[[    -0.4259,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.5901,      0.4638,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.5217,      0.3613,      0.5355,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [    -0.2122,     -0.0068,      0.0339,  ...,      0.1933,
#                  0.0000,      0.0000],
#            [    -0.0035,     -0.0019,     -0.0011,  ...,     -0.0014,
#                  0.1934,      0.0000],
#            [     0.0004,      0.0034,     -0.0030,  ...,     -0.0015,
#                 -0.0014,      0.1971]],
#
#           [[    -0.4412,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.4570,      0.5216,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.5533,      0.4816,      0.2046,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [    -0.0034,      0.0035,     -0.0027,  ...,      0.1932,
#                  0.0000,      0.0000],
#            [     0.0035,     -0.0018,     -0.0020,  ...,      0.0016,
#                  0.1951,      0.0000],
#            [    -0.0018,     -0.0016,     -0.0014,  ...,     -0.0016,
#                  0.0018,      0.1933]],
#
#           [[     0.4609,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.3779,     -0.4724,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.3008,     -0.5169,     -0.4417,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [     0.0119,      0.0037,      0.0011,  ...,      0.1961,
#                  0.0000,      0.0000],
#            [    -0.0014,     -0.0008,      0.0010,  ...,     -0.0017,
#                  0.1934,      0.0000],
#            [     0.0033,     -0.0011,      0.0016,  ...,     -0.0015,
#                  0.0016,      0.1931]]], device='cuda:1', requires_grad=True)),
#  ('5.gp.covar_module.raw_outputscale',
#   Parameter containing:
#   tensor([0.4927, 0.4902, 0.4575], device='cuda:1', requires_grad=True)),
#  ('5.gp.covar_module.base_kernel.raw_lengthscale',
#   Parameter containing:
#   tensor([[[1.3563]],
#
#           [[1.2728]],
#
#           [[1.6554]]], device='cuda:1', requires_grad=True)),
#  ('5.likelihood.raw_noise',
#   Parameter containing:
#   tensor([-4.9607], device='cuda:1', requires_grad=True)),
#  ('5.likelihood.noise_covar.raw_noise',
#   Parameter containing:
#   tensor([-3.9748, -4.0601, -4.2527], device='cuda:1', requires_grad=True)),
#  ('6.fc.weight',
#   Parameter containing:
#   tensor([[ 0.4247,  0.4582, -0.4191,  ...,  0.0167,  0.4617,  0.0827],
#           [ 0.5146,  0.5059, -0.4136,  ...,  0.0225,  0.4784,  0.1493],
#           [-0.5073, -0.4588,  0.4352,  ...,  0.0516, -0.4862, -0.0969],
#           ...,
#           [-0.3509, -0.4365,  0.4149,  ..., -0.0025, -0.3379,  0.0028],
#           [ 0.4859,  0.4509, -0.3760,  ...,  0.0056,  0.3799,  0.1461],
#           [-0.1791, -0.2494, -0.2815,  ..., -0.0020,  0.0035,  0.0030]],
#          device='cuda:1', requires_grad=True)),
#  ('6.fc.bias',
#   Parameter containing:
#   tensor([ 0.5252,  0.4690,  0.5079,  0.4279,  0.5370, -0.4514,  0.4152, -0.4402,
#           -0.5296, -0.5521, -0.4576, -0.4512,  0.4839,  0.5220, -0.4881, -0.5723,
#           -0.5437, -0.4807,  0.5542, -0.4801,  0.4546,  0.4008,  0.4825,  0.5046,
#           -0.5338, -0.5405,  0.5019, -0.5385,  0.0298,  0.4420,  0.5174, -0.4164,
#           -0.5032, -0.4651,  0.5416, -0.4219,  0.3211,  0.4478,  0.4895,  0.4674,
#           -0.4191,  0.4742,  0.5696,  0.4979,  0.5632,  0.4568,  0.5564,  0.4688,
#           -0.4202, -0.5322, -0.5297,  0.5361, -0.5345, -0.5569, -0.5046,  0.4253,
#           -0.5413,  0.4478, -0.5189,  0.5553, -0.5578, -0.4666, -0.5197,  0.5729,
#            0.4774,  0.5440,  0.5387,  0.4372, -0.5254,  0.5473,  0.5076,  0.5422,
#            0.5528, -0.4792,  0.1838, -0.5549,  0.4999, -0.5117, -0.5051,  0.5224,
#           -0.3966,  0.5663, -0.5142,  0.4619,  0.5392,  0.5253, -0.4728,  0.5207,
#            0.4166, -0.5321,  0.5036, -0.5027, -0.5527,  0.5540,  0.5555, -0.5566,
#            0.4926,  0.4431,  0.5288,  0.5060, -0.5552, -0.5484,  0.5120, -0.4612,
#            0.5149, -0.5607, -0.5252,  0.5673,  0.5083,  0.5272,  0.4890,  0.2995,
#           -0.4807, -0.4222, -0.5502, -0.4727, -0.4900,  0.5397,  0.5342, -0.5554,
#            0.5143,  0.5223, -0.5135, -0.5421, -0.4860,  0.4864,  0.5545, -0.5308],
#          device='cuda:1', requires_grad=True)),
#  ('6.gp.variational_strategy.base_variational_strategy.inducing_points',
#   Parameter containing:
#   tensor([[[    -0.3653,     -0.2878,      0.4659,  ...,      0.4752,
#                  0.3713,     -0.4262],
#            [     0.4015,      0.4946,     -0.6569,  ...,     -0.3953,
#                 -0.1422,      0.1790],
#            [     0.5038,      0.6465,      0.6001,  ...,      0.4274,
#                  0.6345,     -0.3724],
#            ...,
#            [     0.0119,      0.0016,      0.0017,  ...,     -0.0018,
#                 -0.0019,     -0.0068],
#            [    -0.0220,      0.0016,      0.0020,  ...,     -0.0048,
#                 -0.0015,     -0.0221],
#            [    -0.0017,      0.0025,      0.0014,  ...,     -0.0019,
#                 -0.0019,     -0.0019]],
#
#           [[     0.3202,     -0.1311,     -0.0755,  ...,      0.3162,
#                  0.3746,      0.2227],
#            [     0.2371,      0.0009,      0.3809,  ...,      0.2801,
#                 -0.1272,      0.0272],
#            [    -0.3345,      0.3632,      0.4509,  ...,      0.4267,
#                 -0.3080,     -0.4185],
#            ...,
#            [     0.0019,      0.0015,     -0.0019,  ...,      0.0023,
#                  0.0019,     -0.0015],
#            [     0.0019,     -0.0014,     -0.0028,  ...,     -0.1097,
#                  0.0070,      0.0023],
#            [     0.0034,      0.0007,     -0.0110,  ...,      0.2089,
#                  0.0920,     -0.0002]],
#
#           [[    -0.2635,     -0.3116,     -0.3504,  ...,     -0.4342,
#                 -0.3109,      0.0019],
#            [     0.1403,     -0.2337,     -0.0786,  ...,     -0.3791,
#                  0.3382,     -0.1834],
#            [     0.5172,      0.0072,     -0.0890,  ...,      0.2005,
#                  0.3466,     -0.3113],
#            ...,
#            [    -0.0612,      0.0019,      0.0231,  ...,      0.2118,
#                 -0.0213,      0.0031],
#            [     0.0525,     -0.0021,      0.0191,  ...,     -0.1084,
#                  0.0200,     -0.0067],
#            [    -0.1249,     -0.0015,      0.0169,  ...,      0.2163,
#                 -0.0101,      0.0014]]], device='cuda:1', requires_grad=True)),
#  ('6.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean',
#   Parameter containing:
#   tensor([[     0.0066,     -0.6708,      1.2117,  ...,      0.0179,
#                -0.0014,      0.0027],
#           [    -0.9805,      0.2033,     -0.0421,  ...,     -0.0018,
# ...
#            [    -0.4686,     -0.5432,     -0.3096,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [    -0.0027,      0.0030,      0.0026,  ...,      0.1969,
#                  0.0000,      0.0000],
#            [     0.0011,     -0.0032,     -0.0029,  ...,     -0.0014,
#                  0.1934,      0.0000],
#            [     0.0004,     -0.0030,     -0.0018,  ...,     -0.0015,
#                  0.0015,      0.1954]]], device='cuda:1', requires_grad=True)),
#  ('17.gp.covar_module.raw_outputscale',
#   Parameter containing:
#   tensor([0.4790, 0.4731, 0.4349], device='cuda:1', requires_grad=True)),
#  ('17.gp.covar_module.base_kernel.raw_lengthscale',
#   Parameter containing:
#   tensor([[[1.3361]],
#
#           [[1.6709]],
#
#           [[1.4606]]], device='cuda:1', requires_grad=True)),
#  ('17.likelihood.raw_noise',
#   Parameter containing:
#   tensor([-5.1309], device='cuda:1', requires_grad=True)),
#  ('17.likelihood.noise_covar.raw_noise',
#   Parameter containing:
#   tensor([-4.1923, -4.3685, -4.1632], device='cuda:1', requires_grad=True)),
#  ('18.fc.weight',
#   Parameter containing:
#   tensor([[     0.0014,      0.0019,     -0.5138,  ...,     -0.0072,
#                -0.0248,     -0.0019],
#           [     0.5230,      0.4421,     -0.4233,  ...,     -0.0046,
#                 0.4086,      0.1500],
#           [    -0.3689,     -0.4772,      0.4459,  ...,      0.0194,
#                -0.4613,     -0.0589],
#           ...,
#           [     0.0139,      0.1174,      0.5275,  ...,     -0.0224,
#                -0.0003,     -0.0026],
#           [     0.4979,      0.3874,     -0.4215,  ...,      0.0034,
#                 0.4296,     -0.0225],
#           [     0.4663,      0.4571,     -0.4504,  ...,     -0.0016,
#                 0.5083,     -0.0112]], device='cuda:1', requires_grad=True)),
#  ('18.fc.bias',
#   Parameter containing:
#   tensor([-0.4717,  0.5197,  0.4134, -0.5504, -0.5280, -0.4522, -0.4187,  0.5484,
#            0.5392, -0.5289, -0.4611, -0.4818,  0.5534, -0.5420, -0.4560,  0.5250,
#            0.4511,  0.4681,  0.5608,  0.5098, -0.4347,  0.5069, -0.5276, -0.4379,
#            0.5615,  0.4739, -0.5054, -0.5583, -0.5617, -0.4713,  0.4373,  0.5446,
#           -0.5418, -0.5572, -0.5583, -0.5660,  0.4490,  0.4403, -0.5264, -0.4401,
#            0.4331,  0.4770,  0.5480,  0.4658,  0.0947, -0.5065, -0.5642,  0.4993,
#            0.5328,  0.5071, -0.5441,  0.4500, -0.5611,  0.4931, -0.4782,  0.4657,
#            0.4858,  0.4570,  0.5097, -0.4374,  0.2452,  0.4617, -0.3901,  0.5094,
#            0.4550, -0.4873,  0.5452,  0.5636,  0.4312, -0.4823, -0.5655, -0.4777,
#            0.5332, -0.4748,  0.4352, -0.5636,  0.5535, -0.5511, -0.1393, -0.4455,
#            0.5609, -0.5424, -0.5512, -0.4727,  0.5093,  0.4322, -0.4400,  0.4589,
#            0.5295, -0.5537,  0.3988,  0.5499, -0.5583, -0.4840,  0.5141, -0.4959,
#            0.5418, -0.5074,  0.4441,  0.5002, -0.4982,  0.5617, -0.5237,  0.4464,
#            0.5480,  0.4747, -0.5374, -0.5436, -0.5227,  0.5424,  0.5343, -0.5332,
#            0.5468,  0.4699,  0.4168, -0.5006,  0.5151,  0.4894, -0.2827,  0.5021,
#           -0.5191,  0.5070, -0.5581,  0.4910, -0.4789,  0.4892, -0.4558,  0.4197],
#          device='cuda:1', requires_grad=True)),
#  ('18.gp.variational_strategy.base_variational_strategy.inducing_points',
#   Parameter containing:
#   tensor([[[     0.1568,     -0.4150,      0.2626,  ...,     -0.4103,
#                  0.3237,     -0.4292],
#            [    -0.0854,      0.6897,      0.2256,  ...,      0.3752,
#                  0.0029,      0.4391],
#            [    -0.3519,     -0.3056,     -0.4233,  ...,     -0.4445,
#                 -0.2157,     -0.4113],
#            ...,
#            [    -0.0014,     -0.0018,     -0.0018,  ...,      0.0016,
#                 -0.0017,      0.0014],
#            [    -0.0019,     -0.0019,      0.0019,  ...,     -0.0015,
#                  0.0010,     -0.0019],
#            [     0.0058,     -0.0019,      0.0019,  ...,      0.0004,
#                 -0.0027,     -0.0018]],
#
#           [[     0.4164,      0.6946,      0.0028,  ...,      0.1068,
#                 -0.0954,      0.5457],
#            [    -0.2550,      0.0056,     -0.0010,  ...,     -0.2624,
#                  0.0071,      0.3896],
#            [    -0.2433,      0.3102,     -0.0760,  ...,      0.3117,
#                  0.2157,      0.0033],
#            ...,
#            [     0.0006,      0.0017,      0.0035,  ...,      0.0067,
#                  0.0017,      0.0017],
#            [     0.0019,     -0.0035,     -0.0016,  ...,      0.0044,
#                  0.0024,     -0.0022],
#            [    -0.0025,      0.0019,     -0.0023,  ...,      0.0055,
#                  0.0019,      0.0000]],
#
#           [[    -0.0033,     -0.2015,      0.4870,  ...,     -0.3224,
#                 -0.1755,     -0.1222],
#            [     0.1975,      0.1683,      0.4469,  ...,     -0.3404,
#                  0.3302,      0.2893],
#            [    -0.0181,     -0.2334,      0.4202,  ...,      0.4098,
#                  0.0215,     -0.2540],
#            ...,
#            [    -0.0057,     -0.0143,      0.0204,  ...,     -0.3253,
#                  0.0003,     -0.0031],
#            [    -0.0028,     -0.0195,      0.0156,  ...,     -0.3085,
#                  0.0038,      0.0009],
#            [     0.0204,      0.0008,     -0.0002,  ...,     -0.2956,
#                 -0.0015,     -0.0035]]], device='cuda:1', requires_grad=True)),
#  ('18.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean',
#   Parameter containing:
#   tensor([[    -0.5629,      0.0092,     -0.9981,  ...,      0.0019,
#                 0.0033,     -0.0034],
#           [    -0.0625,     -1.0226,     -0.6056,  ...,     -0.0007,
#                 0.0006,     -0.0017],
#           [     0.5474,      0.0072,      0.0044,  ...,      0.0016,
#                -0.0021,     -0.0013]], device='cuda:1', requires_grad=True)),
#  ('18.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar',
#   Parameter containing:
#   tensor([[[     0.4564,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.4158,      0.4181,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.4031,     -0.4789,      0.4012,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [     0.0014,     -0.0019,     -0.0019,  ...,      0.1931,
#                  0.0000,      0.0000],
#            [     0.0015,     -0.0017,     -0.0028,  ...,      0.0014,
#                  0.1929,      0.0000],
#            [    -0.0027,     -0.0015,     -0.0019,  ...,      0.0014,
#                  0.0014,      0.1934]],
#
#           [[     0.5165,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.4845,     -0.4516,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.5050,     -0.4470,     -0.1969,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [     0.0006,     -0.0016,      0.0018,  ...,      0.1934,
#                  0.0000,      0.0000],
#            [     0.0016,      0.0002,     -0.0005,  ...,      0.0014,
#                  0.1934,      0.0000],
#            [    -0.0017,     -0.0032,      0.0014,  ...,      0.0015,
#                  0.0028,      0.1934]],
#
#           [[     0.4949,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.3809,     -0.3346,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.4270,     -0.4545,     -0.3865,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [    -0.0106,     -0.0024,      0.0171,  ...,      0.1934,
#                  0.0000,      0.0000],
#            [    -0.0225,      0.0016,     -0.0071,  ...,     -0.0018,
#                  0.1951,      0.0000],
#            [     0.0069,     -0.0015,     -0.0070,  ...,     -0.0016,
#                  0.0015,      0.1933]]], device='cuda:1', requires_grad=True)),
#  ('18.gp.covar_module.raw_outputscale',
#   Parameter containing:
#   tensor([0.4868, 0.4782, 0.4852], device='cuda:1', requires_grad=True)),
#  ('18.gp.covar_module.base_kernel.raw_lengthscale',
#   Parameter containing:
#   tensor([[[1.5758]],
#
#           [[1.5773]],
#
#           [[1.5567]]], device='cuda:1', requires_grad=True)),
#  ('18.likelihood.raw_noise',
#   Parameter containing:
#   tensor([-4.7719], device='cuda:1', requires_grad=True)),
#  ('18.likelihood.noise_covar.raw_noise',
#   Parameter containing:
#   tensor([-3.9351, -3.9288, -4.0441], device='cuda:1', requires_grad=True)),
#  ('19.fc.weight',
#   Parameter containing:
#   tensor([[ 0.3749,  0.3697, -0.4559,  ...,  0.0214,  0.3460,  0.0019],
#           [ 0.4952,  0.5510, -0.5500,  ...,  0.0210,  0.5204,  0.1377],
#           [-0.4658, -0.3792,  0.4077,  ...,  0.0672, -0.5297, -0.0083],
#           ...,
#           [-0.4737, -0.5320, -0.4868,  ..., -0.0017, -0.4957,  0.0110],
#           [ 0.3892,  0.4552, -0.3947,  ..., -0.0686,  0.4704, -0.0019],
#           [ 0.4665,  0.4540,  0.5518,  ...,  0.1477,  0.5087,  0.0303]],
#          device='cuda:1', requires_grad=True)),
#  ('19.fc.bias',
#   Parameter containing:
#   tensor([-0.4550,  0.5090,  0.4797,  0.4899, -0.5635, -0.5403, -0.5236, -0.4240,
#            0.4367, -0.5074,  0.4425, -0.3985,  0.3954, -0.5580,  0.5196, -0.5612,
#            0.5487,  0.3796, -0.4480, -0.5052,  0.4871,  0.4820,  0.4750,  0.3937,
#           -0.4452,  0.4725, -0.5047, -0.4473,  0.5334, -0.5631,  0.5311, -0.4705,
#            0.4906,  0.5619, -0.4951,  0.5651,  0.5592, -0.5132, -0.5188, -0.4589,
#            0.4861, -0.4682,  0.4232,  0.4733, -0.4867, -0.4644,  0.4325,  0.4980,
#            0.4601,  0.4982, -0.4428, -0.5236, -0.5624,  0.5394,  0.5570,  0.4716,
#            0.5281,  0.4801, -0.4036,  0.5595, -0.5572,  0.5108, -0.5208,  0.5678,
#            0.5576, -0.5681, -0.5283,  0.4622, -0.4149, -0.4821,  0.5308,  0.5389,
#            0.5306,  0.5237,  0.5180,  0.5679,  0.4364,  0.4212, -0.5419, -0.4990,
#            0.5424,  0.5136,  0.5082, -0.4712,  0.5171, -0.5032, -0.5280, -0.5163,
#            0.5299, -0.4739, -0.5096, -0.5360,  0.4380,  0.5659,  0.5413,  0.5481,
#            0.4580, -0.4430,  0.4349, -0.5400, -0.5379, -0.5589, -0.4673, -0.5368,
#           -0.5186,  0.4973, -0.4403, -0.5368,  0.4245, -0.4050,  0.3929,  0.4585,
#            0.4601, -0.4076,  0.5146,  0.5427, -0.4456,  0.4570, -0.4485, -0.4316,
#           -0.4881, -0.5072, -0.5298, -0.4418, -0.5667, -0.4950, -0.5593,  0.5524],
#          device='cuda:1', requires_grad=True)),
#  ('19.gp.variational_strategy.base_variational_strategy.inducing_points',
#   Parameter containing:
#   tensor([[[    -0.3331,     -0.3125,      0.6187,  ...,     -0.3402,
#                 -0.0072,      0.4446],
#            [     0.4542,     -0.2397,     -0.3028,  ...,     -0.0016,
#                  0.4714,      0.0004],
#            [    -0.4223,     -0.6317,     -0.1159,  ...,     -0.0615,
#                 -0.3317,     -0.2488],
#            ...,
#            [     0.0150,      0.2112,      0.1291,  ...,     -0.2498,
#                  0.0017,      0.3378],
#            [    -0.0034,      0.0019,      0.0021,  ...,      0.0012,
#                 -0.0018,      0.0027],
#            [    -0.2118,      0.0212,     -0.2116,  ...,      0.1234,
#                  0.0051,     -0.3117]],
#
#           [[    -0.3799,      0.4824,     -0.2186,  ...,     -0.4230,
#                 -0.2211,      0.3909],
#            [     0.2710,     -0.2592,     -0.1935,  ...,      0.3252,
#                  0.2535,     -0.4467],
#            [     0.5012,      0.4380,     -0.5019,  ...,      0.3751,
#                  0.4980,     -0.4842],
#            ...,
#            [     0.0239,     -0.0036,      0.0856,  ...,      0.0015,
#                 -0.0064,     -0.0022],
#            [     0.0072,      0.0019,     -0.0012,  ...,      0.0032,
#                 -0.0028,     -0.0019],
#            [     0.0013,      0.0030,     -0.0068,  ...,     -0.0034,
#                 -0.0044,     -0.0008]],
#
#           [[     0.3869,      0.5090,     -0.3159,  ...,     -0.3906,
#                  0.4283,      0.1729],
#            [     0.5233,      0.5303,     -0.2239,  ...,      0.2497,
#                  0.5161,     -0.4314],
#            [    -0.2269,     -0.1481,      0.4836,  ...,      0.2430,
#                 -0.1669,     -0.4477],
#            ...,
#            [    -0.0010,     -0.0002,     -0.0016,  ...,     -0.0018,
#                  0.0015,     -0.0008],
#            [    -0.0595,     -0.0066,     -0.0813,  ...,      0.0015,
#                  0.2438,     -0.3356],
#            [     0.2698,     -0.0015,      0.3659,  ...,      0.0565,
#                 -0.1839,      0.3894]]], device='cuda:1', requires_grad=True)),
#  ('19.gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean',
#   Parameter containing:
#   tensor([[     0.9499,      0.0223,      1.4771,  ...,      0.0034,
#                 0.0014,      0.0068],
#           [    -0.8265,     -1.4759,      0.2165,  ...,     -0.0028,
#                -0.0026,     -0.0022],
#           [     0.2862,     -0.1266,      0.9158,  ...,     -0.0019,
#                 0.0011,     -0.0226]], device='cuda:1', requires_grad=True)),
#  ('19.gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar',
#   Parameter containing:
#   tensor([[[    -0.5099,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.5592,     -0.4299,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.3635,     -0.5071,     -0.3289,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [     0.1321,     -0.0013,     -0.0070,  ...,      0.1923,
#                  0.0000,      0.0000],
#            [     0.0019,      0.0015,     -0.0015,  ...,     -0.0014,
#                  0.1934,      0.0000],
#            [     0.0217,     -0.0014,     -0.0003,  ...,     -0.0019,
#                 -0.0014,      0.1948]],
#
#           [[    -0.5053,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.4764,     -0.3578,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [    -0.5692,     -0.5867,      0.5620,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [     0.0014,      0.0018,      0.0003,  ...,      0.1930,
#                  0.0000,      0.0000],
#            [    -0.0003,     -0.0166,      0.0620,  ...,      0.0031,
#                  0.1932,      0.0000],
#            [     0.0035,     -0.0014,      0.0199,  ...,      0.0014,
#                 -0.0026,      0.1953]],
#
#           [[     0.4560,      0.0000,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.3948,     -0.3576,      0.0000,  ...,      0.0000,
#                  0.0000,      0.0000],
#            [     0.4472,     -0.4474,      0.4805,  ...,      0.0000,
#                  0.0000,      0.0000],
#            ...,
#            [     0.0020,     -0.0022,     -0.0002,  ...,      0.1934,
#                  0.0000,      0.0000],
#            [     0.3086,     -0.1380,      0.1272,  ...,     -0.0015,
#                  0.1926,      0.0000],
#            [    -0.0035,     -0.0002,      0.0005,  ...,      0.0014,
#                  0.0015,      0.1961]]], device='cuda:1', requires_grad=True)),
#  ('19.gp.covar_module.raw_outputscale',
#   Parameter containing:
#   tensor([0.4286, 0.5227, 0.4961], device='cuda:1', requires_grad=True)),
#  ('19.gp.covar_module.base_kernel.raw_lengthscale',
#   Parameter containing:
#   tensor([[[1.2566]],
#
#           [[1.3562]],
#
#           [[1.4792]]], device='cuda:1', requires_grad=True)),
#  ('19.likelihood.raw_noise',
#   Parameter containing:
#   tensor([-5.2222], device='cuda:1', requires_grad=True)),
#  ('19.likelihood.noise_covar.raw_noise',
#   Parameter containing:
#   tensor([-4.5279, -4.0525, -4.3814], device='cuda:1', requires_grad=True))]

# %% [markdown]
# # Training

# %%
if args.tensorboard:
    import os
    os.system('rm -rf runs/gps')
    from torch.utils.tensorboard import SummaryWriter
    writer = SummaryWriter('runs/gps')
import time
time.sleep(3)

# %%
trainer.model.train()
for e in range(args.num_epochs):
    torch.manual_seed(args.seed)
    minibatch_iter = tqdm(dataloader)
    train_loss = 0.
    for b, data in enumerate(minibatch_iter):
        x,y = data
        
        loss, batch_time = trainer.train(x,y)
        
        train_loss += loss
        ave_loss = train_loss/(b+1)
        step = e*len(dataloader)+(b+1)
        # display data
        minibatch_iter.set_postfix(ave = ave_loss, loss=loss,lr=trainer.scheduler.get_last_lr()[0])
        # tensorboard
        trainer.data2tensorboard(writer,'training loss',{'item loss':loss,'batch loss':ave_loss},step)
        # save model
        #trainer.save_model_step(e,step)
        # step scheduler
        trainer.schedule_step(step,51)
# Out:
#  24%|██▎       | 12/51 [00:49<02:41,  4.15s/it, ave=4.61, loss=4.55, lr=0.01]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3b1e4a7877f2> in <module>
#       7         x,y = data
#       8
# ----> 9         loss, batch_time = trainer.train(x,y)
#      10
#      11         train_loss += loss
#
# <ipython-input-4-b6c874aa241e> in train(self, x, y)
#     161
#     162         #Step 3: update
# --> 163         total_loss.backward()
#     164         self.optimizer.step()
#     165
#
# ~/.local/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~/.local/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# KeyboardInterrupt:

# %%
trainer.save_model('model-fast-zero-mean-fc.pth')
# Out:
# Saving model to model-fast-zero-mean-fc.pth

# %%
x,y = next(iter(dataloader))
trainer.model.eval()
trans_preds, rot_pred, trans_target, rot_target, samples = trainer.eval_forward(x,y)

# %%
trans_preds
# Out:
# tensor([[  75.0240,  238.4550,   -2.2583],
#         [-246.9995,  445.7235,  -12.2136],
#         [-177.5730,  588.5127,  -12.3354],
#         ...,
#         [ -46.7197,  467.6529,  -10.7595],
#         [ -33.5037,  505.6027,   -1.5013],
#         [-278.8232,  437.5095,  -12.2012]], device='cuda:1',
#        grad_fn=<AddBackward0>)

# %%
trans_target
# Out:
# tensor([[  76.4018,  239.5712,   -2.2569],
#         [-247.7184,  445.7048,  -12.2009],
#         [-177.7762,  588.2364,  -12.3849],
#         ...,
#         [ -48.2569,  465.5806,  -10.6875],
#         [ -34.3161,  505.4826,   -1.4701],
#         [-277.7613,  438.0477,  -12.2082]])
