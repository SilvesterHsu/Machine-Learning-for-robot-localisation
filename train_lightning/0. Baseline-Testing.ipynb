# %% [markdown]
# # Library and Basic setting

# %%
import numpy as np

import torch
from torch.nn import functional as F
from torch import nn
import pytorch_lightning as pl

# default setting
np.set_printoptions(precision=2)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, default=135,
                    help='size of mini batch')
parser.add_argument('--learning_rate', type=float, default=0.0008, help='learning rate')
parser.add_argument('--weight_decay', type=float, default=.0001, help='decay rate for rmsprop')
parser.add_argument('--lamda_weights', type=float, default=.01, help='lamda weight')
parser.add_argument('--is_normalization', type=bool,
                    default=True, help='whether do data normalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int,
                    help='Input images will be resized to this for data argumentation.')
parser.add_argument('--model_dir', type=str,
                    default='/notebooks/global_localization/gp_net_torch', help='rnn, gru, or lstm')
parser.add_argument('--test_dataset', type=str, default=['/notebooks/michigan_nn_data/2012_02_12',
                                                         '/notebooks/michigan_nn_data/2012_04_29',
                                                         '/notebooks/michigan_nn_data/2012_05_11',
                                                         '/notebooks/michigan_nn_data/2012_06_15',
                                                         '/notebooks/michigan_nn_data/2012_08_04',
                                                         '/notebooks/michigan_nn_data/2012_10_28',
                                                         '/notebooks/michigan_nn_data/2012_11_16',
                                                         '/notebooks/michigan_nn_data/2012_12_01'])
parser.add_argument('--train_dataset', type=str, default=['/notebooks/michigan_nn_data/2012_01_08',
                                                          '/notebooks/michigan_nn_data/2012_01_15',
                                                          '/notebooks/michigan_nn_data/2012_01_22',
                                                          '/notebooks/michigan_nn_data/2012_02_02',
                                                          '/notebooks/michigan_nn_data/2012_02_04',
                                                          '/notebooks/michigan_nn_data/2012_02_05',
                                                          '/notebooks/michigan_nn_data/2012_03_31',
                                                          '/notebooks/michigan_nn_data/2012_09_28'])
parser.add_argument('--norm_tensor', type=str,
                    default=['/notebooks/global_localization/norm_mean_std.pt'])

sys.argv = ['']
args = parser.parse_args()

# %% [markdown]
# # Load Dataset

# %%
import torchvision.transforms as transforms
import os
import sys
sys.path.append('..')
from torchlib.utils import LocalizationDataset
from torch.utils.data import DataLoader

[args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)

transform = transforms.Compose([transforms.ToTensor()])
test_dataset = LocalizationDataset(dataset_dirs = args.test_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform, 
                              get_pair = False, mode='evaluate', sampling_rate=2)

test_loader = DataLoader(test_dataset, batch_size=args.batch_size, \
                        shuffle=False, num_workers=os.cpu_count(), drop_last=False)
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'
# 100%|██████████| 14301/14301 [00:16<00:00, 878.74it/s]
# 100%|██████████| 7008/7008 [00:08<00:00, 779.84it/s]
# 100%|██████████| 12852/12852 [00:16<00:00, 785.32it/s]
# 100%|██████████| 9567/9567 [00:12<00:00, 783.33it/s]
# 100%|██████████| 13580/13580 [00:17<00:00, 795.38it/s]
# 100%|██████████| 14835/14835 [00:18<00:00, 783.34it/s]
# 100%|██████████| 7114/7114 [00:09<00:00, 763.28it/s]
# 100%|██████████| 12683/12683 [00:16<00:00, 771.06it/s]

# %%
#from torch.cuda.amp import autocast, GradScaler
import gpytorch
import sys
sys.path.append('..')
from torchlib.GPs import Backbone, NN
from torchlib.cnn_auxiliary import normalize, denormalize_navie


# Gaussian Process Model
class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([1]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([1])),
            batch_shape=torch.Size([1]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class Baseline(pl.LightningModule):

    def __init__(self):
        super().__init__()
        # parameters
        inducing_points = torch.zeros(3, 300, 128)
        self.backbone = Backbone()
        self.nn = NN()
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(
            num_tasks=3)
        [norm_mean, norm_std] = torch.load(*args.norm_tensor)
        self.norm_mean = torch.nn.parameter.Parameter(norm_mean,requires_grad=False)
        self.norm_std = torch.nn.parameter.Parameter(norm_std,requires_grad=False) 
        
        # shut down backbone learning
        self._disable_grad(self.backbone)

    def forward(self, x):
        dense_feat = self.backbone(x)
        output, feature_t, feature_r = self.nn(dense_feat)
        _, rot_pred = torch.split(output, [3, 4], dim=1)
        trans_pred = self.gp(feature_t)
        return trans_pred, rot_pred

    def training_step(self, batch, batch_idx):
        x, y = batch.values()
        y = normalize(y, self.norm_mean, self.norm_std)
        train_loss,trans_loss,rot_loss = self.__loss(x, y)
        #self.log('train_loss', train_loss, on_step=True, on_epoch=True, prog_bar=True, logger=True)
        tensorboard = self.logger.experiment
        #tensorboard.add_scalar('train_loss',float(train_loss),self.global_step)
        tensorboard.add_scalars('train_loss',
                                {'total_loss':float(train_loss),
                                'trans_loss':float(trans_loss),
                                'rot_loss':float(rot_loss)},
                                self.global_step)
        return train_loss

    def __loss(self, x, y):
        # target
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        # predict
        trans_pred, rot_pred = self.forward(x)

        # trans loss
        mll = gpytorch.mlls.PredictiveLogLikelihood(self.likelihood, self.gp, num_data=num_data)
        trans_loss = -1.*mll(trans_pred, trans_target)
        # rot loss
        rot_loss = 1. - \
            torch.mean(torch.square(
                torch.sum(torch.mul(rot_pred, rot_target), dim=1)))

        total_loss = trans_loss + args.lamda_weights * rot_loss

        return total_loss, trans_loss, rot_loss
    
    def validation_step(self, batch, batch_idx):
        x, y = batch.values()
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        trans_pred, rot_pred = self.forward(x)
        
        trans_pred, trans_mean, trans_var = self._eval_gp(trans_pred)
        trans_pred = denormalize_navie(trans_pred, self.norm_mean, self.norm_std)
        trans_mean = denormalize_navie(trans_mean, self.norm_mean, self.norm_std)
        trans_var = trans_var.mul(self.norm_std)
        samples = self._sample(trans_mean, trans_var, 100)
        
        trans_loss = torch.sqrt(torch.sum((trans_pred - trans_target)**2,dim=1)).mean()
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        #return trans_pred, rot_pred, trans_target, rot_target, samples
        
        val_loss = trans_loss
        self.log('val_loss', val_loss, on_step=True, on_epoch=True, prog_bar=False, logger=False)
        tensorboard = self.logger.experiment
        tensorboard.add_scalars('val_loss',
                                {'trans_loss':float(trans_loss),
                                'rot_loss':float(rot_loss)},
                                self.current_epoch*self.trainer.num_val_batches[0]+batch_idx)
        return val_loss
    
    def _eval_gp(self, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = self.likelihood(trans_pred).mean, self.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var
    
    def _sample(self, mean, var, num_sample = 100):
        dist = torch.distributions.Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples
    
    def eval_forward(self,x,y):
        x, y = x.to(self.device),y.to(self.device)
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        trans_pred, rot_pred = self.forward(x)
        
        trans_pred, trans_mean, trans_var = self._eval_gp(trans_pred)
        trans_pred = denormalize_navie(trans_pred, self.norm_mean, self.norm_std)
        trans_mean = denormalize_navie(trans_mean, self.norm_mean, self.norm_std)
        trans_var = trans_var.mul(self.norm_std)
        samples = self._sample(trans_mean, trans_var, 100)
        
        return trans_pred, rot_pred, trans_target, rot_target, samples
        
    def configure_optimizers(self):
        lr,weight_decay = args.learning_rate,args.weight_decay
        optimizer_args = [
            {'params': self.gp.parameters(), 'lr': lr, 'weight_decay': weight_decay},
            {'params': self.likelihood.parameters(), 'lr': lr,
             'weight_decay': weight_decay},
            {'params': self.nn.global_regressor.parameters(), 'lr': lr * 0.01,
             'weight_decay': weight_decay},
            {'params': self.nn.global_context.parameters(), 'lr': lr * 0.001, 'weight_decay': weight_decay}]
        
        optimizer = torch.optim.Adam(optimizer_args)

        return optimizer
    
    def show_require_grad(self):
        for name, param in self.named_parameters():
            if param.requires_grad:
                print (name, param.shape)
                
    def _disable_grad(self,model):
        for param in model.parameters():
            param.requires_grad = False
            
    def get_progress_bar_dict(self):
        tqdm_dict = super().get_progress_bar_dict()
        if 'v_num' in tqdm_dict:
            del tqdm_dict['v_num']
        return tqdm_dict
    
    def train_dataloader(self):
        train_loader = DataLoader(train_dataset, batch_size=args.batch_size,
                                  shuffle=True, num_workers=os.cpu_count(),drop_last=True)
        return train_loader

    def val_dataloader(self):
        val_loader = DataLoader(train_dataset, batch_size=args.batch_size,
                                shuffle=False, num_workers=os.cpu_count(),drop_last=True)
        return val_loader
    
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import ModelCheckpoint


#trainer = pl.Trainer(gpus=1,precision=32)
model = Baseline.load_from_checkpoint('pretrained-model-epoch=58-val_loss=0.26.ckpt')
#trainer.fit(model)

# %% [markdown]
# # Initialize

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

# %%
import math

model._disable_grad(model)
model.eval()
model.gp.eval()
model.likelihood.eval()
model.cuda()

for b, data in enumerate(test_loader, 0):
    start = time.time()
    
    x,y = data.values()
    x = x.cuda()
    y = y.cuda()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = model.eval_forward(x,y)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(test_loader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 135/92070, translation error = 2.952, rotation error = 1.948, time/batch = 3.802
# 270/92070, translation error = 2.613, rotation error = 2.189, time/batch = 1.379
# 405/92070, translation error = 7.655, rotation error = 2.955, time/batch = 1.015
# 540/92070, translation error = 7.001, rotation error = 3.138, time/batch = 1.051
# 675/92070, translation error = 6.025, rotation error = 2.858, time/batch = 1.137
# 810/92070, translation error = 5.582, rotation error = 2.745, time/batch = 1.103
# 945/92070, translation error = 6.806, rotation error = 2.883, time/batch = 1.114
# 1080/92070, translation error = 6.426, rotation error = 3.305, time/batch = 1.215
# 1215/92070, translation error = 6.614, rotation error = 3.501, time/batch = 0.939
# 1350/92070, translation error = 6.336, rotation error = 3.813, time/batch = 1.083
# 1485/92070, translation error = 5.955, rotation error = 3.819, time/batch = 0.969
# 1620/92070, translation error = 5.607, rotation error = 4.037, time/batch = 1.087
# 1755/92070, translation error = 5.345, rotation error = 4.094, time/batch = 0.913
# 1890/92070, translation error = 5.073, rotation error = 4.084, time/batch = 1.056
# 2025/92070, translation error = 4.973, rotation error = 4.092, time/batch = 0.938
# 2160/92070, translation error = 4.859, rotation error = 4.178, time/batch = 1.122
# 2295/92070, translation error = 4.661, rotation error = 4.082, time/batch = 1.009
# 2430/92070, translation error = 4.516, rotation error = 3.980, time/batch = 1.058
# 2565/92070, translation error = 4.352, rotation error = 3.963, time/batch = 1.033
# 2700/92070, translation error = 4.271, rotation error = 4.010, time/batch = 1.038
# 2835/92070, translation error = 4.187, rotation error = 4.041, time/batch = 0.943
# 2970/92070, translation error = 4.160, rotation error = 4.045, time/batch = 1.499
# 3105/92070, translation error = 4.061, rotation error = 3.991, time/batch = 0.847
# 3240/92070, translation error = 3.956, rotation error = 3.915, time/batch = 0.873
# 3375/92070, translation error = 3.959, rotation error = 4.072, time/batch = 0.884
# 3510/92070, translation error = 3.878, rotation error = 3.999, time/batch = 1.115
# 3645/92070, translation error = 3.809, rotation error = 3.905, time/batch = 1.005
# 3780/92070, translation error = 3.730, rotation error = 3.859, time/batch = 1.342
# 3915/92070, translation error = 3.638, rotation error = 3.826, time/batch = 0.866
# 4050/92070, translation error = 3.540, rotation error = 3.757, time/batch = 0.875
# 4185/92070, translation error = 3.460, rotation error = 3.737, time/batch = 1.002
# 4320/92070, translation error = 3.381, rotation error = 3.735, time/batch = 0.990
# 4455/92070, translation error = 3.312, rotation error = 3.675, time/batch = 1.228
# 4590/92070, translation error = 3.255, rotation error = 3.663, time/batch = 0.875
# 4725/92070, translation error = 3.183, rotation error = 3.627, time/batch = 1.017
# 4860/92070, translation error = 3.133, rotation error = 3.611, time/batch = 0.991
# 4995/92070, translation error = 3.084, rotation error = 3.653, time/batch = 1.013
# 5130/92070, translation error = 3.132, rotation error = 3.658, time/batch = 1.134
# 5265/92070, translation error = 3.072, rotation error = 3.621, time/batch = 0.971
# 5400/92070, translation error = 3.021, rotation error = 3.592, time/batch = 0.999
# 5535/92070, translation error = 2.986, rotation error = 3.553, time/batch = 1.003
# 5670/92070, translation error = 2.952, rotation error = 3.510, time/batch = 0.975
# 5805/92070, translation error = 2.953, rotation error = 3.484, time/batch = 0.935
# 5940/92070, translation error = 2.934, rotation error = 3.445, time/batch = 0.983
# 6075/92070, translation error = 2.915, rotation error = 3.432, time/batch = 0.917
# 6210/92070, translation error = 2.886, rotation error = 3.389, time/batch = 0.851
# 6345/92070, translation error = 2.881, rotation error = 3.361, time/batch = 0.848
# 6480/92070, translation error = 2.883, rotation error = 3.360, time/batch = 0.852
# 6615/92070, translation error = 2.883, rotation error = 3.358, time/batch = 0.900
# 6750/92070, translation error = 4.912, rotation error = 3.650, time/batch = 0.872
# 6885/92070, translation error = 5.026, rotation error = 3.743, time/batch = 0.849
# 7020/92070, translation error = 5.050, rotation error = 3.810, time/batch = 0.923
# 7155/92070, translation error = 5.001, rotation error = 3.808, time/batch = 1.092
# 7290/92070, translation error = 4.931, rotation error = 3.826, time/batch = 0.836
# 7425/92070, translation error = 4.865, rotation error = 3.885, time/batch = 0.923
# 7560/92070, translation error = 4.868, rotation error = 3.902, time/batch = 1.031
# 7695/92070, translation error = 4.818, rotation error = 3.928, time/batch = 0.833
# 7830/92070, translation error = 4.894, rotation error = 3.990, time/batch = 1.116
# 7965/92070, translation error = 4.911, rotation error = 4.002, time/batch = 1.200
# 24975/92070, translation error = 8.806, rotation error = 4.635, time/batch = 0.914
# 25110/92070, translation error = 8.772, rotation error = 4.629, time/batch = 0.963
# 25245/92070, translation error = 8.736, rotation error = 4.617, time/batch = 1.129
# 25380/92070, translation error = 8.699, rotation error = 4.616, time/batch = 0.935
# 25515/92070, translation error = 8.660, rotation error = 4.609, time/batch = 1.055
# 25650/92070, translation error = 8.620, rotation error = 4.608, time/batch = 1.057
# 25785/92070, translation error = 8.583, rotation error = 4.606, time/batch = 1.002
# 25920/92070, translation error = 8.549, rotation error = 4.599, time/batch = 0.995
# 26055/92070, translation error = 8.514, rotation error = 4.595, time/batch = 1.067
# 26190/92070, translation error = 8.477, rotation error = 4.581, time/batch = 0.881
# 26325/92070, translation error = 8.440, rotation error = 4.570, time/batch = 0.983
# 26460/92070, translation error = 8.402, rotation error = 4.568, time/batch = 0.994
# 26595/92070, translation error = 8.368, rotation error = 4.563, time/batch = 0.927
# 26730/92070, translation error = 8.333, rotation error = 4.557, time/batch = 0.873
# 26865/92070, translation error = 8.373, rotation error = 4.568, time/batch = 0.870
# 27000/92070, translation error = 8.340, rotation error = 4.559, time/batch = 0.887
# 27135/92070, translation error = 8.305, rotation error = 4.544, time/batch = 0.927
# 27270/92070, translation error = 8.278, rotation error = 4.532, time/batch = 0.873
# 27405/92070, translation error = 8.253, rotation error = 4.519, time/batch = 0.930
# 27540/92070, translation error = 8.227, rotation error = 4.509, time/batch = 1.011
# 27675/92070, translation error = 8.197, rotation error = 4.496, time/batch = 0.894
# 27810/92070, translation error = 8.170, rotation error = 4.483, time/batch = 0.996
# 27945/92070, translation error = 8.141, rotation error = 4.484, time/batch = 1.009
# 28080/92070, translation error = 8.113, rotation error = 4.474, time/batch = 1.111
# 28215/92070, translation error = 8.086, rotation error = 4.461, time/batch = 0.829
# 28350/92070, translation error = 8.068, rotation error = 4.465, time/batch = 0.882
# 28485/92070, translation error = 8.043, rotation error = 4.461, time/batch = 0.994
# 28620/92070, translation error = 8.018, rotation error = 4.450, time/batch = 0.968
# 28755/92070, translation error = 7.999, rotation error = 4.445, time/batch = 0.946
# 28890/92070, translation error = 7.980, rotation error = 4.516, time/batch = 1.055
# 29025/92070, translation error = 7.969, rotation error = 4.558, time/batch = 0.949
# 29160/92070, translation error = 8.037, rotation error = 4.574, time/batch = 1.107
# 29295/92070, translation error = 8.100, rotation error = 4.587, time/batch = 0.884
# 29430/92070, translation error = 8.072, rotation error = 4.577, time/batch = 1.016
# 29565/92070, translation error = 8.044, rotation error = 4.565, time/batch = 1.004
# 29700/92070, translation error = 8.014, rotation error = 4.553, time/batch = 0.982
# 29835/92070, translation error = 7.989, rotation error = 4.548, time/batch = 0.934
# 29970/92070, translation error = 7.975, rotation error = 4.547, time/batch = 1.122
# 30105/92070, translation error = 7.957, rotation error = 4.546, time/batch = 0.863
# 30240/92070, translation error = 7.938, rotation error = 4.535, time/batch = 0.893
# 30375/92070, translation error = 7.916, rotation error = 4.528, time/batch = 0.927
# 30510/92070, translation error = 7.893, rotation error = 4.523, time/batch = 0.946
# 41850/92070, translation error = 8.508, rotation error = 4.724, time/batch = 1.388
# 41985/92070, translation error = 8.488, rotation error = 4.725, time/batch = 0.892
# 42120/92070, translation error = 8.547, rotation error = 4.733, time/batch = 0.993
# 42255/92070, translation error = 8.525, rotation error = 4.724, time/batch = 1.125
# 42390/92070, translation error = 8.509, rotation error = 4.715, time/batch = 1.327
# 42525/92070, translation error = 8.493, rotation error = 4.708, time/batch = 0.893
# 42660/92070, translation error = 8.475, rotation error = 4.699, time/batch = 0.999
# 42795/92070, translation error = 8.457, rotation error = 4.692, time/batch = 1.087
# 42930/92070, translation error = 8.436, rotation error = 4.682, time/batch = 1.368
# 43065/92070, translation error = 8.416, rotation error = 4.674, time/batch = 0.900
# 43200/92070, translation error = 8.394, rotation error = 4.673, time/batch = 0.956
# 43335/92070, translation error = 8.376, rotation error = 4.667, time/batch = 1.056
# 43470/92070, translation error = 8.362, rotation error = 4.659, time/batch = 1.426
# 43605/92070, translation error = 8.354, rotation error = 4.661, time/batch = 0.909
# 43740/92070, translation error = 8.380, rotation error = 4.675, time/batch = 0.888
# 43875/92070, translation error = 8.363, rotation error = 4.670, time/batch = 0.919
# 44010/92070, translation error = 8.348, rotation error = 4.665, time/batch = 0.915
# 44145/92070, translation error = 8.327, rotation error = 4.661, time/batch = 0.900
# 44280/92070, translation error = 8.337, rotation error = 4.682, time/batch = 0.903
# 44415/92070, translation error = 8.326, rotation error = 4.678, time/batch = 0.953
# 44550/92070, translation error = 8.309, rotation error = 4.673, time/batch = 0.873
# 44685/92070, translation error = 8.297, rotation error = 4.672, time/batch = 0.849
# 44820/92070, translation error = 8.282, rotation error = 4.671, time/batch = 1.376
# 44955/92070, translation error = 8.263, rotation error = 4.671, time/batch = 0.882
# 45090/92070, translation error = 8.242, rotation error = 4.669, time/batch = 0.875
# 45225/92070, translation error = 8.229, rotation error = 4.667, time/batch = 1.118
# 45360/92070, translation error = 8.211, rotation error = 4.667, time/batch = 1.251
# 45495/92070, translation error = 8.190, rotation error = 4.661, time/batch = 0.921
# 45630/92070, translation error = 8.189, rotation error = 4.674, time/batch = 1.031
# 45765/92070, translation error = 8.169, rotation error = 4.666, time/batch = 1.553
# 45900/92070, translation error = 8.149, rotation error = 4.663, time/batch = 0.902
# 46035/92070, translation error = 8.133, rotation error = 4.675, time/batch = 0.876
# 46170/92070, translation error = 8.117, rotation error = 4.676, time/batch = 0.924
# 46305/92070, translation error = 8.102, rotation error = 4.675, time/batch = 1.077
# 46440/92070, translation error = 8.092, rotation error = 4.671, time/batch = 1.633
# 46575/92070, translation error = 8.076, rotation error = 4.665, time/batch = 0.891
# 46710/92070, translation error = 8.060, rotation error = 4.659, time/batch = 0.904
# 46845/92070, translation error = 8.044, rotation error = 4.654, time/batch = 0.901
# 46980/92070, translation error = 8.030, rotation error = 4.648, time/batch = 1.357
# 47115/92070, translation error = 8.017, rotation error = 4.649, time/batch = 0.885
# 47250/92070, translation error = 7.998, rotation error = 4.642, time/batch = 0.986
# 47385/92070, translation error = 8.011, rotation error = 4.640, time/batch = 1.090
# 64395/92070, translation error = 9.790, rotation error = 5.256, time/batch = 0.857
# 64530/92070, translation error = 9.782, rotation error = 5.277, time/batch = 0.814
# 64665/92070, translation error = 9.768, rotation error = 5.282, time/batch = 0.866
# 64800/92070, translation error = 9.752, rotation error = 5.276, time/batch = 1.101
# 64935/92070, translation error = 9.737, rotation error = 5.269, time/batch = 0.795
# 65070/92070, translation error = 9.730, rotation error = 5.280, time/batch = 0.832
# 65205/92070, translation error = 9.716, rotation error = 5.275, time/batch = 0.904
# 65340/92070, translation error = 9.701, rotation error = 5.270, time/batch = 0.874
# 65475/92070, translation error = 9.684, rotation error = 5.265, time/batch = 0.841
# 65610/92070, translation error = 9.671, rotation error = 5.264, time/batch = 0.929
# 65745/92070, translation error = 9.660, rotation error = 5.261, time/batch = 0.870
# 65880/92070, translation error = 9.650, rotation error = 5.265, time/batch = 1.005
# 66015/92070, translation error = 9.638, rotation error = 5.265, time/batch = 1.058
# 66150/92070, translation error = 9.624, rotation error = 5.262, time/batch = 0.808
# 66285/92070, translation error = 9.609, rotation error = 5.259, time/batch = 0.959
# 66420/92070, translation error = 9.595, rotation error = 5.254, time/batch = 0.935
# 66555/92070, translation error = 9.580, rotation error = 5.253, time/batch = 1.088
# 66690/92070, translation error = 9.610, rotation error = 5.271, time/batch = 1.282
# 66825/92070, translation error = 9.596, rotation error = 5.279, time/batch = 0.809
# 66960/92070, translation error = 9.581, rotation error = 5.277, time/batch = 0.873
# 67095/92070, translation error = 9.566, rotation error = 5.273, time/batch = 0.972
# 67230/92070, translation error = 9.565, rotation error = 5.284, time/batch = 1.177
# 67365/92070, translation error = 9.553, rotation error = 5.300, time/batch = 0.763
# 67500/92070, translation error = 9.547, rotation error = 5.309, time/batch = 0.952
# 67635/92070, translation error = 9.531, rotation error = 5.307, time/batch = 0.999
# 67770/92070, translation error = 9.516, rotation error = 5.300, time/batch = 0.943
# 67905/92070, translation error = 9.500, rotation error = 5.293, time/batch = 1.347
# 68040/92070, translation error = 9.484, rotation error = 5.286, time/batch = 0.829
# 68175/92070, translation error = 9.470, rotation error = 5.280, time/batch = 1.075
# 68310/92070, translation error = 9.457, rotation error = 5.283, time/batch = 0.997
# 68445/92070, translation error = 9.443, rotation error = 5.284, time/batch = 0.956
# 68580/92070, translation error = 9.430, rotation error = 5.280, time/batch = 1.174
# 68715/92070, translation error = 9.416, rotation error = 5.275, time/batch = 0.921
# 68850/92070, translation error = 9.401, rotation error = 5.269, time/batch = 1.169
# 68985/92070, translation error = 9.394, rotation error = 5.270, time/batch = 0.934
# 69120/92070, translation error = 9.383, rotation error = 5.271, time/batch = 0.979
# 69255/92070, translation error = 9.392, rotation error = 5.269, time/batch = 0.996
# 69390/92070, translation error = 9.382, rotation error = 5.268, time/batch = 1.079
# 69525/92070, translation error = 9.382, rotation error = 5.268, time/batch = 1.075
# 69660/92070, translation error = 9.372, rotation error = 5.263, time/batch = 1.043
# 69795/92070, translation error = 9.359, rotation error = 5.256, time/batch = 1.149
# 69930/92070, translation error = 9.376, rotation error = 5.260, time/batch = 0.918
# 75735/92070, translation error = 9.357, rotation error = 5.418, time/batch = 1.030
# 75870/92070, translation error = 9.344, rotation error = 5.413, time/batch = 0.779
# 76005/92070, translation error = 9.336, rotation error = 5.409, time/batch = 0.910
# 76140/92070, translation error = 9.325, rotation error = 5.406, time/batch = 0.907
# 76275/92070, translation error = 9.316, rotation error = 5.403, time/batch = 1.105
# 76410/92070, translation error = 9.303, rotation error = 5.398, time/batch = 0.820
# 76545/92070, translation error = 9.291, rotation error = 5.393, time/batch = 1.094
# 76680/92070, translation error = 9.278, rotation error = 5.388, time/batch = 0.831
# 76815/92070, translation error = 9.288, rotation error = 5.393, time/batch = 1.114
# 76950/92070, translation error = 9.276, rotation error = 5.392, time/batch = 0.853
# 77085/92070, translation error = 9.302, rotation error = 5.396, time/batch = 1.024
# 77220/92070, translation error = 9.296, rotation error = 5.392, time/batch = 1.149
# 77355/92070, translation error = 9.308, rotation error = 5.402, time/batch = 0.778
# 77490/92070, translation error = 9.524, rotation error = 5.450, time/batch = 0.933
# 77625/92070, translation error = 9.689, rotation error = 5.476, time/batch = 1.089
# 77760/92070, translation error = 9.743, rotation error = 5.513, time/batch = 0.867
# 77895/92070, translation error = 9.775, rotation error = 5.562, time/batch = 1.091
# 78030/92070, translation error = 9.856, rotation error = 5.587, time/batch = 1.202
# 78165/92070, translation error = 9.871, rotation error = 5.586, time/batch = 0.787
# 78300/92070, translation error = 9.893, rotation error = 5.592, time/batch = 0.874
# 78435/92070, translation error = 9.903, rotation error = 5.593, time/batch = 0.893
# 78570/92070, translation error = 9.916, rotation error = 5.609, time/batch = 1.067
# 78705/92070, translation error = 9.911, rotation error = 5.611, time/batch = 1.035
# 78840/92070, translation error = 9.903, rotation error = 5.611, time/batch = 1.213
# 78975/92070, translation error = 9.988, rotation error = 5.636, time/batch = 0.791
# 79110/92070, translation error = 10.075, rotation error = 5.706, time/batch = 0.912
# 79245/92070, translation error = 10.133, rotation error = 5.770, time/batch = 0.951
# 79380/92070, translation error = 10.132, rotation error = 5.778, time/batch = 0.979
# 79515/92070, translation error = 10.656, rotation error = 5.782, time/batch = 1.116
# 79650/92070, translation error = 10.642, rotation error = 5.799, time/batch = 0.827
# 79785/92070, translation error = 10.628, rotation error = 5.816, time/batch = 1.020
# 79920/92070, translation error = 10.614, rotation error = 5.832, time/batch = 1.003
# 80055/92070, translation error = 10.601, rotation error = 5.847, time/batch = 0.969
# 80190/92070, translation error = 10.592, rotation error = 5.854, time/batch = 1.124
# 80325/92070, translation error = 10.579, rotation error = 5.852, time/batch = 0.920
# 80460/92070, translation error = 10.577, rotation error = 5.861, time/batch = 1.206
# 80595/92070, translation error = 10.678, rotation error = 5.913, time/batch = 0.792
# 80730/92070, translation error = 10.675, rotation error = 5.928, time/batch = 0.882
# 80865/92070, translation error = 10.663, rotation error = 5.923, time/batch = 0.876
# 81000/92070, translation error = 10.651, rotation error = 5.920, time/batch = 0.923
# 81135/92070, translation error = 10.657, rotation error = 5.924, time/batch = 0.898
# 81270/92070, translation error = 10.675, rotation error = 5.959, time/batch = 0.781
# 81405/92070, translation error = 10.727, rotation error = 5.974, time/batch = 0.931
# 81540/92070, translation error = 10.716, rotation error = 5.989, time/batch = 0.816
# 81675/92070, translation error = 10.704, rotation error = 5.987, time/batch = 0.886
# 81810/92070, translation error = 10.691, rotation error = 5.987, time/batch = 0.894
# 81945/92070, translation error = 10.684, rotation error = 5.989, time/batch = 0.895
# 82080/92070, translation error = 10.677, rotation error = 5.983, time/batch = 1.068
# 82215/92070, translation error = 10.664, rotation error = 5.981, time/batch = 1.039
# 82350/92070, translation error = 10.657, rotation error = 5.975, time/batch = 0.970
# 82485/92070, translation error = 10.647, rotation error = 5.975, time/batch = 0.934
# 82620/92070, translation error = 10.636, rotation error = 5.979, time/batch = 0.928
# 82755/92070, translation error = 10.647, rotation error = 5.987, time/batch = 1.046
# 82890/92070, translation error = 10.635, rotation error = 5.993, time/batch = 1.176
# 83025/92070, translation error = 10.623, rotation error = 5.991, time/batch = 0.790
# 83160/92070, translation error = 10.614, rotation error = 5.990, time/batch = 0.982
# 83295/92070, translation error = 10.603, rotation error = 5.984, time/batch = 0.955
# 83430/92070, translation error = 10.599, rotation error = 5.981, time/batch = 1.084
# 83565/92070, translation error = 10.595, rotation error = 5.979, time/batch = 0.860
# 83700/92070, translation error = 10.581, rotation error = 5.974, time/batch = 0.923
# 83835/92070, translation error = 10.590, rotation error = 5.984, time/batch = 1.332
# 83970/92070, translation error = 10.588, rotation error = 5.991, time/batch = 0.805
# 84105/92070, translation error = 10.585, rotation error = 6.009, time/batch = 0.915
# 84240/92070, translation error = 10.591, rotation error = 6.041, time/batch = 1.015
# 84375/92070, translation error = 10.579, rotation error = 6.053, time/batch = 0.857
# 84510/92070, translation error = 10.567, rotation error = 6.052, time/batch = 1.041
# 84645/92070, translation error = 10.554, rotation error = 6.047, time/batch = 0.989
# 84780/92070, translation error = 10.540, rotation error = 6.041, time/batch = 0.962
# 84915/92070, translation error = 10.531, rotation error = 6.042, time/batch = 0.928
# 85050/92070, translation error = 10.518, rotation error = 6.039, time/batch = 1.043
# 85185/92070, translation error = 10.506, rotation error = 6.037, time/batch = 0.927
# 85320/92070, translation error = 10.493, rotation error = 6.030, time/batch = 1.099
# 85455/92070, translation error = 10.481, rotation error = 6.024, time/batch = 0.904
# 85590/92070, translation error = 10.467, rotation error = 6.019, time/batch = 0.950
# 85725/92070, translation error = 10.454, rotation error = 6.015, time/batch = 0.891
# 85860/92070, translation error = 10.449, rotation error = 6.030, time/batch = 0.907
# 85995/92070, translation error = 10.576, rotation error = 6.096, time/batch = 0.964
# 86130/92070, translation error = 10.581, rotation error = 6.105, time/batch = 0.821
# 86265/92070, translation error = 10.567, rotation error = 6.101, time/batch = 1.052
# 86400/92070, translation error = 10.554, rotation error = 6.096, time/batch = 0.920
# 86535/92070, translation error = 10.544, rotation error = 6.089, time/batch = 0.884
# 86670/92070, translation error = 10.530, rotation error = 6.084, time/batch = 0.863
# 86805/92070, translation error = 10.522, rotation error = 6.078, time/batch = 0.981
# 86940/92070, translation error = 10.509, rotation error = 6.074, time/batch = 0.835
# 87075/92070, translation error = 10.496, rotation error = 6.068, time/batch = 0.968
# 87210/92070, translation error = 10.483, rotation error = 6.062, time/batch = 0.797
# 87345/92070, translation error = 10.532, rotation error = 6.081, time/batch = 0.826
# 87480/92070, translation error = 10.532, rotation error = 6.086, time/batch = 0.795
# 87615/92070, translation error = 10.519, rotation error = 6.089, time/batch = 0.786
# 87750/92070, translation error = 10.506, rotation error = 6.086, time/batch = 0.824
# 87885/92070, translation error = 10.513, rotation error = 6.113, time/batch = 0.823
# 88020/92070, translation error = 10.592, rotation error = 6.146, time/batch = 0.827
# 88155/92070, translation error = 10.611, rotation error = 6.150, time/batch = 0.898
# 88290/92070, translation error = 10.597, rotation error = 6.147, time/batch = 0.970
# 88425/92070, translation error = 10.584, rotation error = 6.145, time/batch = 0.901
# 88560/92070, translation error = 10.570, rotation error = 6.143, time/batch = 0.814
# 88695/92070, translation error = 10.556, rotation error = 6.138, time/batch = 0.763
# 88830/92070, translation error = 10.705, rotation error = 6.154, time/batch = 0.751
# 88965/92070, translation error = 10.752, rotation error = 6.162, time/batch = 0.736
# 89100/92070, translation error = 10.743, rotation error = 6.164, time/batch = 0.759
# 89235/92070, translation error = 10.733, rotation error = 6.169, time/batch = 0.746
# 89370/92070, translation error = 10.720, rotation error = 6.168, time/batch = 0.753
# 89505/92070, translation error = 10.707, rotation error = 6.163, time/batch = 0.757
# 89640/92070, translation error = 10.696, rotation error = 6.160, time/batch = 0.617
# 89775/92070, translation error = 10.691, rotation error = 6.160, time/batch = 0.612
# 89910/92070, translation error = 10.730, rotation error = 6.165, time/batch = 0.614
# 90045/92070, translation error = 10.750, rotation error = 6.160, time/batch = 0.612
# 90180/92070, translation error = 10.736, rotation error = 6.155, time/batch = 0.621
# 90315/92070, translation error = 10.723, rotation error = 6.150, time/batch = 0.613
# 90450/92070, translation error = 10.712, rotation error = 6.151, time/batch = 0.617
# 90585/92070, translation error = 10.707, rotation error = 6.151, time/batch = 0.612
# 90720/92070, translation error = 10.694, rotation error = 6.148, time/batch = 0.614
# 90855/92070, translation error = 10.683, rotation error = 6.146, time/batch = 0.611
# 90990/92070, translation error = 10.670, rotation error = 6.143, time/batch = 0.612
# 91125/92070, translation error = 10.658, rotation error = 6.138, time/batch = 0.611
# 91260/92070, translation error = 10.660, rotation error = 6.177, time/batch = 0.611
# 91395/92070, translation error = 10.652, rotation error = 6.212, time/batch = 0.616
# 91530/92070, translation error = 10.639, rotation error = 6.206, time/batch = 0.611
# 91665/92070, translation error = 10.625, rotation error = 6.202, time/batch = 0.615
# 91800/92070, translation error = 10.612, rotation error = 6.196, time/batch = 0.611
# 91935/92070, translation error = 10.602, rotation error = 6.198, time/batch = 0.614
# 92070/92070, translation error = 10.602, rotation error = 6.199, time/batch = 0.781

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
#plt.savefig('terror.png', bbox_inches='tight')
plt.show()

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
#plt.savefig('rerror.png', bbox_inches='tight')
plt.show()

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.022
# median rotation error = 2.872
# mean translation error = 10.602
# mean rotation error = 6.199

# %%
def evaluate(trans_errors,rot_errors):
    t = test_dataset.last_indexes
    trans_errors_month = list()
    trans_errors_month.append(trans_errors[:t[0]])
    trans_errors_month.append(trans_errors[t[0]:t[1]])
    trans_errors_month.append(trans_errors[t[1]:t[2]])
    trans_errors_month.append(trans_errors[t[2]:t[3]])
    trans_errors_month.append(trans_errors[t[3]:t[4]])
    trans_errors_month.append(trans_errors[t[4]:t[5]])
    trans_errors_month.append(trans_errors[t[5]:t[6]])
    trans_errors_month.append(trans_errors[t[6]:])

    rot_errors_month = list()
    rot_errors_month.append(rot_errors[:t[0]])
    rot_errors_month.append(rot_errors[t[0]:t[1]])
    rot_errors_month.append(rot_errors[t[1]:t[2]])
    rot_errors_month.append(rot_errors[t[2]:t[3]])
    rot_errors_month.append(rot_errors[t[3]:t[4]])
    rot_errors_month.append(rot_errors[t[4]:t[5]])
    rot_errors_month.append(rot_errors[t[5]:t[6]])
    rot_errors_month.append(rot_errors[t[6]:])
    
    print('================== median translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("median translation error = {:.3f}".format(np.median(trans_errors_i)))
        
    print('================== median rotation error ==================')
    for rot_errors_i in rot_errors_month:
        print("median rotation error = {:.3f}".format(np.median(rot_errors_i)))
    
    print('================== mean translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("mean translation error = {:.3f}".format(np.mean(trans_errors_i)))
        
    print('================== mean rotation error ==================')  
    for rot_errors_i in rot_errors_month:
        print("mean rotation error = {:.3f}".format(np.mean(rot_errors_i)))
        
evaluate(trans_errors,rot_errors)
# Out:
# ================== median translation error ==================
# median translation error = 1.575
# median translation error = 1.620
# median translation error = 1.906
# median translation error = 1.884
# median translation error = 2.001
# median translation error = 2.060
# median translation error = 3.374
# median translation error = 2.748
# ================== median rotation error ==================
# median rotation error = 2.482
# median rotation error = 2.552
# median rotation error = 2.672
# median rotation error = 2.619
# median rotation error = 2.852
# median rotation error = 2.936
# median rotation error = 4.056
# median rotation error = 4.016
# ================== mean translation error ==================
# mean translation error = 4.075
# mean translation error = 4.255
# mean translation error = 12.475
# mean translation error = 12.346
# mean translation error = 9.329
# mean translation error = 11.236
# mean translation error = 20.154
# mean translation error = 13.519
# ================== mean rotation error ==================
# mean rotation error = 3.751
# mean rotation error = 4.018
# mean rotation error = 5.373
# mean rotation error = 5.604
# mean rotation error = 5.453
# mean rotation error = 6.497
# mean rotation error = 11.618
# mean rotation error = 8.858
