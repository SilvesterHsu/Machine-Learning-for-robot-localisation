# %% [markdown]
# # Library

# %%
import numpy as np
import torch
import gpytorch
import argparse
import time
import pickle
import scipy.io as sio

from torch.distributions import Normal
import matplotlib.pyplot as plt
import random

import roslib
import rospy
import tf as tf_ros
from nav_msgs.msg import Odometry, Path
from sensor_msgs.msg import Image
from cv_bridge import CvBridge
from geometry_msgs.msg import PoseStamped, PoseArray, Pose
import math
import cv2
import copy

import sys
sys.path.append('..')
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'

# %% [markdown]
# ## Check GPU

# %%
import torch
import numpy as np
import sys
sys.path.append('..')

from torchlib.utils import list_device,set_device

# S1: check GPU
#list_device()

# S2: default parameters
set_device(1)
np.set_printoptions(precision = 2)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, default=420, help='size of mini batch')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data normalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')

parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/gp_net_torch', help='rnn, gru, or lstm')

parser.add_argument('--test_dataset', type=str, default=[# '/notebooks/michigan_nn_data/2012_01_08',
                                                         # '/notebooks/michigan_nn_data/2012_01_15',
                                                         # '/notebooks/michigan_nn_data/2012_01_22',
                                                         # '/notebooks/michigan_nn_data/2012_02_02',
                                                         # '/notebooks/michigan_nn_data/2012_02_04',
                                                         # '/notebooks/michigan_nn_data/2012_02_05',
                                                         '/notebooks/michigan_nn_data/2012_02_12',
                                                         # '/notebooks/michigan_nn_data/2012_03_31',
                                                         '/notebooks/michigan_nn_data/2012_04_29',
                                                         '/notebooks/michigan_nn_data/2012_05_11',
                                                         '/notebooks/michigan_nn_data/2012_06_15',
                                                         '/notebooks/michigan_nn_data/2012_08_04',
                                                         # '/notebooks/michigan_nn_data/2012_09_28'])
                                                         '/notebooks/michigan_nn_data/2012_10_28',
                                                         '/notebooks/michigan_nn_data/2012_11_16',
                                                         '/notebooks/michigan_nn_data/2012_12_01'
                                                        ] )

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/test'])
parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

#parser.add_argument('--map_dataset', type=str, default='/home/kevin/data/michigan_gt/training')
parser.add_argument('--enable_ros', type=bool, default=False, help='put data into ros')
parser.add_argument('--cuda_device', type=int, default=1, help='cuda device')

sys.argv = ['']
args = parser.parse_args()

if args.enable_ros:
    rospy.init_node('global_localization_tf_broadcaster_cnn')

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
#from PIL import Image
import numpy as np
import random

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet, cnn_auxiliary
from torchlib.cnn_auxiliary import normalize, denormalize, denormalize_navie, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

transform = transforms.Compose([transforms.ToTensor()])
dataset = LocalizationDataset(dataset_dirs = args.test_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform,
                              get_pair = False, mode='evaluate', sampling_rate=1)

[args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
print('Load norm and std:',*args.norm_tensor)

dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=False, num_workers=0, \
                        drop_last=False, pin_memory=True)
# Out:
# 100%|██████████| 28602/28602 [00:37<00:00, 767.66it/s]
# 100%|██████████| 14016/14016 [00:18<00:00, 760.96it/s]
# 100%|██████████| 25704/25704 [00:33<00:00, 769.64it/s]
# 100%|██████████| 19135/19135 [00:24<00:00, 765.71it/s]
# 100%|██████████| 27160/27160 [00:39<00:00, 694.29it/s]
# 100%|██████████| 29670/29670 [00:54<00:00, 540.69it/s]
# 100%|██████████| 14229/14229 [00:27<00:00, 514.99it/s]
# 100%|██████████| 25367/25367 [00:51<00:00, 491.30it/s]
# Load norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # Define Model

# %%
from torch.cuda.amp import autocast, GradScaler
from torchlib.GPs import Backbone, NN, BaseModule

class NN(nn.Module):
    def __init__(self):
        super().__init__()
        self.global_context = vggnet.vggnet(input_channel=2048,opt="context")
        self.global_regressor = vggnet.vggnet(opt="regressor")
        
    def forward(self,input_data):
        context_feat = self.global_context(input_data)
        #context_feat = input_data
        output,feature_t, feature_r = self.global_regressor(context_feat)
        return output, feature_t, feature_r

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.MultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ZeroMean()
        #self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([3]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([3])),
            batch_shape=torch.Size([3]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        inducing_points = torch.zeros(3, 1000, 128)
        self.backbone = Backbone()
        self.nn = NN()
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=3)
        
    def forward(self, input_data):
        dense_feat = self.backbone(input_data)
        #dense_feat = input_data
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention 
        trans_pred = self.gp(feature_t)
        return trans_pred, rot_pred

class PosePredictor(BaseModule):
    def __init__(self, norm_mean, norm_std, args,
                 is_training=True, mixed_precision=True,
                 regressor_context_rate = [0.0,0.0], train_rot = False):
        super().__init__(norm_mean, norm_std, args)
        self.model = Model().to(self.device)
        self.train_rot = train_rot
        self.mixed_precision = mixed_precision
        if self.mixed_precision:
            self.scaler = GradScaler()

        self.disable_requires_grad(self.model.backbone)
        
        if is_training:
            self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
            self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                             lr_lambda=lambda epoch: args.decay_rate**epoch)
            num_data = min(len(dataloader)*args.batch_size,len(dataset))
            self.mll = gpytorch.mlls.PredictiveLogLikelihood(self.model.likelihood, \
                                                         self.model.gp, num_data = num_data)
        else:
            self.disable_requires_grad(self.model)
            
    def _optimize(self,regressor_context_rate):
        # GP
        optimizer = [
                {'params': self.model.gp.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay},
                {'params': self.model.likelihood.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay}]
            
        # NN
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            self.disable_requires_grad(self.model.nn.global_regressor)
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
            self.train_rot = True
        else:
            self.disable_requires_grad(self.model.nn.global_context)
            
        
        if not self.train_rot and regressor_context_rate[1]==0.0:
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc1_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc2_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc3_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.logits_r)
                
        return optimizer
    
    def train(self,x, y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
            
        # Step 2: training
        assert trainer.model.training == True
        if self.mixed_precision:
            with autocast():
                single_loss = self._loss(x, y)
            self.scaler.scale(single_loss).backward()
            self.scaler.step(self.optimizer)
            self.scaler.update()
        else:
            single_loss = self._loss(x, y)
            single_loss.backward()
            self.optimizer.step()
            
        batch_time = time.time() - start
        
        return float(single_loss), batch_time
    
    def _loss(self,x, y):
        # target
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        # predict
        trans_pred, rot_pred = self.model(x)
        
        # trans loss
        trans_loss = -1.*self.mll(trans_pred, trans_target)
        # rot loss
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        
        total_loss = trans_loss + args.lamda_weights * rot_loss      
        
        return total_loss
    
    def eval_forward(self,x,y,num_sample = 100,output_denormalize = True):
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        
        # Step 2: forward
        assert trainer.model.training == False
        if self.mixed_precision:
            with autocast():
                trans_prediction, rot_prediction = self.model(x)
            self.scaler.scale(trans_prediction)
            self.scaler.scale(rot_prediction)
        else:
            trans_prediction, rot_prediction = self.model(x)
            
        trans_prediction, trans_mean, trans_var = self._eval_gp(trans_prediction)
        
        if args.is_normalization and output_denormalize:
            trans_prediction = denormalize_navie(trans_prediction, self.norm_mean, self.norm_std)
            trans_mean = denormalize_navie(trans_mean, self.norm_mean, self.norm_std)
            trans_var = trans_var.mul(self.norm_std)
        
        samples = self._sample(trans_mean, trans_var, num_sample)
            
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_prediction, rot_prediction, trans_target, rot_target, samples
    
    def _sample(self, mean, var, num_sample = 100):
        dist = torch.distributions.Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples
    
    def _eval_gp(self, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = self.model.likelihood(trans_pred).mean, self.model.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var

# %%
trainer = PosePredictor(args.norm_mean,args.norm_std,args,mixed_precision=False,is_training = False)
trainer.load_model('model-fast-zero-mean.pth')
# Out:
# Successfully loaded model to TITAN Xp.

# %% [markdown]
# # Initialize

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

# %%
trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward(x,y)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 420/183960, translation error = 3.152, rotation error = 2.385, time/batch = 4.811
# 840/183960, translation error = 8.310, rotation error = 3.766, time/batch = 1.054
# 1260/183960, translation error = 6.764, rotation error = 3.446, time/batch = 1.136
# 1680/183960, translation error = 5.940, rotation error = 3.279, time/batch = 1.054
# 2100/183960, translation error = 6.777, rotation error = 3.423, time/batch = 1.052
# 2520/183960, translation error = 6.547, rotation error = 3.498, time/batch = 1.058
# 2940/183960, translation error = 6.113, rotation error = 3.642, time/batch = 1.054
# 3360/183960, translation error = 5.526, rotation error = 3.658, time/batch = 1.051
# 3780/183960, translation error = 5.147, rotation error = 3.602, time/batch = 1.061
# 4200/183960, translation error = 5.051, rotation error = 3.730, time/batch = 1.059
# 4620/183960, translation error = 4.761, rotation error = 3.701, time/batch = 1.061
# 5040/183960, translation error = 4.557, rotation error = 3.723, time/batch = 1.069
# 5460/183960, translation error = 4.383, rotation error = 3.745, time/batch = 1.058
# 5880/183960, translation error = 4.254, rotation error = 3.707, time/batch = 1.056
# 6300/183960, translation error = 4.116, rotation error = 3.686, time/batch = 1.061
# 6720/183960, translation error = 4.072, rotation error = 3.756, time/batch = 1.065
# 7140/183960, translation error = 3.939, rotation error = 3.705, time/batch = 1.060
# 7560/183960, translation error = 3.824, rotation error = 3.652, time/batch = 1.063
# 7980/183960, translation error = 3.668, rotation error = 3.602, time/batch = 1.057
# 8400/183960, translation error = 3.532, rotation error = 3.562, time/batch = 1.060
# 8820/183960, translation error = 3.407, rotation error = 3.551, time/batch = 1.060
# 9240/183960, translation error = 3.314, rotation error = 3.527, time/batch = 1.060
# 9660/183960, translation error = 3.204, rotation error = 3.488, time/batch = 1.074
# 10080/183960, translation error = 3.124, rotation error = 3.517, time/batch = 1.061
# 10500/183960, translation error = 3.138, rotation error = 3.520, time/batch = 1.063
# 10920/183960, translation error = 3.060, rotation error = 3.475, time/batch = 1.066
# 11340/183960, translation error = 3.011, rotation error = 3.434, time/batch = 1.069
# 11760/183960, translation error = 3.018, rotation error = 3.430, time/batch = 1.069
# 12180/183960, translation error = 2.987, rotation error = 3.405, time/batch = 1.071
# 12600/183960, translation error = 2.943, rotation error = 3.349, time/batch = 1.064
# 13020/183960, translation error = 2.958, rotation error = 3.375, time/batch = 1.070
# 13440/183960, translation error = 5.099, rotation error = 3.731, time/batch = 1.058
# 13860/183960, translation error = 5.322, rotation error = 4.062, time/batch = 1.073
# 14280/183960, translation error = 5.231, rotation error = 4.040, time/batch = 1.061
# 14700/183960, translation error = 5.119, rotation error = 4.089, time/batch = 1.061
# 15120/183960, translation error = 5.042, rotation error = 4.092, time/batch = 1.067
# 15540/183960, translation error = 5.104, rotation error = 4.158, time/batch = 1.060
# 15960/183960, translation error = 5.109, rotation error = 4.136, time/batch = 1.076
# 16380/183960, translation error = 5.125, rotation error = 4.124, time/batch = 1.069
# 16800/183960, translation error = 5.688, rotation error = 4.230, time/batch = 1.067
# 17220/183960, translation error = 5.611, rotation error = 4.237, time/batch = 1.068
# 17640/183960, translation error = 5.520, rotation error = 4.194, time/batch = 1.069
# 18060/183960, translation error = 5.436, rotation error = 4.187, time/batch = 1.066
# 18480/183960, translation error = 5.378, rotation error = 4.173, time/batch = 1.066
# 18900/183960, translation error = 5.317, rotation error = 4.126, time/batch = 1.067
# 19320/183960, translation error = 5.248, rotation error = 4.102, time/batch = 1.071
# 19740/183960, translation error = 5.189, rotation error = 4.093, time/batch = 1.067
# 20160/183960, translation error = 5.151, rotation error = 4.090, time/batch = 1.068
# 20580/183960, translation error = 5.071, rotation error = 4.137, time/batch = 1.070
# 21000/183960, translation error = 5.005, rotation error = 4.170, time/batch = 1.066
# 21420/183960, translation error = 4.945, rotation error = 4.166, time/batch = 1.066
# 21840/183960, translation error = 4.884, rotation error = 4.170, time/batch = 1.066
# 22260/183960, translation error = 4.832, rotation error = 4.141, time/batch = 1.069
# 22680/183960, translation error = 4.772, rotation error = 4.102, time/batch = 1.074
# 23100/183960, translation error = 4.709, rotation error = 4.067, time/batch = 1.079
# 23520/183960, translation error = 4.643, rotation error = 4.031, time/batch = 1.066
# 23940/183960, translation error = 4.588, rotation error = 4.017, time/batch = 1.063
# 24360/183960, translation error = 4.527, rotation error = 3.985, time/batch = 1.061
# 24780/183960, translation error = 4.479, rotation error = 3.973, time/batch = 1.070
# 25200/183960, translation error = 4.423, rotation error = 3.949, time/batch = 1.075
# 25620/183960, translation error = 4.382, rotation error = 3.975, time/batch = 1.067
# 26040/183960, translation error = 4.325, rotation error = 3.948, time/batch = 1.069
# 26460/183960, translation error = 4.399, rotation error = 3.973, time/batch = 1.069
# 26880/183960, translation error = 4.364, rotation error = 3.957, time/batch = 1.069
# 27300/183960, translation error = 4.317, rotation error = 3.926, time/batch = 1.076
# 27720/183960, translation error = 4.293, rotation error = 3.927, time/batch = 1.071
# 28140/183960, translation error = 4.256, rotation error = 3.924, time/batch = 1.076
# 28560/183960, translation error = 4.221, rotation error = 3.941, time/batch = 1.062
# 28980/183960, translation error = 4.192, rotation error = 3.935, time/batch = 1.068
# 29400/183960, translation error = 4.161, rotation error = 3.915, time/batch = 1.080
# 29820/183960, translation error = 4.153, rotation error = 3.914, time/batch = 1.065
# 30240/183960, translation error = 4.133, rotation error = 3.911, time/batch = 1.070
# 30660/183960, translation error = 4.111, rotation error = 3.887, time/batch = 1.073
# 31080/183960, translation error = 4.086, rotation error = 3.869, time/batch = 1.067
# 31500/183960, translation error = 5.078, rotation error = 4.090, time/batch = 1.070
# 31920/183960, translation error = 5.047, rotation error = 4.090, time/batch = 1.069
# 32340/183960, translation error = 5.022, rotation error = 4.103, time/batch = 1.068
# 32760/183960, translation error = 4.988, rotation error = 4.083, time/batch = 1.075
# 33180/183960, translation error = 4.956, rotation error = 4.108, time/batch = 1.068
# 33600/183960, translation error = 4.922, rotation error = 4.124, time/batch = 1.066
# 34020/183960, translation error = 4.885, rotation error = 4.127, time/batch = 1.065
# 34440/183960, translation error = 4.853, rotation error = 4.116, time/batch = 1.067
# 34860/183960, translation error = 4.811, rotation error = 4.094, time/batch = 1.064
# 35280/183960, translation error = 4.772, rotation error = 4.080, time/batch = 1.068
# 35700/183960, translation error = 4.753, rotation error = 4.089, time/batch = 1.066
# 36120/183960, translation error = 4.725, rotation error = 4.102, time/batch = 1.071
# 36540/183960, translation error = 4.695, rotation error = 4.125, time/batch = 1.072
# 36960/183960, translation error = 4.666, rotation error = 4.112, time/batch = 1.070
# 37380/183960, translation error = 4.631, rotation error = 4.123, time/batch = 1.070
# 37800/183960, translation error = 4.600, rotation error = 4.123, time/batch = 1.070
# 38220/183960, translation error = 4.569, rotation error = 4.107, time/batch = 1.069
# 38640/183960, translation error = 4.546, rotation error = 4.097, time/batch = 1.074
# 39060/183960, translation error = 4.534, rotation error = 4.095, time/batch = 1.070
# 39480/183960, translation error = 4.512, rotation error = 4.102, time/batch = 1.082
# 39900/183960, translation error = 4.485, rotation error = 4.093, time/batch = 1.070
# 40320/183960, translation error = 4.458, rotation error = 4.089, time/batch = 1.068
# 40740/183960, translation error = 4.425, rotation error = 4.071, time/batch = 1.067
# 41160/183960, translation error = 4.394, rotation error = 4.068, time/batch = 1.079
# 41580/183960, translation error = 4.372, rotation error = 4.059, time/batch = 1.072
# 42000/183960, translation error = 4.340, rotation error = 4.053, time/batch = 1.069
# 42420/183960, translation error = 4.310, rotation error = 4.057, time/batch = 1.074
# 42840/183960, translation error = 4.286, rotation error = 4.048, time/batch = 1.072
# 43260/183960, translation error = 4.356, rotation error = 4.055, time/batch = 1.067
# 43680/183960, translation error = 5.838, rotation error = 4.222, time/batch = 1.067
# 44100/183960, translation error = 7.924, rotation error = 4.867, time/batch = 1.079
# 44520/183960, translation error = 9.909, rotation error = 5.271, time/batch = 1.072
# 44940/183960, translation error = 9.909, rotation error = 5.252, time/batch = 1.073
# 45360/183960, translation error = 9.851, rotation error = 5.235, time/batch = 1.075
# 45780/183960, translation error = 9.776, rotation error = 5.220, time/batch = 1.073
# 46200/183960, translation error = 9.732, rotation error = 5.226, time/batch = 1.070
# 46620/183960, translation error = 9.663, rotation error = 5.204, time/batch = 1.073
# 47040/183960, translation error = 9.597, rotation error = 5.195, time/batch = 1.073
# 47460/183960, translation error = 9.529, rotation error = 5.187, time/batch = 1.069
# 47880/183960, translation error = 9.466, rotation error = 5.173, time/batch = 1.081
# 48300/183960, translation error = 9.443, rotation error = 5.180, time/batch = 1.066
# 48720/183960, translation error = 9.384, rotation error = 5.174, time/batch = 1.078
# 49140/183960, translation error = 9.328, rotation error = 5.175, time/batch = 1.068
# 49560/183960, translation error = 9.294, rotation error = 5.182, time/batch = 1.070
# 49980/183960, translation error = 9.226, rotation error = 5.169, time/batch = 1.069
# 50400/183960, translation error = 9.168, rotation error = 5.159, time/batch = 1.076
# 50820/183960, translation error = 9.108, rotation error = 5.147, time/batch = 1.074
# 51240/183960, translation error = 9.042, rotation error = 5.136, time/batch = 1.077
# 51660/183960, translation error = 8.983, rotation error = 5.135, time/batch = 1.071
# 52080/183960, translation error = 8.928, rotation error = 5.129, time/batch = 1.070
# 52500/183960, translation error = 8.870, rotation error = 5.108, time/batch = 1.075
# 52920/183960, translation error = 8.808, rotation error = 5.100, time/batch = 1.074
# 53340/183960, translation error = 8.757, rotation error = 5.084, time/batch = 1.066
# 53760/183960, translation error = 8.774, rotation error = 5.088, time/batch = 1.063
# 54180/183960, translation error = 8.719, rotation error = 5.066, time/batch = 1.073
# 54600/183960, translation error = 8.674, rotation error = 5.043, time/batch = 1.069
# 55020/183960, translation error = 8.630, rotation error = 5.026, time/batch = 1.071
# 55440/183960, translation error = 8.581, rotation error = 5.003, time/batch = 1.066
# 55860/183960, translation error = 8.534, rotation error = 4.992, time/batch = 1.067
# 56280/183960, translation error = 8.487, rotation error = 4.974, time/batch = 1.070
# 56700/183960, translation error = 8.455, rotation error = 4.967, time/batch = 1.073
# 57120/183960, translation error = 8.411, rotation error = 4.957, time/batch = 1.072
# 57540/183960, translation error = 8.384, rotation error = 4.946, time/batch = 1.074
# 57960/183960, translation error = 8.362, rotation error = 5.016, time/batch = 1.079
# 58380/183960, translation error = 8.475, rotation error = 5.055, time/batch = 1.076
# 58800/183960, translation error = 8.481, rotation error = 5.054, time/batch = 1.074
# 59220/183960, translation error = 8.433, rotation error = 5.030, time/batch = 1.083
# 59640/183960, translation error = 8.388, rotation error = 5.017, time/batch = 1.069
# 60060/183960, translation error = 8.374, rotation error = 5.010, time/batch = 1.070
# 60480/183960, translation error = 8.337, rotation error = 5.003, time/batch = 1.077
# 60900/183960, translation error = 8.297, rotation error = 4.990, time/batch = 1.073
# 61320/183960, translation error = 8.255, rotation error = 4.982, time/batch = 1.075
# 61740/183960, translation error = 8.209, rotation error = 4.975, time/batch = 1.073
# 62160/183960, translation error = 8.168, rotation error = 4.987, time/batch = 1.067
# 62580/183960, translation error = 8.133, rotation error = 4.980, time/batch = 1.073
# 63000/183960, translation error = 8.090, rotation error = 4.967, time/batch = 1.067
# 63420/183960, translation error = 8.048, rotation error = 4.958, time/batch = 1.074
# 63840/183960, translation error = 8.008, rotation error = 4.937, time/batch = 1.073
# 64260/183960, translation error = 7.974, rotation error = 4.931, time/batch = 1.070
# 64680/183960, translation error = 7.935, rotation error = 4.923, time/batch = 1.079
# 65100/183960, translation error = 7.897, rotation error = 4.920, time/batch = 1.068
# 65520/183960, translation error = 7.857, rotation error = 4.912, time/batch = 1.064
# 65940/183960, translation error = 7.815, rotation error = 4.900, time/batch = 1.073
# 66360/183960, translation error = 7.779, rotation error = 4.888, time/batch = 1.086
# 66780/183960, translation error = 7.751, rotation error = 4.882, time/batch = 1.071
# 67200/183960, translation error = 7.712, rotation error = 4.870, time/batch = 1.065
# 67620/183960, translation error = 7.689, rotation error = 4.865, time/batch = 1.069
# 68040/183960, translation error = 7.653, rotation error = 4.856, time/batch = 1.074
# 68460/183960, translation error = 8.083, rotation error = 4.971, time/batch = 1.076
# 68880/183960, translation error = 8.960, rotation error = 5.130, time/batch = 1.072
# 69300/183960, translation error = 8.927, rotation error = 5.115, time/batch = 1.070
# 69720/183960, translation error = 8.891, rotation error = 5.099, time/batch = 1.069
# 70140/183960, translation error = 8.855, rotation error = 5.091, time/batch = 1.070
# 70560/183960, translation error = 8.824, rotation error = 5.079, time/batch = 1.081
# 70980/183960, translation error = 10.035, rotation error = 5.298, time/batch = 1.073
# 71400/183960, translation error = 10.049, rotation error = 5.285, time/batch = 1.072
# 71820/183960, translation error = 10.008, rotation error = 5.273, time/batch = 1.074
# 72240/183960, translation error = 9.964, rotation error = 5.266, time/batch = 1.074
# 72660/183960, translation error = 9.938, rotation error = 5.272, time/batch = 1.079
# 73080/183960, translation error = 9.900, rotation error = 5.261, time/batch = 1.074
# 73500/183960, translation error = 9.860, rotation error = 5.260, time/batch = 1.084
# 73920/183960, translation error = 9.812, rotation error = 5.255, time/batch = 1.068
# 74340/183960, translation error = 9.773, rotation error = 5.241, time/batch = 1.069
# 74760/183960, translation error = 9.726, rotation error = 5.230, time/batch = 1.071
# 75180/183960, translation error = 9.680, rotation error = 5.218, time/batch = 1.074
# 75600/183960, translation error = 9.637, rotation error = 5.211, time/batch = 1.073
# 76020/183960, translation error = 9.599, rotation error = 5.212, time/batch = 1.075
# 76440/183960, translation error = 9.558, rotation error = 5.211, time/batch = 1.074
# 76860/183960, translation error = 9.514, rotation error = 5.197, time/batch = 1.072
# 77280/183960, translation error = 9.470, rotation error = 5.192, time/batch = 1.072
# 77700/183960, translation error = 9.429, rotation error = 5.188, time/batch = 1.074
# 78120/183960, translation error = 9.396, rotation error = 5.184, time/batch = 1.076
# 78540/183960, translation error = 9.356, rotation error = 5.172, time/batch = 1.077
# 78960/183960, translation error = 9.323, rotation error = 5.178, time/batch = 1.077
# 79380/183960, translation error = 9.285, rotation error = 5.169, time/batch = 1.076
# 79800/183960, translation error = 9.255, rotation error = 5.165, time/batch = 1.072
# 80220/183960, translation error = 9.214, rotation error = 5.154, time/batch = 1.086
# 80640/183960, translation error = 9.176, rotation error = 5.148, time/batch = 1.071
# 81060/183960, translation error = 9.137, rotation error = 5.140, time/batch = 1.076
# 81480/183960, translation error = 9.096, rotation error = 5.136, time/batch = 1.073
# 81900/183960, translation error = 9.057, rotation error = 5.137, time/batch = 1.073
# 82320/183960, translation error = 9.022, rotation error = 5.137, time/batch = 1.078
# 82740/183960, translation error = 8.988, rotation error = 5.131, time/batch = 1.081
# 83160/183960, translation error = 8.953, rotation error = 5.127, time/batch = 1.078
# 83580/183960, translation error = 8.915, rotation error = 5.122, time/batch = 1.070
# 84000/183960, translation error = 8.880, rotation error = 5.121, time/batch = 1.068
# 84420/183960, translation error = 8.927, rotation error = 5.127, time/batch = 1.070
# 84840/183960, translation error = 8.901, rotation error = 5.111, time/batch = 1.073
# 85260/183960, translation error = 8.874, rotation error = 5.097, time/batch = 1.072
# 85680/183960, translation error = 8.844, rotation error = 5.082, time/batch = 1.077
# 86100/183960, translation error = 8.811, rotation error = 5.067, time/batch = 1.072
# 86520/183960, translation error = 8.776, rotation error = 5.062, time/batch = 1.069
# 86940/183960, translation error = 8.756, rotation error = 5.049, time/batch = 1.075
# 87360/183960, translation error = 8.773, rotation error = 5.077, time/batch = 1.070
# 87780/183960, translation error = 8.763, rotation error = 5.073, time/batch = 1.080
# 88200/183960, translation error = 8.732, rotation error = 5.069, time/batch = 1.085
# 88620/183960, translation error = 8.730, rotation error = 5.093, time/batch = 1.072
# 89040/183960, translation error = 8.705, rotation error = 5.079, time/batch = 1.075
# 89460/183960, translation error = 8.683, rotation error = 5.082, time/batch = 1.077
# 89880/183960, translation error = 8.654, rotation error = 5.076, time/batch = 1.074
# 90300/183960, translation error = 8.621, rotation error = 5.074, time/batch = 1.071
# 90720/183960, translation error = 8.596, rotation error = 5.069, time/batch = 1.077
# 91140/183960, translation error = 8.563, rotation error = 5.056, time/batch = 1.078
# 91560/183960, translation error = 8.548, rotation error = 5.060, time/batch = 1.082
# 91980/183960, translation error = 8.520, rotation error = 5.057, time/batch = 1.074
# 92400/183960, translation error = 8.494, rotation error = 5.063, time/batch = 1.072
# 92820/183960, translation error = 8.472, rotation error = 5.061, time/batch = 1.071
# 93240/183960, translation error = 8.448, rotation error = 5.053, time/batch = 1.078
# 93660/183960, translation error = 8.424, rotation error = 5.045, time/batch = 1.076
# 94080/183960, translation error = 8.403, rotation error = 5.043, time/batch = 1.072
# 94500/183960, translation error = 8.375, rotation error = 5.034, time/batch = 1.082
# 94920/183960, translation error = 8.375, rotation error = 5.029, time/batch = 1.073
# 95340/183960, translation error = 8.344, rotation error = 5.020, time/batch = 1.082
# 95760/183960, translation error = 8.313, rotation error = 5.015, time/batch = 1.085
# 96180/183960, translation error = 8.285, rotation error = 5.017, time/batch = 1.073
# 96600/183960, translation error = 8.258, rotation error = 5.009, time/batch = 1.078
# 97020/183960, translation error = 8.233, rotation error = 5.001, time/batch = 1.078
# 97440/183960, translation error = 8.213, rotation error = 4.990, time/batch = 1.075
# 97860/183960, translation error = 8.188, rotation error = 4.978, time/batch = 1.073
# 98280/183960, translation error = 8.165, rotation error = 4.969, time/batch = 1.073
# 98700/183960, translation error = 8.140, rotation error = 4.961, time/batch = 1.075
# 99120/183960, translation error = 8.112, rotation error = 4.959, time/batch = 1.080
# 99540/183960, translation error = 8.089, rotation error = 4.949, time/batch = 1.072
# 99960/183960, translation error = 8.074, rotation error = 4.945, time/batch = 1.072
# 100380/183960, translation error = 8.052, rotation error = 4.938, time/batch = 1.079
# 100800/183960, translation error = 8.030, rotation error = 4.931, time/batch = 1.073
# 101220/183960, translation error = 8.091, rotation error = 4.965, time/batch = 1.072
# 101640/183960, translation error = 9.137, rotation error = 5.071, time/batch = 1.074
# 102060/183960, translation error = 9.126, rotation error = 5.098, time/batch = 1.071
# 102480/183960, translation error = 9.096, rotation error = 5.089, time/batch = 1.075
# 102900/183960, translation error = 9.067, rotation error = 5.083, time/batch = 1.079
# 103320/183960, translation error = 9.038, rotation error = 5.076, time/batch = 1.070
# 103740/183960, translation error = 9.008, rotation error = 5.084, time/batch = 1.067
# 104160/183960, translation error = 8.980, rotation error = 5.081, time/batch = 1.071
# 104580/183960, translation error = 8.969, rotation error = 5.086, time/batch = 1.069
# 105000/183960, translation error = 8.942, rotation error = 5.087, time/batch = 1.076
# 105420/183960, translation error = 8.916, rotation error = 5.075, time/batch = 1.073
# 105840/183960, translation error = 8.889, rotation error = 5.065, time/batch = 1.077
# 106260/183960, translation error = 8.862, rotation error = 5.056, time/batch = 1.076
# 106680/183960, translation error = 8.843, rotation error = 5.081, time/batch = 1.076
# 107100/183960, translation error = 8.821, rotation error = 5.086, time/batch = 1.077
# 107520/183960, translation error = 8.791, rotation error = 5.079, time/batch = 1.075
# 107940/183960, translation error = 8.762, rotation error = 5.075, time/batch = 1.077
# 108360/183960, translation error = 8.809, rotation error = 5.080, time/batch = 1.067
# 108780/183960, translation error = 8.821, rotation error = 5.088, time/batch = 1.080
# 109200/183960, translation error = 8.799, rotation error = 5.081, time/batch = 1.072
# 109620/183960, translation error = 8.772, rotation error = 5.079, time/batch = 1.086
# 110040/183960, translation error = 8.749, rotation error = 5.076, time/batch = 1.068
# 110460/183960, translation error = 8.723, rotation error = 5.071, time/batch = 1.074
# 110880/183960, translation error = 8.703, rotation error = 5.076, time/batch = 1.073
# 111300/183960, translation error = 8.677, rotation error = 5.067, time/batch = 1.070
# 111720/183960, translation error = 8.924, rotation error = 5.115, time/batch = 1.077
# 112140/183960, translation error = 8.993, rotation error = 5.163, time/batch = 1.069
# 112560/183960, translation error = 9.055, rotation error = 5.205, time/batch = 1.078
# 112980/183960, translation error = 9.037, rotation error = 5.208, time/batch = 1.074
# 113400/183960, translation error = 9.016, rotation error = 5.208, time/batch = 1.077
# 113820/183960, translation error = 8.999, rotation error = 5.204, time/batch = 1.073
# 114240/183960, translation error = 8.977, rotation error = 5.207, time/batch = 1.074
# 114660/183960, translation error = 8.953, rotation error = 5.210, time/batch = 1.065
# 115080/183960, translation error = 9.761, rotation error = 5.241, time/batch = 1.072
# 115500/183960, translation error = 9.740, rotation error = 5.241, time/batch = 1.073
# 115920/183960, translation error = 9.713, rotation error = 5.243, time/batch = 1.071
# 116340/183960, translation error = 9.691, rotation error = 5.241, time/batch = 1.067
# 116760/183960, translation error = 9.679, rotation error = 5.243, time/batch = 1.071
# 117180/183960, translation error = 9.675, rotation error = 5.249, time/batch = 1.071
# 117600/183960, translation error = 9.646, rotation error = 5.240, time/batch = 1.075
# 118020/183960, translation error = 9.617, rotation error = 5.235, time/batch = 1.075
# 118440/183960, translation error = 9.590, rotation error = 5.237, time/batch = 1.075
# 118860/183960, translation error = 9.564, rotation error = 5.234, time/batch = 1.071
# 119280/183960, translation error = 9.540, rotation error = 5.226, time/batch = 1.074
# 119700/183960, translation error = 9.515, rotation error = 5.222, time/batch = 1.079
# 120120/183960, translation error = 9.489, rotation error = 5.217, time/batch = 1.085
# 120540/183960, translation error = 9.463, rotation error = 5.209, time/batch = 1.074
# 120960/183960, translation error = 9.441, rotation error = 5.209, time/batch = 1.076
# 121380/183960, translation error = 9.416, rotation error = 5.201, time/batch = 1.072
# 121800/183960, translation error = 9.392, rotation error = 5.197, time/batch = 1.075
# 122220/183960, translation error = 9.376, rotation error = 5.192, time/batch = 1.074
# 122640/183960, translation error = 9.352, rotation error = 5.190, time/batch = 1.074
# 123060/183960, translation error = 9.507, rotation error = 5.245, time/batch = 1.072
# 123480/183960, translation error = 9.720, rotation error = 5.354, time/batch = 1.074
# 123900/183960, translation error = 9.694, rotation error = 5.354, time/batch = 1.078
# 124320/183960, translation error = 9.675, rotation error = 5.353, time/batch = 1.076
# 124740/183960, translation error = 9.650, rotation error = 5.348, time/batch = 1.075
# 125160/183960, translation error = 9.624, rotation error = 5.338, time/batch = 1.074
# 125580/183960, translation error = 9.598, rotation error = 5.336, time/batch = 1.074
# 126000/183960, translation error = 9.573, rotation error = 5.334, time/batch = 1.069
# 126420/183960, translation error = 9.571, rotation error = 5.346, time/batch = 1.064
# 126840/183960, translation error = 9.559, rotation error = 5.352, time/batch = 1.069
# 127260/183960, translation error = 9.533, rotation error = 5.344, time/batch = 1.078
# 127680/183960, translation error = 9.510, rotation error = 5.336, time/batch = 1.074
# 128100/183960, translation error = 9.512, rotation error = 5.341, time/batch = 1.069
# 128520/183960, translation error = 10.161, rotation error = 5.520, time/batch = 1.072
# 128940/183960, translation error = 10.176, rotation error = 5.576, time/batch = 1.074
# 129360/183960, translation error = 10.153, rotation error = 5.579, time/batch = 1.074
# 129780/183960, translation error = 10.129, rotation error = 5.568, time/batch = 1.071
# 130200/183960, translation error = 10.116, rotation error = 5.577, time/batch = 1.073
# 130620/183960, translation error = 10.092, rotation error = 5.569, time/batch = 1.074
# 131040/183960, translation error = 10.065, rotation error = 5.560, time/batch = 1.072
# 131460/183960, translation error = 10.044, rotation error = 5.555, time/batch = 1.073
# 131880/183960, translation error = 10.028, rotation error = 5.568, time/batch = 1.074
# 132300/183960, translation error = 10.006, rotation error = 5.564, time/batch = 1.076
# 132720/183960, translation error = 9.983, rotation error = 5.558, time/batch = 1.076
# 133140/183960, translation error = 9.960, rotation error = 5.553, time/batch = 1.075
# 133560/183960, translation error = 9.978, rotation error = 5.574, time/batch = 1.068
# 133980/183960, translation error = 9.954, rotation error = 5.573, time/batch = 1.068
# 134400/183960, translation error = 9.942, rotation error = 5.576, time/batch = 1.068
# 134820/183960, translation error = 9.921, rotation error = 5.594, time/batch = 1.070
# 135240/183960, translation error = 9.903, rotation error = 5.601, time/batch = 1.068
# 135660/183960, translation error = 9.878, rotation error = 5.591, time/batch = 1.073
# 136080/183960, translation error = 9.852, rotation error = 5.580, time/batch = 1.076
# 136500/183960, translation error = 9.829, rotation error = 5.573, time/batch = 1.074
# 136920/183960, translation error = 9.807, rotation error = 5.585, time/batch = 1.073
# 137340/183960, translation error = 9.787, rotation error = 5.580, time/batch = 1.078
# 137760/183960, translation error = 9.763, rotation error = 5.569, time/batch = 1.073
# 138180/183960, translation error = 9.749, rotation error = 5.576, time/batch = 1.075
# 138600/183960, translation error = 9.750, rotation error = 5.582, time/batch = 1.073
# 139020/183960, translation error = 9.745, rotation error = 5.580, time/batch = 1.074
# 139440/183960, translation error = 9.729, rotation error = 5.572, time/batch = 1.077
# 139860/183960, translation error = 9.743, rotation error = 5.570, time/batch = 1.079
# 140280/183960, translation error = 9.722, rotation error = 5.563, time/batch = 1.077
# 140700/183960, translation error = 9.699, rotation error = 5.559, time/batch = 1.073
# 141120/183960, translation error = 9.673, rotation error = 5.550, time/batch = 1.068
# 141540/183960, translation error = 9.650, rotation error = 5.544, time/batch = 1.071
# 141960/183960, translation error = 9.630, rotation error = 5.540, time/batch = 1.072
# 142380/183960, translation error = 9.605, rotation error = 5.534, time/batch = 1.070
# 142800/183960, translation error = 9.582, rotation error = 5.527, time/batch = 1.078
# 143220/183960, translation error = 9.559, rotation error = 5.519, time/batch = 1.084
# 143640/183960, translation error = 9.538, rotation error = 5.511, time/batch = 1.071
# 144060/183960, translation error = 9.518, rotation error = 5.505, time/batch = 1.073
# 144480/183960, translation error = 9.498, rotation error = 5.499, time/batch = 1.071
# 144900/183960, translation error = 9.476, rotation error = 5.492, time/batch = 1.081
# 145320/183960, translation error = 9.455, rotation error = 5.486, time/batch = 1.073
# 145740/183960, translation error = 9.434, rotation error = 5.484, time/batch = 1.075
# 146160/183960, translation error = 9.414, rotation error = 5.488, time/batch = 1.074
# 146580/183960, translation error = 9.395, rotation error = 5.480, time/batch = 1.077
# 147000/183960, translation error = 9.375, rotation error = 5.479, time/batch = 1.071
# 147420/183960, translation error = 9.380, rotation error = 5.479, time/batch = 1.075
# 147840/183960, translation error = 9.367, rotation error = 5.483, time/batch = 1.075
# 148260/183960, translation error = 9.348, rotation error = 5.478, time/batch = 1.072
# 148680/183960, translation error = 9.325, rotation error = 5.473, time/batch = 1.074
# 149100/183960, translation error = 9.554, rotation error = 5.613, time/batch = 1.071
# 149520/183960, translation error = 9.602, rotation error = 5.654, time/batch = 1.072
# 149940/183960, translation error = 9.585, rotation error = 5.653, time/batch = 1.075
# 150360/183960, translation error = 9.621, rotation error = 5.679, time/batch = 1.072
# 150780/183960, translation error = 9.780, rotation error = 5.713, time/batch = 1.076
# 151200/183960, translation error = 9.760, rotation error = 5.708, time/batch = 1.074
# 151620/183960, translation error = 9.740, rotation error = 5.701, time/batch = 1.075
# 152040/183960, translation error = 9.724, rotation error = 5.694, time/batch = 1.076
# 152460/183960, translation error = 9.708, rotation error = 5.691, time/batch = 1.072
# 152880/183960, translation error = 9.687, rotation error = 5.683, time/batch = 1.073
# 153300/183960, translation error = 9.667, rotation error = 5.674, time/batch = 1.074
# 153720/183960, translation error = 9.670, rotation error = 5.675, time/batch = 1.074
# 154140/183960, translation error = 9.663, rotation error = 5.675, time/batch = 1.076
# 154560/183960, translation error = 9.693, rotation error = 5.676, time/batch = 1.075
# 154980/183960, translation error = 9.933, rotation error = 5.736, time/batch = 1.076
# 155400/183960, translation error = 10.153, rotation error = 5.784, time/batch = 1.071
# 155820/183960, translation error = 10.214, rotation error = 5.851, time/batch = 1.073
# 156240/183960, translation error = 10.282, rotation error = 5.867, time/batch = 1.077
# 156660/183960, translation error = 10.316, rotation error = 5.877, time/batch = 1.073
# 157080/183960, translation error = 10.341, rotation error = 5.890, time/batch = 1.077
# 157500/183960, translation error = 10.336, rotation error = 5.903, time/batch = 1.074
# 157920/183960, translation error = 10.406, rotation error = 5.921, time/batch = 1.076
# 158340/183960, translation error = 10.535, rotation error = 6.040, time/batch = 1.073
# 158760/183960, translation error = 10.570, rotation error = 6.124, time/batch = 1.072
# 159180/183960, translation error = 11.065, rotation error = 6.134, time/batch = 1.073
# 159600/183960, translation error = 11.041, rotation error = 6.141, time/batch = 1.071
# 160020/183960, translation error = 11.018, rotation error = 6.148, time/batch = 1.071
# 160440/183960, translation error = 11.000, rotation error = 6.153, time/batch = 1.075
# 160860/183960, translation error = 10.980, rotation error = 6.149, time/batch = 1.073
# 161280/183960, translation error = 11.077, rotation error = 6.208, time/batch = 1.075
# 161700/183960, translation error = 11.061, rotation error = 6.212, time/batch = 1.076
# 162120/183960, translation error = 11.044, rotation error = 6.220, time/batch = 1.074
# 162540/183960, translation error = 11.060, rotation error = 6.270, time/batch = 1.070
# 162960/183960, translation error = 11.100, rotation error = 6.283, time/batch = 1.071
# 163380/183960, translation error = 11.084, rotation error = 6.290, time/batch = 1.071
# 163800/183960, translation error = 11.072, rotation error = 6.292, time/batch = 1.074
# 164220/183960, translation error = 11.057, rotation error = 6.285, time/batch = 1.072
# 164640/183960, translation error = 11.044, rotation error = 6.281, time/batch = 1.075
# 165060/183960, translation error = 11.029, rotation error = 6.283, time/batch = 1.072
# 165480/183960, translation error = 11.030, rotation error = 6.286, time/batch = 1.074
# 165900/183960, translation error = 11.013, rotation error = 6.305, time/batch = 1.074
# 166320/183960, translation error = 11.000, rotation error = 6.309, time/batch = 1.077
# 166740/183960, translation error = 10.990, rotation error = 6.301, time/batch = 1.078
# 167160/183960, translation error = 10.986, rotation error = 6.296, time/batch = 1.074
# 167580/183960, translation error = 10.984, rotation error = 6.298, time/batch = 1.074
# 168000/183960, translation error = 10.986, rotation error = 6.295, time/batch = 1.075
# 168420/183960, translation error = 10.989, rotation error = 6.330, time/batch = 1.071
# 168840/183960, translation error = 10.970, rotation error = 6.329, time/batch = 1.072
# 169260/183960, translation error = 10.950, rotation error = 6.325, time/batch = 1.077
# 169680/183960, translation error = 10.929, rotation error = 6.317, time/batch = 1.075
# 170100/183960, translation error = 10.911, rotation error = 6.316, time/batch = 1.075
# 170520/183960, translation error = 10.891, rotation error = 6.309, time/batch = 1.072
# 170940/183960, translation error = 10.871, rotation error = 6.301, time/batch = 1.075
# 171360/183960, translation error = 10.849, rotation error = 6.293, time/batch = 1.075
# 171780/183960, translation error = 10.846, rotation error = 6.315, time/batch = 1.074
# 172200/183960, translation error = 10.965, rotation error = 6.367, time/batch = 1.074
# 172620/183960, translation error = 10.948, rotation error = 6.363, time/batch = 1.075
# 173040/183960, translation error = 10.928, rotation error = 6.352, time/batch = 1.068
# 173460/183960, translation error = 10.910, rotation error = 6.345, time/batch = 1.071
# 173880/183960, translation error = 10.890, rotation error = 6.336, time/batch = 1.073
# 174300/183960, translation error = 10.869, rotation error = 6.327, time/batch = 1.074
# 174720/183960, translation error = 10.922, rotation error = 6.349, time/batch = 1.072
# 175140/183960, translation error = 10.908, rotation error = 6.355, time/batch = 1.072
# 175560/183960, translation error = 10.887, rotation error = 6.357, time/batch = 1.071
# 175980/183960, translation error = 10.952, rotation error = 6.429, time/batch = 1.072
# 176400/183960, translation error = 10.995, rotation error = 6.461, time/batch = 1.071
# 176820/183960, translation error = 10.972, rotation error = 6.459, time/batch = 1.073
# 177240/183960, translation error = 10.951, rotation error = 6.454, time/batch = 1.073
# 177660/183960, translation error = 11.094, rotation error = 6.467, time/batch = 1.075
# 178080/183960, translation error = 11.142, rotation error = 6.471, time/batch = 1.067
# 178500/183960, translation error = 11.128, rotation error = 6.482, time/batch = 1.067
# 178920/183960, translation error = 11.105, rotation error = 6.475, time/batch = 1.073
# 179340/183960, translation error = 11.087, rotation error = 6.470, time/batch = 1.076
# 179760/183960, translation error = 11.114, rotation error = 6.479, time/batch = 1.072
# 180180/183960, translation error = 11.134, rotation error = 6.472, time/batch = 1.073
# 180600/183960, translation error = 11.113, rotation error = 6.463, time/batch = 1.073
# 181020/183960, translation error = 11.099, rotation error = 6.462, time/batch = 1.071
# 181440/183960, translation error = 11.081, rotation error = 6.458, time/batch = 1.080
# 181860/183960, translation error = 11.063, rotation error = 6.453, time/batch = 1.072
# 182280/183960, translation error = 11.042, rotation error = 6.450, time/batch = 1.073
# 182700/183960, translation error = 11.039, rotation error = 6.552, time/batch = 1.073
# 183120/183960, translation error = 11.019, rotation error = 6.559, time/batch = 1.076
# 183540/183960, translation error = 10.997, rotation error = 6.552, time/batch = 1.071
# 183960/183960, translation error = 10.984, rotation error = 6.551, time/batch = 4.212

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.084
# median rotation error = 3.121
# mean translation error = 10.984
# mean rotation error = 6.551

# %%
def evaluate(trans_errors,rot_errors):
    t = dataset.last_indexes
    trans_errors_month = list()
    trans_errors_month.append(trans_errors[:t[0]])
    trans_errors_month.append(trans_errors[t[0]:t[1]])
    trans_errors_month.append(trans_errors[t[1]:t[2]])
    trans_errors_month.append(trans_errors[t[2]:t[3]])
    trans_errors_month.append(trans_errors[t[3]:t[4]])
    trans_errors_month.append(trans_errors[t[4]:t[5]])
    trans_errors_month.append(trans_errors[t[5]:t[6]])
    trans_errors_month.append(trans_errors[t[6]:])

    rot_errors_month = list()
    rot_errors_month.append(rot_errors[:t[0]])
    rot_errors_month.append(rot_errors[t[0]:t[1]])
    rot_errors_month.append(rot_errors[t[1]:t[2]])
    rot_errors_month.append(rot_errors[t[2]:t[3]])
    rot_errors_month.append(rot_errors[t[3]:t[4]])
    rot_errors_month.append(rot_errors[t[4]:t[5]])
    rot_errors_month.append(rot_errors[t[5]:t[6]])
    rot_errors_month.append(rot_errors[t[6]:])
    
    print('================== median translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("median translation error = {:.3f}".format(np.median(trans_errors_i)))
        
    print('================== median rotation error ==================')
    for rot_errors_i in rot_errors_month:
        print("median rotation error = {:.3f}".format(np.median(rot_errors_i)))
    
    print('================== mean translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("mean translation error = {:.3f}".format(np.mean(trans_errors_i)))
        
    print('================== mean rotation error ==================')  
    for rot_errors_i in rot_errors_month:
        print("mean rotation error = {:.3f}".format(np.mean(rot_errors_i)))
        
evaluate(trans_errors,rot_errors)
# Out:
# ================== median translation error ==================
# median translation error = 1.588
# median translation error = 1.702
# median translation error = 1.969
# median translation error = 1.956
# median translation error = 2.056
# median translation error = 2.144
# median translation error = 3.554
# median translation error = 2.780
# ================== median rotation error ==================
# median rotation error = 2.584
# median rotation error = 2.794
# median rotation error = 2.950
# median rotation error = 2.925
# median rotation error = 3.105
# median rotation error = 3.262
# median rotation error = 4.395
# median rotation error = 4.155
# ================== mean translation error ==================
# mean translation error = 4.221
# mean translation error = 4.448
# mean translation error = 13.170
# mean translation error = 12.878
# mean translation error = 9.518
# mean translation error = 11.637
# mean translation error = 21.389
# mean translation error = 13.546
# ================== mean rotation error ==================
# mean rotation error = 3.956
# mean rotation error = 4.262
# mean rotation error = 6.160
# mean rotation error = 5.901
# mean rotation error = 5.634
# mean rotation error = 6.627
# mean rotation error = 12.331
# mean rotation error = 9.281
