# %% [markdown]
# # Library

# %%
import numpy as np
import torch
import gpytorch
import argparse
import time
import pickle
import scipy.io as sio

from torch.distributions import Normal
import matplotlib.pyplot as plt
import random

import roslib
import rospy
import tf as tf_ros
from nav_msgs.msg import Odometry, Path
from sensor_msgs.msg import Image
from cv_bridge import CvBridge
from geometry_msgs.msg import PoseStamped, PoseArray, Pose
import math
import cv2
import copy

import sys
sys.path.append('..')
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'

# %% [markdown]
# ## Check GPU

# %%
import torch
import sys
sys.path.append('..')
from torchlib.utils import list_device,set_device

list_device()
# Out:
# ------------ List Devices ------------
# Device 0 :
# GeForce RTX 2060
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
#
# Device 1 :
# TITAN Xp
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %% [markdown]
# ## Set torch default parameters

# %%
set_device(1)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, default=300, help='size of mini batch')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data normalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')

parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/gp_net_torch', help='rnn, gru, or lstm')

parser.add_argument('--test_dataset', type=str, default=[# '/notebooks/michigan_nn_data/2012_01_08',
                                                         # '/notebooks/michigan_nn_data/2012_01_15',
                                                         # '/notebooks/michigan_nn_data/2012_01_22',
                                                         # '/notebooks/michigan_nn_data/2012_02_02',
                                                         # '/notebooks/michigan_nn_data/2012_02_04',
                                                         # '/notebooks/michigan_nn_data/2012_02_05',
                                                         '/notebooks/michigan_nn_data/2012_02_12',
                                                         # '/notebooks/michigan_nn_data/2012_03_31',
                                                         '/notebooks/michigan_nn_data/2012_04_29',
                                                         '/notebooks/michigan_nn_data/2012_05_11',
                                                         '/notebooks/michigan_nn_data/2012_06_15',
                                                         '/notebooks/michigan_nn_data/2012_08_04',
                                                         # '/notebooks/michigan_nn_data/2012_09_28'])
                                                         '/notebooks/michigan_nn_data/2012_10_28',
                                                         '/notebooks/michigan_nn_data/2012_11_16',
                                                         '/notebooks/michigan_nn_data/2012_12_01'
                                                        ] )

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/test'])
parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

#parser.add_argument('--map_dataset', type=str, default='/home/kevin/data/michigan_gt/training')
parser.add_argument('--enable_ros', type=bool, default=False, help='put data into ros')

sys.argv = ['']
args = parser.parse_args()

if args.enable_ros:
    rospy.init_node('global_localization_tf_broadcaster_cnn')

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
#from PIL import Image
import numpy as np
import random

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet, cnn_auxiliary
from torchlib.cnn_auxiliary import normalize, denormalize, denormalize_navie, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

transform = transforms.Compose([transforms.ToTensor()])
dataset = LocalizationDataset(dataset_dirs = args.test_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform,
                              get_pair = False, mode='evaluate')
if len(args.train_dataset)>7:
    [args.norm_mean, args.norm_std] = [torch.tensor(x) for x in dataset.get_norm()]
    torch.save([args.norm_mean, args.norm_std], *args.norm_tensor)
    print('Save norm and std:',*args.norm_tensor)
else:
    [args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
    print('Load norm and std:',*args.norm_tensor)

dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=False, num_workers=0, \
                        drop_last=False, pin_memory=True)
# Out:
# 100%|██████████| 14301/14301 [00:18<00:00, 783.35it/s]
# 100%|██████████| 7008/7008 [00:09<00:00, 775.79it/s]
# 100%|██████████| 12852/12852 [00:16<00:00, 785.22it/s]
# 100%|██████████| 9567/9567 [00:12<00:00, 781.45it/s]
# 100%|██████████| 13580/13580 [00:17<00:00, 794.62it/s]
# 100%|██████████| 14835/14835 [00:18<00:00, 787.94it/s]
# 100%|██████████| 7114/7114 [00:09<00:00, 771.57it/s]
# 100%|██████████| 12683/12683 [00:16<00:00, 779.00it/s]
# Load norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # Define Model

# %%
class Backbone(nn.Module):
    def __init__(self):
        super().__init__()
        self.resnet = resnet.resnet50(pretrained=True)
    def forward(self,input_data):
        dense_feat = self.resnet(input_data)
        return dense_feat
    
class NN(nn.Module):
    def __init__(self):
        super().__init__()
        self.global_context = vggnet.vggnet(input_channel=2048,opt="context")
        self.global_regressor = vggnet.vggnet(opt="regressor")
        
    def forward(self,input_data):
        context_feat = self.global_context(input_data)
        output,feature_t, feature_r = self.global_regressor(context_feat)
        return output, feature_t, feature_r

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.MultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([1]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([1])),
            batch_shape=torch.Size([1]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        inducing_points = torch.zeros(3, args.batch_size, 128)
        self.backbone = Backbone()
        self.nn = NN()
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=3)
        
    def forward(self, input_data):
        dense_feat = self.backbone(input_data)
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention 
        trans_pred = self.gp(feature_t)
        return trans_pred, rot_pred

# %%
class Trainer:
    def __init__(self,regressor_context_rate = [0.0,0.0]):
        # data
        self.model = Model().cuda()
        self.norm_mean = args.norm_mean.cuda()
        self.norm_std = args.norm_std.cuda()
        
        # disable learning backbone
        for param in self.model.backbone.parameters():
            param.requires_grad = False
        
        '''
        # training tool
        self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
        self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                         lr_lambda=lambda epoch: args.decay_rate**epoch)
        '''
        # or use `gpytorch.mlls.VariationalELBO`
        num_data = min(len(dataloader)*args.batch_size,len(dataset))
        self.mll = gpytorch.mlls.PredictiveLogLikelihood(self.model.likelihood, \
                                                         self.model.gp, num_data = num_data)
        
    def load_model(self, file_name = 'pretrained.pth'):
        # load file info
        state_dict = torch.load(os.path.join(args.model_dir, file_name))
        if 'net.resnet.conv1.weight' in state_dict:
            print('Transform from old model.')
            state_dict = self._from_old_model(state_dict)
        print('Parameters layer:',len(state_dict.keys()))
        # load file to model
        self.model.load_state_dict(state_dict,strict = True)
        # Display model structure
        for name, param in self.model.named_parameters():
            print(name, param.shape)
        print('Parameters layer:',len(self.model.state_dict().keys()))
        # check load
        assert len(state_dict.keys()) == len(self.model.state_dict().keys())
    
    def _from_old_model(self, state_dict):
        for key in list(state_dict):
            if 'net.resnet.' in key:
                state_dict[key.replace('net.resnet.','backbone.resnet.')] = state_dict.pop(key)
            elif 'net.global_regressor.' in key:
                state_dict[key.replace('net.global_regressor.','nn.global_regressor.')] = state_dict.pop(key)
            elif 'net.global_context.' in key:
                state_dict[key.replace('net.global_context.','nn.global_context.')] = state_dict.pop(key)
        return state_dict
         
    def save_model(self, file_name = 'model-{}-{}.pth'):
        checkpoint_path = os.path.join(args.model_dir, file_name)
        torch.save(self.model.state_dict(),checkpoint_path)
        print('Saving model to ' +  file_name)
  
    def _optimize(self,regressor_context_rate = [0.0,0.0]):
        optimizer = [
                {'params': self.model.gp.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay},
                {'params': self.model.likelihood.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay}]
            
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            for param in self.model.nn.global_regressor.parameters():
                param.requires_grad = False
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
        else:
            for param in self.model.nn.global_context.parameters():
                param.requires_grad = False
                
        return optimizer
    
    def train(self,x, y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        x,y = x.cuda(),y.cuda()
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
            
        # Step 2: training
        assert trainer.model.training == True
        single_loss = self._loss(x, y)
        batch_time = time.time() - start
        
        #Step 3: update
        single_loss.backward()
        self.optimizer.step()
        
        return float(single_loss), batch_time
            
    def _loss(self,x, y):
        # target
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        # predict
        trans_pred, rot_pred = self.model(x)
        
        # trans loss
        trans_loss = -1.*self.mll(trans_pred, trans_target)
        # rot loss
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        
        total_loss = trans_loss + args.lamda_weights * rot_loss      
        
        return total_loss
    
    def eval_forward(self,x,y,num_sample = 100,output_denormalize = True):
        # Step 1: get data
        x,y = x.cuda(),y.cuda()
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
        
        # Step 2: forward
        assert trainer.model.training == False
        trans_prediction, rot_prediction = self.model(x)
        trans_prediction, trans_mean, trans_var = self._eval_gp(trans_prediction)
        
        if args.is_normalization and output_denormalize:
            trans_prediction = denormalize_navie(trans_prediction, self.norm_mean, self.norm_std)
            trans_mean = denormalize_navie(trans_mean, self.norm_mean, self.norm_std)
            trans_var = trans_var.mul(self.norm_std)
            y = denormalize(y, self.norm_mean, self.norm_std)
        
        samples = self._sample(trans_mean, trans_var, num_sample)
            
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_prediction, rot_prediction, trans_target, rot_target, samples
    
    def _sample(self, mean, var, num_sample = 100):
        dist = Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples
    
    def _eval_gp(self, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = self.model.likelihood(trans_pred).mean, self.model.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var
    
trainer = Trainer(regressor_context_rate = [0,0])
trainer.load_model('pretrained.pth')
# Out:
# Transform from old model.
# Parameters layer: 356
# backbone.resnet.conv1.weight torch.Size([64, 1, 7, 7])
# backbone.resnet.bn1.weight torch.Size([64])
# backbone.resnet.bn1.bias torch.Size([64])
# backbone.resnet.layer1.0.conv1.weight torch.Size([64, 64, 1, 1])
# backbone.resnet.layer1.0.bn1.weight torch.Size([64])
# backbone.resnet.layer1.0.bn1.bias torch.Size([64])
# backbone.resnet.layer1.0.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.0.bn2.weight torch.Size([64])
# backbone.resnet.layer1.0.bn2.bias torch.Size([64])
# backbone.resnet.layer1.0.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.0.bn3.weight torch.Size([256])
# backbone.resnet.layer1.0.bn3.bias torch.Size([256])
# backbone.resnet.layer1.0.downsample.0.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.0.downsample.1.weight torch.Size([256])
# backbone.resnet.layer1.0.downsample.1.bias torch.Size([256])
# backbone.resnet.layer1.1.conv1.weight torch.Size([64, 256, 1, 1])
# backbone.resnet.layer1.1.bn1.weight torch.Size([64])
# backbone.resnet.layer1.1.bn1.bias torch.Size([64])
# backbone.resnet.layer1.1.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.1.bn2.weight torch.Size([64])
# backbone.resnet.layer1.1.bn2.bias torch.Size([64])
# backbone.resnet.layer1.1.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.1.bn3.weight torch.Size([256])
# backbone.resnet.layer1.1.bn3.bias torch.Size([256])
# backbone.resnet.layer1.2.conv1.weight torch.Size([64, 256, 1, 1])
# backbone.resnet.layer1.2.bn1.weight torch.Size([64])
# backbone.resnet.layer1.2.bn1.bias torch.Size([64])
# backbone.resnet.layer1.2.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.resnet.layer1.2.bn2.weight torch.Size([64])
# backbone.resnet.layer1.2.bn2.bias torch.Size([64])
# backbone.resnet.layer1.2.conv3.weight torch.Size([256, 64, 1, 1])
# backbone.resnet.layer1.2.bn3.weight torch.Size([256])
# backbone.resnet.layer1.2.bn3.bias torch.Size([256])
# backbone.resnet.layer2.0.conv1.weight torch.Size([128, 256, 1, 1])
# backbone.resnet.layer2.0.bn1.weight torch.Size([128])
# backbone.resnet.layer2.0.bn1.bias torch.Size([128])
# backbone.resnet.layer2.0.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.0.bn2.weight torch.Size([128])
# backbone.resnet.layer2.0.bn2.bias torch.Size([128])
# backbone.resnet.layer2.0.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.0.bn3.weight torch.Size([512])
# backbone.resnet.layer2.0.bn3.bias torch.Size([512])
# backbone.resnet.layer2.0.downsample.0.weight torch.Size([512, 256, 1, 1])
# backbone.resnet.layer2.0.downsample.1.weight torch.Size([512])
# backbone.resnet.layer2.0.downsample.1.bias torch.Size([512])
# backbone.resnet.layer2.1.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.1.bn1.weight torch.Size([128])
# backbone.resnet.layer2.1.bn1.bias torch.Size([128])
# backbone.resnet.layer2.1.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.1.bn2.weight torch.Size([128])
# backbone.resnet.layer2.1.bn2.bias torch.Size([128])
# backbone.resnet.layer2.1.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.1.bn3.weight torch.Size([512])
# backbone.resnet.layer2.1.bn3.bias torch.Size([512])
# backbone.resnet.layer2.2.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.2.bn1.weight torch.Size([128])
# backbone.resnet.layer2.2.bn1.bias torch.Size([128])
# backbone.resnet.layer2.2.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.2.bn2.weight torch.Size([128])
# backbone.resnet.layer2.2.bn2.bias torch.Size([128])
# backbone.resnet.layer2.2.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.2.bn3.weight torch.Size([512])
# backbone.resnet.layer2.2.bn3.bias torch.Size([512])
# backbone.resnet.layer2.3.conv1.weight torch.Size([128, 512, 1, 1])
# backbone.resnet.layer2.3.bn1.weight torch.Size([128])
# backbone.resnet.layer2.3.bn1.bias torch.Size([128])
# backbone.resnet.layer2.3.conv2.weight torch.Size([128, 128, 3, 3])
# backbone.resnet.layer2.3.bn2.weight torch.Size([128])
# backbone.resnet.layer2.3.bn2.bias torch.Size([128])
# backbone.resnet.layer2.3.conv3.weight torch.Size([512, 128, 1, 1])
# backbone.resnet.layer2.3.bn3.weight torch.Size([512])
# backbone.resnet.layer2.3.bn3.bias torch.Size([512])
# backbone.resnet.layer3.0.conv1.weight torch.Size([256, 512, 1, 1])
# backbone.resnet.layer3.0.bn1.weight torch.Size([256])
# backbone.resnet.layer3.0.bn1.bias torch.Size([256])
# backbone.resnet.layer3.0.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.0.bn2.weight torch.Size([256])
# backbone.resnet.layer3.0.bn2.bias torch.Size([256])
# backbone.resnet.layer3.0.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.0.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.0.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.0.downsample.0.weight torch.Size([1024, 512, 1, 1])
# backbone.resnet.layer3.0.downsample.1.weight torch.Size([1024])
# backbone.resnet.layer3.0.downsample.1.bias torch.Size([1024])
# backbone.resnet.layer3.1.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.1.bn1.weight torch.Size([256])
# backbone.resnet.layer3.1.bn1.bias torch.Size([256])
# backbone.resnet.layer3.1.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.1.bn2.weight torch.Size([256])
# backbone.resnet.layer3.1.bn2.bias torch.Size([256])
# backbone.resnet.layer3.1.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.1.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.1.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.2.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.2.bn1.weight torch.Size([256])
# backbone.resnet.layer3.2.bn1.bias torch.Size([256])
# backbone.resnet.layer3.2.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.2.bn2.weight torch.Size([256])
# backbone.resnet.layer3.2.bn2.bias torch.Size([256])
# backbone.resnet.layer3.2.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.2.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.2.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.3.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.3.bn1.weight torch.Size([256])
# backbone.resnet.layer3.3.bn1.bias torch.Size([256])
# backbone.resnet.layer3.3.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.3.bn2.weight torch.Size([256])
# backbone.resnet.layer3.3.bn2.bias torch.Size([256])
# backbone.resnet.layer3.3.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.3.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.3.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.4.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.4.bn1.weight torch.Size([256])
# backbone.resnet.layer3.4.bn1.bias torch.Size([256])
# backbone.resnet.layer3.4.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.4.bn2.weight torch.Size([256])
# backbone.resnet.layer3.4.bn2.bias torch.Size([256])
# backbone.resnet.layer3.4.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.4.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.4.bn3.bias torch.Size([1024])
# backbone.resnet.layer3.5.conv1.weight torch.Size([256, 1024, 1, 1])
# backbone.resnet.layer3.5.bn1.weight torch.Size([256])
# backbone.resnet.layer3.5.bn1.bias torch.Size([256])
# backbone.resnet.layer3.5.conv2.weight torch.Size([256, 256, 3, 3])
# backbone.resnet.layer3.5.bn2.weight torch.Size([256])
# backbone.resnet.layer3.5.bn2.bias torch.Size([256])
# backbone.resnet.layer3.5.conv3.weight torch.Size([1024, 256, 1, 1])
# backbone.resnet.layer3.5.bn3.weight torch.Size([1024])
# backbone.resnet.layer3.5.bn3.bias torch.Size([1024])
# backbone.resnet.layer4.0.conv1.weight torch.Size([512, 1024, 1, 1])
# backbone.resnet.layer4.0.bn1.weight torch.Size([512])
# backbone.resnet.layer4.0.bn1.bias torch.Size([512])
# backbone.resnet.layer4.0.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.0.bn2.weight torch.Size([512])
# backbone.resnet.layer4.0.bn2.bias torch.Size([512])
# backbone.resnet.layer4.0.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.0.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.0.bn3.bias torch.Size([2048])
# backbone.resnet.layer4.0.downsample.0.weight torch.Size([2048, 1024, 1, 1])
# backbone.resnet.layer4.0.downsample.1.weight torch.Size([2048])
# backbone.resnet.layer4.0.downsample.1.bias torch.Size([2048])
# backbone.resnet.layer4.1.conv1.weight torch.Size([512, 2048, 1, 1])
# backbone.resnet.layer4.1.bn1.weight torch.Size([512])
# backbone.resnet.layer4.1.bn1.bias torch.Size([512])
# backbone.resnet.layer4.1.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.1.bn2.weight torch.Size([512])
# backbone.resnet.layer4.1.bn2.bias torch.Size([512])
# backbone.resnet.layer4.1.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.1.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.1.bn3.bias torch.Size([2048])
# backbone.resnet.layer4.2.conv1.weight torch.Size([512, 2048, 1, 1])
# backbone.resnet.layer4.2.bn1.weight torch.Size([512])
# backbone.resnet.layer4.2.bn1.bias torch.Size([512])
# backbone.resnet.layer4.2.conv2.weight torch.Size([512, 512, 3, 3])
# backbone.resnet.layer4.2.bn2.weight torch.Size([512])
# backbone.resnet.layer4.2.bn2.bias torch.Size([512])
# backbone.resnet.layer4.2.conv3.weight torch.Size([2048, 512, 1, 1])
# backbone.resnet.layer4.2.bn3.weight torch.Size([2048])
# backbone.resnet.layer4.2.bn3.bias torch.Size([2048])
# nn.global_context.context.squeeze.0.weight torch.Size([128, 2048, 1, 1])
# nn.global_context.context.squeeze.0.bias torch.Size([128])
# nn.global_context.context.context5_1.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_1.0.bias torch.Size([128])
# nn.global_context.context.context5_2.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_2.0.bias torch.Size([128])
# nn.global_context.context.context5_3.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_3.0.bias torch.Size([128])
# nn.global_context.context.context5_4.0.weight torch.Size([128, 128, 3, 3])
# nn.global_context.context.context5_4.0.bias torch.Size([128])
# nn.global_context.context.squeeze2.0.weight torch.Size([64, 128, 1, 1])
# nn.global_context.context.squeeze2.0.bias torch.Size([64])
# nn.global_regressor.regressor.fc1_trans.0.weight torch.Size([4096, 6400])
# nn.global_regressor.regressor.fc1_trans.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc2_trans.0.weight torch.Size([4096, 4096])
# nn.global_regressor.regressor.fc2_trans.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc3_trans.0.weight torch.Size([128, 4096])
# nn.global_regressor.regressor.fc3_trans.0.bias torch.Size([128])
# nn.global_regressor.regressor.logits_t.weight torch.Size([3, 128])
# nn.global_regressor.regressor.logits_t.bias torch.Size([3])
# nn.global_regressor.regressor.fc1_rot.0.weight torch.Size([4096, 6400])
# nn.global_regressor.regressor.fc1_rot.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc2_rot.0.weight torch.Size([4096, 4096])
# nn.global_regressor.regressor.fc2_rot.0.bias torch.Size([4096])
# nn.global_regressor.regressor.fc3_rot.0.weight torch.Size([128, 4096])
# nn.global_regressor.regressor.fc3_rot.0.bias torch.Size([128])
# nn.global_regressor.regressor.logits_r.weight torch.Size([4, 128])
# nn.global_regressor.regressor.logits_r.bias torch.Size([4])
# gp.variational_strategy.base_variational_strategy.inducing_points torch.Size([3, 300, 128])
# gp.variational_strategy.base_variational_strategy._variational_distribution.variational_mean torch.Size([3, 300])
# gp.variational_strategy.base_variational_strategy._variational_distribution.chol_variational_covar torch.Size([3, 300, 300])
# gp.mean_module.constant torch.Size([1, 1])
# gp.covar_module.raw_outputscale torch.Size([1])
# gp.covar_module.base_kernel.raw_lengthscale torch.Size([1, 1, 1])
# likelihood.raw_noise torch.Size([1])
# likelihood.noise_covar.raw_noise torch.Size([3])
# Parameters layer: 356

# %%
for param in trainer.model.parameters():
    param.requires_grad = False

# %% [markdown]
# # Initialize

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

# %%
trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward(x,y)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 300/92100, translation error = 2.968, rotation error = 2.768, time/batch = 3.965
# 600/92100, translation error = 7.641, rotation error = 3.431, time/batch = 0.809
# 900/92100, translation error = 7.965, rotation error = 3.388, time/batch = 0.758
# 1200/92100, translation error = 7.033, rotation error = 3.443, time/batch = 0.764
# 1500/92100, translation error = 6.305, rotation error = 3.544, time/batch = 0.758
# 1800/92100, translation error = 5.560, rotation error = 3.528, time/batch = 0.760
# 2100/92100, translation error = 5.322, rotation error = 3.683, time/batch = 0.778
# 2400/92100, translation error = 4.892, rotation error = 3.598, time/batch = 0.756
# 2700/92100, translation error = 4.676, rotation error = 3.707, time/batch = 0.762
# 3000/92100, translation error = 4.491, rotation error = 3.726, time/batch = 0.764
# 3300/92100, translation error = 4.225, rotation error = 3.607, time/batch = 0.759
# 3600/92100, translation error = 4.153, rotation error = 3.643, time/batch = 0.760
# 3900/92100, translation error = 3.943, rotation error = 3.592, time/batch = 0.760
# 4200/92100, translation error = 3.727, rotation error = 3.520, time/batch = 0.764
# 4500/92100, translation error = 3.548, rotation error = 3.484, time/batch = 0.761
# 4800/92100, translation error = 3.388, rotation error = 3.471, time/batch = 0.761
# 5100/92100, translation error = 3.318, rotation error = 3.508, time/batch = 0.765
# 5400/92100, translation error = 3.242, rotation error = 3.470, time/batch = 0.764
# 5700/92100, translation error = 3.156, rotation error = 3.404, time/batch = 0.765
# 6000/92100, translation error = 3.135, rotation error = 3.397, time/batch = 0.761
# 6300/92100, translation error = 3.079, rotation error = 3.331, time/batch = 0.763
# 6600/92100, translation error = 3.078, rotation error = 3.347, time/batch = 0.765
# 6900/92100, translation error = 5.244, rotation error = 3.910, time/batch = 0.764
# 7200/92100, translation error = 5.176, rotation error = 4.016, time/batch = 0.768
# 7500/92100, translation error = 5.022, rotation error = 4.061, time/batch = 0.762
# 7800/92100, translation error = 5.083, rotation error = 4.126, time/batch = 0.762
# 8100/92100, translation error = 5.138, rotation error = 4.102, time/batch = 0.771
# 8400/92100, translation error = 5.674, rotation error = 4.208, time/batch = 0.767
# 8700/92100, translation error = 5.556, rotation error = 4.192, time/batch = 0.761
# 9000/92100, translation error = 5.434, rotation error = 4.164, time/batch = 0.766
# 9300/92100, translation error = 5.356, rotation error = 4.148, time/batch = 0.768
# 9600/92100, translation error = 5.274, rotation error = 4.086, time/batch = 0.768
# 9900/92100, translation error = 5.183, rotation error = 4.068, time/batch = 0.767
# 10200/92100, translation error = 5.111, rotation error = 4.061, time/batch = 0.764
# 10500/92100, translation error = 5.015, rotation error = 4.148, time/batch = 0.763
# 10800/92100, translation error = 4.926, rotation error = 4.144, time/batch = 0.765
# 11100/92100, translation error = 4.864, rotation error = 4.127, time/batch = 0.769
# 11400/92100, translation error = 4.780, rotation error = 4.075, time/batch = 0.764
# 11700/92100, translation error = 4.689, rotation error = 4.025, time/batch = 0.766
# 12000/92100, translation error = 4.605, rotation error = 3.991, time/batch = 0.761
# 12300/92100, translation error = 4.517, rotation error = 3.951, time/batch = 0.764
# 12600/92100, translation error = 4.448, rotation error = 3.928, time/batch = 0.770
# 12900/92100, translation error = 4.390, rotation error = 3.946, time/batch = 0.766
# 13200/92100, translation error = 4.328, rotation error = 3.920, time/batch = 0.765
# 13500/92100, translation error = 4.388, rotation error = 3.931, time/batch = 0.768
# 13800/92100, translation error = 4.337, rotation error = 3.912, time/batch = 0.768
# 14100/92100, translation error = 4.291, rotation error = 3.901, time/batch = 0.771
# 14400/92100, translation error = 4.264, rotation error = 3.923, time/batch = 0.765
# 14700/92100, translation error = 4.216, rotation error = 3.893, time/batch = 0.764
# 15000/92100, translation error = 4.194, rotation error = 3.892, time/batch = 0.768
# 15300/92100, translation error = 4.169, rotation error = 3.867, time/batch = 0.773
# 15600/92100, translation error = 4.172, rotation error = 3.926, time/batch = 0.765
# 15900/92100, translation error = 5.102, rotation error = 4.063, time/batch = 0.766
# 16200/92100, translation error = 5.060, rotation error = 4.079, time/batch = 0.772
# 16500/92100, translation error = 5.009, rotation error = 4.059, time/batch = 0.770
# 16800/92100, translation error = 4.963, rotation error = 4.097, time/batch = 0.771
# 17100/92100, translation error = 4.915, rotation error = 4.090, time/batch = 0.767
# 17400/92100, translation error = 4.857, rotation error = 4.070, time/batch = 0.766
# 17700/92100, translation error = 4.800, rotation error = 4.055, time/batch = 0.769
# 18000/92100, translation error = 4.772, rotation error = 4.083, time/batch = 0.769
# 18300/92100, translation error = 4.733, rotation error = 4.105, time/batch = 0.774
# 18600/92100, translation error = 4.688, rotation error = 4.096, time/batch = 0.781
# 18900/92100, translation error = 4.640, rotation error = 4.102, time/batch = 0.772
# 19200/92100, translation error = 4.600, rotation error = 4.084, time/batch = 0.769
# 19500/92100, translation error = 4.582, rotation error = 4.076, time/batch = 0.771
# 19800/92100, translation error = 4.548, rotation error = 4.081, time/batch = 0.774
# 20100/92100, translation error = 4.513, rotation error = 4.073, time/batch = 0.770
# 20400/92100, translation error = 4.465, rotation error = 4.051, time/batch = 0.770
# 20700/92100, translation error = 4.422, rotation error = 4.042, time/batch = 0.767
# 21000/92100, translation error = 4.382, rotation error = 4.034, time/batch = 0.778
# 21300/92100, translation error = 4.339, rotation error = 4.038, time/batch = 0.785
# 21600/92100, translation error = 4.405, rotation error = 4.039, time/batch = 0.769
# 21900/92100, translation error = 6.458, rotation error = 4.373, time/batch = 0.769
# 22200/92100, translation error = 9.805, rotation error = 5.256, time/batch = 0.768
# 22500/92100, translation error = 9.923, rotation error = 5.226, time/batch = 0.774
# 22800/92100, translation error = 9.831, rotation error = 5.202, time/batch = 0.769
# 23100/92100, translation error = 9.756, rotation error = 5.202, time/batch = 0.772
# 23400/92100, translation error = 9.661, rotation error = 5.182, time/batch = 0.773
# 23700/92100, translation error = 9.563, rotation error = 5.164, time/batch = 0.766
# 24000/92100, translation error = 9.472, rotation error = 5.147, time/batch = 0.775
# 24300/92100, translation error = 9.436, rotation error = 5.154, time/batch = 0.770
# 24600/92100, translation error = 9.354, rotation error = 5.159, time/batch = 0.772
# 24900/92100, translation error = 9.294, rotation error = 5.155, time/batch = 0.773
# 25200/92100, translation error = 9.206, rotation error = 5.139, time/batch = 0.773
# 25500/92100, translation error = 9.118, rotation error = 5.119, time/batch = 0.771
# 25800/92100, translation error = 9.028, rotation error = 5.112, time/batch = 0.777
# 26100/92100, translation error = 8.951, rotation error = 5.105, time/batch = 0.767
# 26400/92100, translation error = 8.866, rotation error = 5.083, time/batch = 0.772
# 26700/92100, translation error = 8.785, rotation error = 5.061, time/batch = 0.770
# 27000/92100, translation error = 8.778, rotation error = 5.053, time/batch = 0.772
# 27300/92100, translation error = 8.709, rotation error = 5.021, time/batch = 0.776
# 27600/92100, translation error = 8.646, rotation error = 4.993, time/batch = 0.772
# 27900/92100, translation error = 8.576, rotation error = 4.969, time/batch = 0.773
# 28200/92100, translation error = 8.507, rotation error = 4.946, time/batch = 0.769
# 28500/92100, translation error = 8.453, rotation error = 4.942, time/batch = 0.775
# 28800/92100, translation error = 8.405, rotation error = 4.923, time/batch = 0.771
# 29100/92100, translation error = 8.397, rotation error = 5.016, time/batch = 0.771
# 29400/92100, translation error = 8.498, rotation error = 5.037, time/batch = 0.784
# 29700/92100, translation error = 8.433, rotation error = 5.006, time/batch = 0.770
# 30000/92100, translation error = 8.394, rotation error = 4.996, time/batch = 0.774
# 30300/92100, translation error = 8.348, rotation error = 4.982, time/batch = 0.773
# 30600/92100, translation error = 8.293, rotation error = 4.969, time/batch = 0.775
# 30900/92100, translation error = 8.227, rotation error = 4.960, time/batch = 0.777
# 31200/92100, translation error = 8.172, rotation error = 4.969, time/batch = 0.772
# 31500/92100, translation error = 8.113, rotation error = 4.952, time/batch = 0.769
# 31800/92100, translation error = 8.055, rotation error = 4.932, time/batch = 0.772
# 32100/92100, translation error = 8.006, rotation error = 4.918, time/batch = 0.770
# 32400/92100, translation error = 7.952, rotation error = 4.910, time/batch = 0.771
# 32700/92100, translation error = 7.896, rotation error = 4.902, time/batch = 0.773
# 33000/92100, translation error = 7.836, rotation error = 4.887, time/batch = 0.770
# 33300/92100, translation error = 7.788, rotation error = 4.869, time/batch = 0.773
# 33600/92100, translation error = 7.741, rotation error = 4.857, time/batch = 0.773
# 33900/92100, translation error = 7.703, rotation error = 4.851, time/batch = 0.768
# 34200/92100, translation error = 7.908, rotation error = 4.912, time/batch = 0.771
# 34500/92100, translation error = 8.999, rotation error = 5.115, time/batch = 0.773
# 34800/92100, translation error = 8.953, rotation error = 5.090, time/batch = 0.781
# 35100/92100, translation error = 8.899, rotation error = 5.082, time/batch = 0.771
# 35400/92100, translation error = 9.875, rotation error = 5.267, time/batch = 0.778
# 35700/92100, translation error = 10.097, rotation error = 5.274, time/batch = 0.771
# 36000/92100, translation error = 10.041, rotation error = 5.256, time/batch = 0.772
# 36300/92100, translation error = 9.993, rotation error = 5.263, time/batch = 0.774
# 36600/92100, translation error = 9.938, rotation error = 5.252, time/batch = 0.775
# 36900/92100, translation error = 9.876, rotation error = 5.244, time/batch = 0.780
# 37200/92100, translation error = 9.815, rotation error = 5.230, time/batch = 0.784
# 37500/92100, translation error = 9.749, rotation error = 5.214, time/batch = 0.771
# 37800/92100, translation error = 9.685, rotation error = 5.200, time/batch = 0.774
# 38100/92100, translation error = 9.629, rotation error = 5.201, time/batch = 0.777
# 38400/92100, translation error = 9.568, rotation error = 5.192, time/batch = 0.771
# 38700/92100, translation error = 9.506, rotation error = 5.184, time/batch = 0.775
# 39000/92100, translation error = 9.455, rotation error = 5.175, time/batch = 0.772
# 39300/92100, translation error = 9.401, rotation error = 5.162, time/batch = 0.778
# 39600/92100, translation error = 9.350, rotation error = 5.163, time/batch = 0.772
# 39900/92100, translation error = 9.304, rotation error = 5.156, time/batch = 0.772
# 40200/92100, translation error = 9.245, rotation error = 5.144, time/batch = 0.780
# 40500/92100, translation error = 9.192, rotation error = 5.133, time/batch = 0.777
# 40800/92100, translation error = 9.135, rotation error = 5.127, time/batch = 0.774
# 41100/92100, translation error = 9.085, rotation error = 5.129, time/batch = 0.774
# 41400/92100, translation error = 9.034, rotation error = 5.120, time/batch = 0.777
# 41700/92100, translation error = 8.982, rotation error = 5.115, time/batch = 0.772
# 42000/92100, translation error = 8.932, rotation error = 5.112, time/batch = 0.771
# 42300/92100, translation error = 8.959, rotation error = 5.112, time/batch = 0.774
# 42600/92100, translation error = 8.923, rotation error = 5.090, time/batch = 0.780
# 42900/92100, translation error = 8.880, rotation error = 5.069, time/batch = 0.774
# 43200/92100, translation error = 8.832, rotation error = 5.054, time/batch = 0.771
# 43500/92100, translation error = 8.798, rotation error = 5.039, time/batch = 0.770
# 43800/92100, translation error = 8.817, rotation error = 5.067, time/batch = 0.770
# 44100/92100, translation error = 8.778, rotation error = 5.062, time/batch = 0.771
# 44400/92100, translation error = 8.769, rotation error = 5.081, time/batch = 0.775
# 44700/92100, translation error = 8.733, rotation error = 5.074, time/batch = 0.772
# 45000/92100, translation error = 8.691, rotation error = 5.068, time/batch = 0.773
# 45300/92100, translation error = 8.649, rotation error = 5.063, time/batch = 0.772
# 45600/92100, translation error = 8.619, rotation error = 5.062, time/batch = 0.770
# 45900/92100, translation error = 8.575, rotation error = 5.051, time/batch = 0.772
# 46200/92100, translation error = 8.540, rotation error = 5.056, time/batch = 0.772
# 46500/92100, translation error = 8.506, rotation error = 5.053, time/batch = 0.771
# 46800/92100, translation error = 8.471, rotation error = 5.040, time/batch = 0.772
# 47100/92100, translation error = 8.440, rotation error = 5.035, time/batch = 0.773
# 47400/92100, translation error = 8.425, rotation error = 5.023, time/batch = 0.773
# 47700/92100, translation error = 8.383, rotation error = 5.012, time/batch = 0.772
# 48000/92100, translation error = 8.339, rotation error = 5.010, time/batch = 0.775
# 48300/92100, translation error = 8.303, rotation error = 5.002, time/batch = 0.773
# 48600/92100, translation error = 8.269, rotation error = 4.989, time/batch = 0.774
# 48900/92100, translation error = 8.234, rotation error = 4.973, time/batch = 0.774
# 49200/92100, translation error = 8.200, rotation error = 4.960, time/batch = 0.773
# 49500/92100, translation error = 8.163, rotation error = 4.954, time/batch = 0.774
# 49800/92100, translation error = 8.129, rotation error = 4.941, time/batch = 0.772
# 50100/92100, translation error = 8.104, rotation error = 4.935, time/batch = 0.772
# 50400/92100, translation error = 8.071, rotation error = 4.924, time/batch = 0.773
# 50700/92100, translation error = 8.697, rotation error = 5.051, time/batch = 0.774
# 51000/92100, translation error = 9.142, rotation error = 5.089, time/batch = 0.773
# 51300/92100, translation error = 9.102, rotation error = 5.079, time/batch = 0.775
# 51600/92100, translation error = 9.061, rotation error = 5.068, time/batch = 0.775
# 51900/92100, translation error = 9.018, rotation error = 5.075, time/batch = 0.771
# 52200/92100, translation error = 8.997, rotation error = 5.080, time/batch = 0.770
# 52500/92100, translation error = 8.959, rotation error = 5.076, time/batch = 0.773
# 52800/92100, translation error = 8.922, rotation error = 5.060, time/batch = 0.774
# 53100/92100, translation error = 8.884, rotation error = 5.046, time/batch = 0.774
# 53400/92100, translation error = 8.853, rotation error = 5.070, time/batch = 0.772
# 53700/92100, translation error = 8.817, rotation error = 5.068, time/batch = 0.772
# 54000/92100, translation error = 8.776, rotation error = 5.063, time/batch = 0.772
# 54300/92100, translation error = 8.837, rotation error = 5.079, time/batch = 0.769
# 54600/92100, translation error = 8.808, rotation error = 5.071, time/batch = 0.775
# 54900/92100, translation error = 8.774, rotation error = 5.073, time/batch = 0.774
# 55200/92100, translation error = 8.734, rotation error = 5.062, time/batch = 0.774
# 55500/92100, translation error = 8.704, rotation error = 5.064, time/batch = 0.775
# 55800/92100, translation error = 8.900, rotation error = 5.078, time/batch = 0.773
# 56100/92100, translation error = 9.033, rotation error = 5.169, time/batch = 0.770
# 56400/92100, translation error = 9.086, rotation error = 5.192, time/batch = 0.772
# 56700/92100, translation error = 9.059, rotation error = 5.198, time/batch = 0.772
# 57000/92100, translation error = 9.034, rotation error = 5.193, time/batch = 0.773
# 57300/92100, translation error = 9.002, rotation error = 5.200, time/batch = 0.773
# 57600/92100, translation error = 9.820, rotation error = 5.235, time/batch = 0.771
# 57900/92100, translation error = 9.787, rotation error = 5.234, time/batch = 0.776
# 58200/92100, translation error = 9.753, rotation error = 5.237, time/batch = 0.775
# 58500/92100, translation error = 9.753, rotation error = 5.244, time/batch = 0.777
# 58800/92100, translation error = 9.714, rotation error = 5.232, time/batch = 0.776
# 59100/92100, translation error = 9.673, rotation error = 5.225, time/batch = 0.774
# 59400/92100, translation error = 9.635, rotation error = 5.225, time/batch = 0.774
# 59700/92100, translation error = 9.599, rotation error = 5.214, time/batch = 0.778
# 60000/92100, translation error = 9.562, rotation error = 5.208, time/batch = 0.775
# 60300/92100, translation error = 9.525, rotation error = 5.201, time/batch = 0.774
# 60600/92100, translation error = 9.494, rotation error = 5.197, time/batch = 0.774
# 60900/92100, translation error = 9.459, rotation error = 5.188, time/batch = 0.776
# 61200/92100, translation error = 9.434, rotation error = 5.185, time/batch = 0.774
# 61500/92100, translation error = 9.482, rotation error = 5.210, time/batch = 0.775
# 61800/92100, translation error = 9.744, rotation error = 5.345, time/batch = 0.775
# 62100/92100, translation error = 9.709, rotation error = 5.343, time/batch = 0.775
# 62400/92100, translation error = 9.679, rotation error = 5.339, time/batch = 0.775
# 62700/92100, translation error = 9.642, rotation error = 5.331, time/batch = 0.774
# 63000/92100, translation error = 9.606, rotation error = 5.327, time/batch = 0.772
# 63300/92100, translation error = 9.605, rotation error = 5.342, time/batch = 0.769
# 63600/92100, translation error = 9.570, rotation error = 5.337, time/batch = 0.774
# 63900/92100, translation error = 9.537, rotation error = 5.326, time/batch = 0.775
# 64200/92100, translation error = 9.979, rotation error = 5.462, time/batch = 0.772
# 64500/92100, translation error = 10.137, rotation error = 5.569, time/batch = 0.773
# 64800/92100, translation error = 10.102, rotation error = 5.566, time/batch = 0.776
# 65100/92100, translation error = 10.080, rotation error = 5.570, time/batch = 0.774
# 65400/92100, translation error = 10.044, rotation error = 5.557, time/batch = 0.774
# 65700/92100, translation error = 10.011, rotation error = 5.547, time/batch = 0.773
# 66000/92100, translation error = 9.989, rotation error = 5.561, time/batch = 0.775
# 66300/92100, translation error = 9.955, rotation error = 5.553, time/batch = 0.776
# 66600/92100, translation error = 9.922, rotation error = 5.545, time/batch = 0.779
# 66900/92100, translation error = 9.932, rotation error = 5.568, time/batch = 0.772
# 67200/92100, translation error = 9.911, rotation error = 5.568, time/batch = 0.769
# 67500/92100, translation error = 9.889, rotation error = 5.595, time/batch = 0.770
# 67800/92100, translation error = 9.854, rotation error = 5.585, time/batch = 0.773
# 68100/92100, translation error = 9.819, rotation error = 5.571, time/batch = 0.776
# 68400/92100, translation error = 9.787, rotation error = 5.579, time/batch = 0.775
# 68700/92100, translation error = 9.758, rotation error = 5.572, time/batch = 0.774
# 69000/92100, translation error = 9.730, rotation error = 5.568, time/batch = 0.773
# 69300/92100, translation error = 9.724, rotation error = 5.575, time/batch = 0.775
# 69600/92100, translation error = 9.716, rotation error = 5.571, time/batch = 0.776
# 69900/92100, translation error = 9.723, rotation error = 5.563, time/batch = 0.775
# 70200/92100, translation error = 9.693, rotation error = 5.553, time/batch = 0.778
# 70500/92100, translation error = 9.658, rotation error = 5.545, time/batch = 0.773
# 70800/92100, translation error = 9.624, rotation error = 5.535, time/batch = 0.777
# 71100/92100, translation error = 9.594, rotation error = 5.530, time/batch = 0.773
# 71400/92100, translation error = 9.560, rotation error = 5.520, time/batch = 0.774
# 71700/92100, translation error = 9.528, rotation error = 5.509, time/batch = 0.774
# 72000/92100, translation error = 9.500, rotation error = 5.499, time/batch = 0.773
# 72300/92100, translation error = 9.473, rotation error = 5.491, time/batch = 0.773
# 72600/92100, translation error = 9.441, rotation error = 5.482, time/batch = 0.775
# 72900/92100, translation error = 9.413, rotation error = 5.477, time/batch = 0.778
# 73200/92100, translation error = 9.386, rotation error = 5.477, time/batch = 0.776
# 73500/92100, translation error = 9.357, rotation error = 5.473, time/batch = 0.776
# 73800/92100, translation error = 9.357, rotation error = 5.475, time/batch = 0.775
# 74100/92100, translation error = 9.334, rotation error = 5.472, time/batch = 0.777
# 74400/92100, translation error = 9.373, rotation error = 5.498, time/batch = 0.774
# 74700/92100, translation error = 9.577, rotation error = 5.652, time/batch = 0.777
# 75000/92100, translation error = 9.552, rotation error = 5.648, time/batch = 0.775
# 75300/92100, translation error = 9.709, rotation error = 5.694, time/batch = 0.775
# 75600/92100, translation error = 9.722, rotation error = 5.706, time/batch = 0.776
# 75900/92100, translation error = 9.696, rotation error = 5.696, time/batch = 0.777
# 76200/92100, translation error = 9.672, rotation error = 5.689, time/batch = 0.775
# 76500/92100, translation error = 9.643, rotation error = 5.678, time/batch = 0.774
# 76800/92100, translation error = 9.638, rotation error = 5.675, time/batch = 0.774
# 77100/92100, translation error = 9.654, rotation error = 5.674, time/batch = 0.775
# 77400/92100, translation error = 9.773, rotation error = 5.708, time/batch = 0.776
# 77700/92100, translation error = 10.125, rotation error = 5.782, time/batch = 0.774
# 78000/92100, translation error = 10.263, rotation error = 5.870, time/batch = 0.775
# 78300/92100, translation error = 10.298, rotation error = 5.873, time/batch = 0.777
# 78600/92100, translation error = 10.323, rotation error = 5.895, time/batch = 0.777
# 78900/92100, translation error = 10.326, rotation error = 5.901, time/batch = 0.775
# 79200/92100, translation error = 10.544, rotation error = 6.065, time/batch = 0.774
# 79500/92100, translation error = 11.092, rotation error = 6.129, time/batch = 0.773
# 79800/92100, translation error = 11.060, rotation error = 6.140, time/batch = 0.776
# 80100/92100, translation error = 11.033, rotation error = 6.152, time/batch = 0.777
# 80400/92100, translation error = 11.002, rotation error = 6.146, time/batch = 0.777
# 80700/92100, translation error = 11.096, rotation error = 6.214, time/batch = 0.780
# 81000/92100, translation error = 11.069, rotation error = 6.210, time/batch = 0.777
# 81300/92100, translation error = 11.086, rotation error = 6.267, time/batch = 0.775
# 81600/92100, translation error = 11.128, rotation error = 6.289, time/batch = 0.775
# 81900/92100, translation error = 11.107, rotation error = 6.289, time/batch = 0.779
# 82200/92100, translation error = 11.082, rotation error = 6.283, time/batch = 0.776
# 82500/92100, translation error = 11.064, rotation error = 6.280, time/batch = 0.776
# 82800/92100, translation error = 11.061, rotation error = 6.295, time/batch = 0.775
# 83100/92100, translation error = 11.037, rotation error = 6.302, time/batch = 0.776
# 83400/92100, translation error = 11.030, rotation error = 6.298, time/batch = 0.776
# 83700/92100, translation error = 11.010, rotation error = 6.289, time/batch = 0.776
# 84000/92100, translation error = 11.026, rotation error = 6.294, time/batch = 0.774
# 84300/92100, translation error = 11.027, rotation error = 6.333, time/batch = 0.774
# 84600/92100, translation error = 10.998, rotation error = 6.327, time/batch = 0.776
# 84900/92100, translation error = 10.971, rotation error = 6.320, time/batch = 0.778
# 85200/92100, translation error = 10.944, rotation error = 6.312, time/batch = 0.775
# 85500/92100, translation error = 10.914, rotation error = 6.300, time/batch = 0.777
# 85800/92100, translation error = 10.885, rotation error = 6.290, time/batch = 0.777
# 86100/92100, translation error = 11.017, rotation error = 6.367, time/batch = 0.776
# 86400/92100, translation error = 10.992, rotation error = 6.359, time/batch = 0.774
# 86700/92100, translation error = 10.966, rotation error = 6.346, time/batch = 0.773
# 87000/92100, translation error = 10.937, rotation error = 6.335, time/batch = 0.776
# 87300/92100, translation error = 10.920, rotation error = 6.332, time/batch = 0.776
# 87600/92100, translation error = 10.960, rotation error = 6.354, time/batch = 0.772
# 87900/92100, translation error = 10.955, rotation error = 6.393, time/batch = 0.772
# 88200/92100, translation error = 11.048, rotation error = 6.463, time/batch = 0.774
# 88500/92100, translation error = 11.017, rotation error = 6.459, time/batch = 0.776
# 88800/92100, translation error = 11.101, rotation error = 6.460, time/batch = 0.776
# 89100/92100, translation error = 11.194, rotation error = 6.476, time/batch = 0.771
# 89400/92100, translation error = 11.165, rotation error = 6.479, time/batch = 0.776
# 89700/92100, translation error = 11.138, rotation error = 6.471, time/batch = 0.778
# 90000/92100, translation error = 11.202, rotation error = 6.477, time/batch = 0.776
# 90300/92100, translation error = 11.171, rotation error = 6.466, time/batch = 0.778
# 90600/92100, translation error = 11.152, rotation error = 6.463, time/batch = 0.774
# 90900/92100, translation error = 11.126, rotation error = 6.457, time/batch = 0.774
# 91200/92100, translation error = 11.109, rotation error = 6.488, time/batch = 0.775
# 91500/92100, translation error = 11.087, rotation error = 6.563, time/batch = 0.776
# 91800/92100, translation error = 11.056, rotation error = 6.553, time/batch = 0.777
# 92100/92100, translation error = 11.046, rotation error = 6.554, time/batch = 2.484

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.136
# median rotation error = 3.120
# mean translation error = 11.046
# mean rotation error = 6.554

# %%
def evaluate(trans_errors,rot_errors):
    t = [14301,7008,12852,9567,13580,14835,7114,12683]
    for i in range(len(t)):
        if i >0:
            t[i] += t[i-1]
    trans_errors_month = list()
    trans_errors_month.append(trans_errors[:t[0]])
    trans_errors_month.append(trans_errors[t[0]:t[1]])
    trans_errors_month.append(trans_errors[t[1]:t[2]])
    trans_errors_month.append(trans_errors[t[2]:t[3]])
    trans_errors_month.append(trans_errors[t[3]:t[4]])
    trans_errors_month.append(trans_errors[t[4]:t[5]])
    trans_errors_month.append(trans_errors[t[5]:t[6]])
    trans_errors_month.append(trans_errors[t[6]:])

    rot_errors_month = list()
    rot_errors_month.append(rot_errors[:t[0]])
    rot_errors_month.append(rot_errors[t[0]:t[1]])
    rot_errors_month.append(rot_errors[t[1]:t[2]])
    rot_errors_month.append(rot_errors[t[2]:t[3]])
    rot_errors_month.append(rot_errors[t[3]:t[4]])
    rot_errors_month.append(rot_errors[t[4]:t[5]])
    rot_errors_month.append(rot_errors[t[5]:t[6]])
    rot_errors_month.append(rot_errors[t[6]:])
    
    print('================== median translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("median translation error = {:.3f}".format(np.median(trans_errors_i)))
        
    print('================== median rotation error ==================')
    for rot_errors_i in rot_errors_month:
        print("median rotation error = {:.3f}".format(np.median(rot_errors_i)))
    
    print('================== mean translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("mean translation error = {:.3f}".format(np.mean(trans_errors_i)))
        
    print('================== mean rotation error ==================')  
    for rot_errors_i in rot_errors_month:
        print("mean rotation error = {:.3f}".format(np.mean(rot_errors_i)))
        
evaluate(trans_errors,rot_errors)
# Out:
# ================== median translation error ==================
# median translation error = 1.655
# median translation error = 1.734
# median translation error = 2.025
# median translation error = 2.005
# median translation error = 2.097
# median translation error = 2.204
# median translation error = 3.586
# median translation error = 2.945
# ================== median rotation error ==================
# median rotation error = 2.588
# median rotation error = 2.798
# median rotation error = 2.953
# median rotation error = 2.918
# median rotation error = 3.114
# median rotation error = 3.276
# median rotation error = 4.390
# median rotation error = 4.147
# ================== mean translation error ==================
# mean translation error = 4.277
# mean translation error = 4.461
# mean translation error = 13.177
# mean translation error = 12.988
# mean translation error = 9.556
# mean translation error = 11.367
# mean translation error = 21.611
# mean translation error = 13.982
# ================== mean rotation error ==================
# mean rotation error = 3.933
# mean rotation error = 4.252
# mean rotation error = 6.159
# mean rotation error = 5.911
# mean rotation error = 5.624
# mean rotation error = 6.623
# mean rotation error = 12.380
# mean rotation error = 9.309
