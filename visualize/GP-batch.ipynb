# %% [markdown]
# # Library

# %%
import numpy as np
import torch
import gpytorch
import argparse
import time
import pickle
import scipy.io as sio

from torch.distributions import Normal
import matplotlib.pyplot as plt
import random

import roslib
import rospy
import tf as tf_ros
from nav_msgs.msg import Odometry, Path
from sensor_msgs.msg import Image
from cv_bridge import CvBridge
from geometry_msgs.msg import PoseStamped, PoseArray, Pose
import math
import cv2
import copy

import sys
sys.path.append('..')
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'

# %% [markdown]
# ## Check GPU

# %%
import torch
import numpy as np
import sys
sys.path.append('..')

from torchlib.utils import list_device,set_device

# S1: check GPU
#list_device()

# S2: default parameters
set_device(1)
np.set_printoptions(precision = 2)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, default=420, help='size of mini batch')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data normalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')

parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/gp_net_torch', help='rnn, gru, or lstm')

parser.add_argument('--test_dataset', type=str, default=[# '/notebooks/michigan_nn_data/2012_01_08',
                                                         # '/notebooks/michigan_nn_data/2012_01_15',
                                                         # '/notebooks/michigan_nn_data/2012_01_22',
                                                         # '/notebooks/michigan_nn_data/2012_02_02',
                                                         # '/notebooks/michigan_nn_data/2012_02_04',
                                                         # '/notebooks/michigan_nn_data/2012_02_05',
                                                         '/notebooks/michigan_nn_data/2012_02_12',
                                                         # '/notebooks/michigan_nn_data/2012_03_31',
                                                         '/notebooks/michigan_nn_data/2012_04_29',
                                                         '/notebooks/michigan_nn_data/2012_05_11',
                                                         '/notebooks/michigan_nn_data/2012_06_15',
                                                         '/notebooks/michigan_nn_data/2012_08_04',
                                                         # '/notebooks/michigan_nn_data/2012_09_28'])
                                                         '/notebooks/michigan_nn_data/2012_10_28',
                                                         '/notebooks/michigan_nn_data/2012_11_16',
                                                         '/notebooks/michigan_nn_data/2012_12_01'
                                                        ] )

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/test'])
parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

#parser.add_argument('--map_dataset', type=str, default='/home/kevin/data/michigan_gt/training')
parser.add_argument('--enable_ros', type=bool, default=False, help='put data into ros')
parser.add_argument('--cuda_device', type=int, default=1, help='cuda device')

sys.argv = ['']
args = parser.parse_args()

if args.enable_ros:
    rospy.init_node('global_localization_tf_broadcaster_cnn')

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
#from PIL import Image
import numpy as np
import random

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet, cnn_auxiliary
from torchlib.cnn_auxiliary import normalize, denormalize, denormalize_navie, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

transform = transforms.Compose([transforms.ToTensor()])
dataset = LocalizationDataset(dataset_dirs = args.test_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform,
                              get_pair = False, mode='evaluate', sampling_rate=1)

[args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
print('Load norm and std:',*args.norm_tensor)

dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=False, num_workers=0, \
                        drop_last=False, pin_memory=True)
# Out:
# 100%|██████████| 28602/28602 [00:36<00:00, 775.61it/s]
# 100%|██████████| 14016/14016 [00:18<00:00, 769.39it/s]
# 100%|██████████| 25704/25704 [00:33<00:00, 777.36it/s]
# 100%|██████████| 19135/19135 [00:24<00:00, 768.91it/s]
# 100%|██████████| 27160/27160 [00:38<00:00, 705.63it/s]
# 100%|██████████| 29670/29670 [00:53<00:00, 556.70it/s]
# 100%|██████████| 14229/14229 [00:26<00:00, 536.53it/s]
# 100%|██████████| 25367/25367 [00:50<00:00, 502.80it/s]
# Load norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # Define Model

# %%
from torch.cuda.amp import autocast, GradScaler
from torchlib.GPs import Backbone, NN, BaseModule

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.MultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([1]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([1])),
            batch_shape=torch.Size([1]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        inducing_points = torch.zeros(3, 300, 128)
        self.backbone = Backbone()
        self.nn = NN()
        self.gp = GP(inducing_points)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=3)
        
    def forward(self, input_data):
        dense_feat = self.backbone(input_data)
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention 
        trans_pred = self.gp(feature_t)
        return trans_pred, rot_pred

class PosePredictor(BaseModule):
    def __init__(self, norm_mean, norm_std, args,
                 is_training=True, mixed_precision=True,
                 regressor_context_rate = [0.0,0.0], train_rot = False):
        super().__init__(norm_mean, norm_std, args)
        self.model = Model().to(self.device)
        self.train_rot = train_rot
        self.mixed_precision = mixed_precision
        if self.mixed_precision:
            self.scaler = GradScaler()

        self.disable_requires_grad(self.model.backbone)
        
        if is_training:
            self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
            self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                             lr_lambda=lambda epoch: args.decay_rate**epoch)
            num_data = min(len(dataloader)*args.batch_size,len(dataset))
            self.mll = gpytorch.mlls.PredictiveLogLikelihood(self.model.likelihood, \
                                                         self.model.gp, num_data = num_data)
        else:
            self.disable_requires_grad(self.model)
            
    def _optimize(self,regressor_context_rate):
        # GP
        optimizer = [
                {'params': self.model.gp.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay},
                {'params': self.model.likelihood.parameters(), \
                 'lr': args.learning_rate,'weight_decay':args.weight_decay}]
            
        # NN
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            self.disable_requires_grad(self.model.nn.global_regressor)
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
            self.train_rot = True
        else:
            self.disable_requires_grad(self.model.nn.global_context)
            
        
        if not self.train_rot and regressor_context_rate[1]==0.0:
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc1_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc2_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc3_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.logits_r)
                
        return optimizer
    
    def train(self,x, y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        if args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
            
        # Step 2: training
        assert trainer.model.training == True
        if self.mixed_precision:
            with autocast():
                single_loss = self._loss(x, y)
            self.scaler.scale(single_loss).backward()
            self.scaler.step(self.optimizer)
            self.scaler.update()
        else:
            single_loss = self._loss(x, y)
            single_loss.backward()
            self.optimizer.step()
            
        batch_time = time.time() - start
        
        return float(single_loss), batch_time
    
    def _loss(self,x, y):
        # target
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        # predict
        trans_pred, rot_pred = self.model(x)
        
        # trans loss
        trans_loss = -1.*self.mll(trans_pred, trans_target)
        # rot loss
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        
        total_loss = trans_loss + args.lamda_weights * rot_loss      
        
        return total_loss
    
    def eval_forward(self,x,y,num_sample = 100,output_denormalize = True):
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        
        # Step 2: forward
        assert trainer.model.training == False
        if self.mixed_precision:
            with autocast():
                trans_prediction, rot_prediction = self.model(x)
            self.scaler.scale(trans_prediction)
            self.scaler.scale(rot_prediction)
        else:
            trans_prediction, rot_prediction = self.model(x)
            
        trans_prediction, trans_mean, trans_var = self._eval_gp(trans_prediction)
        
        if args.is_normalization and output_denormalize:
            trans_prediction = denormalize_navie(trans_prediction, self.norm_mean, self.norm_std)
            trans_mean = denormalize_navie(trans_mean, self.norm_mean, self.norm_std)
            trans_var = trans_var.mul(self.norm_std)
        
        samples = self._sample(trans_mean, trans_var, num_sample)
            
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_prediction, rot_prediction, trans_target, rot_target, samples
    
    def _sample(self, mean, var, num_sample = 100):
        dist = torch.distributions.Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples
    
    def _eval_gp(self, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = self.model.likelihood(trans_pred).mean, self.model.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var

# %%
trainer = PosePredictor(args.norm_mean,args.norm_std,args,mixed_precision=False,is_training = False)
trainer.load_model('pretrained.pth')
# Out:
# Transform from old model.
# Successfully loaded model to TITAN Xp.

# %% [markdown]
# # Initialize

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

# %%
trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward(x,y)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 420/183960, translation error = 3.384, rotation error = 2.385, time/batch = 4.953
# 840/183960, translation error = 8.967, rotation error = 3.766, time/batch = 1.071
# 1260/183960, translation error = 7.408, rotation error = 3.446, time/batch = 1.142
# 1680/183960, translation error = 6.481, rotation error = 3.279, time/batch = 1.063
# 2100/183960, translation error = 7.201, rotation error = 3.423, time/batch = 1.067
# 2520/183960, translation error = 6.865, rotation error = 3.498, time/batch = 1.065
# 2940/183960, translation error = 6.380, rotation error = 3.642, time/batch = 1.067
# 3360/183960, translation error = 5.796, rotation error = 3.658, time/batch = 1.064
# 3780/183960, translation error = 5.382, rotation error = 3.602, time/batch = 1.070
# 4200/183960, translation error = 5.295, rotation error = 3.730, time/batch = 1.073
# 4620/183960, translation error = 4.991, rotation error = 3.701, time/batch = 1.065
# 5040/183960, translation error = 4.800, rotation error = 3.723, time/batch = 1.073
# 5460/183960, translation error = 4.629, rotation error = 3.745, time/batch = 1.069
# 5880/183960, translation error = 4.479, rotation error = 3.707, time/batch = 1.068
# 6300/183960, translation error = 4.325, rotation error = 3.686, time/batch = 1.076
# 6720/183960, translation error = 4.281, rotation error = 3.756, time/batch = 1.066
# 7140/183960, translation error = 4.130, rotation error = 3.705, time/batch = 1.076
# 7560/183960, translation error = 4.009, rotation error = 3.652, time/batch = 1.070
# 7980/183960, translation error = 3.845, rotation error = 3.602, time/batch = 1.072
# 8400/183960, translation error = 3.705, rotation error = 3.562, time/batch = 1.066
# 8820/183960, translation error = 3.575, rotation error = 3.551, time/batch = 1.069
# 9240/183960, translation error = 3.476, rotation error = 3.527, time/batch = 1.080
# 9660/183960, translation error = 3.358, rotation error = 3.488, time/batch = 1.070
# 10080/183960, translation error = 3.274, rotation error = 3.517, time/batch = 1.079
# 10500/183960, translation error = 3.285, rotation error = 3.520, time/batch = 1.075
# 10920/183960, translation error = 3.201, rotation error = 3.475, time/batch = 1.075
# 11340/183960, translation error = 3.148, rotation error = 3.434, time/batch = 1.077
# 11760/183960, translation error = 3.146, rotation error = 3.430, time/batch = 1.072
# 12180/183960, translation error = 3.108, rotation error = 3.405, time/batch = 1.074
# 12600/183960, translation error = 3.062, rotation error = 3.349, time/batch = 1.072
# 13020/183960, translation error = 3.065, rotation error = 3.375, time/batch = 1.073
# 13440/183960, translation error = 5.127, rotation error = 3.731, time/batch = 1.069
# 13860/183960, translation error = 5.273, rotation error = 4.062, time/batch = 1.079
# 14280/183960, translation error = 5.184, rotation error = 4.040, time/batch = 1.077
# 14700/183960, translation error = 5.079, rotation error = 4.089, time/batch = 1.079
# 15120/183960, translation error = 5.005, rotation error = 4.092, time/batch = 1.068
# 15540/183960, translation error = 5.064, rotation error = 4.158, time/batch = 1.078
# 15960/183960, translation error = 5.075, rotation error = 4.136, time/batch = 1.077
# 16380/183960, translation error = 5.095, rotation error = 4.124, time/batch = 1.086
# 16800/183960, translation error = 5.654, rotation error = 4.230, time/batch = 1.074
# 17220/183960, translation error = 5.578, rotation error = 4.237, time/batch = 1.084
# 17640/183960, translation error = 5.490, rotation error = 4.194, time/batch = 1.076
# 18060/183960, translation error = 5.411, rotation error = 4.187, time/batch = 1.075
# 18480/183960, translation error = 5.355, rotation error = 4.173, time/batch = 1.075
# 18900/183960, translation error = 5.305, rotation error = 4.126, time/batch = 1.082
# 19320/183960, translation error = 5.239, rotation error = 4.102, time/batch = 1.080
# 19740/183960, translation error = 5.177, rotation error = 4.093, time/batch = 1.084
# 20160/183960, translation error = 5.144, rotation error = 4.090, time/batch = 1.080
# 20580/183960, translation error = 5.065, rotation error = 4.137, time/batch = 1.080
# 21000/183960, translation error = 5.002, rotation error = 4.170, time/batch = 1.076
# 21420/183960, translation error = 4.944, rotation error = 4.166, time/batch = 1.074
# 21840/183960, translation error = 4.890, rotation error = 4.170, time/batch = 1.089
# 22260/183960, translation error = 4.841, rotation error = 4.141, time/batch = 1.080
# 22680/183960, translation error = 4.783, rotation error = 4.102, time/batch = 1.091
# 23100/183960, translation error = 4.721, rotation error = 4.067, time/batch = 1.083
# 23520/183960, translation error = 4.657, rotation error = 4.031, time/batch = 1.078
# 23940/183960, translation error = 4.601, rotation error = 4.017, time/batch = 1.078
# 24360/183960, translation error = 4.540, rotation error = 3.985, time/batch = 1.077
# 24780/183960, translation error = 4.493, rotation error = 3.973, time/batch = 1.084
# 25200/183960, translation error = 4.436, rotation error = 3.949, time/batch = 1.080
# 25620/183960, translation error = 4.402, rotation error = 3.975, time/batch = 1.077
# 26040/183960, translation error = 4.345, rotation error = 3.948, time/batch = 1.075
# 26460/183960, translation error = 4.429, rotation error = 3.973, time/batch = 1.087
# 26880/183960, translation error = 4.393, rotation error = 3.957, time/batch = 1.079
# 27300/183960, translation error = 4.347, rotation error = 3.926, time/batch = 1.082
# 27720/183960, translation error = 4.325, rotation error = 3.927, time/batch = 1.083
# 28140/183960, translation error = 4.290, rotation error = 3.924, time/batch = 1.084
# 28560/183960, translation error = 4.259, rotation error = 3.941, time/batch = 1.081
# 28980/183960, translation error = 4.237, rotation error = 3.935, time/batch = 1.084
# 29400/183960, translation error = 4.207, rotation error = 3.915, time/batch = 1.076
# 29820/183960, translation error = 4.198, rotation error = 3.914, time/batch = 1.079
# 30240/183960, translation error = 4.176, rotation error = 3.911, time/batch = 1.097
# 30660/183960, translation error = 4.155, rotation error = 3.887, time/batch = 1.079
# 31080/183960, translation error = 4.131, rotation error = 3.869, time/batch = 1.092
# 31500/183960, translation error = 5.108, rotation error = 4.090, time/batch = 1.078
# 31920/183960, translation error = 5.080, rotation error = 4.090, time/batch = 1.083
# 32340/183960, translation error = 5.054, rotation error = 4.103, time/batch = 1.081
# 32760/183960, translation error = 5.018, rotation error = 4.083, time/batch = 1.078
# 33180/183960, translation error = 4.987, rotation error = 4.108, time/batch = 1.085
# 33600/183960, translation error = 4.952, rotation error = 4.124, time/batch = 1.082
# 34020/183960, translation error = 4.915, rotation error = 4.127, time/batch = 1.080
# 34440/183960, translation error = 4.882, rotation error = 4.116, time/batch = 1.079
# 34860/183960, translation error = 4.841, rotation error = 4.094, time/batch = 1.077
# 35280/183960, translation error = 4.801, rotation error = 4.080, time/batch = 1.092
# 35700/183960, translation error = 4.782, rotation error = 4.089, time/batch = 1.080
# 36120/183960, translation error = 4.755, rotation error = 4.102, time/batch = 1.083
# 36540/183960, translation error = 4.725, rotation error = 4.125, time/batch = 1.088
# 36960/183960, translation error = 4.697, rotation error = 4.112, time/batch = 1.084
# 37380/183960, translation error = 4.663, rotation error = 4.123, time/batch = 1.095
# 37800/183960, translation error = 4.632, rotation error = 4.123, time/batch = 1.081
# 38220/183960, translation error = 4.604, rotation error = 4.107, time/batch = 1.083
# 38640/183960, translation error = 4.582, rotation error = 4.097, time/batch = 1.083
# 39060/183960, translation error = 4.569, rotation error = 4.095, time/batch = 1.090
# 39480/183960, translation error = 4.548, rotation error = 4.102, time/batch = 1.084
# 39900/183960, translation error = 4.521, rotation error = 4.093, time/batch = 1.087
# 40320/183960, translation error = 4.494, rotation error = 4.089, time/batch = 1.082
# 40740/183960, translation error = 4.462, rotation error = 4.071, time/batch = 1.095
# 41160/183960, translation error = 4.431, rotation error = 4.068, time/batch = 1.092
# 41580/183960, translation error = 4.407, rotation error = 4.059, time/batch = 1.083
# 42000/183960, translation error = 4.376, rotation error = 4.053, time/batch = 1.082
# 42420/183960, translation error = 4.346, rotation error = 4.057, time/batch = 1.084
# 42840/183960, translation error = 4.322, rotation error = 4.048, time/batch = 1.088
# 43260/183960, translation error = 4.399, rotation error = 4.055, time/batch = 1.078
# 43680/183960, translation error = 5.941, rotation error = 4.222, time/batch = 1.095
# 44100/183960, translation error = 7.978, rotation error = 4.867, time/batch = 1.083
# 44520/183960, translation error = 9.922, rotation error = 5.271, time/batch = 1.087
# 44940/183960, translation error = 9.927, rotation error = 5.252, time/batch = 1.083
# 45360/183960, translation error = 9.872, rotation error = 5.235, time/batch = 1.082
# 45780/183960, translation error = 9.799, rotation error = 5.220, time/batch = 1.084
# 46200/183960, translation error = 9.754, rotation error = 5.226, time/batch = 1.086
# 46620/183960, translation error = 9.686, rotation error = 5.204, time/batch = 1.089
# 47040/183960, translation error = 9.620, rotation error = 5.195, time/batch = 1.085
# 47460/183960, translation error = 9.552, rotation error = 5.187, time/batch = 1.087
# 47880/183960, translation error = 9.488, rotation error = 5.173, time/batch = 1.085
# 48300/183960, translation error = 9.478, rotation error = 5.180, time/batch = 1.080
# 48720/183960, translation error = 9.419, rotation error = 5.174, time/batch = 1.086
# 49140/183960, translation error = 9.362, rotation error = 5.175, time/batch = 1.088
# 49560/183960, translation error = 9.332, rotation error = 5.182, time/batch = 1.089
# 49980/183960, translation error = 9.264, rotation error = 5.169, time/batch = 1.083
# 50400/183960, translation error = 9.205, rotation error = 5.159, time/batch = 1.086
# 50820/183960, translation error = 9.146, rotation error = 5.147, time/batch = 1.087
# 51240/183960, translation error = 9.080, rotation error = 5.136, time/batch = 1.082
# 51660/183960, translation error = 9.021, rotation error = 5.135, time/batch = 1.095
# 52080/183960, translation error = 8.966, rotation error = 5.129, time/batch = 1.087
# 52500/183960, translation error = 8.909, rotation error = 5.108, time/batch = 1.086
# 52920/183960, translation error = 8.848, rotation error = 5.100, time/batch = 1.093
# 53340/183960, translation error = 8.795, rotation error = 5.084, time/batch = 1.082
# 53760/183960, translation error = 8.805, rotation error = 5.088, time/batch = 1.084
# 54180/183960, translation error = 8.750, rotation error = 5.066, time/batch = 1.084
# 54600/183960, translation error = 8.705, rotation error = 5.043, time/batch = 1.080
# 55020/183960, translation error = 8.661, rotation error = 5.026, time/batch = 1.082
# 55440/183960, translation error = 8.612, rotation error = 5.003, time/batch = 1.084
# 55860/183960, translation error = 8.565, rotation error = 4.992, time/batch = 1.080
# 56280/183960, translation error = 8.517, rotation error = 4.974, time/batch = 1.085
# 56700/183960, translation error = 8.481, rotation error = 4.967, time/batch = 1.079
# 57120/183960, translation error = 8.439, rotation error = 4.957, time/batch = 1.087
# 57540/183960, translation error = 8.410, rotation error = 4.946, time/batch = 1.086
# 57960/183960, translation error = 8.384, rotation error = 5.016, time/batch = 1.087
# 58380/183960, translation error = 8.492, rotation error = 5.055, time/batch = 1.086
# 58800/183960, translation error = 8.499, rotation error = 5.054, time/batch = 1.085
# 59220/183960, translation error = 8.453, rotation error = 5.030, time/batch = 1.086
# 59640/183960, translation error = 8.410, rotation error = 5.017, time/batch = 1.086
# 60060/183960, translation error = 8.397, rotation error = 5.010, time/batch = 1.090
# 60480/183960, translation error = 8.360, rotation error = 5.003, time/batch = 1.083
# 60900/183960, translation error = 8.321, rotation error = 4.990, time/batch = 1.098
# 61320/183960, translation error = 8.280, rotation error = 4.982, time/batch = 1.086
# 61740/183960, translation error = 8.234, rotation error = 4.975, time/batch = 1.101
# 62160/183960, translation error = 8.192, rotation error = 4.987, time/batch = 1.078
# 62580/183960, translation error = 8.158, rotation error = 4.980, time/batch = 1.088
# 63000/183960, translation error = 8.114, rotation error = 4.967, time/batch = 1.084
# 63420/183960, translation error = 8.074, rotation error = 4.958, time/batch = 1.086
# 63840/183960, translation error = 8.035, rotation error = 4.937, time/batch = 1.088
# 64260/183960, translation error = 8.001, rotation error = 4.931, time/batch = 1.093
# 64680/183960, translation error = 7.963, rotation error = 4.923, time/batch = 1.089
# 65100/183960, translation error = 7.925, rotation error = 4.920, time/batch = 1.082
# 65520/183960, translation error = 7.885, rotation error = 4.912, time/batch = 1.081
# 65940/183960, translation error = 7.843, rotation error = 4.900, time/batch = 1.088
# 66360/183960, translation error = 7.808, rotation error = 4.888, time/batch = 1.087
# 66780/183960, translation error = 7.781, rotation error = 4.882, time/batch = 1.090
# 67200/183960, translation error = 7.741, rotation error = 4.870, time/batch = 1.084
# 67620/183960, translation error = 7.719, rotation error = 4.865, time/batch = 1.092
# 68040/183960, translation error = 7.683, rotation error = 4.856, time/batch = 1.085
# 68460/183960, translation error = 8.123, rotation error = 4.971, time/batch = 1.095
# 68880/183960, translation error = 9.008, rotation error = 5.130, time/batch = 1.085
# 69300/183960, translation error = 8.975, rotation error = 5.115, time/batch = 1.091
# 69720/183960, translation error = 8.940, rotation error = 5.099, time/batch = 1.083
# 70140/183960, translation error = 8.903, rotation error = 5.091, time/batch = 1.083
# 70560/183960, translation error = 8.872, rotation error = 5.079, time/batch = 1.085
# 70980/183960, translation error = 10.079, rotation error = 5.298, time/batch = 1.084
# 71400/183960, translation error = 10.095, rotation error = 5.285, time/batch = 1.085
# 71820/183960, translation error = 10.055, rotation error = 5.273, time/batch = 1.083
# 72240/183960, translation error = 10.011, rotation error = 5.266, time/batch = 1.084
# 72660/183960, translation error = 9.986, rotation error = 5.272, time/batch = 1.083
# 73080/183960, translation error = 9.947, rotation error = 5.261, time/batch = 1.085
# 73500/183960, translation error = 9.909, rotation error = 5.260, time/batch = 1.086
# 73920/183960, translation error = 9.861, rotation error = 5.255, time/batch = 1.086
# 74340/183960, translation error = 9.819, rotation error = 5.241, time/batch = 1.086
# 74760/183960, translation error = 9.773, rotation error = 5.230, time/batch = 1.081
# 75180/183960, translation error = 9.727, rotation error = 5.218, time/batch = 1.084
# 75600/183960, translation error = 9.683, rotation error = 5.211, time/batch = 1.082
# 76020/183960, translation error = 9.644, rotation error = 5.212, time/batch = 1.095
# 76440/183960, translation error = 9.604, rotation error = 5.211, time/batch = 1.090
# 76860/183960, translation error = 9.560, rotation error = 5.197, time/batch = 1.087
# 77280/183960, translation error = 9.515, rotation error = 5.192, time/batch = 1.095
# 77700/183960, translation error = 9.476, rotation error = 5.188, time/batch = 1.090
# 78120/183960, translation error = 9.444, rotation error = 5.184, time/batch = 1.085
# 78540/183960, translation error = 9.404, rotation error = 5.172, time/batch = 1.086
# 78960/183960, translation error = 9.372, rotation error = 5.178, time/batch = 1.082
# 79380/183960, translation error = 9.333, rotation error = 5.169, time/batch = 1.089
# 79800/183960, translation error = 9.303, rotation error = 5.165, time/batch = 1.091
# 80220/183960, translation error = 9.261, rotation error = 5.154, time/batch = 1.085
# 80640/183960, translation error = 9.224, rotation error = 5.148, time/batch = 1.086
# 81060/183960, translation error = 9.185, rotation error = 5.140, time/batch = 1.088
# 81480/183960, translation error = 9.145, rotation error = 5.136, time/batch = 1.089
# 81900/183960, translation error = 9.105, rotation error = 5.137, time/batch = 1.082
# 82320/183960, translation error = 9.072, rotation error = 5.137, time/batch = 1.089
# 82740/183960, translation error = 9.038, rotation error = 5.131, time/batch = 1.086
# 83160/183960, translation error = 9.003, rotation error = 5.127, time/batch = 1.086
# 83580/183960, translation error = 8.964, rotation error = 5.122, time/batch = 1.089
# 84000/183960, translation error = 8.930, rotation error = 5.121, time/batch = 1.080
# 84420/183960, translation error = 8.975, rotation error = 5.127, time/batch = 1.085
# 84840/183960, translation error = 8.948, rotation error = 5.111, time/batch = 1.086
# 85260/183960, translation error = 8.920, rotation error = 5.097, time/batch = 1.088
# 85680/183960, translation error = 8.889, rotation error = 5.082, time/batch = 1.085
# 86100/183960, translation error = 8.857, rotation error = 5.067, time/batch = 1.087
# 86520/183960, translation error = 8.823, rotation error = 5.062, time/batch = 1.086
# 86940/183960, translation error = 8.803, rotation error = 5.049, time/batch = 1.084
# 87360/183960, translation error = 8.819, rotation error = 5.077, time/batch = 1.081
# 87780/183960, translation error = 8.809, rotation error = 5.073, time/batch = 1.083
# 88200/183960, translation error = 8.778, rotation error = 5.069, time/batch = 1.089
# 88620/183960, translation error = 8.776, rotation error = 5.093, time/batch = 1.084
# 89040/183960, translation error = 8.752, rotation error = 5.079, time/batch = 1.087
# 89460/183960, translation error = 8.730, rotation error = 5.082, time/batch = 1.088
# 89880/183960, translation error = 8.701, rotation error = 5.076, time/batch = 1.088
# 90300/183960, translation error = 8.668, rotation error = 5.074, time/batch = 1.087
# 90720/183960, translation error = 8.641, rotation error = 5.069, time/batch = 1.086
# 91140/183960, translation error = 8.608, rotation error = 5.056, time/batch = 1.087
# 91560/183960, translation error = 8.593, rotation error = 5.060, time/batch = 1.096
# 91980/183960, translation error = 8.566, rotation error = 5.057, time/batch = 1.085
# 92400/183960, translation error = 8.540, rotation error = 5.063, time/batch = 1.085
# 92820/183960, translation error = 8.517, rotation error = 5.061, time/batch = 1.085
# 93240/183960, translation error = 8.492, rotation error = 5.053, time/batch = 1.089
# 93660/183960, translation error = 8.469, rotation error = 5.045, time/batch = 1.089
# 94080/183960, translation error = 8.448, rotation error = 5.043, time/batch = 1.093
# 94500/183960, translation error = 8.420, rotation error = 5.034, time/batch = 1.090
# 94920/183960, translation error = 8.419, rotation error = 5.029, time/batch = 1.100
# 95340/183960, translation error = 8.389, rotation error = 5.020, time/batch = 1.095
# 95760/183960, translation error = 8.359, rotation error = 5.015, time/batch = 1.094
# 96180/183960, translation error = 8.331, rotation error = 5.017, time/batch = 1.091
# 96600/183960, translation error = 8.304, rotation error = 5.009, time/batch = 1.084
# 97020/183960, translation error = 8.279, rotation error = 5.001, time/batch = 1.101
# 97440/183960, translation error = 8.259, rotation error = 4.990, time/batch = 1.090
# 97860/183960, translation error = 8.233, rotation error = 4.978, time/batch = 1.084
# 98280/183960, translation error = 8.209, rotation error = 4.969, time/batch = 1.089
# 98700/183960, translation error = 8.185, rotation error = 4.961, time/batch = 1.084
# 99120/183960, translation error = 8.156, rotation error = 4.959, time/batch = 1.088
# 99540/183960, translation error = 8.134, rotation error = 4.949, time/batch = 1.088
# 99960/183960, translation error = 8.117, rotation error = 4.945, time/batch = 1.083
# 100380/183960, translation error = 8.095, rotation error = 4.938, time/batch = 1.090
# 100800/183960, translation error = 8.073, rotation error = 4.931, time/batch = 1.089
# 101220/183960, translation error = 8.137, rotation error = 4.965, time/batch = 1.086
# 101640/183960, translation error = 9.158, rotation error = 5.071, time/batch = 1.093
# 102060/183960, translation error = 9.147, rotation error = 5.098, time/batch = 1.100
# 102480/183960, translation error = 9.118, rotation error = 5.089, time/batch = 1.094
# 102900/183960, translation error = 9.090, rotation error = 5.083, time/batch = 1.087
# 103320/183960, translation error = 9.062, rotation error = 5.076, time/batch = 1.084
# 103740/183960, translation error = 9.032, rotation error = 5.084, time/batch = 1.089
# 104160/183960, translation error = 9.005, rotation error = 5.081, time/batch = 1.085
# 104580/183960, translation error = 8.994, rotation error = 5.086, time/batch = 1.083
# 105000/183960, translation error = 8.969, rotation error = 5.087, time/batch = 1.094
# 105420/183960, translation error = 8.944, rotation error = 5.075, time/batch = 1.087
# 105840/183960, translation error = 8.917, rotation error = 5.065, time/batch = 1.090
# 106260/183960, translation error = 8.890, rotation error = 5.056, time/batch = 1.097
# 106680/183960, translation error = 8.871, rotation error = 5.081, time/batch = 1.089
# 107100/183960, translation error = 8.848, rotation error = 5.086, time/batch = 1.085
# 107520/183960, translation error = 8.819, rotation error = 5.079, time/batch = 1.081
# 107940/183960, translation error = 8.790, rotation error = 5.075, time/batch = 1.083
# 108360/183960, translation error = 8.834, rotation error = 5.080, time/batch = 1.083
# 108780/183960, translation error = 8.844, rotation error = 5.088, time/batch = 1.088
# 109200/183960, translation error = 8.823, rotation error = 5.081, time/batch = 1.086
# 109620/183960, translation error = 8.796, rotation error = 5.079, time/batch = 1.084
# 110040/183960, translation error = 8.773, rotation error = 5.076, time/batch = 1.084
# 110460/183960, translation error = 8.747, rotation error = 5.071, time/batch = 1.088
# 110880/183960, translation error = 8.726, rotation error = 5.076, time/batch = 1.087
# 111300/183960, translation error = 8.700, rotation error = 5.067, time/batch = 1.085
# 111720/183960, translation error = 8.967, rotation error = 5.115, time/batch = 1.081
# 112140/183960, translation error = 9.049, rotation error = 5.163, time/batch = 1.085
# 112560/183960, translation error = 9.116, rotation error = 5.205, time/batch = 1.087
# 112980/183960, translation error = 9.098, rotation error = 5.208, time/batch = 1.088
# 113400/183960, translation error = 9.078, rotation error = 5.208, time/batch = 1.085
# 113820/183960, translation error = 9.061, rotation error = 5.204, time/batch = 1.087
# 114240/183960, translation error = 9.037, rotation error = 5.207, time/batch = 1.081
# 114660/183960, translation error = 9.015, rotation error = 5.210, time/batch = 1.080
# 115080/183960, translation error = 9.844, rotation error = 5.241, time/batch = 1.086
# 115500/183960, translation error = 9.824, rotation error = 5.241, time/batch = 1.084
# 115920/183960, translation error = 9.796, rotation error = 5.243, time/batch = 1.091
# 116340/183960, translation error = 9.773, rotation error = 5.241, time/batch = 1.093
# 116760/183960, translation error = 9.761, rotation error = 5.243, time/batch = 1.091
# 117180/183960, translation error = 9.760, rotation error = 5.249, time/batch = 1.089
# 117600/183960, translation error = 9.731, rotation error = 5.240, time/batch = 1.088
# 118020/183960, translation error = 9.702, rotation error = 5.235, time/batch = 1.087
# 118440/183960, translation error = 9.674, rotation error = 5.237, time/batch = 1.088
# 118860/183960, translation error = 9.649, rotation error = 5.234, time/batch = 1.085
# 119280/183960, translation error = 9.624, rotation error = 5.226, time/batch = 1.084
# 119700/183960, translation error = 9.598, rotation error = 5.222, time/batch = 1.088
# 120120/183960, translation error = 9.571, rotation error = 5.217, time/batch = 1.097
# 120540/183960, translation error = 9.546, rotation error = 5.209, time/batch = 1.091
# 120960/183960, translation error = 9.524, rotation error = 5.209, time/batch = 1.089
# 121380/183960, translation error = 9.499, rotation error = 5.201, time/batch = 1.095
# 121800/183960, translation error = 9.475, rotation error = 5.197, time/batch = 1.084
# 122220/183960, translation error = 9.459, rotation error = 5.192, time/batch = 1.091
# 122640/183960, translation error = 9.435, rotation error = 5.190, time/batch = 1.087
# 123060/183960, translation error = 9.574, rotation error = 5.245, time/batch = 1.084
# 123480/183960, translation error = 9.771, rotation error = 5.354, time/batch = 1.088
# 123900/183960, translation error = 9.745, rotation error = 5.354, time/batch = 1.089
# 124320/183960, translation error = 9.728, rotation error = 5.353, time/batch = 1.084
# 124740/183960, translation error = 9.702, rotation error = 5.348, time/batch = 1.092
# 125160/183960, translation error = 9.676, rotation error = 5.338, time/batch = 1.086
# 125580/183960, translation error = 9.651, rotation error = 5.336, time/batch = 1.088
# 126000/183960, translation error = 9.626, rotation error = 5.334, time/batch = 1.082
# 126420/183960, translation error = 9.623, rotation error = 5.346, time/batch = 1.079
# 126840/183960, translation error = 9.613, rotation error = 5.352, time/batch = 1.088
# 127260/183960, translation error = 9.586, rotation error = 5.344, time/batch = 1.086
# 127680/183960, translation error = 9.563, rotation error = 5.336, time/batch = 1.083
# 128100/183960, translation error = 9.565, rotation error = 5.341, time/batch = 1.089
# 128520/183960, translation error = 10.139, rotation error = 5.520, time/batch = 1.085
# 128940/183960, translation error = 10.158, rotation error = 5.576, time/batch = 1.085
# 129360/183960, translation error = 10.135, rotation error = 5.579, time/batch = 1.086
# 129780/183960, translation error = 10.111, rotation error = 5.568, time/batch = 1.085
# 130200/183960, translation error = 10.098, rotation error = 5.577, time/batch = 1.086
# 130620/183960, translation error = 10.074, rotation error = 5.569, time/batch = 1.085
# 131040/183960, translation error = 10.047, rotation error = 5.560, time/batch = 1.087
# 131460/183960, translation error = 10.027, rotation error = 5.555, time/batch = 1.088
# 131880/183960, translation error = 10.012, rotation error = 5.568, time/batch = 1.091
# 132300/183960, translation error = 9.991, rotation error = 5.564, time/batch = 1.087
# 132720/183960, translation error = 9.967, rotation error = 5.558, time/batch = 1.087
# 133140/183960, translation error = 9.945, rotation error = 5.553, time/batch = 1.086
# 133560/183960, translation error = 9.964, rotation error = 5.574, time/batch = 1.090
# 133980/183960, translation error = 9.939, rotation error = 5.573, time/batch = 1.085
# 134400/183960, translation error = 9.929, rotation error = 5.576, time/batch = 1.083
# 134820/183960, translation error = 9.908, rotation error = 5.594, time/batch = 1.093
# 135240/183960, translation error = 9.892, rotation error = 5.601, time/batch = 1.085
# 135660/183960, translation error = 9.868, rotation error = 5.591, time/batch = 1.093
# 136080/183960, translation error = 9.842, rotation error = 5.580, time/batch = 1.096
# 136500/183960, translation error = 9.820, rotation error = 5.573, time/batch = 1.092
# 136920/183960, translation error = 9.798, rotation error = 5.585, time/batch = 1.087
# 137340/183960, translation error = 9.778, rotation error = 5.580, time/batch = 1.086
# 137760/183960, translation error = 9.754, rotation error = 5.569, time/batch = 1.084
# 138180/183960, translation error = 9.740, rotation error = 5.576, time/batch = 1.083
# 138600/183960, translation error = 9.741, rotation error = 5.582, time/batch = 1.084
# 139020/183960, translation error = 9.737, rotation error = 5.580, time/batch = 1.089
# 139440/183960, translation error = 9.721, rotation error = 5.572, time/batch = 1.087
# 139860/183960, translation error = 9.735, rotation error = 5.570, time/batch = 1.086
# 140280/183960, translation error = 9.715, rotation error = 5.563, time/batch = 1.096
# 140700/183960, translation error = 9.691, rotation error = 5.559, time/batch = 1.080
# 141120/183960, translation error = 9.666, rotation error = 5.550, time/batch = 1.085
# 141540/183960, translation error = 9.643, rotation error = 5.544, time/batch = 1.090
# 141960/183960, translation error = 9.624, rotation error = 5.540, time/batch = 1.088
# 142380/183960, translation error = 9.599, rotation error = 5.534, time/batch = 1.084
# 142800/183960, translation error = 9.575, rotation error = 5.527, time/batch = 1.100
# 143220/183960, translation error = 9.553, rotation error = 5.519, time/batch = 1.087
# 143640/183960, translation error = 9.532, rotation error = 5.511, time/batch = 1.083
# 144060/183960, translation error = 9.513, rotation error = 5.505, time/batch = 1.089
# 144480/183960, translation error = 9.493, rotation error = 5.499, time/batch = 1.081
# 144900/183960, translation error = 9.472, rotation error = 5.492, time/batch = 1.085
# 145320/183960, translation error = 9.451, rotation error = 5.486, time/batch = 1.083
# 145740/183960, translation error = 9.431, rotation error = 5.484, time/batch = 1.089
# 146160/183960, translation error = 9.411, rotation error = 5.488, time/batch = 1.088
# 146580/183960, translation error = 9.392, rotation error = 5.480, time/batch = 1.085
# 147000/183960, translation error = 9.372, rotation error = 5.479, time/batch = 1.087
# 147420/183960, translation error = 9.376, rotation error = 5.479, time/batch = 1.087
# 147840/183960, translation error = 9.363, rotation error = 5.483, time/batch = 1.089
# 148260/183960, translation error = 9.345, rotation error = 5.478, time/batch = 1.091
# 148680/183960, translation error = 9.322, rotation error = 5.473, time/batch = 1.090
# 149100/183960, translation error = 9.538, rotation error = 5.613, time/batch = 1.086
# 149520/183960, translation error = 9.584, rotation error = 5.654, time/batch = 1.083
# 149940/183960, translation error = 9.567, rotation error = 5.653, time/batch = 1.090
# 150360/183960, translation error = 9.601, rotation error = 5.679, time/batch = 1.088
# 150780/183960, translation error = 9.752, rotation error = 5.713, time/batch = 1.087
# 151200/183960, translation error = 9.734, rotation error = 5.708, time/batch = 1.090
# 151620/183960, translation error = 9.714, rotation error = 5.701, time/batch = 1.087
# 152040/183960, translation error = 9.698, rotation error = 5.694, time/batch = 1.087
# 152460/183960, translation error = 9.682, rotation error = 5.691, time/batch = 1.081
# 152880/183960, translation error = 9.661, rotation error = 5.683, time/batch = 1.092
# 153300/183960, translation error = 9.640, rotation error = 5.674, time/batch = 1.090
# 153720/183960, translation error = 9.644, rotation error = 5.675, time/batch = 1.095
# 154140/183960, translation error = 9.636, rotation error = 5.675, time/batch = 1.091
# 154560/183960, translation error = 9.665, rotation error = 5.676, time/batch = 1.090
# 154980/183960, translation error = 9.913, rotation error = 5.736, time/batch = 1.100
# 155400/183960, translation error = 10.138, rotation error = 5.784, time/batch = 1.085
# 155820/183960, translation error = 10.198, rotation error = 5.851, time/batch = 1.085
# 156240/183960, translation error = 10.268, rotation error = 5.867, time/batch = 1.089
# 156660/183960, translation error = 10.310, rotation error = 5.877, time/batch = 1.089
# 157080/183960, translation error = 10.339, rotation error = 5.890, time/batch = 1.088
# 157500/183960, translation error = 10.335, rotation error = 5.903, time/batch = 1.088
# 157920/183960, translation error = 10.408, rotation error = 5.921, time/batch = 1.089
# 158340/183960, translation error = 10.548, rotation error = 6.040, time/batch = 1.089
# 158760/183960, translation error = 10.586, rotation error = 6.124, time/batch = 1.092
# 159180/183960, translation error = 11.096, rotation error = 6.134, time/batch = 1.086
# 159600/183960, translation error = 11.074, rotation error = 6.141, time/batch = 1.081
# 160020/183960, translation error = 11.052, rotation error = 6.148, time/batch = 1.085
# 160440/183960, translation error = 11.034, rotation error = 6.153, time/batch = 1.091
# 160860/183960, translation error = 11.014, rotation error = 6.149, time/batch = 1.087
# 161280/183960, translation error = 11.110, rotation error = 6.208, time/batch = 1.084
# 161700/183960, translation error = 11.095, rotation error = 6.212, time/batch = 1.091
# 162120/183960, translation error = 11.080, rotation error = 6.220, time/batch = 1.087
# 162540/183960, translation error = 11.101, rotation error = 6.270, time/batch = 1.079
# 162960/183960, translation error = 11.148, rotation error = 6.283, time/batch = 1.086
# 163380/183960, translation error = 11.132, rotation error = 6.290, time/batch = 1.088
# 163800/183960, translation error = 11.119, rotation error = 6.292, time/batch = 1.086
# 164220/183960, translation error = 11.103, rotation error = 6.285, time/batch = 1.088
# 164640/183960, translation error = 11.089, rotation error = 6.281, time/batch = 1.087
# 165060/183960, translation error = 11.074, rotation error = 6.283, time/batch = 1.088
# 165480/183960, translation error = 11.077, rotation error = 6.286, time/batch = 1.085
# 165900/183960, translation error = 11.060, rotation error = 6.305, time/batch = 1.090
# 166320/183960, translation error = 11.048, rotation error = 6.309, time/batch = 1.086
# 166740/183960, translation error = 11.041, rotation error = 6.301, time/batch = 1.086
# 167160/183960, translation error = 11.036, rotation error = 6.296, time/batch = 1.084
# 167580/183960, translation error = 11.036, rotation error = 6.298, time/batch = 1.087
# 168000/183960, translation error = 11.039, rotation error = 6.295, time/batch = 1.088
# 168420/183960, translation error = 11.045, rotation error = 6.330, time/batch = 1.089
# 168840/183960, translation error = 11.027, rotation error = 6.329, time/batch = 1.088
# 169260/183960, translation error = 11.007, rotation error = 6.325, time/batch = 1.087
# 169680/183960, translation error = 10.987, rotation error = 6.317, time/batch = 1.086
# 170100/183960, translation error = 10.969, rotation error = 6.316, time/batch = 1.088
# 170520/183960, translation error = 10.949, rotation error = 6.309, time/batch = 1.095
# 170940/183960, translation error = 10.929, rotation error = 6.301, time/batch = 1.084
# 171360/183960, translation error = 10.908, rotation error = 6.293, time/batch = 1.088
# 171780/183960, translation error = 10.907, rotation error = 6.315, time/batch = 1.091
# 172200/183960, translation error = 11.028, rotation error = 6.367, time/batch = 1.090
# 172620/183960, translation error = 11.013, rotation error = 6.363, time/batch = 1.085
# 173040/183960, translation error = 10.993, rotation error = 6.352, time/batch = 1.092
# 173460/183960, translation error = 10.975, rotation error = 6.345, time/batch = 1.087
# 173880/183960, translation error = 10.954, rotation error = 6.336, time/batch = 1.082
# 174300/183960, translation error = 10.933, rotation error = 6.327, time/batch = 1.086
# 174720/183960, translation error = 10.987, rotation error = 6.349, time/batch = 1.092
# 175140/183960, translation error = 10.974, rotation error = 6.355, time/batch = 1.084
# 175560/183960, translation error = 10.952, rotation error = 6.357, time/batch = 1.086
# 175980/183960, translation error = 11.016, rotation error = 6.429, time/batch = 1.088
# 176400/183960, translation error = 11.059, rotation error = 6.461, time/batch = 1.089
# 176820/183960, translation error = 11.036, rotation error = 6.459, time/batch = 1.083
# 177240/183960, translation error = 11.016, rotation error = 6.454, time/batch = 1.088
# 177660/183960, translation error = 11.159, rotation error = 6.467, time/batch = 1.088
# 178080/183960, translation error = 11.207, rotation error = 6.471, time/batch = 1.085
# 178500/183960, translation error = 11.192, rotation error = 6.482, time/batch = 1.085
# 178920/183960, translation error = 11.169, rotation error = 6.475, time/batch = 1.090
# 179340/183960, translation error = 11.151, rotation error = 6.470, time/batch = 1.086
# 179760/183960, translation error = 11.180, rotation error = 6.479, time/batch = 1.096
# 180180/183960, translation error = 11.204, rotation error = 6.472, time/batch = 1.093
# 180600/183960, translation error = 11.183, rotation error = 6.463, time/batch = 1.092
# 181020/183960, translation error = 11.169, rotation error = 6.462, time/batch = 1.092
# 181440/183960, translation error = 11.151, rotation error = 6.458, time/batch = 1.086
# 181860/183960, translation error = 11.133, rotation error = 6.453, time/batch = 1.088
# 182280/183960, translation error = 11.113, rotation error = 6.450, time/batch = 1.092
# 182700/183960, translation error = 11.111, rotation error = 6.552, time/batch = 1.088
# 183120/183960, translation error = 11.092, rotation error = 6.559, time/batch = 1.093
# 183540/183960, translation error = 11.069, rotation error = 6.552, time/batch = 1.095
# 183960/183960, translation error = 11.056, rotation error = 6.551, time/batch = 4.676

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.136
# median rotation error = 3.121
# mean translation error = 11.056
# mean rotation error = 6.551

# %%
def evaluate(trans_errors,rot_errors):
    t = dataset.last_indexes
    trans_errors_month = list()
    trans_errors_month.append(trans_errors[:t[0]])
    trans_errors_month.append(trans_errors[t[0]:t[1]])
    trans_errors_month.append(trans_errors[t[1]:t[2]])
    trans_errors_month.append(trans_errors[t[2]:t[3]])
    trans_errors_month.append(trans_errors[t[3]:t[4]])
    trans_errors_month.append(trans_errors[t[4]:t[5]])
    trans_errors_month.append(trans_errors[t[5]:t[6]])
    trans_errors_month.append(trans_errors[t[6]:])

    rot_errors_month = list()
    rot_errors_month.append(rot_errors[:t[0]])
    rot_errors_month.append(rot_errors[t[0]:t[1]])
    rot_errors_month.append(rot_errors[t[1]:t[2]])
    rot_errors_month.append(rot_errors[t[2]:t[3]])
    rot_errors_month.append(rot_errors[t[3]:t[4]])
    rot_errors_month.append(rot_errors[t[4]:t[5]])
    rot_errors_month.append(rot_errors[t[5]:t[6]])
    rot_errors_month.append(rot_errors[t[6]:])
    
    print('================== median translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("median translation error = {:.3f}".format(np.median(trans_errors_i)))
        
    print('================== median rotation error ==================')
    for rot_errors_i in rot_errors_month:
        print("median rotation error = {:.3f}".format(np.median(rot_errors_i)))
    
    print('================== mean translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("mean translation error = {:.3f}".format(np.mean(trans_errors_i)))
        
    print('================== mean rotation error ==================')  
    for rot_errors_i in rot_errors_month:
        print("mean rotation error = {:.3f}".format(np.mean(rot_errors_i)))
        
evaluate(trans_errors,rot_errors)
# Out:
# ================== median translation error ==================
# median translation error = 1.648
# median translation error = 1.740
# median translation error = 2.013
# median translation error = 2.008
# median translation error = 2.107
# median translation error = 2.190
# median translation error = 3.579
# median translation error = 2.932
# ================== median rotation error ==================
# median rotation error = 2.584
# median rotation error = 2.794
# median rotation error = 2.950
# median rotation error = 2.925
# median rotation error = 3.105
# median rotation error = 3.262
# median rotation error = 4.395
# median rotation error = 4.155
# ================== mean translation error ==================
# mean translation error = 4.265
# mean translation error = 4.468
# mean translation error = 13.187
# mean translation error = 12.985
# mean translation error = 9.629
# mean translation error = 11.376
# mean translation error = 21.605
# mean translation error = 13.976
# ================== mean rotation error ==================
# mean rotation error = 3.956
# mean rotation error = 4.262
# mean rotation error = 6.160
# mean rotation error = 5.901
# mean rotation error = 5.634
# mean rotation error = 6.627
# mean rotation error = 12.331
# mean rotation error = 9.281
