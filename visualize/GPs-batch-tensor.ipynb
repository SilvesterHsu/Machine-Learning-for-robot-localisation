# %% [markdown]
# # Library

# %%
import numpy as np
import torch
import gpytorch
import argparse
import time
import pickle
import scipy.io as sio

from torch.distributions import Normal
import matplotlib.pyplot as plt
import random

import roslib
import rospy
import tf as tf_ros
from nav_msgs.msg import Odometry, Path
from sensor_msgs.msg import Image
from cv_bridge import CvBridge
from geometry_msgs.msg import PoseStamped, PoseArray, Pose
import math
import cv2
import copy

import sys
sys.path.append('..')
# Out:
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'

# %% [markdown]
# ## Check GPU

# %%
import torch
import numpy as np
import sys
sys.path.append('..')

from torchlib.utils import list_device,set_device

# S1: check GPU
#list_device()

# S2: default parameters
set_device(1)
np.set_printoptions(precision = 2)
torch.set_default_dtype(torch.float32)
torch.set_printoptions(precision=4)
torch.backends.cudnn.benchmark = True
torch.set_printoptions(sci_mode=False)
# Out:
# Using Device 1 : TITAN Xp

# %% [markdown]
# # Set Arguments

# %%
import argparse
import sys
import os
import time
import pickle

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, default=320, help='size of mini batch')
parser.add_argument('--is_normalization', type=bool, default=True, help='whether do data normalization')
parser.add_argument('--target_image_size', default=[300, 300], nargs=2, type=int, help='Input images will be resized to this for data argumentation.')
parser.add_argument('--output_dim', default=3, type=int, help='output dimention.')
parser.add_argument('--feat_dim', default=128, type=int, help='feature dimention.')
parser.add_argument('--model_dir', type=str, default='/notebooks/global_localization/gps_net_torch', help='rnn, gru, or lstm')

parser.add_argument('--test_dataset', type=str, default=[# '/notebooks/michigan_nn_data/2012_01_08',
                                                         # '/notebooks/michigan_nn_data/2012_01_15',
                                                         # '/notebooks/michigan_nn_data/2012_01_22',
                                                         # '/notebooks/michigan_nn_data/2012_02_02',
                                                         # '/notebooks/michigan_nn_data/2012_02_04',
                                                         # '/notebooks/michigan_nn_data/2012_02_05',
                                                         '/notebooks/michigan_nn_data/2012_02_12',
                                                         # '/notebooks/michigan_nn_data/2012_03_31',
                                                         '/notebooks/michigan_nn_data/2012_04_29',
                                                         '/notebooks/michigan_nn_data/2012_05_11',
                                                         '/notebooks/michigan_nn_data/2012_06_15',
                                                         '/notebooks/michigan_nn_data/2012_08_04',
                                                         # '/notebooks/michigan_nn_data/2012_09_28'])
                                                         '/notebooks/michigan_nn_data/2012_10_28',
                                                         '/notebooks/michigan_nn_data/2012_11_16',
                                                         '/notebooks/michigan_nn_data/2012_12_01'
                                                        ] )

parser.add_argument('--train_dataset', type=str, default = ['/notebooks/michigan_nn_data/test'])
parser.add_argument('--norm_tensor', type=str, default = ['/notebooks/global_localization/norm_mean_std.pt'])

#parser.add_argument('--map_dataset', type=str, default='/home/kevin/data/michigan_gt/training')
parser.add_argument('--enable_ros', type=bool, default=False, help='put data into ros')
parser.add_argument('--cuda_device', type=int, default=1, help='cuda device')

sys.argv = ['']
args = parser.parse_args()

if args.enable_ros:
    rospy.init_node('global_localization_tf_broadcaster_cnn')

# %% [markdown]
# # Load Dataset

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import tf.transformations as tf_tran
from tqdm import tqdm
#from PIL import Image
import numpy as np
import random

import torch.nn as nn
import torch.optim as optim
from torchlib import resnet, vggnet, cnn_auxiliary
from torchlib.cnn_auxiliary import normalize, denormalize, denormalize_navie, get_relative_pose, translational_rotational_loss
from torchlib.utils import LocalizationDataset, display_loss, data2tensorboard
import time

transform = transforms.Compose([transforms.ToTensor()])
dataset = LocalizationDataset(dataset_dirs = args.test_dataset, \
                              image_size = args.target_image_size, \
                              transform = transform,
                              get_pair = False, mode='evaluate', sampling_rate=1)

[args.norm_mean, args.norm_std] = torch.load(*args.norm_tensor)
print('Load norm and std:',*args.norm_tensor)

dataloader = DataLoader(dataset, batch_size=args.batch_size, \
                        shuffle=False, num_workers=0, \
                        drop_last=False, pin_memory=True)
# Out:
# 100%|██████████| 28602/28602 [00:37<00:00, 770.60it/s]
# 100%|██████████| 14016/14016 [00:18<00:00, 762.05it/s]
# 100%|██████████| 25704/25704 [00:33<00:00, 773.15it/s]
# 100%|██████████| 19135/19135 [00:24<00:00, 765.81it/s]
# 100%|██████████| 27160/27160 [00:43<00:00, 630.33it/s]
# 100%|██████████| 29670/29670 [00:54<00:00, 540.87it/s]
# 100%|██████████| 14229/14229 [00:27<00:00, 525.28it/s]
# 100%|██████████| 25367/25367 [00:50<00:00, 498.31it/s]
# Load norm and std: /notebooks/global_localization/norm_mean_std.pt

# %% [markdown]
# # Define Model

# %%
from torch.cuda.amp import autocast, GradScaler
from torchlib.GPs import Backbone, NN, GPNode, BaseModule

class NN(nn.Module):
    def __init__(self):
        super().__init__()
        self.global_context = vggnet.vggnet(input_channel=2048,opt="context")
        self.global_regressor = vggnet.vggnet(opt="regressor")
        
    def forward(self,input_data):
        context_feat = self.global_context(input_data)
        #context_feat = input_data
        output,feature_t, feature_r = self.global_regressor(context_feat)
        return output, feature_t, feature_r

class GP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, output_dim=3):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(
            inducing_points.size(-2), batch_shape=torch.Size([output_dim])
        )
        variational_strategy = gpytorch.variational.MultitaskVariationalStrategy(
            gpytorch.variational.VariationalStrategy(
                self, inducing_points, variational_distribution, learn_inducing_locations=True
            ), num_tasks=output_dim
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ZeroMean()
        #self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([output_dim]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([output_dim])),
            batch_shape=torch.Size([output_dim]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class GPNode(nn.Module):
    def __init__(self, inducing_points):
        super().__init__()
        output_dim = inducing_points.shape[0]

        self.gp = GP(inducing_points,output_dim)
        self.likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=output_dim) 
        
    def forward(self,input_data):
        output = self.gp(input_data)
        return output

class Model(nn.Module):
    def __init__(self, num_gp = 20):
        super().__init__()
        self.backbone = Backbone()
        self.nn = NN()
        self.gps = nn.ModuleList()
        
        self.num_gp = num_gp
        
        for i in range(self.num_gp):
            inducing_points = torch.zeros(3, 1000, 128)
            gp = GPNode(inducing_points)
            self.gps.append(gp)
        
    def forward_nn(self, input_data):
        dense_feat = self.backbone(input_data)
        #dense_feat = input_data
        output, feature_t, feature_r = self.nn(dense_feat)
        rot_pred = torch.split(output, [3, 4], dim=1)[1] # 4-dimention            
        return feature_t, rot_pred
    
    def forward_gp(self,gp,trans_feat):
        trans_pred = gp(trans_feat)
        return trans_pred
    
class PosePredictor(BaseModule):
    def __init__(self, norm_mean, norm_std, args, num_gp = 20,
                 regressor_context_rate = [0.0,0.0],
                 is_training=True, train_rot = True):
        
        super().__init__(norm_mean, norm_std, args)
        self.num_gp = num_gp
        self.model = Model(num_gp).to(self.device)
        self.train_rot = train_rot
        self.num_sub_data = self.args.batch_size//num_gp
        
        # disable learning backbone
        self.disable_requires_grad(self.model.backbone)
        
        if is_training:
            # training tool
            self.optimizer = optim.Adam(self._optimize(regressor_context_rate))
            self.scheduler = optim.lr_scheduler.LambdaLR(optimizer=self.optimizer,
                                                             lr_lambda=lambda epoch: args.decay_rate**epoch)
        else:
            self.disable_requires_grad(self.model)
            
    def _optimize(self, regressor_context_rate = [0.0,0.0]):
        optimizer = [
                {'params': self.model.gps.parameters(), \
                 'lr': self.args.learning_rate,'weight_decay':self.args.weight_decay}]
            
        # NN
        if regressor_context_rate[0]!=0:
            optimizer += [{'params': self.model.nn.global_regressor.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[0],'weight_decay':args.weight_decay}]
            print('Regressor learn rate:',regressor_context_rate[0])
        else:
            self.disable_requires_grad(self.model.nn.global_regressor)
                
        if regressor_context_rate[1]!=0:
            optimizer += [{'params': self.model.nn.global_context.parameters(), \
                 'lr': args.learning_rate * regressor_context_rate[1],'weight_decay':args.weight_decay}]
            print('Context learn rate:',regressor_context_rate[1])
            self.train_rot = True
        else:
            self.disable_requires_grad(self.model.nn.global_context)
            
        
        if not self.train_rot and regressor_context_rate[1]==0.0:
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc1_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc2_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.fc3_rot)
            self.disable_requires_grad(self.model.nn.global_regressor.regressor.logits_r)
                
        return optimizer
    
    def train(self, x, y):
        # Step 0: zero grad
        self.optimizer.zero_grad()
        
        start = time.time()
        # Step 1: get data
        x,y = x.to(self.device),y.to(self.device)
        if self.args.is_normalization:
            y = normalize(y,self.norm_mean, self.norm_std)
            
        # Step 2: training
        assert self.model.training == True
        
        trans_loss = torch.tensor(0.).to(self.device)
        
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        trans_feat, rot_pred = self.model.forward_nn(x)
        rot_loss = self._nn_loss(rot_pred,rot_target)
        
        mask = torch.randperm(self.args.batch_size)
        for i,gp in enumerate(self.model.gps):
            sampled_mask = mask[self.num_sub_data*i:self.num_sub_data*(i+1)]
            sub_x = trans_feat[sampled_mask]
            sub_y = trans_target[sampled_mask]
            gp_loss = self._gp_loss(gp,sub_x,sub_y)
            trans_loss += gp_loss
        trans_loss = trans_loss/self.model.num_gp
        
        total_loss = trans_loss + self.args.lamda_weights * rot_loss
        
        batch_time = time.time() - start
        
        #Step 3: update
        total_loss.backward()
        self.optimizer.step()
        
        return float(total_loss), batch_time    
    
    def _nn_loss(self, rot_pred, rot_target):
        rot_loss = 1. - torch.mean(torch.square(torch.sum(torch.mul(rot_pred,rot_target),dim=1)))
        return rot_loss
        
    def _gp_loss(self, gp, trans_feat, trans_target):
        # predict
        trans_pred = self.model.forward_gp(gp,trans_feat)
        
        #num_data = int(min(len(dataloader)*args.batch_size,len(dataset))*self.model.sub_batch_rate)
        num_data = min(len(dataloader)*self.args.batch_size,len(dataset))//self.num_gp
        mll = gpytorch.mlls.PredictiveLogLikelihood(gp.likelihood, gp.gp, num_data = num_data)
        
        # trans loss
        trans_loss = -1.*mll(trans_pred, trans_target)
        
        return trans_loss
    
    def _eval_gp(self, gp, trans_pred):
        c_mean, c_var = trans_pred.mean, trans_pred.variance
        y_mean, y_var = gp.likelihood(trans_pred).mean, gp.likelihood(trans_pred).variance
        
        return y_mean, c_mean, c_var
    
    def _sample(self, mean, var, num_sample = 100):
        dist = torch.distributions.Normal(mean, var)
        samples = dist.sample([num_sample])
        return samples

    def eval_forward(self, x, y, num_sample = 100, output_denormalize = True):
        # Step 1: get data
        x = x.to(self.device)
        
        # Step 2: forward
        assert self.model.training == False
        trans_feat, rot_pred = self.model.forward_nn(x)
        
        trans_preds = 0
        trans_means = 0
        trans_vars = 0
        for gp in self.model.gps:
            trans_pred = self.model.forward_gp(gp,trans_feat)
            trans_pred, trans_mean, trans_var = self._eval_gp(gp, trans_pred)
            trans_preds += trans_pred * 1/trans_var
            trans_means += trans_mean * 1/trans_var
            trans_vars += 1/trans_var
         
        trans_vars = 1/trans_vars
        trans_preds *= trans_vars
        trans_means *= trans_vars
        
        if self.args.is_normalization and output_denormalize:
            trans_preds = denormalize_navie(trans_preds, self.norm_mean, self.norm_std)
            trans_means = denormalize_navie(trans_means, self.norm_mean, self.norm_std)
            trans_vars = trans_vars.mul(self.norm_std)
        
        samples = self._sample(trans_means, trans_vars, num_sample)
        
        # Step 3: split output
        trans_target, rot_target = torch.split(y, [3, 4], dim=1)
        
        return trans_preds, rot_pred, trans_target, rot_target, samples

# %%
trainer = PosePredictor(args.norm_mean,args.norm_std,args,is_training = False)
trainer.load_model('model-fast-zero-mean.pth')
# Out:
# Successfully loaded model to TITAN Xp.

# %% [markdown]
# # Initialize

# %%
trans_errors = []
rot_errors = []
uncertainties = []
pose_map = []

total_trans_error = 0.
total_rot_error = 0.

count = 0.

is_save_map = False
is_read_map = False

trans_preds = []
trans_gts = []

rot_preds = []
rot_gts = []

pred_uncertainties = []

pred_time = []

br = tf_ros.TransformBroadcaster()

GT_POSE_TOPIC = '/gt_pose'
BIRDVIEW_TOPIC_PUB = '/bird_view'
MAP_TOPIC_PUB = '/pose_map'
PARTICLES_PUB = '/particles'
NN_LOCALIZASION_PUB = '/nn_pose'
gt_pose_pub = rospy.Publisher(GT_POSE_TOPIC, Odometry, queue_size=1)
bird_view_pub = rospy.Publisher(BIRDVIEW_TOPIC_PUB, Image, queue_size=1)
map_pub = rospy.Publisher(MAP_TOPIC_PUB, Path, queue_size=1)
particles_pub = rospy.Publisher(PARTICLES_PUB, PoseArray, queue_size=1)
nn_pose_pub = rospy.Publisher(NN_LOCALIZASION_PUB, Odometry, queue_size=1)

# %%
trainer.model.eval()

for b, data in enumerate(dataloader, 0):
    start = time.time()
    x,y = data.values()
    trans_pred, rot_pred, trans_gt, rot_gt, samples = trainer.eval_forward(x,y)
    
    # transform data
    trans_pred = trans_pred.cpu().numpy()
    rot_pred = rot_pred.cpu().numpy()
    trans_gt = trans_gt.cpu().numpy()
    rot_gt = rot_gt.cpu().numpy()
    
    end = time.time()
    
    if args.enable_ros:
        particles = PoseArray()
        particles.header.stamp = rospy.Time.now()
        particles.header.frame_id = 'world'
        for s in samples:
            pose = Pose()
            [pose.position.x, pose.position.y, pose.position.z] = s
            [pose.orientation.x, pose.orientation.y, pose.orientation.z, pose.orientation.w] = rot_pred[0]
            particles.poses.append(pose)
        particles_pub.publish(particles)

        [px_pred, py_pred, pz_pred] = trans_pred[0]
        [qx_pred, qy_pred, qz_pred, qw_pred] = rot_pred[0]

        br.sendTransform((px_pred, py_pred, pz_pred),
                         (qx_pred, qy_pred, qz_pred, qw_pred), rospy.Time.now(),
                         "estimation", "world")

        [px_gt, py_gt, pz_gt] = trans_gt[0]
        [qx_gt, qy_gt, qz_gt, qw_gt] = rot_gt[0]

        br.sendTransform((px_gt, py_gt, pz_gt),
                         (qx_gt, qy_gt, qz_gt, qw_gt),
                         rospy.Time.now(), "gt", "world")

        timestamp = rospy.Time.now()

        nn_pose_msg = Odometry()
        nn_pose_msg.header.frame_id = 'world'
        nn_pose_msg.header.stamp = timestamp
        nn_pose_msg.child_frame_id = 'base_link'
        nn_pose_msg.pose.pose.position.x = px_pred
        nn_pose_msg.pose.pose.position.y = py_pred
        nn_pose_msg.pose.pose.position.z = pz_pred
        [nn_pose_msg.pose.pose.orientation.x, nn_pose_msg.pose.pose.orientation.y, nn_pose_msg.pose.pose.orientation.z, nn_pose_msg.pose.pose.orientation.w] = [qx_pred, qy_pred, qz_pred, qw_pred]

        conv = np.zeros((6,6), dtype=np.float32)
        [conv[0][0], conv[1][1], conv[2][2]] = trans_cov[0]
        nn_pose_msg.pose.covariance = conv.flatten().tolist()
        nn_pose_pub.publish(nn_pose_msg)

        bridge = CvBridge()

        bird_view_img_msg = bridge.cv2_to_imgmsg(np.asarray(x[0].cpu(), dtype=np.float32), encoding="passthrough")
        stamp_now = rospy.Time.now()
        bird_view_img_msg.header.stamp = stamp_now

        bird_view_pub.publish(bird_view_img_msg)

        rospy.sleep(.0)
        cv2.waitKey(0)

        count += 1
    else:
        count += y.shape[0]
    
    trans_preds += [x for x in trans_pred]
    rot_preds += [x for x in rot_pred]
    trans_gts += [x for x in trans_gt]
    rot_gts += [x for x in rot_gt]

    trans_error = np.sqrt(np.sum((trans_pred - trans_gt)**2,axis=1))
    rot_error_1 = np.arccos(np.sum(np.multiply(rot_pred,rot_gt),axis=1))/math.pi*180
    rot_error_2 = np.arccos(np.sum(np.multiply(rot_pred,-rot_gt),axis=1))/math.pi*180
    rot_error = np.minimum(rot_error_1,rot_error_2)

    trans_errors += [x for x in trans_error]
    rot_errors += [x for x in rot_error]

    total_trans_error += np.sum(trans_error)
    total_rot_error += np.sum(rot_error)
    
    display = 1

    if b % display == 0:
        print(
            "{}/{}, translation error = {:.3f}, rotation error = {:.3f}, time/batch = {:.3f}"
            .format(
             (b+1)*args.batch_size,
            len(dataloader)*args.batch_size,
            total_trans_error / count,
            total_rot_error / count,
            end - start))
# Out:
# 320/184000, translation error = 3.303, rotation error = 2.444, time/batch = 5.005
# 640/184000, translation error = 4.624, rotation error = 3.214, time/batch = 1.265
# 960/184000, translation error = 7.600, rotation error = 3.931, time/batch = 1.259
# 1280/184000, translation error = 6.316, rotation error = 3.424, time/batch = 1.261
# 1600/184000, translation error = 5.790, rotation error = 3.294, time/batch = 1.260
# 1920/184000, translation error = 6.942, rotation error = 3.369, time/batch = 1.266
# 2240/184000, translation error = 6.472, rotation error = 3.514, time/batch = 1.262
# 2560/184000, translation error = 6.198, rotation error = 3.548, time/batch = 1.387
# 2880/184000, translation error = 5.892, rotation error = 3.669, time/batch = 1.268
# 3200/184000, translation error = 5.388, rotation error = 3.526, time/batch = 1.258
# 3520/184000, translation error = 5.092, rotation error = 3.601, time/batch = 1.386
# 3840/184000, translation error = 4.865, rotation error = 3.642, time/batch = 1.266
# 4160/184000, translation error = 4.796, rotation error = 3.716, time/batch = 1.259
# 4480/184000, translation error = 4.635, rotation error = 3.767, time/batch = 1.275
# 4800/184000, translation error = 4.435, rotation error = 3.641, time/batch = 1.268
# 5120/184000, translation error = 4.317, rotation error = 3.742, time/batch = 1.387
# 5440/184000, translation error = 4.206, rotation error = 3.745, time/batch = 1.271
# 5760/184000, translation error = 4.138, rotation error = 3.720, time/batch = 1.264
# 6080/184000, translation error = 4.063, rotation error = 3.752, time/batch = 1.268
# 6400/184000, translation error = 3.930, rotation error = 3.665, time/batch = 1.272
# 6720/184000, translation error = 3.943, rotation error = 3.756, time/batch = 1.273
# 7040/184000, translation error = 3.848, rotation error = 3.739, time/batch = 1.261
# 7360/184000, translation error = 3.763, rotation error = 3.654, time/batch = 1.280
# 7680/184000, translation error = 3.671, rotation error = 3.644, time/batch = 1.264
# 8000/184000, translation error = 3.553, rotation error = 3.598, time/batch = 1.268
# 8320/184000, translation error = 3.452, rotation error = 3.573, time/batch = 1.273
# 8640/184000, translation error = 3.360, rotation error = 3.574, time/batch = 1.276
# 8960/184000, translation error = 3.278, rotation error = 3.523, time/batch = 1.278
# 9280/184000, translation error = 3.214, rotation error = 3.521, time/batch = 1.270
# 9600/184000, translation error = 3.128, rotation error = 3.494, time/batch = 1.273
# 9920/184000, translation error = 3.082, rotation error = 3.529, time/batch = 1.271
# 10240/184000, translation error = 3.114, rotation error = 3.540, time/batch = 1.269
# 10560/184000, translation error = 3.053, rotation error = 3.508, time/batch = 1.270
# 91840/184000, translation error = 8.561, rotation error = 5.057, time/batch = 1.280
# 92160/184000, translation error = 8.542, rotation error = 5.061, time/batch = 1.277
# 92480/184000, translation error = 8.522, rotation error = 5.064, time/batch = 1.276
# 92800/184000, translation error = 8.504, rotation error = 5.060, time/batch = 1.279
# 93120/184000, translation error = 8.487, rotation error = 5.056, time/batch = 1.277
# 93440/184000, translation error = 8.470, rotation error = 5.048, time/batch = 1.282
# 93760/184000, translation error = 8.450, rotation error = 5.042, time/batch = 1.282
# 94080/184000, translation error = 8.436, rotation error = 5.043, time/batch = 1.283
# 94400/184000, translation error = 8.415, rotation error = 5.036, time/batch = 1.276
# 94720/184000, translation error = 8.407, rotation error = 5.030, time/batch = 1.283
# 95040/184000, translation error = 8.399, rotation error = 5.025, time/batch = 1.278
# 95360/184000, translation error = 8.375, rotation error = 5.019, time/batch = 1.402
# 95680/184000, translation error = 8.352, rotation error = 5.015, time/batch = 1.287
# 96000/184000, translation error = 8.329, rotation error = 5.016, time/batch = 1.289
# 96320/184000, translation error = 8.310, rotation error = 5.015, time/batch = 1.281
# 96640/184000, translation error = 8.289, rotation error = 5.009, time/batch = 1.278
# 96960/184000, translation error = 8.270, rotation error = 5.002, time/batch = 1.403
# 97280/184000, translation error = 8.256, rotation error = 4.993, time/batch = 1.282
# 97600/184000, translation error = 8.237, rotation error = 4.985, time/batch = 1.297
# 97920/184000, translation error = 8.217, rotation error = 4.977, time/batch = 1.277
# 98240/184000, translation error = 8.199, rotation error = 4.970, time/batch = 1.280
# 98560/184000, translation error = 8.180, rotation error = 4.964, time/batch = 1.283
# 98880/184000, translation error = 8.161, rotation error = 4.963, time/batch = 1.285
# 99200/184000, translation error = 8.138, rotation error = 4.958, time/batch = 1.284
# 99520/184000, translation error = 8.122, rotation error = 4.950, time/batch = 1.284
# 99840/184000, translation error = 8.102, rotation error = 4.941, time/batch = 1.279
# 100160/184000, translation error = 8.095, rotation error = 4.942, time/batch = 1.277
# 100480/184000, translation error = 8.077, rotation error = 4.935, time/batch = 1.283
# 100800/184000, translation error = 8.059, rotation error = 4.931, time/batch = 1.273
# 101120/184000, translation error = 8.067, rotation error = 4.939, time/batch = 1.277
# 101440/184000, translation error = 8.882, rotation error = 5.060, time/batch = 1.286
# 101760/184000, translation error = 9.145, rotation error = 5.070, time/batch = 1.283
# 102080/184000, translation error = 9.135, rotation error = 5.098, time/batch = 1.279
# 102400/184000, translation error = 9.112, rotation error = 5.091, time/batch = 1.289
# 102720/184000, translation error = 9.091, rotation error = 5.086, time/batch = 1.276
# 103040/184000, translation error = 9.070, rotation error = 5.082, time/batch = 1.283
# 103360/184000, translation error = 9.047, rotation error = 5.075, time/batch = 1.280
# 103680/184000, translation error = 9.024, rotation error = 5.082, time/batch = 1.278
# 104000/184000, translation error = 9.003, rotation error = 5.084, time/batch = 1.401
# 104320/184000, translation error = 8.997, rotation error = 5.088, time/batch = 1.277
# 104640/184000, translation error = 8.976, rotation error = 5.086, time/batch = 1.274
# 104960/184000, translation error = 8.956, rotation error = 5.087, time/batch = 1.274
# 105280/184000, translation error = 8.936, rotation error = 5.079, time/batch = 1.277
# 105600/184000, translation error = 8.917, rotation error = 5.071, time/batch = 1.279
# 105920/184000, translation error = 8.896, rotation error = 5.062, time/batch = 1.280
# 106240/184000, translation error = 8.876, rotation error = 5.056, time/batch = 1.279
# 106560/184000, translation error = 8.863, rotation error = 5.078, time/batch = 1.284
# 106880/184000, translation error = 8.846, rotation error = 5.080, time/batch = 1.274
# 107200/184000, translation error = 8.827, rotation error = 5.083, time/batch = 1.284
# 107520/184000, translation error = 8.804, rotation error = 5.079, time/batch = 1.280
# 107840/184000, translation error = 8.782, rotation error = 5.077, time/batch = 1.278
# 108160/184000, translation error = 8.761, rotation error = 5.069, time/batch = 1.274
# 108480/184000, translation error = 8.849, rotation error = 5.087, time/batch = 1.269
# 108800/184000, translation error = 8.833, rotation error = 5.087, time/batch = 1.406
# 109120/184000, translation error = 8.818, rotation error = 5.082, time/batch = 1.278
# 109440/184000, translation error = 8.796, rotation error = 5.078, time/batch = 1.275
# 109760/184000, translation error = 8.779, rotation error = 5.081, time/batch = 1.282
# 110080/184000, translation error = 8.759, rotation error = 5.075, time/batch = 1.392
# 110400/184000, translation error = 8.738, rotation error = 5.071, time/batch = 1.287
# 110720/184000, translation error = 8.726, rotation error = 5.076, time/batch = 1.278
# 111040/184000, translation error = 8.706, rotation error = 5.074, time/batch = 1.282
# 111360/184000, translation error = 8.690, rotation error = 5.073, time/batch = 1.286
# 111680/184000, translation error = 8.927, rotation error = 5.100, time/batch = 1.277
# 112000/184000, translation error = 8.917, rotation error = 5.154, time/batch = 1.272
# 112320/184000, translation error = 9.063, rotation error = 5.194, time/batch = 1.282
# 112640/184000, translation error = 9.062, rotation error = 5.203, time/batch = 1.278
# 112960/184000, translation error = 9.049, rotation error = 5.208, time/batch = 1.279
# 113280/184000, translation error = 9.034, rotation error = 5.208, time/batch = 1.284
# 113600/184000, translation error = 9.018, rotation error = 5.204, time/batch = 1.281
# 113920/184000, translation error = 9.008, rotation error = 5.202, time/batch = 1.274
# 114240/184000, translation error = 8.988, rotation error = 5.207, time/batch = 1.286
# 114560/184000, translation error = 8.973, rotation error = 5.208, time/batch = 1.274
# 114880/184000, translation error = 9.209, rotation error = 5.214, time/batch = 1.284
# 115200/184000, translation error = 9.771, rotation error = 5.243, time/batch = 1.276
# 115520/184000, translation error = 9.759, rotation error = 5.241, time/batch = 1.278
# 115840/184000, translation error = 9.738, rotation error = 5.241, time/batch = 1.276
# 116160/184000, translation error = 9.721, rotation error = 5.240, time/batch = 1.279
# 116480/184000, translation error = 9.703, rotation error = 5.247, time/batch = 1.278
# 116800/184000, translation error = 9.713, rotation error = 5.246, time/batch = 1.275
# 117120/184000, translation error = 9.701, rotation error = 5.251, time/batch = 1.277
# 117440/184000, translation error = 9.680, rotation error = 5.245, time/batch = 1.275
# 117760/184000, translation error = 9.656, rotation error = 5.237, time/batch = 1.278
# 118080/184000, translation error = 9.636, rotation error = 5.234, time/batch = 1.280
# 118400/184000, translation error = 9.614, rotation error = 5.238, time/batch = 1.273
# 145920/184000, translation error = 9.402, rotation error = 5.486, time/batch = 1.274
# 146240/184000, translation error = 9.389, rotation error = 5.486, time/batch = 1.279
# 146560/184000, translation error = 9.373, rotation error = 5.480, time/batch = 1.283
# 146880/184000, translation error = 9.358, rotation error = 5.480, time/batch = 1.279
# 147200/184000, translation error = 9.345, rotation error = 5.478, time/batch = 1.275
# 147520/184000, translation error = 9.352, rotation error = 5.479, time/batch = 1.282
# 147840/184000, translation error = 9.344, rotation error = 5.483, time/batch = 1.280
# 148160/184000, translation error = 9.330, rotation error = 5.479, time/batch = 1.276
# 148480/184000, translation error = 9.313, rotation error = 5.475, time/batch = 1.279
# 148800/184000, translation error = 9.365, rotation error = 5.503, time/batch = 1.279
# 149120/184000, translation error = 9.527, rotation error = 5.622, time/batch = 1.276
# 149440/184000, translation error = 9.572, rotation error = 5.655, time/batch = 1.283
# 149760/184000, translation error = 9.557, rotation error = 5.654, time/batch = 1.279
# 150080/184000, translation error = 9.546, rotation error = 5.650, time/batch = 1.279
# 150400/184000, translation error = 9.590, rotation error = 5.682, time/batch = 1.277
# 150720/184000, translation error = 9.741, rotation error = 5.713, time/batch = 1.275
# 151040/184000, translation error = 9.728, rotation error = 5.713, time/batch = 1.281
# 151360/184000, translation error = 9.712, rotation error = 5.704, time/batch = 1.279
# 151680/184000, translation error = 9.697, rotation error = 5.699, time/batch = 1.279
# 152000/184000, translation error = 9.686, rotation error = 5.694, time/batch = 1.277
# 152320/184000, translation error = 9.672, rotation error = 5.692, time/batch = 1.278
# 152640/184000, translation error = 9.660, rotation error = 5.687, time/batch = 1.289
# 152960/184000, translation error = 9.644, rotation error = 5.682, time/batch = 1.275
# 153280/184000, translation error = 9.628, rotation error = 5.675, time/batch = 1.274
# 153600/184000, translation error = 9.637, rotation error = 5.678, time/batch = 1.276
# 153920/184000, translation error = 9.622, rotation error = 5.674, time/batch = 1.279
# 154240/184000, translation error = 9.653, rotation error = 5.677, time/batch = 1.279
# 154560/184000, translation error = 9.653, rotation error = 5.676, time/batch = 1.275
# 154880/184000, translation error = 9.875, rotation error = 5.726, time/batch = 1.277
# 155200/184000, translation error = 10.013, rotation error = 5.746, time/batch = 1.282
# 155520/184000, translation error = 10.134, rotation error = 5.795, time/batch = 1.279
# 155840/184000, translation error = 10.195, rotation error = 5.860, time/batch = 1.281
# 156160/184000, translation error = 10.255, rotation error = 5.869, time/batch = 1.277
# 156480/184000, translation error = 10.294, rotation error = 5.870, time/batch = 1.281
# 156800/184000, translation error = 10.286, rotation error = 5.877, time/batch = 1.277
# 157120/184000, translation error = 10.315, rotation error = 5.895, time/batch = 1.276
# 157440/184000, translation error = 10.311, rotation error = 5.903, time/batch = 1.277
# 157760/184000, translation error = 10.302, rotation error = 5.903, time/batch = 1.278
# 158080/184000, translation error = 10.439, rotation error = 5.971, time/batch = 1.281
# 158400/184000, translation error = 10.527, rotation error = 6.067, time/batch = 1.283
# 158720/184000, translation error = 10.559, rotation error = 6.122, time/batch = 1.272
# 159040/184000, translation error = 11.067, rotation error = 6.131, time/batch = 1.396
# 159360/184000, translation error = 11.048, rotation error = 6.137, time/batch = 1.274
# 159680/184000, translation error = 11.028, rotation error = 6.142, time/batch = 1.275
# 160000/184000, translation error = 11.009, rotation error = 6.147, time/batch = 1.280
# 160320/184000, translation error = 10.997, rotation error = 6.154, time/batch = 1.279
# 160640/184000, translation error = 10.981, rotation error = 6.151, time/batch = 1.280
# 160960/184000, translation error = 10.989, rotation error = 6.151, time/batch = 1.399
# 161280/184000, translation error = 11.072, rotation error = 6.208, time/batch = 1.282
# 161600/184000, translation error = 11.061, rotation error = 6.214, time/batch = 1.278
# 161920/184000, translation error = 11.046, rotation error = 6.213, time/batch = 1.283
# 162240/184000, translation error = 11.047, rotation error = 6.221, time/batch = 1.281
# 162560/184000, translation error = 11.057, rotation error = 6.270, time/batch = 1.274
# 162880/184000, translation error = 11.105, rotation error = 6.281, time/batch = 1.275
# 163200/184000, translation error = 11.093, rotation error = 6.291, time/batch = 1.282
# 163520/184000, translation error = 11.078, rotation error = 6.288, time/batch = 1.278
# 163840/184000, translation error = 11.070, rotation error = 6.292, time/batch = 1.281
# 164160/184000, translation error = 11.059, rotation error = 6.286, time/batch = 1.275
# 164480/184000, translation error = 11.047, rotation error = 6.285, time/batch = 1.279
# 164800/184000, translation error = 11.035, rotation error = 6.277, time/batch = 1.281
# 165120/184000, translation error = 11.024, rotation error = 6.285, time/batch = 1.276
# 165440/184000, translation error = 11.027, rotation error = 6.285, time/batch = 1.282
# 165760/184000, translation error = 11.019, rotation error = 6.306, time/batch = 1.278
# 166080/184000, translation error = 11.004, rotation error = 6.305, time/batch = 1.278
# 166400/184000, translation error = 10.996, rotation error = 6.308, time/batch = 1.278
# 166720/184000, translation error = 10.990, rotation error = 6.301, time/batch = 1.276
# 167040/184000, translation error = 10.991, rotation error = 6.299, time/batch = 1.282
# 167360/184000, translation error = 10.973, rotation error = 6.292, time/batch = 1.283
# 167680/184000, translation error = 10.987, rotation error = 6.296, time/batch = 1.285
# 168000/184000, translation error = 10.983, rotation error = 6.295, time/batch = 1.290
# 168320/184000, translation error = 10.991, rotation error = 6.329, time/batch = 1.284
# 168640/184000, translation error = 10.978, rotation error = 6.333, time/batch = 1.273
# 168960/184000, translation error = 10.962, rotation error = 6.329, time/batch = 1.275
# 169280/184000, translation error = 10.947, rotation error = 6.325, time/batch = 1.277
# 169600/184000, translation error = 10.931, rotation error = 6.318, time/batch = 1.275
# 169920/184000, translation error = 10.919, rotation error = 6.318, time/batch = 1.276
# 170240/184000, translation error = 10.904, rotation error = 6.315, time/batch = 1.281
# 170560/184000, translation error = 10.888, rotation error = 6.308, time/batch = 1.280
# 170880/184000, translation error = 10.873, rotation error = 6.302, time/batch = 1.283
# 171200/184000, translation error = 10.856, rotation error = 6.295, time/batch = 1.279
# 171520/184000, translation error = 10.840, rotation error = 6.290, time/batch = 1.279
# 171840/184000, translation error = 10.884, rotation error = 6.331, time/batch = 1.283
# 172160/184000, translation error = 10.959, rotation error = 6.364, time/batch = 1.277
# 172480/184000, translation error = 10.956, rotation error = 6.365, time/batch = 1.280
# 172800/184000, translation error = 10.940, rotation error = 6.359, time/batch = 1.279
# 173120/184000, translation error = 10.925, rotation error = 6.350, time/batch = 1.278
# 173440/184000, translation error = 10.911, rotation error = 6.345, time/batch = 1.278
# 173760/184000, translation error = 10.897, rotation error = 6.337, time/batch = 1.276
# 174080/184000, translation error = 10.881, rotation error = 6.333, time/batch = 1.279
# 174400/184000, translation error = 10.865, rotation error = 6.325, time/batch = 1.280
# 174720/184000, translation error = 10.925, rotation error = 6.349, time/batch = 1.279
# 175040/184000, translation error = 10.914, rotation error = 6.346, time/batch = 1.272
# 175360/184000, translation error = 10.899, rotation error = 6.353, time/batch = 1.277
# 175680/184000, translation error = 10.895, rotation error = 6.364, time/batch = 1.393
# 176000/184000, translation error = 10.963, rotation error = 6.433, time/batch = 1.274
# 176320/184000, translation error = 11.001, rotation error = 6.461, time/batch = 1.280
# 176640/184000, translation error = 10.985, rotation error = 6.459, time/batch = 1.280
# 176960/184000, translation error = 10.968, rotation error = 6.456, time/batch = 1.278
# 177280/184000, translation error = 10.953, rotation error = 6.453, time/batch = 1.279
# 177600/184000, translation error = 11.048, rotation error = 6.458, time/batch = 1.276
# 177920/184000, translation error = 11.151, rotation error = 6.474, time/batch = 1.403
# 178240/184000, translation error = 11.140, rotation error = 6.476, time/batch = 1.270
# 178560/184000, translation error = 11.127, rotation error = 6.481, time/batch = 1.278
# 178880/184000, translation error = 11.110, rotation error = 6.476, time/batch = 1.283
# 179200/184000, translation error = 11.094, rotation error = 6.471, time/batch = 1.276
# 179520/184000, translation error = 11.086, rotation error = 6.467, time/batch = 1.274
# 179840/184000, translation error = 11.122, rotation error = 6.477, time/batch = 1.277
# 180160/184000, translation error = 11.137, rotation error = 6.472, time/batch = 1.272
# 180480/184000, translation error = 11.121, rotation error = 6.465, time/batch = 1.282
# 180800/184000, translation error = 11.105, rotation error = 6.461, time/batch = 1.278
# 181120/184000, translation error = 11.099, rotation error = 6.461, time/batch = 1.275
# 181440/184000, translation error = 11.083, rotation error = 6.458, time/batch = 1.287
# 181760/184000, translation error = 11.071, rotation error = 6.455, time/batch = 1.284
# 182080/184000, translation error = 11.054, rotation error = 6.449, time/batch = 1.279
# 182400/184000, translation error = 11.051, rotation error = 6.485, time/batch = 1.277
# 182720/184000, translation error = 11.041, rotation error = 6.556, time/batch = 1.281
# 183040/184000, translation error = 11.026, rotation error = 6.560, time/batch = 1.284
# 183360/184000, translation error = 11.009, rotation error = 6.556, time/batch = 1.279
# 183680/184000, translation error = 10.994, rotation error = 6.550, time/batch = 1.279
# 184000/184000, translation error = 10.987, rotation error = 6.551, time/batch = 3.698

# %%
sio.savemat('results.mat', {'trans_pred': np.array(trans_preds), 'trans_gt': np.array(trans_gts), 'uncertainty': np.array(pred_uncertainties)})

if len(pose_map):
    np.savetxt(os.path.join(args.map_dataset, 'map.txt'), np.asarray(pose_map, dtype=np.float32))
    print("map is saved!")

plt.hist(trans_errors, bins='auto')
plt.title("Translation errors")
plt.xlabel("translational error in meters")
plt.ylabel("number of frames")
plt.savefig('terror.png', bbox_inches='tight')

plt.hist(rot_errors, bins='auto')
plt.title("Rotation errors")
plt.xlabel("rotational error in degree")
plt.ylabel("number of frames")
plt.savefig('rerror.png', bbox_inches='tight')

median_trans_errors = np.median(trans_errors)
median_rot_errors = np.median(rot_errors)
mean_trans_errors = np.mean(trans_errors)
mean_rot_errors = np.mean(rot_errors)

print("median translation error = {:.3f}".format(median_trans_errors))
print("median rotation error = {:.3f}".format(median_rot_errors))
print("mean translation error = {:.3f}".format(mean_trans_errors))
print("mean rotation error = {:.3f}".format(mean_rot_errors))
# Out:
# median translation error = 2.138
# median rotation error = 3.121
# mean translation error = 10.987
# mean rotation error = 6.551

# %%
def evaluate(trans_errors,rot_errors):
    t = dataset.last_indexes
    trans_errors_month = list()
    trans_errors_month.append(trans_errors[:t[0]])
    trans_errors_month.append(trans_errors[t[0]:t[1]])
    trans_errors_month.append(trans_errors[t[1]:t[2]])
    trans_errors_month.append(trans_errors[t[2]:t[3]])
    trans_errors_month.append(trans_errors[t[3]:t[4]])
    trans_errors_month.append(trans_errors[t[4]:t[5]])
    trans_errors_month.append(trans_errors[t[5]:t[6]])
    trans_errors_month.append(trans_errors[t[6]:])

    rot_errors_month = list()
    rot_errors_month.append(rot_errors[:t[0]])
    rot_errors_month.append(rot_errors[t[0]:t[1]])
    rot_errors_month.append(rot_errors[t[1]:t[2]])
    rot_errors_month.append(rot_errors[t[2]:t[3]])
    rot_errors_month.append(rot_errors[t[3]:t[4]])
    rot_errors_month.append(rot_errors[t[4]:t[5]])
    rot_errors_month.append(rot_errors[t[5]:t[6]])
    rot_errors_month.append(rot_errors[t[6]:])
    
    print('================== median translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("median translation error = {:.3f}".format(np.median(trans_errors_i)))
        
    print('================== median rotation error ==================')
    for rot_errors_i in rot_errors_month:
        print("median rotation error = {:.3f}".format(np.median(rot_errors_i)))
    
    print('================== mean translation error ==================')
    for trans_errors_i in trans_errors_month:
        print("mean translation error = {:.3f}".format(np.mean(trans_errors_i)))
        
    print('================== mean rotation error ==================')  
    for rot_errors_i in rot_errors_month:
        print("mean rotation error = {:.3f}".format(np.mean(rot_errors_i)))
        
evaluate(trans_errors,rot_errors)
# Out:
# ================== median translation error ==================
# median translation error = 1.641
# median translation error = 1.759
# median translation error = 2.035
# median translation error = 2.011
# median translation error = 2.117
# median translation error = 2.217
# median translation error = 3.593
# median translation error = 2.843
# ================== median rotation error ==================
# median rotation error = 2.584
# median rotation error = 2.794
# median rotation error = 2.950
# median rotation error = 2.925
# median rotation error = 3.105
# median rotation error = 3.262
# median rotation error = 4.395
# median rotation error = 4.155
# ================== mean translation error ==================
# mean translation error = 4.212
# mean translation error = 4.438
# mean translation error = 13.218
# mean translation error = 12.991
# mean translation error = 9.460
# mean translation error = 11.472
# mean translation error = 21.473
# mean translation error = 13.659
# ================== mean rotation error ==================
# mean rotation error = 3.956
# mean rotation error = 4.262
# mean rotation error = 6.160
# mean rotation error = 5.901
# mean rotation error = 5.634
# mean rotation error = 6.627
# mean rotation error = 12.331
# mean rotation error = 9.281
